# %%
#!/usr/bin/env python3

########################################################################
# File: Chan_Nicholas_problem11.ipynb
# Purpose: Given a genome Text, PathGraphk(Text) is the path consisting of |Text| - k + 1 edges, where the i-th edge of this path is labeled by the i-th k-mer in Text and the i-th node of the path is labeled by the i-th (k - 1)-mer in Text. The de Bruijn graph DeBruijnk(Text) is formed by gluing identically labeled nodes in PathGraphk(Text).
# main(infile='FILE_PATH',outfile='FILE_PATH', inCL=[])
#
# Author: Nicholas Chan
# History: 10/18/2021 Created
########################################################################

# %% [markdown]
# # Assignment 3: Problem 11
# <br>
# Given a genome Text, PathGraphk(Text) is the path consisting of |Text| - k + 1 edges, <br>
# where the i-th edge of this path is labeled by the i-th k-mer in Text and the i-th node <br>
# of the path is labeled by the i-th (k - 1)-mer in Text. The de Bruijn graph DeBruijnk(Text) <br>
# is formed by gluing identically labeled nodes in PathGraphk(Text).<br>
# <br>
# Input:<br>
# 4<br>
# AAGATTCTCTAC<br>
# <br>
# Desired output:<br>
# AAG -> AGA<br>
# AGA -> GAT<br>
# ATT -> TTC<br>
# CTA -> TAC<br>
# CTC -> TCT<br>
# GAT -> ATT<br>
# TCT -> CTA,CTC<br>
# TTC -> TCT<br>

# %%
class Solution:
    '''
    To solve the de Bruijn graph for problem 11, I collected 
    edges (k-mer of size k) from the input sequence and made their
    prefixes keys with their suffixes as values. I utilized the 
    information of the input string to correctly match prefixes
    to their suffixes. Starting out with the whole input sequence and 
    edges made graphing the nodes (assigning suffixes to prefixes) 
    less ambiguous that it would have been just starting out with nodes.
    '''
    def __init__(self, k, seqString):
        '''
        Initializes Solution object with input integer k, input sequence string,
        list of edges computed from the edgeComp() method, and a graph computed from 
        the graph() method.
        '''
        self.k = k
        self.seqString = seqString
        self.edgeList = self.edgeComp()
        self.graph = self.graph()
        
    def edgeComp(self) -> 'list':
        '''
        Creates a list of edges from seqString. Edges are to be
        k characters long 
        '''
        seqRange = len(self.seqString) - (self.k) + 1 # Valid frame index range on seqString
        seqList = []
        for idx in range(seqRange):
            kmer = self.seqString[idx:idx + self.k]
            seqList.append(kmer)
        return seqList       
    
    def graph(self) -> 'dict':
        '''
        Create a graph dict from edges in edgeList. Keys are prefixes of each edge
        and values are each edge's corresponding suffixes. Knowledge of the edge makes 
        the assignment of keys to values less ambiguous than they would be just starting
        out with nodes of size k-1.
        '''
        graphDict = dict()
        
        for edge in self.edgeList:
            prefix = edge[:-1]
            graphDict[prefix] = []
        
        for edge in self.edgeList:
            prefix = edge[:-1]
            suffix = edge[1:]
            graphDict[prefix].append(suffix)
            
        return graphDict
            
            
    def printGraph(self) -> 'str':
        '''
        Call this method to return a string containing output
        '''
        output = ""
        keyList = [key for key in self.graph]
        for key in sorted(keyList):
            valList = []
            for vals in self.graph[key]:
                valList.append(vals)
            valList.sort()
            valstring = ','.join(valList)
            output += f"{key} -> {valstring}\n"
        return output

# %% [markdown]
# # Main function
# Main function is written here. This function handles argument parsing, input, and output.

# %%
def main(infile, outfile, inCL=None):
    '''
    main function parses in lines from an input file, with the first line
    assumed to be some integer k and the second line being a sequence of nucleotides. 
    A Solution class object is initialized with the inputs to generate a De Bruijn 
    Graph.
    '''
    k = 0
    inputSeqString = ''
    with open(infile,'r') as myfile:
        for line in myfile:
            k = int(line.rstrip())
            inputSeqString = next(myfile).rstrip() 
            
    solution = Solution(k, inputSeqString)
    solutionString = solution.printGraph()
    
    with open(outfile, "w") as myfile:
        myfile.write(solutionString)
        print(solutionString)

# %%
if __name__ == "__main__":
    main(infile='data/rosalind_ba3d.txt',outfile='output/output-problem11.txt', inCL=[])
#     main(infile='data/extra-input.txt',outfile='output-problem11.txt', inCL=[])
# Out:
# AAAAACTAAGT -> AAAACTAAGTA
# AAAAAGCTTCT -> AAAAGCTTCTA
# AAAACGAGACG -> AAACGAGACGG
# AAAACTAAGTA -> AAACTAAGTAT
# AAAAGCTTCTA -> AAAGCTTCTAG
# AAAAGGGCCGA -> AAAGGGCCGAG
# AAAAGGGTTTT -> AAAGGGTTTTC
# AAAATTGAGTC -> AAATTGAGTCA
# AAACATCGTAG -> AACATCGTAGC
# AAACATCTCAA -> AACATCTCAAC
# AAACCTCTCCG -> AACCTCTCCGC
# AAACGAGACGG -> AACGAGACGGG
# AAACGCCTGGC -> AACGCCTGGCA
# AAACTAAGTAT -> AACTAAGTATT
# AAACTGAAATG -> AACTGAAATGC
# AAAGACTTAAT -> AAGACTTAATG
# AAAGCAATTAT -> AAGCAATTATC
# AAAGCTTCTAG -> AAGCTTCTAGA
# AAAGGGCCGAG -> AAGGGCCGAGC
# AAAGGGTTTTC -> AAGGGTTTTCC
# AAAGTAGGGAA -> AAGTAGGGAAT
# AAAGTGTCGCG -> AAGTGTCGCGA
# AAATACAGTGG -> AATACAGTGGT
# AAATCATTCAC -> AATCATTCACC
# AAATGCAGGCA -> AATGCAGGCAG
# AAATGCCCGCA -> AATGCCCGCAG
# AAATGCGACGT -> AATGCGACGTT
# AAATGCTCGTA -> AATGCTCGTAT
# AAATGCTTTTT -> AATGCTTTTTA
# AAATTGAGTCA -> AATTGAGTCAA
# AAATTGTCTAA -> AATTGTCTAAC
# AAATTTCAGTC -> AATTTCAGTCT
# AACACGCCGGG -> ACACGCCGGGT
# AACAGAACTAG -> ACAGAACTAGC
# AACAGACTCAA -> ACAGACTCAAT
# AACAGCTTTTT -> ACAGCTTTTTA
# AACATAGGGGT -> ACATAGGGGTT
# AACATCGTAGC -> ACATCGTAGCT
# AACATCTCAAC -> ACATCTCAACC
# AACATGTCTTA -> ACATGTCTTAC
# AACCAAACTGA -> ACCAAACTGAA
# AACCATCATCT -> ACCATCATCTG
# AACCCTGTTAA -> ACCCTGTTAAC
# AACCGAGGTCT -> ACCGAGGTCTA
# AACCGCACGCA -> ACCGCACGCAT
# AACCGGGACTT -> ACCGGGACTTT
# AACCGTAACGC -> ACCGTAACGCG
# AACCTAAGTCC -> ACCTAAGTCCA
# AACCTCTCCGC -> ACCTCTCCGCA
# AACGAACCGAG -> ACGAACCGAGG
# AACGACGCATT -> ACGACGCATTA
# AACGAGACGGG -> ACGAGACGGGG
# AACGATCAGCC -> ACGATCAGCCC
# AACGATGTCCT -> ACGATGTCCTC
# AACGCCTGGCA -> ACGCCTGGCAT
# AACGCGAACAG -> ACGCGAACAGA
# AACGCGCACGA -> ACGCGCACGAT
# AACGCTCCTTC -> ACGCTCCTTCA
# AACGGCGCCGA -> ACGGCGCCGAT
# AACTAAGTATT -> ACTAAGTATTC
# AACTAGCCCTT -> ACTAGCCCTTT
# AACTATGGGCG -> ACTATGGGCGC
# AACTCAGCGGT -> ACTCAGCGGTC
# AACTCCTGAGA -> ACTCCTGAGAG
# AACTGAAATGC -> ACTGAAATGCT
# AACTGGCGCAT -> ACTGGCGCATC
# AACTTCCTCGG -> ACTTCCTCGGA
# AACTTGGTAGG -> ACTTGGTAGGA
# AACTTTTAGTA -> ACTTTTAGTAT
# AAGACCCGTCC -> AGACCCGTCCC
# AAGACGATTCA -> AGACGATTCAT
# AAGACTTAATG -> AGACTTAATGG
# AAGAGCTTCAT -> AGAGCTTCATT
# AAGATGCAGCT -> AGATGCAGCTA
# AAGCAATTATC -> AGCAATTATCA
# AAGCGTAATTT -> AGCGTAATTTA
# AAGCTTCTAGA -> AGCTTCTAGAT
# AAGGGACCCCA -> AGGGACCCCAG
# AAGGGCCGAGC -> AGGGCCGAGCC
# AAGGGGTTCTA -> AGGGGTTCTAG
# AAGGGTTTTCC -> AGGGTTTTCCT
# AAGTACAGAAA -> AGTACAGAAAT
# AAGTACCACAA -> AGTACCACAAC
# AAGTACCGGCC -> AGTACCGGCCA
# AAGTAGGGAAT -> AGTAGGGAATA
# AAGTATTCCCC -> AGTATTCCCCG
# AAGTCATAGGT -> AGTCATAGGTA
# AAGTCCAGATT -> AGTCCAGATTT
# AAGTGTCGCGA -> AGTGTCGCGAC
# AAGTTGTTGTC -> AGTTGTTGTCC
# AATAAACATCG -> ATAAACATCGT
# AATAACACGCC -> ATAACACGCCG
# AATACAGTGGT -> ATACAGTGGTC
# AATAGCTGTTT -> ATAGCTGTTTA
# AATATTTGGCT -> ATATTTGGCTC
# AATCATCGACG -> ATCATCGACGG
# AATCATTCACC -> ATCATTCACCA
# AATCCTAAATG -> ATCCTAAATGC
# AATCTAGCCCG -> ATCTAGCCCGG
# AATCTCACTTC -> ATCTCACTTCA
# AATCTCAGCAG -> ATCTCAGCAGT
# AATCTGTTGAT -> ATCTGTTGATC
# AATCTTCGATG -> ATCTTCGATGC
# AATGAGCAGAC -> ATGAGCAGACG
# AATGATGGCCC -> ATGATGGCCCG
# AATGCAACGAC -> ATGCAACGACG
# AATGCAGGCAG -> ATGCAGGCAGG
# AATGCCCGCAG -> ATGCCCGCAGC
# AATGCGACGTT -> ATGCGACGTTG
# AATGCTCGTAT -> ATGCTCGTATC
# AATGCTTTTTA -> ATGCTTTTTAA
# AATGGCTTTTA -> ATGGCTTTTAT
# AATGGGCTGAT -> ATGGGCTGATT
# AATGGGGATCG -> ATGGGGATCGG
# AATGTATGATG -> ATGTATGATGT
# AATTATCAATA -> ATTATCAATAA
# AATTGAGTCAA -> ATTGAGTCAAC
# AATTGCCGCCG -> ATTGCCGCCGA
# AATTGTCTAAC -> ATTGTCTAACG
# AATTTACGTGC -> ATTTACGTGCG
# AATTTATATAA -> ATTTATATAAG
# AATTTCAGTCT -> ATTTCAGTCTG
# ACAACATAGGG -> CAACATAGGGG
# ACAACATGTCT -> CAACATGTCTT
# ACAACGGCGCC -> CAACGGCGCCG
# ACAACTCAGCG -> CAACTCAGCGG
# ACAAGACCCGT -> CAAGACCCGTC
# ACACGCCGGGT -> CACGCCGGGTG
# ACACGGAACAG -> CACGGAACAGC
# ACACGGAGTAA -> CACGGAGTAAA
# ACACGGCCCAG -> CACGGCCCAGT
# ACACTCAAACC -> CACTCAAACCT
# ACACTCTGGTA -> CACTCTGGTAC
# ACAGAAATTTC -> CAGAAATTTCA
# ACAGAACTAGC -> CAGAACTAGCC
# ACAGACTCAAT -> CAGACTCAATC
# ACAGCTTTTTA -> CAGCTTTTTAC
# ACAGGTTTCGT -> CAGGTTTCGTG
# ACAGTGGTCTC -> CAGTGGTCTCT
# ACATAACCGTA -> CATAACCGTAA
# ACATAGGGGTT -> CATAGGGGTTT
# ACATATTCATT -> CATATTCATTT
# ACATCGCCAGC -> CATCGCCAGCA
# ACATCGTAGCT -> CATCGTAGCTC
# ACATCTCAACC -> CATCTCAACCT
# ACATGATCCAG -> CATGATCCAGC
# ACATGTCTTAC -> CATGTCTTACC
# ACATTAAGATG -> CATTAAGATGC
# ACATTAATTGC -> CATTAATTGCC
# ACCAAACTGAA -> CCAAACTGAAA
# ACCACAACTCA -> CCACAACTCAG
# ACCACACGGCC -> CCACACGGCCC
# ACCACGTAGGC -> CCACGTAGGCT
# ACCACTGATTT -> CCACTGATTTT
# ACCAGCGCTGC -> CCAGCGCTGCT
# ACCATCATCTG -> CCATCATCTGC
# ACCCCAGCCAT -> CCCCAGCCATG
# ACCCCTCAGGG -> CCCCTCAGGGC
# ACCCGTCCCTT -> CCCGTCCCTTT
# ACCCTAGGGGT -> CCCTAGGGGTT
# ACCCTGTTAAC -> CCCTGTTAACT
# ACCCTTAACTA -> CCCTTAACTAT
# ACCGAAGTACC -> CCGAAGTACCG
# ACCGAGGTCTA -> CCGAGGTCTAA
# ACCGCACGCAT -> CCGCACGCATA
# ACCGGAAATTG -> CCGGAAATTGT
# ACCGGCATGAA -> CCGGCATGAAA
# ACCGGCCATTA -> CCGGCCATTAG
# ACCGGGACTTT -> CCGGGACTTTG
# ACCGTAACGCG -> CCGTAACGCGA
# ACCTAAGTCCA -> CCTAAGTCCAG
# ACCTCACTAGT -> CCTCACTAGTG
# ACCTCTCCGCA -> CCTCTCCGCAG
# ACCTTACCACG -> CCTTACCACGT
# ACGAACCGAGG -> CGAACCGAGGT
# ACGACGAGAAG -> CGACGAGAAGG
# ACGACGCATTA -> CGACGCATTAC
# ACGAGAAGGGA -> CGAGAAGGGAC
# ACGAGACGGGG -> CGAGACGGGGT
# ACGAGCATAAC -> CGAGCATAACG
# ACGATCAGCCC -> CGATCAGCCCG
# ACGATCGCTTC -> CGATCGCTTCT
# ACGATGTCCTC -> CGATGTCCTCG
# ACGATGTGTCT -> CGATGTGTCTA
# ACGATTCATGG -> CGATTCATGGT
# ACGCATAGGGA -> CGCATAGGGAT
# ACGCATTACCC -> CGCATTACCCT
# ACGCCGGGTGG -> CGCCGGGTGGC
# ACGCCTCCCTT -> CGCCTCCCTTT
# ACGCCTGGCAT -> CGCCTGGCATC
# ACGCGAACAGA -> CGCGAACAGAC
# ACGCGCACGAT -> CGCGCACGATC
# ACGCGGAGATC -> CGCGGAGATCA
# ACGCGTTATTC -> CGCGTTATTCC
# ACGCTCCTTCA -> CGCTCCTTCAG
# ACGGAACAGCT -> CGGAACAGCTT
# ACGGAGTAAAA -> CGGAGTAAAAG
# ACGGCCCAGTG -> CGGCCCAGTGA
# ACGGCGCCGAT -> CGGCGCCGATC
# ACGGGCAGGGA -> CGGGCAGGGAG
# ACGGGCGTAAT -> CGGGCGTAATC
# ACGGGGTTGGT -> CGGGGTTGGTT
# ACGGTAGTCAA -> CGGTAGTCAAG
# ACGGTTGAGAT -> CGGTTGAGATC
# ACGTAGGCTTG -> CGTAGGCTTGT
# ACGTAGGTGGA -> CGTAGGTGGAT
# ACGTGCGTAGA -> CGTGCGTAGAG
# ACGTTCCCTTG -> CGTTCCCTTGA
# ACGTTGGTCAC -> CGTTGGTCACG
# ACTAAGTATTC -> CTAAGTATTCC
# ACTAGCCCTTT -> CTAGCCCTTTC
# ACTAGTGCCGG -> CTAGTGCCGGT
# ACTATAGCCCA -> CTATAGCCCAC
# ACTATGGGCGC -> CTATGGGCGCC
# ACTCAAACCTC -> CTCAAACCTCT
# ACTCAAACGCC -> CTCAAACGCCT
# ACTCAATCATC -> CTCAATCATCG
# ACTCAGCGGTC -> CTCAGCGGTCC
# ACTCCAGTACA -> CTCCAGTACAA
# ACTCCGTGAGA -> CTCCGTGAGAA
# ACTCCTGAGAG -> CTCCTGAGAGT
# ACTCGTTCTTC -> CTCGTTCTTCG
# ACTCTGGTACT -> CTCTGGTACTC
# ACTGAAATGCT -> CTGAAATGCTT
# ACTGATTTTAG -> CTGATTTTAGA
# ACTGGAACTCC -> CTGGAACTCCT
# ACTGGCGCATC -> CTGGCGCATCA
# ACTGGTGACGC -> CTGGTGACGCG
# ACTGTATACTC -> CTGTATACTCG
# ACTTAATGGGG -> CTTAATGGGGA
# ACTTAGCTGGC -> CTTAGCTGGCT
# ACTTCAGAGGC -> CTTCAGAGGCC
# ACTTCAGAGTT -> CTTCAGAGTTT
# ACTTCCTCGGA -> CTTCCTCGGAT
# ACTTCGTGCTT -> CTTCGTGCTTG
# ACTTGGTAGGA -> CTTGGTAGGAG
# ACTTTGACTGG -> CTTTGACTGGT
# ACTTTTAGTAT -> CTTTTAGTATC
# AGAAATTTCAG -> GAAATTTCAGT
# AGAACGCTCCT -> GAACGCTCCTT
# AGAACTAGCCC -> GAACTAGCCCT
# AGAAGGGACCC -> GAAGGGACCCC
# AGAAGTACAGA -> GAAGTACAGAA
# AGAATCTCAGC -> GAATCTCAGCA
# AGACAGGTTTC -> GACAGGTTTCG
# AGACATCGCCA -> GACATCGCCAG
# AGACCCGTCCC -> GACCCGTCCCT
# AGACGATTCAT -> GACGATTCATG
# AGACGGGGTTG -> GACGGGGTTGG
# AGACGGTTGAG -> GACGGTTGAGA
# AGACTCAATCA -> GACTCAATCAT
# AGACTTAATGG -> GACTTAATGGG
# AGAGAATCTCA -> GAGAATCTCAG
# AGAGCCGAGGT -> GAGCCGAGGTT
# AGAGCGATAAT -> GAGCGATAATC
# AGAGCGGTAGG -> GAGCGGTAGGT
# AGAGCTTCATT -> GAGCTTCATTT
# AGAGGCCCACG -> GAGGCCCACGA
# AGAGGGAGTAA -> GAGGGAGTAAT
# AGAGTCCCGGC -> GAGTCCCGGCC
# AGAGTTTATCT -> GAGTTTATCTT
# AGATCATCACA -> GATCATCACAA
# AGATCGAACTT -> GATCGAACTTG
# AGATCTACCCC -> GATCTACCCCT
# AGATGCAGCTA -> GATGCAGCTAT
# AGATGCTGTGA -> GATGCTGTGAT
# AGATTGGCTAA -> GATTGGCTAAA
# AGATTTTGCTA -> GATTTTGCTAT
# AGCAATTATCA -> GCAATTATCAA
# AGCACCAGCGC -> GCACCAGCGCT
# AGCAGACGGTT -> GCAGACGGTTG
# AGCAGTCCAGC -> GCAGTCCAGCA
# AGCATAACGAT -> GCATAACGATG
# AGCATCAAAGT -> GCATCAAAGTA
# AGCATTTGGCA -> GCATTTGGCAC
# AGCCATGACTA -> GCCATGACTAT
# AGCCCACACGG -> GCCCACACGGA
# AGCCCGGCTTA -> GCCCGGCTTAA
# AGCCCGGCTTC -> GCCCGGCTTCG
# AGCCCGTATCT -> GCCCGTATCTA
# AGCCCTTTCAA -> GCCCTTTCAAT
# AGCCGAGGTTT -> GCCGAGGTTTG
# AGCCGTATAAT -> GCCGTATAATG
# AGCCGTTTTCC -> GCCGTTTTCCC
# AGCCTTCGGTT -> GCCTTCGGTTT
# AGCGAGATTGG -> GCGAGATTGGC
# AGCGATAATCT -> GCGATAATCTA
# AGCGCTGCTTA -> GCGCTGCTTAC
# AGCGGTAGGTA -> GCGGTAGGTAG
# AGCGGTCCGGT -> GCGGTCCGGTC
# AGCGTAATTTA -> GCGTAATTTAC
# AGCTATGAGCA -> GCTATGAGCAT
# AGCTCAATTTA -> GCTCAATTTAT
# AGCTGGCTAGT -> GCTGGCTAGTG
# AGCTGTTTAGT -> GCTGTTTAGTG
# AGCTTCATTTG -> GCTTCATTTGG
# AGCTTCTAGAT -> GCTTCTAGATC
# AGCTTTTTACT -> GCTTTTTACTG
# AGGAATGCAAC -> GGAATGCAACG
# AGGAGAGCGAT -> GGAGAGCGATA
# AGGATGGATTC -> GGATGGATTCA
# AGGCAGGCGTC -> GGCAGGCGTCA
# AGGCCACGTAG -> GGCCACGTAGG
# AGGCCCACGAC -> GGCCCACGACG
# AGGCGGGTCGT -> GGCGGGTCGTA
# AGGCGTCACAT -> GGCGTCACATG
# AGGCTTGTCAA -> GGCTTGTCAAC
# AGGGAATAGCT -> GGGAATAGCTG
# AGGGACCCCAG -> GGGACCCCAGC
# AGGGAGGGCCA -> GGGAGGGCCAC
# AGGGAGTAATG -> GGGAGTAATGG
# AGGGATGAGTC -> GGGATGAGTCC
# AGGGCATTCTA -> GGGCATTCTAT
# AGGGCCACAAC -> GGGCCACAACA
# AGGGCCGAGCC -> GGGCCGAGCCG
# AGGGCTCCCGC -> GGGCTCCCGCG
# AGGGCTGGGGT -> GGGCTGGGGTA
# AGGGGTTCTAG -> GGGGTTCTAGA
# AGGGGTTGGCT -> GGGGTTGGCTC
# AGGGGTTTGCC -> GGGGTTTGCCA
# AGGGTTTTCCT -> GGGTTTTCCTA
# AGGTACTTCAG -> GGTACTTCAGA
# AGGTAGCCCGG -> GGTAGCCCGGC
# AGGTCACCACT -> GGTCACCACTG
# AGGTCTAACCG -> GGTCTAACCGC
# AGGTGGATCTC -> GGTGGATCTCC
# AGGTTTCGTGC -> GGTTTCGTGCG
# AGGTTTGTAAC -> GGTTTGTAACG
# AGTAAAAGGGC -> GTAAAAGGGCC
# AGTAACCAAAC -> GTAACCAAACT
# AGTAATGGGCT -> GTAATGGGCTG
# AGTACAACGGC -> GTACAACGGCG
# AGTACAGAAAT -> GTACAGAAATT
# AGTACCACAAC -> GTACCACAACT
# AGTACCGGCCA -> GTACCGGCCAT
# AGTAGGGAATA -> GTAGGGAATAG
# AGTATCGGTAA -> GTATCGGTAAG
# AGTATTCCCCG -> GTATTCCCCGC
# AGTCAACGATC -> GTCAACGATCA
# AGTCAAGTTGT -> GTCAAGTTGTT
# AGTCATAGGTA -> GTCATAGGTAC
# AGTCCAGATTT -> GTCCAGATTTT
# AGTCCAGCACC -> GTCCAGCACCA
# AGTCCATGGTC -> GTCCATGGTCC
# AGTCCCGGCCC -> GTCCCGGCCCA
# AGTCGCGGGGG -> GTCGCGGGGGC
# AGTCTGGACCC -> GTCTGGACCCT
# AGTGAAAGCAA -> GTGAAAGCAAT
# AGTGAAGCGTA -> GTGAAGCGTAA
# AGTGCCGGTAT -> GTGCCGGTATT
# AGTGGTCTCTA -> GTGGTCTCTAA
# AGTGTAAAAAG -> GTGTAAAAAGC
# AGTGTCGCGAC -> GTGTCGCGACG
# AGTGTTGAAAC -> GTGTTGAAACA
# AGTTCTATGGA -> GTTCTATGGAT
# AGTTGTTGTCC -> GTTGTTGTCCG
# AGTTTATCTTT -> GTTTATCTTTG
# AGTTTTTCAGG -> GTTTTTCAGGA
# ATAAACATCGT -> TAAACATCGTA
# ATAAATGCTCG -> TAAATGCTCGT
# ATAACACGCCG -> TAACACGCCGG
# ATAACCGTAAC -> TAACCGTAACG
# ATAACGATGTC -> TAACGATGTCC
# ATAACTGGCGC -> TAACTGGCGCA
# ATAACTTCCTC -> TAACTTCCTCG
# ATAAGGGGTTC -> TAAGGGGTTCT
# ATAAGTCATAG -> TAAGTCATAGG
# ATAATCTAGCC -> TAATCTAGCCC
# ATAATGAGCAG -> TAATGAGCAGA
# ATACAGTGGTC -> TACAGTGGTCT
# ATACATATTCA -> TACATATTCAT
# ATACCTTACCA -> TACCTTACCAC
# ATACTCGTTCT -> TACTCGTTCTT
# ATAGCCCACAC -> TAGCCCACACG
# ATAGCTGTTTA -> TAGCTGTTTAG
# ATAGGGATGAG -> TAGGGATGAGT
# ATAGGGGTTTG -> TAGGGGTTTGC
# ATAGGTACTTC -> TAGGTACTTCA
# ATATAAGTCAT -> TATAAGTCATA
# ATATTCATTTA -> TATTCATTTAT
# ATATTTGGCTC -> TATTTGGCTCA
# ATCAAAAACTA -> TCAAAAACTAA
# ATCAAAGTAGG -> TCAAAGTAGGG
# ATCAATAAACA -> TCAATAAACAT
# ATCAATATTTG -> TCAATATTTGG
# ATCACAAGACC -> TCACAAGACCC
# ATCACTGTATA -> TCACTGTATAC
# ATCAGCCCGTA -> TCAGCCCGTAT
# ATCATCACAAG -> TCATCACAAGA
# ATCATCGACGG -> TCATCGACGGG
# ATCATCTGCGG -> TCATCTGCGGT
# ATCATTCACCA -> TCATTCACCAC
# ATCCAGCGAGA -> TCCAGCGAGAT
# ATCCCATGTTC -> TCCCATGTTCG
# ATCCTAAATGC -> TCCTAAATGCA
# ATCGAACTTGG -> TCGAACTTGGT
# ATCGACGGGCA -> TCGACGGGCAG
# ATCGCAACAGA -> TCGCAACAGAA
# ATCGCCAGCAT -> TCGCCAGCATT
# ATCGCTTCTAA -> TCGCTTCTAAA
# ATCGGGGGCAC -> TCGGGGGCACA
# ATCGGTAAGTA -> TCGGTAAGTAC
# ATCGGTGCCCC -> TCGGTGCCCCT
# ATCGTAGCTCA -> TCGTAGCTCAA
# ATCTAAAAGGG -> TCTAAAAGGGT
# ATCTACCCCTC -> TCTACCCCTCA
# ATCTAGCCCGG -> TCTAGCCCGGC
# ATCTCAACCTA -> TCTCAACCTAA
# ATCTCACTTCA -> TCTCACTTCAG
# ATCTCAGCAGT -> TCTCAGCAGTC
# ATCTCAGTTCT -> TCTCAGTTCTA
# ATCTCCGCTTC -> TCTCCGCTTCC
# ATCTGCGGTGA -> TCTGCGGTGAG
# ATCTGTTGATC -> TCTGTTGATCG
# ATCTTACTTCG -> TCTTACTTCGT
# ATCTTCGATGC -> TCTTCGATGCT
# ATCTTTGTCCC -> TCTTTGTCCCA
# ATGAAAATTGA -> TGAAAATTGAG
# ATGACTATAGC -> TGACTATAGCC
# ATGAGCAGACG -> TGAGCAGACGG
# ATGAGCATCAA -> TGAGCATCAAA
# ATGAGTCCATG -> TGAGTCCATGG
# ATGATCCAGCG -> TGATCCAGCGA
# ATGATGGCCCG -> TGATGGCCCGT
# ATGATGTGGAA -> TGATGTGGAAA
# ATGCAACGACG -> TGCAACGACGC
# ATGCAGCTATG -> TGCAGCTATGA
# ATGCAGGCAGG -> TGCAGGCAGGC
# ATGCCCGCAGC -> TGCCCGCAGCC
# ATGCGACGTTG -> TGCGACGTTGG
# ATGCTCGTATC -> TGCTCGTATCA
# ATGCTGCCTGG -> TGCTGCCTGGG
# ATGCTGTGATA -> TGCTGTGATAC
# ATGCTTTGGAG -> TGCTTTGGAGG
# ATGCTTTTTAA -> TGCTTTTTAAC
# ATGGATTCATC -> TGGATTCATCC
# ATGGATTGCGT -> TGGATTGCGTG
# ATGGCCCGTTC -> TGGCCCGTTCC
# ATGGCTTTTAT -> TGGCTTTTATG
# ATGGGCGCCGG -> TGGGCGCCGGT
# ATGGGCTGATT -> TGGGCTGATTC
# ATGGGGAAAAC -> TGGGGAAAACG
# ATGGGGATCGG -> TGGGGATCGGT
# ATGGTCCCCTA -> TGGTCCCCTAA
# ATGGTGTGTGA -> TGGTGTGTGAT
# ATGTACGCGTT -> TGTACGCGTTA
# ATGTATGATGT -> TGTATGATGTG
# ATGTCCTCGCA -> TGTCCTCGCAT
# ATGTCTTACCT -> TGTCTTACCTC
# ATGTGGAAATG -> TGTGGAAATGC
# ATGTGTCTACT -> TGTGTCTACTC
# ATGTTCGCTAC -> TGTTCGCTACG
# ATTAAGATGCA -> TTAAGATGCAG
# ATTAATTGCCG -> TTAATTGCCGC
# ATTACCCTAGG -> TTACCCTAGGG
# ATTAGTGTTGA -> TTAGTGTTGAA
# ATTATCAATAA -> TTATCAATAAA
# ATTCACCACAC -> TTCACCACACG
# ATTCATCCCAT -> TTCATCCCATG
# ATTCATGGTGT -> TTCATGGTGTG
# ATTCATTTATA -> TTCATTTATAA
# ATTCCAAATAC -> TTCCAAATACA
# ATTCCCCGCGC -> TTCCCCGCGCA
# ATTCGACACTC -> TTCGACACTCA
# ATTCGATCGGG -> TTCGATCGGGG
# ATTCTATCTTA -> TTCTATCTTAC
# ATTCTCGCGAC -> TTCTCGCGACC
# ATTGAAAGTGT -> TTGAAAGTGTC
# ATTGAGTCAAC -> TTGAGTCAACG
# ATTGCCGCCGA -> TTGCCGCCGAC
# ATTGCGTGCGG -> TTGCGTGCGGC
# ATTGGCTAAAT -> TTGGCTAAATG
# ATTGTCTAACG -> TTGTCTAACGC
# ATTTACGTGCG -> TTTACGTGCGT
# ATTTAGACAGG -> TTTAGACAGGT
# ATTTATAACTT -> TTTATAACTTC
# ATTTATATAAG -> TTTATATAAGT
# ATTTCAGTCTG -> TTTCAGTCTGG
# ATTTGGCACGA -> TTTGGCACGAG
# ATTTGGCTCAA -> TTTGGCTCAAC
# ATTTGGTCGGG -> TTTGGTCGGGC
# ATTTTAGAGCC -> TTTTAGAGCCG
# ATTTTGCTATC -> TTTTGCTATCA
# CAAAAACTAAG -> AAAAACTAAGT
# CAAACCTCTCC -> AAACCTCTCCG
# CAAACGCCTGG -> AAACGCCTGGC
# CAAACTGAAAT -> AAACTGAAATG
# CAAAGTAGGGA -> AAAGTAGGGAA
# CAAATACAGTG -> AAATACAGTGG
# CAACAGAACTA -> AACAGAACTAG
# CAACATAGGGG -> AACATAGGGGT
# CAACATGTCTT -> AACATGTCTTA
# CAACCATCATC -> AACCATCATCT
# CAACCCTGTTA -> AACCCTGTTAA
# CAACCTAAGTC -> AACCTAAGTCC
# CAACGACGCAT -> AACGACGCATT
# CAACGATCAGC -> AACGATCAGCC
# CAACGGCGCCG -> AACGGCGCCGA
# CAACTCAGCGG -> AACTCAGCGGT
# CAAGACCCGTC -> AAGACCCGTCC
# CAAGTTGTTGT -> AAGTTGTTGTC
# CAATAAACATC -> AATAAACATCG
# CAATATTTGGC -> AATATTTGGCT
# CAATCATCGAC -> AATCATCGACG
# CAATCCTAAAT -> AATCCTAAATG
# CAATGTATGAT -> AATGTATGATG
# CAATTATCAAT -> AATTATCAATA
# CAATTTATATA -> AATTTATATAA
# CACAACATAGG -> ACAACATAGGG
# CACAACATGTC -> ACAACATGTCT
# CACAACTCAGC -> ACAACTCAGCG
# CACAAGACCCG -> ACAAGACCCGT
# CACACGGAACA -> ACACGGAACAG
# CACACGGAGTA -> ACACGGAGTAA
# CACACGGCCCA -> ACACGGCCCAG
# CACATGATCCA -> ACATGATCCAG
# CACATTAAGAT -> ACATTAAGATG
# CACATTAATTG -> ACATTAATTGC
# CACCACACGGC -> ACCACACGGCC
# CACCACTGATT -> ACCACTGATTT
# CACCAGCGCTG -> ACCAGCGCTGC
# CACCGAAGTAC -> ACCGAAGTACC
# CACGACGAGAA -> ACGACGAGAAG
# CACGAGCATAA -> ACGAGCATAAC
# CACGATCGCTT -> ACGATCGCTTC
# CACGCATAGGG -> ACGCATAGGGA
# CACGCCGGGTG -> ACGCCGGGTGG
# CACGCCTCCCT -> ACGCCTCCCTT
# CACGGAACAGC -> ACGGAACAGCT
# CACGGAGTAAA -> ACGGAGTAAAA
# CACGGCCCAGT -> ACGGCCCAGTG
# CACGGGCGTAA -> ACGGGCGTAAT
# CACGTAGGCTT -> ACGTAGGCTTG
# CACGTAGGTGG -> ACGTAGGTGGA
# CACTAGTGCCG -> ACTAGTGCCGG
# CACTCAAACCT -> ACTCAAACCTC
# CACTCAAACGC -> ACTCAAACGCC
# CACTCTGGTAC -> ACTCTGGTACT
# CACTGATTTTA -> ACTGATTTTAG
# CACTGTATACT -> ACTGTATACTC
# CACTTAGCTGG -> ACTTAGCTGGC
# CACTTCAGAGG -> ACTTCAGAGGC
# CAGAAATTTCA -> AGAAATTTCAG
# CAGAACTAGCC -> AGAACTAGCCC
# CAGAAGTACAG -> AGAAGTACAGA
# CAGACATCGCC -> AGACATCGCCA
# CAGACGGTTGA -> AGACGGTTGAG
# CAGACTCAATC -> AGACTCAATCA
# CAGAGGCCCAC -> AGAGGCCCACG
# CAGAGTTTATC -> AGAGTTTATCT
# CAGATTTTGCT -> AGATTTTGCTA
# CAGCACCAGCG -> AGCACCAGCGC
# CAGCAGTCCAG -> AGCAGTCCAGC
# CAGCATTTGGC -> AGCATTTGGCA
# CAGCCATGACT -> AGCCATGACTA
# CAGCCCGTATC -> AGCCCGTATCT
# CAGCCTTCGGT -> AGCCTTCGGTT
# CAGCGAGATTG -> AGCGAGATTGG
# CAGCGCTGCTT -> AGCGCTGCTTA
# CAGCGGTCCGG -> AGCGGTCCGGT
# CAGCTATGAGC -> AGCTATGAGCA
# CAGCTTTTTAC -> AGCTTTTTACT
# CAGGAATGCAA -> AGGAATGCAAC
# CAGGATGGATT -> AGGATGGATTC
# CAGGCAGGCGT -> AGGCAGGCGTC
# CAGGCGTCACA -> AGGCGTCACAT
# CAGGGAGGGCC -> AGGGAGGGCCA
# CAGGGCATTCT -> AGGGCATTCTA
# CAGGGCTCCCG -> AGGGCTCCCGC
# CAGGGCTGGGG -> AGGGCTGGGGT
# CAGGTTTCGTG -> AGGTTTCGTGC
# CAGTAACCAAA -> AGTAACCAAAC
# CAGTACAACGG -> AGTACAACGGC
# CAGTCCAGCAC -> AGTCCAGCACC
# CAGTCTGGACC -> AGTCTGGACCC
# CAGTGAAGCGT -> AGTGAAGCGTA
# CAGTGGTCTCT -> AGTGGTCTCTA
# CAGTTCTATGG -> AGTTCTATGGA
# CATAACCGTAA -> ATAACCGTAAC
# CATAACGATGT -> ATAACGATGTC
# CATAAGGGGTT -> ATAAGGGGTTC
# CATACATATTC -> ATACATATTCA
# CATAGGGATGA -> ATAGGGATGAG
# CATAGGGGTTT -> ATAGGGGTTTG
# CATAGGTACTT -> ATAGGTACTTC
# CATATTCATTT -> ATATTCATTTA
# CATCAAAAACT -> ATCAAAAACTA
# CATCAAAGTAG -> ATCAAAGTAGG
# CATCACAAGAC -> ATCACAAGACC
# CATCACTGTAT -> ATCACTGTATA
# CATCATCTGCG -> ATCATCTGCGG
# CATCCCATGTT -> ATCCCATGTTC
# CATCGACGGGC -> ATCGACGGGCA
# CATCGCCAGCA -> ATCGCCAGCAT
# CATCGTAGCTC -> ATCGTAGCTCA
# CATCTCAACCT -> ATCTCAACCTA
# CATCTGCGGTG -> ATCTGCGGTGA
# CATGAAAATTG -> ATGAAAATTGA
# CATGACTATAG -> ATGACTATAGC
# CATGATCCAGC -> ATGATCCAGCG
# CATGGTCCCCT -> ATGGTCCCCTA
# CATGGTGTGTG -> ATGGTGTGTGA
# CATGTCTTACC -> ATGTCTTACCT
# CATGTTCGCTA -> ATGTTCGCTAC
# CATTAAGATGC -> ATTAAGATGCA
# CATTAATTGCC -> ATTAATTGCCG
# CATTACCCTAG -> ATTACCCTAGG
# CATTAGTGTTG -> ATTAGTGTTGA
# CATTCACCACA -> ATTCACCACAC
# CATTCTATCTT -> ATTCTATCTTA
# CATTTATAACT -> ATTTATAACTT
# CATTTGGCACG -> ATTTGGCACGA
# CATTTGGTCGG -> ATTTGGTCGGG
# CCAAACTGAAA -> CAAACTGAAAT
# CCAAATACAGT -> CAAATACAGTG
# CCAATCCTAAA -> CAATCCTAAAT
# CCACAACATGT -> CACAACATGTC
# CCACAACTCAG -> CACAACTCAGC
# CCACACGGAAC -> CACACGGAACA
# CCACACGGCCC -> CACACGGCCCA
# CCACGACGAGA -> CACGACGAGAA
# CCACGCCTCCC -> CACGCCTCCCT
# CCACGTAGGCT -> CACGTAGGCTT
# CCACGTAGGTG -> CACGTAGGTGG
# CCACTCAAACG -> CACTCAAACGC
# CCACTGATTTT -> CACTGATTTTA
# CCAGACATCGC -> CAGACATCGCC
# CCAGATTTTGC -> CAGATTTTGCT
# CCAGCACCAGC -> CAGCACCAGCG
# CCAGCATTTGG -> CAGCATTTGGC
# CCAGCCATGAC -> CAGCCATGACT
# CCAGCGAGATT -> CAGCGAGATTG
# CCAGCGCTGCT -> CAGCGCTGCTT
# CCAGTACAACG -> CAGTACAACGG
# CCAGTGAAGCG -> CAGTGAAGCGT
# CCATCATCTGC -> CATCATCTGCG
# CCATGACTATA -> CATGACTATAG
# CCATGGTCCCC -> CATGGTCCCCT
# CCATGTTCGCT -> CATGTTCGCTA
# CCATTAGTGTT -> CATTAGTGTTG
# CCCACACGGAA -> CCACACGGAAC
# CCCACGACGAG -> CCACGACGAGA
# CCCACGCCTCC -> CCACGCCTCCC
# CCCAGACATCG -> CCAGACATCGC
# CCCAGCCATGA -> CCAGCCATGAC
# CCCAGTGAAGC -> CCAGTGAAGCG
# CCCATGTTCGC -> CCATGTTCGCT
# CCCCAGCCATG -> CCCAGCCATGA
# CCCCGCGCACT -> CCCGCGCACTT
# CCCCGTTTATA -> CCCGTTTATAA
# CCCCTAATGGC -> CCCTAATGGCT
# CCCCTCAGGGC -> CCCTCAGGGCA
# CCCCTGTGTGC -> CCCTGTGTGCA
# CCCGCAGCCTT -> CCGCAGCCTTC
# CCCGCGCACTT -> CCGCGCACTTA
# CCCGCGTAGCC -> CCGCGTAGCCG
# CCCGGCCCACG -> CCGGCCCACGC
# CCCGGCTTAAT -> CCGGCTTAATA
# CCCGGCTTCGA -> CCGGCTTCGAG
# CCCGTAAATCA -> CCGTAAATCAT
# CCCGTATCTAA -> CCGTATCTAAA
# CCCGTCCCTTT -> CCGTCCCTTTG
# CCCGTTCCGTA -> CCGTTCCGTAC
# CCCGTTTATAA -> CCGTTTATAAC
# CCCTAATGGCT -> CCTAATGGCTT
# CCCTAGGGGTT -> CCTAGGGGTTG
# CCCTCAGGGCA -> CCTCAGGGCAT
# CCCTGTGTGCA -> CCTGTGTGCAG
# CCCTGTTAACT -> CCTGTTAACTT
# CCCTTAACTAT -> CCTTAACTATG
# CCCTTGAGTCG -> CCTTGAGTCGC
# CCCTTTACGGT -> CCTTTACGGTA
# CCCTTTCAATG -> CCTTTCAATGT
# CCCTTTGGAAG -> CCTTTGGAAGA
# CCGAAGTACCG -> CGAAGTACCGG
# CCGACATAACC -> CGACATAACCG
# CCGAGCCGTAT -> CGAGCCGTATA
# CCGAGGTCTAA -> CGAGGTCTAAC
# CCGAGGTTTGT -> CGAGGTTTGTA
# CCGATCTCAGT -> CGATCTCAGTT
# CCGCACGCATA -> CGCACGCATAG
# CCGCAGAAGTA -> CGCAGAAGTAC
# CCGCAGCCTTC -> CGCAGCCTTCG
# CCGCCAATCCT -> CGCCAATCCTA
# CCGCCGACATA -> CGCCGACATAA
# CCGCGCACTTA -> CGCGCACTTAG
# CCGCGTAGCCG -> CGCGTAGCCGT
# CCGCTTCCTGG -> CGCTTCCTGGG
# CCGGAAATTGT -> CGGAAATTGTC
# CCGGCATGAAA -> CGGCATGAAAA
# CCGGCCATTAG -> CGGCCATTAGT
# CCGGCCCACGC -> CGGCCCACGCC
# CCGGCTTAATA -> CGGCTTAATAA
# CCGGCTTCGAG -> CGGCTTCGAGA
# CCGGGACTTTG -> CGGGACTTTGA
# CCGGGTGGCAC -> CGGGTGGCACA
# CCGGTATTGAA -> CGGTATTGAAA
# CCGGTCATACA -> CGGTCATACAT
# CCGGTTTGGCG -> CGGTTTGGCGG
# CCGTAAATCAT -> CGTAAATCATT
# CCGTAACGCGA -> CGTAACGCGAA
# CCGTACCGGCA -> CGTACCGGCAT
# CCGTATAATGA -> CGTATAATGAG
# CCGTATCTAAA -> CGTATCTAAAA
# CCGTCCCTTTG -> CGTCCCTTTGG
# CCGTGAGAACG -> CGTGAGAACGC
# CCGTTCCGTAC -> CGTTCCGTACC
# CCGTTGTGTTG -> CGTTGTGTTGT
# CCGTTTATAAC -> CGTTTATAACT
# CCGTTTTCCCG -> CGTTTTCCCGT
# CCTAAATGCAG -> CTAAATGCAGG
# CCTAAGTCCAG -> CTAAGTCCAGA
# CCTAATGGCTT -> CTAATGGCTTT
# CCTAGGGGTTG -> CTAGGGGTTGG
# CCTATTTAGAC -> CTATTTAGACA
# CCTCACTAGTG -> CTCACTAGTGC
# CCTCAGGGCAT -> CTCAGGGCATT
# CCTCCCTTTAC -> CTCCCTTTACG
# CCTCGCATAAG -> CTCGCATAAGG
# CCTCGGATGCT -> CTCGGATGCTG
# CCTCTCCGCAG -> CTCTCCGCAGA
# CCTGAGAGTCC -> CTGAGAGTCCC
# CCTGGCATCAA -> CTGGCATCAAA
# CCTGGGCACAT -> CTGGGCACATT
# CCTGGGCGAGG -> CTGGGCGAGGC
# CCTGTGTGCAG -> CTGTGTGCAGG
# CCTGTTAACTT -> CTGTTAACTTT
# CCTTAACTATG -> CTTAACTATGG
# CCTTACCACGT -> CTTACCACGTA
# CCTTCAGTAAC -> CTTCAGTAACC
# CCTTCGGTTTT -> CTTCGGTTTTC
# CCTTGAGTCGC -> CTTGAGTCGCG
# CCTTTACGGTA -> CTTTACGGTAG
# CCTTTCAATGT -> CTTTCAATGTA
# CCTTTGGAAGA -> CTTTGGAAGAC
# CGAACAGACTC -> GAACAGACTCA
# CGAACCGAGGT -> GAACCGAGGTC
# CGAACTTGGTA -> GAACTTGGTAG
# CGAAGTACCGG -> GAAGTACCGGC
# CGAATCTTCGA -> GAATCTTCGAT
# CGAATGATGGC -> GAATGATGGCC
# CGACACTCAAA -> GACACTCAAAC
# CGACATAACCG -> GACATAACCGT
# CGACCGGAAAT -> GACCGGAAATT
# CGACGAGAAGG -> GACGAGAAGGG
# CGACGCATTAC -> GACGCATTACC
# CGACGGGCAGG -> GACGGGCAGGG
# CGACGTTCCCT -> GACGTTCCCTT
# CGACGTTGGTC -> GACGTTGGTCA
# CGAGAAGGGAC -> GAGAAGGGACC
# CGAGACGGGGT -> GAGACGGGGTT
# CGAGAGGGAGT -> GAGAGGGAGTA
# CGAGATTGGCT -> GAGATTGGCTA
# CGAGCATAACG -> GAGCATAACGA
# CGAGCCGTATA -> GAGCCGTATAA
# CGAGGCGGGTC -> GAGGCGGGTCG
# CGAGGTCACCA -> GAGGTCACCAC
# CGAGGTCTAAC -> GAGGTCTAACC
# CGAGGTTTGTA -> GAGGTTTGTAA
# CGATAATCTAG -> GATAATCTAGC
# CGATCAGCCCG -> GATCAGCCCGT
# CGATCGCTTCT -> GATCGCTTCTA
# CGATCGGGGGC -> GATCGGGGGCA
# CGATCTCAGTT -> GATCTCAGTTC
# CGATGCTTTGG -> GATGCTTTGGA
# CGATGGGGAAA -> GATGGGGAAAA
# CGATGTCCTCG -> GATGTCCTCGC
# CGATGTGTCTA -> GATGTGTCTAC
# CGATTCATGGT -> GATTCATGGTG
# CGCAACAGAAC -> GCAACAGAACT
# CGCACATTAAG -> GCACATTAAGA
# CGCACGATCGC -> GCACGATCGCT
# CGCACGCATAG -> GCACGCATAGG
# CGCACTTAGCT -> GCACTTAGCTG
# CGCAGAAGTAC -> GCAGAAGTACA
# CGCAGCCTTCG -> GCAGCCTTCGG
# CGCATAAGGGG -> GCATAAGGGGT
# CGCATAGGGAT -> GCATAGGGATG
# CGCATCACTGT -> GCATCACTGTA
# CGCATTACCCT -> GCATTACCCTA
# CGCCAATCCTA -> GCCAATCCTAA
# CGCCAGCATTT -> GCCAGCATTTG
# CGCCGACATAA -> GCCGACATAAC
# CGCCGATCTCA -> GCCGATCTCAG
# CGCCGGGTGGC -> GCCGGGTGGCA
# CGCCGGTTTGG -> GCCGGTTTGGC
# CGCCTCCCTTT -> GCCTCCCTTTA
# CGCCTGGCATC -> GCCTGGCATCA
# CGCGAACAGAC -> GCGAACAGACT
# CGCGACCGGAA -> GCGACCGGAAA
# CGCGACGTTCC -> GCGACGTTCCC
# CGCGCACGATC -> GCGCACGATCG
# CGCGCACTTAG -> GCGCACTTAGC
# CGCGGAGATCA -> GCGGAGATCAT
# CGCGGGGGCGA -> GCGGGGGCGAT
# CGCGTAGCCGT -> GCGTAGCCGTT
# CGCGTTATTCC -> GCGTTATTCCA
# CGCTACGATGT -> GCTACGATGTG
# CGCTCCTTCAG -> GCTCCTTCAGT
# CGCTGCTTACA -> GCTGCTTACAC
# CGCTTCCTGGG -> GCTTCCTGGGC
# CGCTTCTAAAG -> GCTTCTAAAGA
# CGGAAATTGTC -> GGAAATTGTCT
# CGGAACAGCTT -> GGAACAGCTTT
# CGGAGATCATC -> GGAGATCATCA
# CGGAGTAAAAG -> GGAGTAAAAGG
# CGGATGCTGCC -> GGATGCTGCCT
# CGGCATGAAAA -> GGCATGAAAAT
# CGGCCATTAGT -> GGCCATTAGTG
# CGGCCCACGCC -> GGCCCACGCCT
# CGGCCCAGTGA -> GGCCCAGTGAA
# CGGCCCCGTTT -> GGCCCCGTTTA
# CGGCCGCCAAT -> GGCCGCCAATC
# CGGCGAATGAT -> GGCGAATGATG
# CGGCGCCGATC -> GGCGCCGATCT
# CGGCTTAATAA -> GGCTTAATAAC
# CGGCTTCGAGA -> GGCTTCGAGAG
# CGGGACTTTGA -> GGGACTTTGAC
# CGGGCAGGATG -> GGGCAGGATGG
# CGGGCAGGGAG -> GGGCAGGGAGG
# CGGGCGTAATC -> GGGCGTAATCT
# CGGGGGCACAC -> GGGGGCACACG
# CGGGGGCGATG -> GGGGGCGATGG
# CGGGGTTGGTT -> GGGGTTGGTTA
# CGGGTCGAGGT -> GGGTCGAGGTC
# CGGGTCGTAGT -> GGGTCGTAGTT
# CGGGTGGCACA -> GGGTGGCACAA
# CGGTAAGTACC -> GGTAAGTACCA
# CGGTAGGTAGC -> GGTAGGTAGCC
# CGGTAGTCAAG -> GGTAGTCAAGT
# CGGTATTGAAA -> GGTATTGAAAG
# CGGTCATACAT -> GGTCATACATA
# CGGTCCGGTCA -> GGTCCGGTCAT
# CGGTGAGAGAA -> GGTGAGAGAAT
# CGGTGCCCCTG -> GGTGCCCCTGT
# CGGTTGAGATC -> GGTTGAGATCG
# CGGTTTGGCGG -> GGTTTGGCGGC
# CGGTTTTCACC -> GGTTTTCACCG
# CGTAAATCATT -> GTAAATCATTC
# CGTAACGCGAA -> GTAACGCGAAC
# CGTAATCTGTT -> GTAATCTGTTG
# CGTAATTTACG -> GTAATTTACGT
# CGTACCGGCAT -> GTACCGGCATG
# CGTAGAGCGGT -> GTAGAGCGGTA
# CGTAGCCGTTT -> GTAGCCGTTTT
# CGTAGCTCAAT -> GTAGCTCAATT
# CGTAGGCTTGT -> GTAGGCTTGTC
# CGTAGGTGGAT -> GTAGGTGGATC
# CGTAGTTTTTC -> GTAGTTTTTCA
# CGTATAATGAG -> GTATAATGAGC
# CGTATCAATAT -> GTATCAATATT
# CGTATCTAAAA -> GTATCTAAAAG
# CGTCACATGAT -> GTCACATGATC
# CGTCCCTTTGG -> GTCCCTTTGGA
# CGTGAGAACGC -> GTGAGAACGCT
# CGTGCGCACAT -> GTGCGCACATT
# CGTGCGGCCGC -> GTGCGGCCGCC
# CGTGCGTAGAG -> GTGCGTAGAGC
# CGTGCTTGATT -> GTGCTTGATTC
# CGTTATTCCAA -> GTTATTCCAAA
# CGTTCCCTTGA -> GTTCCCTTGAG
# CGTTCCGTACC -> GTTCCGTACCG
# CGTTCTTCGAA -> GTTCTTCGAAT
# CGTTGGTCACG -> GTTGGTCACGG
# CGTTGTGTTGT -> GTTGTGTTGTT
# CGTTTATAACT -> GTTTATAACTG
# CGTTTTCCCGT -> GTTTTCCCGTA
# CTAAAAGGGTT -> TAAAAGGGTTT
# CTAAAGACTTA -> TAAAGACTTAA
# CTAAATGCAGG -> TAAATGCAGGC
# CTAAATGCGAC -> TAAATGCGACG
# CTAACCGCACG -> TAACCGCACGC
# CTAACGCGCAC -> TAACGCGCACG
# CTAAGTATTCC -> TAAGTATTCCC
# CTAAGTCCAGA -> TAAGTCCAGAT
# CTAATCTCACT -> TAATCTCACTT
# CTAATGGCTTT -> TAATGGCTTTT
# CTACCCCTCAG -> TACCCCTCAGG
# CTACGATGTGT -> TACGATGTGTC
# CTACTCCGTGA -> TACTCCGTGAG
# CTAGATCTACC -> TAGATCTACCC
# CTAGATGCTGT -> TAGATGCTGTG
# CTAGCCCGGCT -> TAGCCCGGCTT
# CTAGCCCTTTC -> TAGCCCTTTCA
# CTAGGGGTTGG -> TAGGGGTTGGC
# CTAGTGAAAGC -> TAGTGAAAGCA
# CTAGTGCCGGT -> TAGTGCCGGTA
# CTATAGCCCAC -> TATAGCCCACA
# CTATCTTACTT -> TATCTTACTTC
# CTATGAGCATC -> TATGAGCATCA
# CTATGGATTGC -> TATGGATTGCG
# CTATGGGCGCC -> TATGGGCGCCG
# CTATTTAGACA -> TATTTAGACAG
# CTCAAACCTCT -> TCAAACCTCTC
# CTCAAACGCCT -> TCAAACGCCTG
# CTCAACCATCA -> TCAACCATCAT
# CTCAACCTAAG -> TCAACCTAAGT
# CTCAATCATCG -> TCAATCATCGA
# CTCAATTTATA -> TCAATTTATAT
# CTCACTAGTGC -> TCACTAGTGCC
# CTCACTTCAGA -> TCACTTCAGAG
# CTCAGCAGTCC -> TCAGCAGTCCA
# CTCAGCGGTCC -> TCAGCGGTCCG
# CTCAGGGCATT -> TCAGGGCATTC
# CTCAGTTCTAT -> TCAGTTCTATG
# CTCCAGTACAA -> TCCAGTACAAC
# CTCCCGCGTAG -> TCCCGCGTAGC
# CTCCCTTTACG -> TCCCTTTACGG
# CTCCGCAGAAG -> TCCGCAGAAGT
# CTCCGCTTCCT -> TCCGCTTCCTG
# CTCCGTGAGAA -> TCCGTGAGAAC
# CTCCTGAGAGT -> TCCTGAGAGTC
# CTCCTTCAGTA -> TCCTTCAGTAA
# CTCGCATAAGG -> TCGCATAAGGG
# CTCGCGACCGG -> TCGCGACCGGA
# CTCGGATGCTG -> TCGGATGCTGC
# CTCGGGTCGAG -> TCGGGTCGAGG
# CTCGTATCAAT -> TCGTATCAATA
# CTCGTTCTTCG -> TCGTTCTTCGA
# CTCTAATCTCA -> TCTAATCTCAC
# CTCTCCGCAGA -> TCTCCGCAGAA
# CTCTGGTACTC -> TCTGGTACTCC
# CTGAAATGCTT -> TGAAATGCTTT
# CTGAGAGTCCC -> TGAGAGTCCCG
# CTGATTCTCGC -> TGATTCTCGCG
# CTGATTTTAGA -> TGATTTTAGAG
# CTGCCTGGGCA -> TGCCTGGGCAC
# CTGCGGTGAGA -> TGCGGTGAGAG
# CTGCTTACACT -> TGCTTACACTC
# CTGGAACTCCT -> TGGAACTCCTG
# CTGGACCCTTA -> TGGACCCTTAA
# CTGGCATCAAA -> TGGCATCAAAA
# CTGGCGCATCA -> TGGCGCATCAC
# CTGGCTAGTGA -> TGGCTAGTGAA
# CTGGGCACATT -> TGGGCACATTA
# CTGGGCGAGGC -> TGGGCGAGGCG
# CTGGGGTAAGA -> TGGGGTAAGAG
# CTGGTACTCCA -> TGGTACTCCAG
# CTGGTGACGCG -> TGGTGACGCGG
# CTGTATACTCG -> TGTATACTCGT
# CTGTGATACCT -> TGTGATACCTT
# CTGTGTGCAGG -> TGTGTGCAGGG
# CTGTTAACTTT -> TGTTAACTTTT
# CTGTTGATCGC -> TGTTGATCGCA
# CTGTTTAGTGT -> TGTTTAGTGTA
# CTTAACTATGG -> TTAACTATGGG
# CTTAATAACAC -> TTAATAACACG
# CTTAATGGGGA -> TTAATGGGGAT
# CTTACACTCTG -> TTACACTCTGG
# CTTACCACGTA -> TTACCACGTAG
# CTTACCTCACT -> TTACCTCACTA
# CTTACTTCGTG -> TTACTTCGTGC
# CTTAGCTGGCT -> TTAGCTGGCTA
# CTTCAGAGGCC -> TTCAGAGGCCC
# CTTCAGAGTTT -> TTCAGAGTTTA
# CTTCAGTAACC -> TTCAGTAACCA
# CTTCATTTGGT -> TTCATTTGGTC
# CTTCCTCGGAT -> TTCCTCGGATG
# CTTCCTGGGCG -> TTCCTGGGCGA
# CTTCGAATCTT -> TTCGAATCTTC
# CTTCGAGAGGG -> TTCGAGAGGGA
# CTTCGATGCTT -> TTCGATGCTTT
# CTTCGGTTTTC -> TTCGGTTTTCA
# CTTCGTGCTTG -> TTCGTGCTTGA
# CTTCTAAAGAC -> TTCTAAAGACT
# CTTCTAGATCT -> TTCTAGATCTA
# CTTGAGTCGCG -> TTGAGTCGCGG
# CTTGATTCGAT -> TTGATTCGATC
# CTTGGTAGGAG -> TTGGTAGGAGA
# CTTGTCAACCC -> TTGTCAACCCT
# CTTTACGGTAG -> TTTACGGTAGT
# CTTTCAATGTA -> TTTCAATGTAT
# CTTTGACTGGT -> TTTGACTGGTG
# CTTTGGAAGAC -> TTTGGAAGACG
# CTTTGGAGGCC -> TTTGGAGGCCA
# CTTTGTCCCAG -> TTTGTCCCAGA
# CTTTTAGTATC -> TTTTAGTATCG
# CTTTTATGTAC -> TTTTATGTACG
# CTTTTTAACCG -> TTTTTAACCGG
# CTTTTTACTGG -> TTTTTACTGGA
# GAAAACGAGAC -> AAAACGAGACG
# GAAAATTGAGT -> AAAATTGAGTC
# GAAACATCTCA -> AAACATCTCAA
# GAAAGCAATTA -> AAAGCAATTAT
# GAAAGTGTCGC -> AAAGTGTCGCG
# GAAATGCCCGC -> AAATGCCCGCA
# GAAATGCTTTT -> AAATGCTTTTT
# GAAATTGTCTA -> AAATTGTCTAA
# GAAATTTCAGT -> AAATTTCAGTC
# GAACAGACTCA -> AACAGACTCAA
# GAACAGCTTTT -> AACAGCTTTTT
# GAACCGAGGTC -> AACCGAGGTCT
# GAACGCTCCTT -> AACGCTCCTTC
# GAACTAGCCCT -> AACTAGCCCTT
# GAACTCCTGAG -> AACTCCTGAGA
# GAACTTGGTAG -> AACTTGGTAGG
# GAAGACGATTC -> AAGACGATTCA
# GAAGCGTAATT -> AAGCGTAATTT
# GAAGGGACCCC -> AAGGGACCCCA
# GAAGTACAGAA -> AAGTACAGAAA
# GAAGTACCGGC -> AAGTACCGGCC
# GAATAGCTGTT -> AATAGCTGTTT
# GAATCTCAGCA -> AATCTCAGCAG
# GAATCTTCGAT -> AATCTTCGATG
# GAATGATGGCC -> AATGATGGCCC
# GAATGCAACGA -> AATGCAACGAC
# GACACTCAAAC -> ACACTCAAACC
# GACAGGTTTCG -> ACAGGTTTCGT
# GACATAACCGT -> ACATAACCGTA
# GACATCGCCAG -> ACATCGCCAGC
# GACCCCAGCCA -> ACCCCAGCCAT
# GACCCGTCCCT -> ACCCGTCCCTT
# GACCCTTAACT -> ACCCTTAACTA
# GACCGGAAATT -> ACCGGAAATTG
# GACGAGAAGGG -> ACGAGAAGGGA
# GACGATTCATG -> ACGATTCATGG
# GACGCATTACC -> ACGCATTACCC
# GACGCGGAGAT -> ACGCGGAGATC
# GACGGGCAGGG -> ACGGGCAGGGA
# GACGGGGTTGG -> ACGGGGTTGGT
# GACGGTTGAGA -> ACGGTTGAGAT
# GACGTTCCCTT -> ACGTTCCCTTG
# GACGTTGGTCA -> ACGTTGGTCAC
# GACTATAGCCC -> ACTATAGCCCA
# GACTCAATCAT -> ACTCAATCATC
# GACTGGTGACG -> ACTGGTGACGC
# GACTTAATGGG -> ACTTAATGGGG
# GACTTTGACTG -> ACTTTGACTGG
# GAGAACGCTCC -> AGAACGCTCCT
# GAGAAGGGACC -> AGAAGGGACCC
# GAGAATCTCAG -> AGAATCTCAGC
# GAGACGGGGTT -> AGACGGGGTTG
# GAGAGAATCTC -> AGAGAATCTCA
# GAGAGCGATAA -> AGAGCGATAAT
# GAGAGGGAGTA -> AGAGGGAGTAA
# GAGAGTCCCGG -> AGAGTCCCGGC
# GAGATCATCAC -> AGATCATCACA
# GAGATCGAACT -> AGATCGAACTT
# GAGATTGGCTA -> AGATTGGCTAA
# GAGCAGACGGT -> AGCAGACGGTT
# GAGCATAACGA -> AGCATAACGAT
# GAGCATCAAAG -> AGCATCAAAGT
# GAGCCGAGGTT -> AGCCGAGGTTT
# GAGCCGTATAA -> AGCCGTATAAT
# GAGCGATAATC -> AGCGATAATCT
# GAGCGGTAGGT -> AGCGGTAGGTA
# GAGCTTCATTT -> AGCTTCATTTG
# GAGGCCACGTA -> AGGCCACGTAG
# GAGGCCCACGA -> AGGCCCACGAC
# GAGGCGGGTCG -> AGGCGGGTCGT
# GAGGGAGTAAT -> AGGGAGTAATG
# GAGGGCCACAA -> AGGGCCACAAC
# GAGGTCACCAC -> AGGTCACCACT
# GAGGTCTAACC -> AGGTCTAACCG
# GAGGTTTGTAA -> AGGTTTGTAAC
# GAGTAAAAGGG -> AGTAAAAGGGC
# GAGTAATGGGC -> AGTAATGGGCT
# GAGTCAACGAT -> AGTCAACGATC
# GAGTCCATGGT -> AGTCCATGGTC
# GAGTCCCGGCC -> AGTCCCGGCCC
# GAGTCGCGGGG -> AGTCGCGGGGG
# GAGTTTATCTT -> AGTTTATCTTT
# GATAATCTAGC -> ATAATCTAGCC
# GATACCTTACC -> ATACCTTACCA
# GATCAGCCCGT -> ATCAGCCCGTA
# GATCATCACAA -> ATCATCACAAG
# GATCCAGCGAG -> ATCCAGCGAGA
# GATCGAACTTG -> ATCGAACTTGG
# GATCGCAACAG -> ATCGCAACAGA
# GATCGCTTCTA -> ATCGCTTCTAA
# GATCGGGGGCA -> ATCGGGGGCAC
# GATCGGTGCCC -> ATCGGTGCCCC
# GATCTACCCCT -> ATCTACCCCTC
# GATCTCAGTTC -> ATCTCAGTTCT
# GATCTCCGCTT -> ATCTCCGCTTC
# GATGAGTCCAT -> ATGAGTCCATG
# GATGCAGCTAT -> ATGCAGCTATG
# GATGCTGCCTG -> ATGCTGCCTGG
# GATGCTGTGAT -> ATGCTGTGATA
# GATGCTTTGGA -> ATGCTTTGGAG
# GATGGATTCAT -> ATGGATTCATC
# GATGGCCCGTT -> ATGGCCCGTTC
# GATGGGGAAAA -> ATGGGGAAAAC
# GATGTCCTCGC -> ATGTCCTCGCA
# GATGTGGAAAT -> ATGTGGAAATG
# GATGTGTCTAC -> ATGTGTCTACT
# GATTCATCCCA -> ATTCATCCCAT
# GATTCATGGTG -> ATTCATGGTGT
# GATTCGACACT -> ATTCGACACTC
# GATTCGATCGG -> ATTCGATCGGG
# GATTCTCGCGA -> ATTCTCGCGAC
# GATTGCGTGCG -> ATTGCGTGCGG
# GATTGGCTAAA -> ATTGGCTAAAT
# GATTTTAGAGC -> ATTTTAGAGCC
# GATTTTGCTAT -> ATTTTGCTATC
# GCAACAGAACT -> CAACAGAACTA
# GCAACGACGCA -> CAACGACGCAT
# GCAATTATCAA -> CAATTATCAAT
# GCACAACATAG -> CACAACATAGG
# GCACACGGAGT -> CACACGGAGTA
# GCACATTAAGA -> CACATTAAGAT
# GCACATTAATT -> CACATTAATTG
# GCACCAGCGCT -> CACCAGCGCTG
# GCACGAGCATA -> CACGAGCATAA
# GCACGATCGCT -> CACGATCGCTT
# GCACGCATAGG -> CACGCATAGGG
# GCACTTAGCTG -> CACTTAGCTGG
# GCAGAAGTACA -> CAGAAGTACAG
# GCAGACGGTTG -> CAGACGGTTGA
# GCAGCCTTCGG -> CAGCCTTCGGT
# GCAGCTATGAG -> CAGCTATGAGC
# GCAGGATGGAT -> CAGGATGGATT
# GCAGGCAGGCG -> CAGGCAGGCGT
# GCAGGCGTCAC -> CAGGCGTCACA
# GCAGGGAGGGC -> CAGGGAGGGCC
# GCAGGGCTGGG -> CAGGGCTGGGG
# GCAGTCCAGCA -> CAGTCCAGCAC
# GCATAACGATG -> CATAACGATGT
# GCATAAGGGGT -> CATAAGGGGTT
# GCATAGGGATG -> CATAGGGATGA
# GCATCAAAAAC -> CATCAAAAACT
# GCATCAAAGTA -> CATCAAAGTAG
# GCATCACTGTA -> CATCACTGTAT
# GCATGAAAATT -> CATGAAAATTG
# GCATTACCCTA -> CATTACCCTAG
# GCATTCTATCT -> CATTCTATCTT
# GCATTTGGCAC -> CATTTGGCACG
# GCCAATCCTAA -> CCAATCCTAAA
# GCCACAACATG -> CCACAACATGT
# GCCACGTAGGT -> CCACGTAGGTG
# GCCACTCAAAC -> CCACTCAAACG
# GCCAGCATTTG -> CCAGCATTTGG
# GCCATGACTAT -> CCATGACTATA
# GCCATTAGTGT -> CCATTAGTGTT
# GCCCACACGGA -> CCCACACGGAA
# GCCCACGACGA -> CCCACGACGAG
# GCCCACGCCTC -> CCCACGCCTCC
# GCCCAGTGAAG -> CCCAGTGAAGC
# GCCCCGTTTAT -> CCCCGTTTATA
# GCCCCTGTGTG -> CCCCTGTGTGC
# GCCCGCAGCCT -> CCCGCAGCCTT
# GCCCGGCTTAA -> CCCGGCTTAAT
# GCCCGGCTTCG -> CCCGGCTTCGA
# GCCCGTATCTA -> CCCGTATCTAA
# GCCCGTTCCGT -> CCCGTTCCGTA
# GCCCTTTCAAT -> CCCTTTCAATG
# GCCGACATAAC -> CCGACATAACC
# GCCGAGCCGTA -> CCGAGCCGTAT
# GCCGAGGTTTG -> CCGAGGTTTGT
# GCCGATCTCAG -> CCGATCTCAGT
# GCCGCCAATCC -> CCGCCAATCCT
# GCCGCCGACAT -> CCGCCGACATA
# GCCGGGTGGCA -> CCGGGTGGCAC
# GCCGGTATTGA -> CCGGTATTGAA
# GCCGGTTTGGC -> CCGGTTTGGCG
# GCCGTATAATG -> CCGTATAATGA
# GCCGTTTTCCC -> CCGTTTTCCCG
# GCCTCCCTTTA -> CCTCCCTTTAC
# GCCTGGCATCA -> CCTGGCATCAA
# GCCTGGGCACA -> CCTGGGCACAT
# GCCTTCGGTTT -> CCTTCGGTTTT
# GCGAACAGACT -> CGAACAGACTC
# GCGAATGATGG -> CGAATGATGGC
# GCGACCGGAAA -> CGACCGGAAAT
# GCGACGTTCCC -> CGACGTTCCCT
# GCGACGTTGGT -> CGACGTTGGTC
# GCGAGATTGGC -> CGAGATTGGCT
# GCGAGGCGGGT -> CGAGGCGGGTC
# GCGATAATCTA -> CGATAATCTAG
# GCGATGGGGAA -> CGATGGGGAAA
# GCGCACATTAA -> CGCACATTAAG
# GCGCACGATCG -> CGCACGATCGC
# GCGCACTTAGC -> CGCACTTAGCT
# GCGCATCACTG -> CGCATCACTGT
# GCGCCGATCTC -> CGCCGATCTCA
# GCGCCGGTTTG -> CGCCGGTTTGG
# GCGCTGCTTAC -> CGCTGCTTACA
# GCGGAGATCAT -> CGGAGATCATC
# GCGGCCCCGTT -> CGGCCCCGTTT
# GCGGCCGCCAA -> CGGCCGCCAAT
# GCGGGGGCGAT -> CGGGGGCGATG
# GCGGGTCGTAG -> CGGGTCGTAGT
# GCGGTAGGTAG -> CGGTAGGTAGC
# GCGGTCCGGTC -> CGGTCCGGTCA
# GCGGTGAGAGA -> CGGTGAGAGAA
# GCGTAATCTGT -> CGTAATCTGTT
# GCGTAATTTAC -> CGTAATTTACG
# GCGTAGAGCGG -> CGTAGAGCGGT
# GCGTAGCCGTT -> CGTAGCCGTTT
# GCGTCACATGA -> CGTCACATGAT
# GCGTGCGGCCG -> CGTGCGGCCGC
# GCGTTATTCCA -> CGTTATTCCAA
# GCTAAATGCGA -> CTAAATGCGAC
# GCTACGATGTG -> CTACGATGTGT
# GCTAGTGAAAG -> CTAGTGAAAGC
# GCTATGAGCAT -> CTATGAGCATC
# GCTCAACCATC -> CTCAACCATCA
# GCTCAATTTAT -> CTCAATTTATA
# GCTCCCGCGTA -> CTCCCGCGTAG
# GCTCCTTCAGT -> CTCCTTCAGTA
# GCTCGGGTCGA -> CTCGGGTCGAG
# GCTCGTATCAA -> CTCGTATCAAT
# GCTGATTCTCG -> CTGATTCTCGC
# GCTGCCTGGGC -> CTGCCTGGGCA
# GCTGCTTACAC -> CTGCTTACACT
# GCTGGCTAGTG -> CTGGCTAGTGA
# GCTGGGGTAAG -> CTGGGGTAAGA
# GCTGTGATACC -> CTGTGATACCT
# GCTGTTTAGTG -> CTGTTTAGTGT
# GCTTAATAACA -> CTTAATAACAC
# GCTTACACTCT -> CTTACACTCTG
# GCTTCATTTGG -> CTTCATTTGGT
# GCTTCCTGGGC -> CTTCCTGGGCG
# GCTTCGAGAGG -> CTTCGAGAGGG
# GCTTCTAAAGA -> CTTCTAAAGAC
# GCTTCTAGATC -> CTTCTAGATCT
# GCTTGATTCGA -> CTTGATTCGAT
# GCTTGTCAACC -> CTTGTCAACCC
# GCTTTGGAGGC -> CTTTGGAGGCC
# GCTTTTATGTA -> CTTTTATGTAC
# GCTTTTTAACC -> CTTTTTAACCG
# GCTTTTTACTG -> CTTTTTACTGG
# GGAAAACGAGA -> GAAAACGAGAC
# GGAAATGCCCG -> GAAATGCCCGC
# GGAAATTGTCT -> GAAATTGTCTA
# GGAACAGCTTT -> GAACAGCTTTT
# GGAACTCCTGA -> GAACTCCTGAG
# GGAAGACGATT -> GAAGACGATTC
# GGAATAGCTGT -> GAATAGCTGTT
# GGAATGCAACG -> GAATGCAACGA
# GGACCCCAGCC -> GACCCCAGCCA
# GGACCCTTAAC -> GACCCTTAACT
# GGACTTTGACT -> GACTTTGACTG
# GGAGAGCGATA -> GAGAGCGATAA
# GGAGATCATCA -> GAGATCATCAC
# GGAGGCCACGT -> GAGGCCACGTA
# GGAGGGCCACA -> GAGGGCCACAA
# GGAGTAAAAGG -> GAGTAAAAGGG
# GGAGTAATGGG -> GAGTAATGGGC
# GGATCGGTGCC -> GATCGGTGCCC
# GGATCTCCGCT -> GATCTCCGCTT
# GGATGAGTCCA -> GATGAGTCCAT
# GGATGCTGCCT -> GATGCTGCCTG
# GGATGGATTCA -> GATGGATTCAT
# GGATTCATCCC -> GATTCATCCCA
# GGATTGCGTGC -> GATTGCGTGCG
# GGCACAACATA -> GCACAACATAG
# GGCACACGGAG -> GCACACGGAGT
# GGCACATTAAT -> GCACATTAATT
# GGCACGAGCAT -> GCACGAGCATA
# GGCAGGATGGA -> GCAGGATGGAT
# GGCAGGCGTCA -> GCAGGCGTCAC
# GGCAGGGAGGG -> GCAGGGAGGGC
# GGCATCAAAAA -> GCATCAAAAAC
# GGCATGAAAAT -> GCATGAAAATT
# GGCATTCTATC -> GCATTCTATCT
# GGCCACAACAT -> GCCACAACATG
# GGCCACGTAGG -> GCCACGTAGGT
# GGCCATTAGTG -> GCCATTAGTGT
# GGCCCACGACG -> GCCCACGACGA
# GGCCCACGCCT -> GCCCACGCCTC
# GGCCCAGTGAA -> GCCCAGTGAAG
# GGCCCCGTTTA -> GCCCCGTTTAT
# GGCCCGTTCCG -> GCCCGTTCCGT
# GGCCGAGCCGT -> GCCGAGCCGTA
# GGCCGCCAATC -> GCCGCCAATCC
# GGCGAATGATG -> GCGAATGATGG
# GGCGAGGCGGG -> GCGAGGCGGGT
# GGCGATGGGGA -> GCGATGGGGAA
# GGCGCATCACT -> GCGCATCACTG
# GGCGCCGATCT -> GCGCCGATCTC
# GGCGCCGGTTT -> GCGCCGGTTTG
# GGCGGCCCCGT -> GCGGCCCCGTT
# GGCGGGTCGTA -> GCGGGTCGTAG
# GGCGTAATCTG -> GCGTAATCTGT
# GGCGTCACATG -> GCGTCACATGA
# GGCTAAATGCG -> GCTAAATGCGA
# GGCTAGTGAAA -> GCTAGTGAAAG
# GGCTCAACCAT -> GCTCAACCATC
# GGCTCCCGCGT -> GCTCCCGCGTA
# GGCTCGGGTCG -> GCTCGGGTCGA
# GGCTGATTCTC -> GCTGATTCTCG
# GGCTGGGGTAA -> GCTGGGGTAAG
# GGCTTAATAAC -> GCTTAATAACA
# GGCTTCGAGAG -> GCTTCGAGAGG
# GGCTTGTCAAC -> GCTTGTCAACC
# GGCTTTTATGT -> GCTTTTATGTA
# GGGAAAACGAG -> GGAAAACGAGA
# GGGAATAGCTG -> GGAATAGCTGT
# GGGACCCCAGC -> GGACCCCAGCC
# GGGACTTTGAC -> GGACTTTGACT
# GGGAGGGCCAC -> GGAGGGCCACA
# GGGAGTAATGG -> GGAGTAATGGG
# GGGATCGGTGC -> GGATCGGTGCC
# GGGATGAGTCC -> GGATGAGTCCA
# GGGCACACGGA -> GGCACACGGAG
# GGGCACATTAA -> GGCACATTAAT
# GGGCAGGATGG -> GGCAGGATGGA
# GGGCAGGGAGG -> GGCAGGGAGGG
# GGGCATTCTAT -> GGCATTCTATC
# GGGCCACAACA -> GGCCACAACAT
# GGGCCGAGCCG -> GGCCGAGCCGT
# GGGCGAGGCGG -> GGCGAGGCGGG
# GGGCGATGGGG -> GGCGATGGGGA
# GGGCGCCGGTT -> GGCGCCGGTTT
# GGGCGTAATCT -> GGCGTAATCTG
# GGGCTCCCGCG -> GGCTCCCGCGT
# GGGCTGATTCT -> GGCTGATTCTC
# GGGCTGGGGTA -> GGCTGGGGTAA
# GGGGAAAACGA -> GGGAAAACGAG
# GGGGATCGGTG -> GGGATCGGTGC
# GGGGCACACGG -> GGGCACACGGA
# GGGGCGATGGG -> GGGCGATGGGG
# GGGGGCACACG -> GGGGCACACGG
# GGGGGCGATGG -> GGGGCGATGGG
# GGGGTAAGAGC -> GGGTAAGAGCT
# GGGGTTCTAGA -> GGGTTCTAGAT
# GGGGTTGGCTC -> GGGTTGGCTCG
# GGGGTTGGTTA -> GGGTTGGTTAT
# GGGGTTTGCCA -> GGGTTTGCCAC
# GGGTAAGAGCT -> GGTAAGAGCTT
# GGGTCGAGGTC -> GGTCGAGGTCA
# GGGTCGTAGTT -> GGTCGTAGTTT
# GGGTGGCACAA -> GGTGGCACAAC
# GGGTTCTAGAT -> GGTTCTAGATG
# GGGTTGGCTCG -> GGTTGGCTCGG
# GGGTTGGTTAT -> GGTTGGTTATA
# GGGTTTGCCAC -> GGTTTGCCACT
# GGGTTTTCCTA -> GGTTTTCCTAT
# GGTAAGAGCTT -> GTAAGAGCTTC
# GGTAAGTACCA -> GTAAGTACCAC
# GGTACTCCAGT -> GTACTCCAGTA
# GGTACTTCAGA -> GTACTTCAGAG
# GGTAGCCCGGC -> GTAGCCCGGCT
# GGTAGGAGAGC -> GTAGGAGAGCG
# GGTAGGTAGCC -> GTAGGTAGCCC
# GGTAGTCAAGT -> GTAGTCAAGTT
# GGTATTGAAAG -> GTATTGAAAGT
# GGTCACCACTG -> GTCACCACTGA
# GGTCACGGGCG -> GTCACGGGCGT
# GGTCATACATA -> GTCATACATAT
# GGTCCCCTAAT -> GTCCCCTAATG
# GGTCCGGTCAT -> GTCCGGTCATA
# GGTCGAGGTCA -> GTCGAGGTCAC
# GGTCGGGCAGG -> GTCGGGCAGGA
# GGTCGTAGTTT -> GTCGTAGTTTT
# GGTCTAACCGC -> GTCTAACCGCA
# GGTCTCTAATC -> GTCTCTAATCT
# GGTGACGCGGA -> GTGACGCGGAG
# GGTGAGAGAAT -> GTGAGAGAATC
# GGTGCCCCTGT -> GTGCCCCTGTG
# GGTGGATCTCC -> GTGGATCTCCG
# GGTGGCACAAC -> GTGGCACAACA
# GGTGTGTGATT -> GTGTGTGATTC
# GGTTATAAATG -> GTTATAAATGC
# GGTTCTAGATG -> GTTCTAGATGC
# GGTTGAGATCG -> GTTGAGATCGA
# GGTTGGCTCGG -> GTTGGCTCGGG
# GGTTGGTTATA -> GTTGGTTATAA
# GGTTTCGTGCG -> GTTTCGTGCGC
# GGTTTGCCACT -> GTTTGCCACTC
# GGTTTGGCGGC -> GTTTGGCGGCC
# GGTTTGTAACG -> GTTTGTAACGA
# GGTTTTCACCG -> GTTTTCACCGA
# GGTTTTCCTAT -> GTTTTCCTATT
# GTAAAAAGCTT -> TAAAAAGCTTC
# GTAAAAGGGCC -> TAAAAGGGCCG
# GTAAATCATTC -> TAAATCATTCA
# GTAACCAAACT -> TAACCAAACTG
# GTAACGAACCG -> TAACGAACCGA
# GTAACGCGAAC -> TAACGCGAACA
# GTAAGAGCTTC -> TAAGAGCTTCA
# GTAAGTACCAC -> TAAGTACCACA
# GTAATCTGTTG -> TAATCTGTTGA
# GTAATGGGCTG -> TAATGGGCTGA
# GTAATTTACGT -> TAATTTACGTG
# GTACAACGGCG -> TACAACGGCGC
# GTACAGAAATT -> TACAGAAATTT
# GTACCACAACT -> TACCACAACTC
# GTACCGGCATG -> TACCGGCATGA
# GTACCGGCCAT -> TACCGGCCATT
# GTACGCGTTAT -> TACGCGTTATT
# GTACTCCAGTA -> TACTCCAGTAC
# GTACTTCAGAG -> TACTTCAGAGT
# GTAGAGCGGTA -> TAGAGCGGTAG
# GTAGCCCGGCT -> TAGCCCGGCTT
# GTAGCCGTTTT -> TAGCCGTTTTC
# GTAGCTCAATT -> TAGCTCAATTT
# GTAGGAGAGCG -> TAGGAGAGCGA
# GTAGGCTTGTC -> TAGGCTTGTCA
# GTAGGGAATAG -> TAGGGAATAGC
# GTAGGTAGCCC -> TAGGTAGCCCG
# GTAGGTGGATC -> TAGGTGGATCT
# GTAGTCAAGTT -> TAGTCAAGTTG
# GTAGTTTTTCA -> TAGTTTTTCAG
# GTATAATGAGC -> TATAATGAGCA
# GTATACTCGTT -> TATACTCGTTC
# GTATCAATATT -> TATCAATATTT
# GTATCGGTAAG -> TATCGGTAAGT
# GTATCTAAAAG -> TATCTAAAAGG
# GTATGATGTGG -> TATGATGTGGA
# GTATTCCCCGC -> TATTCCCCGCG
# GTATTGAAAGT -> TATTGAAAGTG
# GTCAACCCTGT -> TCAACCCTGTT
# GTCAACGATCA -> TCAACGATCAG
# GTCAAGTTGTT -> TCAAGTTGTTG
# GTCACATGATC -> TCACATGATCC
# GTCACCACTGA -> TCACCACTGAT
# GTCACGGGCGT -> TCACGGGCGTA
# GTCATACATAT -> TCATACATATT
# GTCATAGGTAC -> TCATAGGTACT
# GTCCAGATTTT -> TCCAGATTTTG
# GTCCAGCACCA -> TCCAGCACCAG
# GTCCATGGTCC -> TCCATGGTCCC
# GTCCCAGACAT -> TCCCAGACATC
# GTCCCCTAATG -> TCCCCTAATGG
# GTCCCGGCCCA -> TCCCGGCCCAC
# GTCCCTTTGGA -> TCCCTTTGGAA
# GTCCGGTCATA -> TCCGGTCATAC
# GTCCGTTGTGT -> TCCGTTGTGTT
# GTCCTCGCATA -> TCCTCGCATAA
# GTCGAGGTCAC -> TCGAGGTCACC
# GTCGCGACGTT -> TCGCGACGTTC
# GTCGCGGGGGC -> TCGCGGGGGCG
# GTCGGGCAGGA -> TCGGGCAGGAT
# GTCGTAGTTTT -> TCGTAGTTTTT
# GTCTAACCGCA -> TCTAACCGCAC
# GTCTAACGCGC -> TCTAACGCGCA
# GTCTACTCCGT -> TCTACTCCGTG
# GTCTCTAATCT -> TCTCTAATCTC
# GTCTGGACCCT -> TCTGGACCCTT
# GTCTTACCTCA -> TCTTACCTCAC
# GTGAAAGCAAT -> TGAAAGCAATT
# GTGAAGCGTAA -> TGAAGCGTAAT
# GTGACGCGGAG -> TGACGCGGAGA
# GTGAGAACGCT -> TGAGAACGCTC
# GTGAGAGAATC -> TGAGAGAATCT
# GTGATACCTTA -> TGATACCTTAC
# GTGATTCGACA -> TGATTCGACAC
# GTGCAGGGCTG -> TGCAGGGCTGG
# GTGCCCCTGTG -> TGCCCCTGTGT
# GTGCCGGTATT -> TGCCGGTATTG
# GTGCGCACATT -> TGCGCACATTA
# GTGCGGCCGCC -> TGCGGCCGCCA
# GTGCGTAGAGC -> TGCGTAGAGCG
# GTGCTTGATTC -> TGCTTGATTCG
# GTGGAAATGCC -> TGGAAATGCCC
# GTGGATCTCCG -> TGGATCTCCGC
# GTGGCACAACA -> TGGCACAACAT
# GTGGTCTCTAA -> TGGTCTCTAAT
# GTGTAAAAAGC -> TGTAAAAAGCT
# GTGTCGCGACG -> TGTCGCGACGT
# GTGTCTACTCC -> TGTCTACTCCG
# GTGTGATTCGA -> TGTGATTCGAC
# GTGTGCAGGGC -> TGTGCAGGGCT
# GTGTGTGATTC -> TGTGTGATTCG
# GTGTTGAAACA -> TGTTGAAACAT
# GTGTTGTTCAG -> TGTTGTTCAGG
# GTTAACTTTTA -> TTAACTTTTAG
# GTTATAAATGC -> TTATAAATGCT
# GTTATTCCAAA -> TTATTCCAAAT
# GTTCAGGGCTC -> TTCAGGGCTCC
# GTTCCCTTGAG -> TTCCCTTGAGT
# GTTCCGTACCG -> TTCCGTACCGG
# GTTCGCTACGA -> TTCGCTACGAT
# GTTCTAGATGC -> TTCTAGATGCT
# GTTCTATGGAT -> TTCTATGGATT
# GTTCTTCGAAT -> TTCTTCGAATC
# GTTGAAACATC -> TTGAAACATCT
# GTTGAGATCGA -> TTGAGATCGAA
# GTTGATCGCAA -> TTGATCGCAAC
# GTTGGCTCGGG -> TTGGCTCGGGT
# GTTGGTCACGG -> TTGGTCACGGG
# GTTGGTTATAA -> TTGGTTATAAA
# GTTGTCCGTTG -> TTGTCCGTTGT
# GTTGTGTTGTT -> TTGTGTTGTTC
# GTTGTTCAGGG -> TTGTTCAGGGC
# GTTGTTGTCCG -> TTGTTGTCCGT
# GTTTAGTGTAA -> TTTAGTGTAAA
# GTTTATAACTG -> TTTATAACTGG
# GTTTATCTTTG -> TTTATCTTTGT
# GTTTCGTGCGC -> TTTCGTGCGCA
# GTTTGCCACTC -> TTTGCCACTCA
# GTTTGGCGGCC -> TTTGGCGGCCC
# GTTTGTAACGA -> TTTGTAACGAA
# GTTTTCACCGA -> TTTTCACCGAA
# GTTTTCCCGTA -> TTTTCCCGTAA
# GTTTTCCTATT -> TTTTCCTATTT
# GTTTTTCAGGA -> TTTTTCAGGAA
# TAAAAAGCTTC -> AAAAAGCTTCT
# TAAAAGGGCCG -> AAAAGGGCCGA
# TAAAAGGGTTT -> AAAAGGGTTTT
# TAAACATCGTA -> AAACATCGTAG
# TAAAGACTTAA -> AAAGACTTAAT
# TAAATCATTCA -> AAATCATTCAC
# TAAATGCAGGC -> AAATGCAGGCA
# TAAATGCGACG -> AAATGCGACGT
# TAAATGCTCGT -> AAATGCTCGTA
# TAACACGCCGG -> AACACGCCGGG
# TAACCAAACTG -> AACCAAACTGA
# TAACCGCACGC -> AACCGCACGCA
# TAACCGGGACT -> AACCGGGACTT
# TAACCGTAACG -> AACCGTAACGC
# TAACGAACCGA -> AACGAACCGAG
# TAACGATGTCC -> AACGATGTCCT
# TAACGCGAACA -> AACGCGAACAG
# TAACGCGCACG -> AACGCGCACGA
# TAACTATGGGC -> AACTATGGGCG
# TAACTGGCGCA -> AACTGGCGCAT
# TAACTTCCTCG -> AACTTCCTCGG
# TAACTTTTAGT -> AACTTTTAGTA
# TAAGAGCTTCA -> AAGAGCTTCAT
# TAAGATGCAGC -> AAGATGCAGCT
# TAAGGGGTTCT -> AAGGGGTTCTA
# TAAGTACCACA -> AAGTACCACAA
# TAAGTATTCCC -> AAGTATTCCCC
# TAAGTCATAGG -> AAGTCATAGGT
# TAAGTCCAGAT -> AAGTCCAGATT
# TAATAACACGC -> AATAACACGCC
# TAATCTAGCCC -> AATCTAGCCCG
# TAATCTCACTT -> AATCTCACTTC
# TAATCTGTTGA -> AATCTGTTGAT
# TAATGAGCAGA -> AATGAGCAGAC
# TAATGGCTTTT -> AATGGCTTTTA
# TAATGGGCTGA -> AATGGGCTGAT
# TAATGGGGATC -> AATGGGGATCG
# TAATTGCCGCC -> AATTGCCGCCG
# TAATTTACGTG -> AATTTACGTGC
# TACAACGGCGC -> ACAACGGCGCC
# TACACTCTGGT -> ACACTCTGGTA
# TACAGAAATTT -> ACAGAAATTTC
# TACAGTGGTCT -> ACAGTGGTCTC
# TACATATTCAT -> ACATATTCATT
# TACCACAACTC -> ACCACAACTCA
# TACCACGTAGG -> ACCACGTAGGC
# TACCCCTCAGG -> ACCCCTCAGGG
# TACCCTAGGGG -> ACCCTAGGGGT
# TACCGGCATGA -> ACCGGCATGAA
# TACCGGCCATT -> ACCGGCCATTA
# TACCTCACTAG -> ACCTCACTAGT
# TACCTTACCAC -> ACCTTACCACG
# TACGATGTGTC -> ACGATGTGTCT
# TACGCGTTATT -> ACGCGTTATTC
# TACGGTAGTCA -> ACGGTAGTCAA
# TACGTGCGTAG -> ACGTGCGTAGA
# TACTCCAGTAC -> ACTCCAGTACA
# TACTCCGTGAG -> ACTCCGTGAGA
# TACTCGTTCTT -> ACTCGTTCTTC
# TACTGGAACTC -> ACTGGAACTCC
# TACTTCAGAGT -> ACTTCAGAGTT
# TACTTCGTGCT -> ACTTCGTGCTT
# TAGACAGGTTT -> AGACAGGTTTC
# TAGAGCCGAGG -> AGAGCCGAGGT
# TAGAGCGGTAG -> AGAGCGGTAGG
# TAGATCTACCC -> AGATCTACCCC
# TAGATGCTGTG -> AGATGCTGTGA
# TAGCCCACACG -> AGCCCACACGG
# TAGCCCGGCTT -> AGCCCGGCTTA,AGCCCGGCTTC
# TAGCCCTTTCA -> AGCCCTTTCAA
# TAGCCGTTTTC -> AGCCGTTTTCC
# TAGCTCAATTT -> AGCTCAATTTA
# TAGCTGGCTAG -> AGCTGGCTAGT
# TAGCTGTTTAG -> AGCTGTTTAGT
# TAGGAGAGCGA -> AGGAGAGCGAT
# TAGGCTTGTCA -> AGGCTTGTCAA
# TAGGGAATAGC -> AGGGAATAGCT
# TAGGGATGAGT -> AGGGATGAGTC
# TAGGGGTTGGC -> AGGGGTTGGCT
# TAGGGGTTTGC -> AGGGGTTTGCC
# TAGGTACTTCA -> AGGTACTTCAG
# TAGGTAGCCCG -> AGGTAGCCCGG
# TAGGTGGATCT -> AGGTGGATCTC
# TAGTATCGGTA -> AGTATCGGTAA
# TAGTCAAGTTG -> AGTCAAGTTGT
# TAGTGAAAGCA -> AGTGAAAGCAA
# TAGTGCCGGTA -> AGTGCCGGTAT
# TAGTGTAAAAA -> AGTGTAAAAAG
# TAGTGTTGAAA -> AGTGTTGAAAC
# TAGTTTTTCAG -> AGTTTTTCAGG
# TATAAATGCTC -> ATAAATGCTCG
# TATAACTGGCG -> ATAACTGGCGC
# TATAACTTCCT -> ATAACTTCCTC
# TATAAGTCATA -> ATAAGTCATAG
# TATAATGAGCA -> ATAATGAGCAG
# TATACTCGTTC -> ATACTCGTTCT
# TATAGCCCACA -> ATAGCCCACAC
# TATATAAGTCA -> ATATAAGTCAT
# TATCAATAAAC -> ATCAATAAACA
# TATCAATATTT -> ATCAATATTTG
# TATCGGTAAGT -> ATCGGTAAGTA
# TATCTAAAAGG -> ATCTAAAAGGG
# TATCTTACTTC -> ATCTTACTTCG
# TATCTTTGTCC -> ATCTTTGTCCC
# TATGAGCATCA -> ATGAGCATCAA
# TATGATGTGGA -> ATGATGTGGAA
# TATGGATTGCG -> ATGGATTGCGT
# TATGGGCGCCG -> ATGGGCGCCGG
# TATGTACGCGT -> ATGTACGCGTT
# TATTCATTTAT -> ATTCATTTATA
# TATTCCAAATA -> ATTCCAAATAC
# TATTCCCCGCG -> ATTCCCCGCGC
# TATTGAAAGTG -> ATTGAAAGTGT
# TATTTAGACAG -> ATTTAGACAGG
# TATTTGGCTCA -> ATTTGGCTCAA
# TCAAAAACTAA -> CAAAAACTAAG
# TCAAACCTCTC -> CAAACCTCTCC
# TCAAACGCCTG -> CAAACGCCTGG
# TCAAAGTAGGG -> CAAAGTAGGGA
# TCAACCATCAT -> CAACCATCATC
# TCAACCCTGTT -> CAACCCTGTTA
# TCAACCTAAGT -> CAACCTAAGTC
# TCAACGATCAG -> CAACGATCAGC
# TCAAGTTGTTG -> CAAGTTGTTGT
# TCAATAAACAT -> CAATAAACATC
# TCAATATTTGG -> CAATATTTGGC
# TCAATCATCGA -> CAATCATCGAC
# TCAATGTATGA -> CAATGTATGAT
# TCAATTTATAT -> CAATTTATATA
# TCACAAGACCC -> CACAAGACCCG
# TCACATGATCC -> CACATGATCCA
# TCACCACACGG -> CACCACACGGC
# TCACCACTGAT -> CACCACTGATT
# TCACCGAAGTA -> CACCGAAGTAC
# TCACGGGCGTA -> CACGGGCGTAA
# TCACTAGTGCC -> CACTAGTGCCG
# TCACTGTATAC -> CACTGTATACT
# TCACTTCAGAG -> CACTTCAGAGG
# TCAGAGGCCCA -> CAGAGGCCCAC
# TCAGAGTTTAT -> CAGAGTTTATC
# TCAGCAGTCCA -> CAGCAGTCCAG
# TCAGCCCGTAT -> CAGCCCGTATC
# TCAGCGGTCCG -> CAGCGGTCCGG
# TCAGGAATGCA -> CAGGAATGCAA
# TCAGGGCATTC -> CAGGGCATTCT
# TCAGGGCTCCC -> CAGGGCTCCCG
# TCAGTAACCAA -> CAGTAACCAAA
# TCAGTCTGGAC -> CAGTCTGGACC
# TCAGTTCTATG -> CAGTTCTATGG
# TCATACATATT -> CATACATATTC
# TCATAGGTACT -> CATAGGTACTT
# TCATCACAAGA -> CATCACAAGAC
# TCATCCCATGT -> CATCCCATGTT
# TCATCGACGGG -> CATCGACGGGC
# TCATCTGCGGT -> CATCTGCGGTG
# TCATGGTGTGT -> CATGGTGTGTG
# TCATTCACCAC -> CATTCACCACA
# TCATTTATAAC -> CATTTATAACT
# TCATTTGGTCG -> CATTTGGTCGG
# TCCAAATACAG -> CCAAATACAGT
# TCCAGATTTTG -> CCAGATTTTGC
# TCCAGCACCAG -> CCAGCACCAGC
# TCCAGCGAGAT -> CCAGCGAGATT
# TCCAGTACAAC -> CCAGTACAACG
# TCCATGGTCCC -> CCATGGTCCCC
# TCCCAGACATC -> CCCAGACATCG
# TCCCATGTTCG -> CCCATGTTCGC
# TCCCCGCGCAC -> CCCCGCGCACT
# TCCCCTAATGG -> CCCCTAATGGC
# TCCCGCGTAGC -> CCCGCGTAGCC
# TCCCGGCCCAC -> CCCGGCCCACG
# TCCCGTAAATC -> CCCGTAAATCA
# TCCCTTGAGTC -> CCCTTGAGTCG
# TCCCTTTACGG -> CCCTTTACGGT
# TCCCTTTGGAA -> CCCTTTGGAAG
# TCCGCAGAAGT -> CCGCAGAAGTA
# TCCGCTTCCTG -> CCGCTTCCTGG
# TCCGGTCATAC -> CCGGTCATACA
# TCCGTACCGGC -> CCGTACCGGCA
# TCCGTGAGAAC -> CCGTGAGAACG
# TCCGTTGTGTT -> CCGTTGTGTTG
# TCCTAAATGCA -> CCTAAATGCAG
# TCCTATTTAGA -> CCTATTTAGAC
# TCCTCGCATAA -> CCTCGCATAAG
# TCCTCGGATGC -> CCTCGGATGCT
# TCCTGAGAGTC -> CCTGAGAGTCC
# TCCTGGGCGAG -> CCTGGGCGAGG
# TCCTTCAGTAA -> CCTTCAGTAAC
# TCGAACTTGGT -> CGAACTTGGTA
# TCGAATCTTCG -> CGAATCTTCGA
# TCGACACTCAA -> CGACACTCAAA
# TCGACGGGCAG -> CGACGGGCAGG
# TCGAGAGGGAG -> CGAGAGGGAGT
# TCGAGGTCACC -> CGAGGTCACCA
# TCGATCGGGGG -> CGATCGGGGGC
# TCGATGCTTTG -> CGATGCTTTGG
# TCGCAACAGAA -> CGCAACAGAAC
# TCGCATAAGGG -> CGCATAAGGGG
# TCGCCAGCATT -> CGCCAGCATTT
# TCGCGACCGGA -> CGCGACCGGAA
# TCGCGACGTTC -> CGCGACGTTCC
# TCGCGGGGGCG -> CGCGGGGGCGA
# TCGCTACGATG -> CGCTACGATGT
# TCGCTTCTAAA -> CGCTTCTAAAG
# TCGGATGCTGC -> CGGATGCTGCC
# TCGGGCAGGAT -> CGGGCAGGATG
# TCGGGGGCACA -> CGGGGGCACAC
# TCGGGTCGAGG -> CGGGTCGAGGT
# TCGGTAAGTAC -> CGGTAAGTACC
# TCGGTGCCCCT -> CGGTGCCCCTG
# TCGGTTTTCAC -> CGGTTTTCACC
# TCGTAGCTCAA -> CGTAGCTCAAT
# TCGTAGTTTTT -> CGTAGTTTTTC
# TCGTATCAATA -> CGTATCAATAT
# TCGTGCGCACA -> CGTGCGCACAT
# TCGTGCTTGAT -> CGTGCTTGATT
# TCGTTCTTCGA -> CGTTCTTCGAA
# TCTAAAAGGGT -> CTAAAAGGGTT
# TCTAAAGACTT -> CTAAAGACTTA
# TCTAACCGCAC -> CTAACCGCACG
# TCTAACGCGCA -> CTAACGCGCAC
# TCTAATCTCAC -> CTAATCTCACT
# TCTACCCCTCA -> CTACCCCTCAG
# TCTACTCCGTG -> CTACTCCGTGA
# TCTAGATCTAC -> CTAGATCTACC
# TCTAGATGCTG -> CTAGATGCTGT
# TCTAGCCCGGC -> CTAGCCCGGCT
# TCTATCTTACT -> CTATCTTACTT
# TCTATGGATTG -> CTATGGATTGC
# TCTCAACCTAA -> CTCAACCTAAG
# TCTCACTTCAG -> CTCACTTCAGA
# TCTCAGCAGTC -> CTCAGCAGTCC
# TCTCAGTTCTA -> CTCAGTTCTAT
# TCTCCGCAGAA -> CTCCGCAGAAG
# TCTCCGCTTCC -> CTCCGCTTCCT
# TCTCGCGACCG -> CTCGCGACCGG
# TCTCTAATCTC -> CTCTAATCTCA
# TCTGCGGTGAG -> CTGCGGTGAGA
# TCTGGACCCTT -> CTGGACCCTTA
# TCTGGTACTCC -> CTGGTACTCCA
# TCTGTTGATCG -> CTGTTGATCGC
# TCTTACCTCAC -> CTTACCTCACT
# TCTTACTTCGT -> CTTACTTCGTG
# TCTTCGAATCT -> CTTCGAATCTT
# TCTTCGATGCT -> CTTCGATGCTT
# TCTTTGTCCCA -> CTTTGTCCCAG
# TGAAAATTGAG -> GAAAATTGAGT
# TGAAACATCTC -> GAAACATCTCA
# TGAAAGCAATT -> GAAAGCAATTA
# TGAAAGTGTCG -> GAAAGTGTCGC
# TGAAATGCTTT -> GAAATGCTTTT
# TGAAGCGTAAT -> GAAGCGTAATT
# TGACGCGGAGA -> GACGCGGAGAT
# TGACTATAGCC -> GACTATAGCCC
# TGACTGGTGAC -> GACTGGTGACG
# TGAGAACGCTC -> GAGAACGCTCC
# TGAGAGAATCT -> GAGAGAATCTC
# TGAGAGTCCCG -> GAGAGTCCCGG
# TGAGATCGAAC -> GAGATCGAACT
# TGAGCAGACGG -> GAGCAGACGGT
# TGAGCATCAAA -> GAGCATCAAAG
# TGAGTCAACGA -> GAGTCAACGAT
# TGAGTCCATGG -> GAGTCCATGGT
# TGAGTCGCGGG -> GAGTCGCGGGG
# TGATACCTTAC -> GATACCTTACC
# TGATCCAGCGA -> GATCCAGCGAG
# TGATCGCAACA -> GATCGCAACAG
# TGATGGCCCGT -> GATGGCCCGTT
# TGATGTGGAAA -> GATGTGGAAAT
# TGATTCGACAC -> GATTCGACACT
# TGATTCGATCG -> GATTCGATCGG
# TGATTCTCGCG -> GATTCTCGCGA
# TGATTTTAGAG -> GATTTTAGAGC
# TGCAACGACGC -> GCAACGACGCA
# TGCAGCTATGA -> GCAGCTATGAG
# TGCAGGCAGGC -> GCAGGCAGGCG
# TGCAGGGCTGG -> GCAGGGCTGGG
# TGCCACTCAAA -> GCCACTCAAAC
# TGCCCCTGTGT -> GCCCCTGTGTG
# TGCCCGCAGCC -> GCCCGCAGCCT
# TGCCGCCGACA -> GCCGCCGACAT
# TGCCGGTATTG -> GCCGGTATTGA
# TGCCTGGGCAC -> GCCTGGGCACA
# TGCGACGTTGG -> GCGACGTTGGT
# TGCGCACATTA -> GCGCACATTAA
# TGCGGCCGCCA -> GCGGCCGCCAA
# TGCGGTGAGAG -> GCGGTGAGAGA
# TGCGTAGAGCG -> GCGTAGAGCGG
# TGCGTGCGGCC -> GCGTGCGGCCG
# TGCTCGTATCA -> GCTCGTATCAA
# TGCTGCCTGGG -> GCTGCCTGGGC
# TGCTGTGATAC -> GCTGTGATACC
# TGCTTACACTC -> GCTTACACTCT
# TGCTTGATTCG -> GCTTGATTCGA
# TGCTTTGGAGG -> GCTTTGGAGGC
# TGCTTTTTAAC -> GCTTTTTAACC
# TGGAAATGCCC -> GGAAATGCCCG
# TGGAACTCCTG -> GGAACTCCTGA
# TGGAAGACGAT -> GGAAGACGATT
# TGGACCCTTAA -> GGACCCTTAAC
# TGGAGGCCACG -> GGAGGCCACGT
# TGGATCTCCGC -> GGATCTCCGCT
# TGGATTCATCC -> GGATTCATCCC
# TGGATTGCGTG -> GGATTGCGTGC
# TGGCACAACAT -> GGCACAACATA
# TGGCACGAGCA -> GGCACGAGCAT
# TGGCATCAAAA -> GGCATCAAAAA
# TGGCCCGTTCC -> GGCCCGTTCCG
# TGGCGCATCAC -> GGCGCATCACT
# TGGCGGCCCCG -> GGCGGCCCCGT
# TGGCTAAATGC -> GGCTAAATGCG
# TGGCTAGTGAA -> GGCTAGTGAAA
# TGGCTCAACCA -> GGCTCAACCAT
# TGGCTCGGGTC -> GGCTCGGGTCG
# TGGCTTTTATG -> GGCTTTTATGT
# TGGGCACATTA -> GGGCACATTAA
# TGGGCGAGGCG -> GGGCGAGGCGG
# TGGGCGCCGGT -> GGGCGCCGGTT
# TGGGCTGATTC -> GGGCTGATTCT
# TGGGGAAAACG -> GGGGAAAACGA
# TGGGGATCGGT -> GGGGATCGGTG
# TGGGGTAAGAG -> GGGGTAAGAGC
# TGGTACTCCAG -> GGTACTCCAGT
# TGGTAGGAGAG -> GGTAGGAGAGC
# TGGTCACGGGC -> GGTCACGGGCG
# TGGTCCCCTAA -> GGTCCCCTAAT
# TGGTCGGGCAG -> GGTCGGGCAGG
# TGGTCTCTAAT -> GGTCTCTAATC
# TGGTGACGCGG -> GGTGACGCGGA
# TGGTGTGTGAT -> GGTGTGTGATT
# TGGTTATAAAT -> GGTTATAAATG
# TGTAAAAAGCT -> GTAAAAAGCTT
# TGTAACGAACC -> GTAACGAACCG
# TGTACGCGTTA -> GTACGCGTTAT
# TGTATACTCGT -> GTATACTCGTT
# TGTATGATGTG -> GTATGATGTGG
# TGTCAACCCTG -> GTCAACCCTGT
# TGTCCCAGACA -> GTCCCAGACAT
# TGTCCGTTGTG -> GTCCGTTGTGT
# TGTCCTCGCAT -> GTCCTCGCATA
# TGTCGCGACGT -> GTCGCGACGTT
# TGTCTAACGCG -> GTCTAACGCGC
# TGTCTACTCCG -> GTCTACTCCGT
# TGTCTTACCTC -> GTCTTACCTCA
# TGTGATACCTT -> GTGATACCTTA
# TGTGATTCGAC -> GTGATTCGACA
# TGTGCAGGGCT -> GTGCAGGGCTG
# TGTGGAAATGC -> GTGGAAATGCC
# TGTGTCTACTC -> GTGTCTACTCC
# TGTGTGATTCG -> GTGTGATTCGA
# TGTGTGCAGGG -> GTGTGCAGGGC
# TGTGTTGTTCA -> GTGTTGTTCAG
# TGTTAACTTTT -> GTTAACTTTTA
# TGTTCAGGGCT -> GTTCAGGGCTC
# TGTTCGCTACG -> GTTCGCTACGA
# TGTTGAAACAT -> GTTGAAACATC
# TGTTGATCGCA -> GTTGATCGCAA
# TGTTGTCCGTT -> GTTGTCCGTTG
# TGTTGTTCAGG -> GTTGTTCAGGG
# TGTTTAGTGTA -> GTTTAGTGTAA
# TTAACCGGGAC -> TAACCGGGACT
# TTAACTATGGG -> TAACTATGGGC
# TTAACTTTTAG -> TAACTTTTAGT
# TTAAGATGCAG -> TAAGATGCAGC
# TTAATAACACG -> TAATAACACGC
# TTAATGGGGAT -> TAATGGGGATC
# TTAATTGCCGC -> TAATTGCCGCC
# TTACACTCTGG -> TACACTCTGGT
# TTACCACGTAG -> TACCACGTAGG
# TTACCCTAGGG -> TACCCTAGGGG
# TTACCTCACTA -> TACCTCACTAG
# TTACGGTAGTC -> TACGGTAGTCA
# TTACGTGCGTA -> TACGTGCGTAG
# TTACTGGAACT -> TACTGGAACTC
# TTACTTCGTGC -> TACTTCGTGCT
# TTAGACAGGTT -> TAGACAGGTTT
# TTAGAGCCGAG -> TAGAGCCGAGG
# TTAGCTGGCTA -> TAGCTGGCTAG
# TTAGTATCGGT -> TAGTATCGGTA
# TTAGTGTAAAA -> TAGTGTAAAAA
# TTAGTGTTGAA -> TAGTGTTGAAA
# TTATAAATGCT -> TATAAATGCTC
# TTATAACTGGC -> TATAACTGGCG
# TTATAACTTCC -> TATAACTTCCT
# TTATATAAGTC -> TATATAAGTCA
# TTATCAATAAA -> TATCAATAAAC
# TTATCTTTGTC -> TATCTTTGTCC
# TTATGTACGCG -> TATGTACGCGT
# TTATTCCAAAT -> TATTCCAAATA
# TTCAATGTATG -> TCAATGTATGA
# TTCACCACACG -> TCACCACACGG
# TTCACCGAAGT -> TCACCGAAGTA
# TTCAGAGGCCC -> TCAGAGGCCCA
# TTCAGAGTTTA -> TCAGAGTTTAT
# TTCAGGAATGC -> TCAGGAATGCA
# TTCAGGGCTCC -> TCAGGGCTCCC
# TTCAGTAACCA -> TCAGTAACCAA
# TTCAGTCTGGA -> TCAGTCTGGAC
# TTCATCCCATG -> TCATCCCATGT
# TTCATGGTGTG -> TCATGGTGTGT
# TTCATTTATAA -> TCATTTATAAC
# TTCATTTGGTC -> TCATTTGGTCG
# TTCCAAATACA -> TCCAAATACAG
# TTCCCCGCGCA -> TCCCCGCGCAC
# TTCCCGTAAAT -> TCCCGTAAATC
# TTCCCTTGAGT -> TCCCTTGAGTC
# TTCCGTACCGG -> TCCGTACCGGC
# TTCCTATTTAG -> TCCTATTTAGA
# TTCCTCGGATG -> TCCTCGGATGC
# TTCCTGGGCGA -> TCCTGGGCGAG
# TTCGAATCTTC -> TCGAATCTTCG
# TTCGACACTCA -> TCGACACTCAA
# TTCGAGAGGGA -> TCGAGAGGGAG
# TTCGATCGGGG -> TCGATCGGGGG
# TTCGATGCTTT -> TCGATGCTTTG
# TTCGCTACGAT -> TCGCTACGATG
# TTCGGTTTTCA -> TCGGTTTTCAC
# TTCGTGCGCAC -> TCGTGCGCACA
# TTCGTGCTTGA -> TCGTGCTTGAT
# TTCTAAAGACT -> TCTAAAGACTT
# TTCTAGATCTA -> TCTAGATCTAC
# TTCTAGATGCT -> TCTAGATGCTG
# TTCTATCTTAC -> TCTATCTTACT
# TTCTATGGATT -> TCTATGGATTG
# TTCTCGCGACC -> TCTCGCGACCG
# TTCTTCGAATC -> TCTTCGAATCT
# TTGAAACATCT -> TGAAACATCTC
# TTGAAAGTGTC -> TGAAAGTGTCG
# TTGACTGGTGA -> TGACTGGTGAC
# TTGAGATCGAA -> TGAGATCGAAC
# TTGAGTCAACG -> TGAGTCAACGA
# TTGAGTCGCGG -> TGAGTCGCGGG
# TTGATCGCAAC -> TGATCGCAACA
# TTGATTCGATC -> TGATTCGATCG
# TTGCCACTCAA -> TGCCACTCAAA
# TTGCCGCCGAC -> TGCCGCCGACA
# TTGCGTGCGGC -> TGCGTGCGGCC
# TTGGAAGACGA -> TGGAAGACGAT
# TTGGAGGCCAC -> TGGAGGCCACG
# TTGGCACGAGC -> TGGCACGAGCA
# TTGGCGGCCCC -> TGGCGGCCCCG
# TTGGCTAAATG -> TGGCTAAATGC
# TTGGCTCAACC -> TGGCTCAACCA
# TTGGCTCGGGT -> TGGCTCGGGTC
# TTGGTAGGAGA -> TGGTAGGAGAG
# TTGGTCACGGG -> TGGTCACGGGC
# TTGGTCGGGCA -> TGGTCGGGCAG
# TTGGTTATAAA -> TGGTTATAAAT
# TTGTAACGAAC -> TGTAACGAACC
# TTGTCAACCCT -> TGTCAACCCTG
# TTGTCCCAGAC -> TGTCCCAGACA
# TTGTCCGTTGT -> TGTCCGTTGTG
# TTGTCTAACGC -> TGTCTAACGCG
# TTGTGTTGTTC -> TGTGTTGTTCA
# TTGTTCAGGGC -> TGTTCAGGGCT
# TTGTTGTCCGT -> TGTTGTCCGTT
# TTTAACCGGGA -> TTAACCGGGAC
# TTTACGGTAGT -> TTACGGTAGTC
# TTTACGTGCGT -> TTACGTGCGTA
# TTTACTGGAAC -> TTACTGGAACT
# TTTAGACAGGT -> TTAGACAGGTT
# TTTAGAGCCGA -> TTAGAGCCGAG
# TTTAGTATCGG -> TTAGTATCGGT
# TTTAGTGTAAA -> TTAGTGTAAAA
# TTTATAACTGG -> TTATAACTGGC
# TTTATAACTTC -> TTATAACTTCC
# TTTATATAAGT -> TTATATAAGTC
# TTTATCTTTGT -> TTATCTTTGTC
# TTTATGTACGC -> TTATGTACGCG
# TTTCAATGTAT -> TTCAATGTATG
# TTTCACCGAAG -> TTCACCGAAGT
# TTTCAGGAATG -> TTCAGGAATGC
# TTTCAGTCTGG -> TTCAGTCTGGA
# TTTCCCGTAAA -> TTCCCGTAAAT
# TTTCCTATTTA -> TTCCTATTTAG
# TTTCGTGCGCA -> TTCGTGCGCAC
# TTTGACTGGTG -> TTGACTGGTGA
# TTTGCCACTCA -> TTGCCACTCAA
# TTTGGAAGACG -> TTGGAAGACGA
# TTTGGAGGCCA -> TTGGAGGCCAC
# TTTGGCACGAG -> TTGGCACGAGC
# TTTGGCGGCCC -> TTGGCGGCCCC
# TTTGGCTCAAC -> TTGGCTCAACC
# TTTGGTCGGGC -> TTGGTCGGGCA
# TTTGTAACGAA -> TTGTAACGAAC
# TTTGTCCCAGA -> TTGTCCCAGAC
# TTTTAACCGGG -> TTTAACCGGGA
# TTTTACTGGAA -> TTTACTGGAAC
# TTTTAGAGCCG -> TTTAGAGCCGA
# TTTTAGTATCG -> TTTAGTATCGG
# TTTTATGTACG -> TTTATGTACGC
# TTTTCACCGAA -> TTTCACCGAAG
# TTTTCAGGAAT -> TTTCAGGAATG
# TTTTCCCGTAA -> TTTCCCGTAAA
# TTTTCCTATTT -> TTTCCTATTTA
# TTTTGCTATCA -> TTTGCTATCAT
# TTTTTAACCGG -> TTTTAACCGGG
# TTTTTACTGGA -> TTTTACTGGAA
# TTTTTCAGGAA -> TTTTCAGGAAT

# %%
# INSPECTION

# INSPECTION TEAM
# Hsiang-Yun Lu (Eloise)
# Jodi Lee
# Nabil Mohammed

# RESPONSES
# - Work on implementing main function
# - Write more markdown comments
# - Clean up code
# - Add more docstrings and inline comments

# CORRECTIONS
# - Finished main function
# - Wrote markdown comments
# - Cleaned code
# - Added more docstrings and inline comments
