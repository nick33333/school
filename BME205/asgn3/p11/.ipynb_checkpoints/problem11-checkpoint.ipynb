# %%
#!/usr/bin/env python3

########################################################################
# File: Chan_Nicholas_problem11.ipynb
# Purpose: Given a genome Text, PathGraphk(Text) is the path consisting of |Text| - k + 1 edges, where the i-th edge of this path is labeled by the i-th k-mer in Text and the i-th node of the path is labeled by the i-th (k - 1)-mer in Text. The de Bruijn graph DeBruijnk(Text) is formed by gluing identically labeled nodes in PathGraphk(Text).
# main(infile='FILE_PATH',outfile='FILE_PATH', inCL=[])
#
# Author: Nicholas Chan
# History: 10/18/2021 Created
########################################################################

# %% [markdown]
# # Assignment 3: Problem 11

# %%
'''
Problem 11: 
Given a genome Text, PathGraphk(Text) is the path consisting of |Text| - k + 1 edges, 
where the i-th edge of this path is labeled by the i-th k-mer in Text and the i-th node 
of the path is labeled by the i-th (k - 1)-mer in Text. The de Bruijn graph DeBruijnk(Text) 
is formed by gluing identically labeled nodes in PathGraphk(Text).

Input:
4
AAGATTCTCTAC

Desired output:
AAG -> AGA
AGA -> GAT
ATT -> TTC
CTA -> TAC
CTC -> TCT
GAT -> ATT
TCT -> CTA,CTC
TTC -> TCT
'''

class Solution:
    '''
    To solve the de Bruijn graph for problem 11, I collected 
    edges (k-mer of size k) from the input sequence and made their
    prefixes keys with their suffixes as values. I utilized the 
    information of the input string to correctly match prefixes
    to their suffixes. Starting out with the whole input sequence and 
    edges made graphing the nodes (assigning suffixes to prefixes) 
    less ambiguous that it would have been just starting out with nodes.
    '''
    def __init__(self, k, seqString):
        self.k = k
        self.seqString = seqString
        self.edgeList = self.edgeComp()
        self.graph = self.graph()
        
    def edgeComp(self) -> 'list':
        '''
        Creates a list of edges from seqString. Edges are to be
        k characters long 
        '''
        seqRange = len(self.seqString) - (self.k) + 1 # Valid frame index range on seqString
        seqList = []
        for idx in range(seqRange):
            kmer = self.seqString[idx:idx + self.k]
            seqList.append(kmer)
        return seqList       
    
    def graph(self) -> 'dict':
        '''
        Create a graph dict from edges in edgeList. Keys are prefixes of each edge
        and values are each edge's corresponding suffixes. Knowledge of the edge makes 
        the assignment of keys to values less ambiguous than they would be just starting
        out with nodes of size k-1.
        '''
        graphDict = dict()
        
        for edge in self.edgeList:
            prefix = edge[:-1]
            graphDict[prefix] = []
        
        for edge in self.edgeList:
            prefix = edge[:-1]
            suffix = edge[1:]
            graphDict[prefix].append(suffix)
            
        return graphDict
            
            
    def printGraph(self) -> 'str':
        '''
        Call this method to return a string containing output
        '''
        output = ""
        keyList = [key for key in self.graph]
        for key in sorted(keyList):
            valList = []
            for vals in self.graph[key]:
                valList.append(vals)
            valList.sort()
            valstring = ','.join(valList)
            output += f"{key} -> {valstring}\n"
        return output

# %% [markdown]
# # Main function
# Main function is written here. This function handles argument parsing, input, and output.

# %%
def main(infile, outfile, inCL=None):
    k = 0
    inputSeqString = ''
    with open(infile,'r') as myfile:
        for line in myfile:
            k = int(line.rstrip())
            inputSeqString = next(myfile).rstrip() 
            
    solution = Solution(k, inputSeqString)
    solutionString = solution.printGraph()
    
    with open(outfile, "w") as myfile:
        myfile.write(solutionString)
        print(solutionString)

# %%
if __name__ == "__main__":
    main(infile='data/rosalind_ba3d.txt',outfile='output-problem11.txt', inCL=[])
#     main(infile='data/extra-input.txt',outfile='output-problem11.txt', inCL=[])
# Out:
# AAAAAATAGAA -> AAAAATAGAAC
# AAAAATAGAAC -> AAAATAGAACA
# AAAACAACGGG -> AAACAACGGGA
# AAAACTCATGC -> AAACTCATGCA
# AAAATAGAACA -> AAATAGAACAC
# AAAATCCAAAT -> AAATCCAAATC
# AAAATCTGATC -> AAATCTGATCA
# AAAATGATCGG -> AAATGATCGGG
# AAACAACGGGA -> AACAACGGGAA
# AAACATCATCA -> AACATCATCAC
# AAACCCTTGTT -> AACCCTTGTTA
# AAACCTTTTGA -> AACCTTTTGAT
# AAACGTACTAG -> AACGTACTAGT
# AAACTCATGCA -> AACTCATGCAA
# AAACTCGACCC -> AACTCGACCCC
# AAACTTCATAT -> AACTTCATATC
# AAACTTGAAAC -> AACTTGAAACT
# AAACTTTATCA -> AACTTTATCAT
# AAAGCACCTTG -> AAGCACCTTGC
# AAAGTACCCAT -> AAGTACCCATG
# AAATAGAACAC -> AATAGAACACG
# AAATCCAAATC -> AATCCAAATCT
# AAATCTCGTCT -> AATCTCGTCTG
# AAATCTGATCA -> AATCTGATCAA
# AAATGATCGGG -> AATGATCGGGT
# AAATGCGTCCA -> AATGCGTCCAT
# AAATTACTGTA -> AATTACTGTAA
# AAATTGACCTC -> AATTGACCTCA
# AAATTGTGAAT -> AATTGTGAATC
# AAATTTAGCAG -> AATTTAGCAGT
# AAATTTCGCCG -> AATTTCGCCGT
# AACAACAACCC -> ACAACAACCCA
# AACAACCCACC -> ACAACCCACCT
# AACAACGGGAA -> ACAACGGGAAA
# AACACGTATAA -> ACACGTATAAA
# AACAGGGGACC -> ACAGGGGACCC
# AACATAACTCG -> ACATAACTCGG
# AACATATAGAC -> ACATATAGACG
# AACATCATCAC -> ACATCATCACG
# AACATGAGTGT -> ACATGAGTGTC
# AACATGCCATG -> ACATGCCATGG
# AACATTAGGGA -> ACATTAGGGAA
# AACATTGGCGC -> ACATTGGCGCA
# AACCATAGTTA -> ACCATAGTTAT
# AACCCACCTGC -> ACCCACCTGCT
# AACCCTCACAT -> ACCCTCACATG
# AACCCTGCCTT -> ACCCTGCCTTA
# AACCCTTACAT -> ACCCTTACATT
# AACCCTTGTTA -> ACCCTTGTTAT
# AACCGCCTCGC -> ACCGCCTCGCA
# AACCTTTTGAT -> ACCTTTTGATC
# AACGACTGTGG -> ACGACTGTGGC
# AACGCATTAAA -> ACGCATTAAAT
# AACGCGTCAGT -> ACGCGTCAGTC
# AACGGGAAACG -> ACGGGAAACGT
# AACGTACTAGT -> ACGTACTAGTC
# AACGTCTTGCC -> ACGTCTTGCCA
# AACTATGAAAG -> ACTATGAAAGC
# AACTCATGCAA -> ACTCATGCAAC
# AACTCGACCCC -> ACTCGACCCCA
# AACTCGCTAGT -> ACTCGCTAGTG
# AACTCGGACAG -> ACTCGGACAGC
# AACTGTAAGTT -> ACTGTAAGTTC
# AACTTAACCAT -> ACTTAACCATA
# AACTTCATATC -> ACTTCATATCA
# AACTTGAAACT -> ACTTGAAACTT
# AACTTTATCAT -> ACTTTATCATT
# AACTTTCGGGC -> ACTTTCGGGCT
# AAGAAACATCA -> AGAAACATCAT
# AAGACTCTTTT -> AGACTCTTTTG
# AAGAGCCAGAG -> AGAGCCAGAGG
# AAGAGCTACAC -> AGAGCTACACA
# AAGCACCTTGC -> AGCACCTTGCA
# AAGCAGGGAAA -> AGCAGGGAAAT
# AAGCCAACTTT -> AGCCAACTTTC
# AAGCGCCGAAA -> AGCGCCGAAAA
# AAGCGGGATCG -> AGCGGGATCGA
# AAGCGGGTGAA -> AGCGGGTGAAC
# AAGCGGGTGTC -> AGCGGGTGTCT
# AAGGCAACATG -> AGGCAACATGC
# AAGGCAGATGA -> AGGCAGATGAG
# AAGGCGGAACT -> AGGCGGAACTT
# AAGTACCCATG -> AGTACCCATGT
# AAGTACGTCCG -> AGTACGTCCGC
# AAGTTCAGTAC -> AGTTCAGTACT
# AATACCGACGT -> ATACCGACGTG
# AATAGAACACG -> ATAGAACACGT
# AATAGAGCTGA -> ATAGAGCTGAA
# AATAGGACGGC -> ATAGGACGGCG
# AATAGGCGCTT -> ATAGGCGCTTA
# AATAGGGCATA -> ATAGGGCATAC
# AATCACCACAT -> ATCACCACATA
# AATCCAAATCT -> ATCCAAATCTC
# AATCCCACCGC -> ATCCCACCGCT
# AATCTCCAGAA -> ATCTCCAGAAT
# AATCTCGTCTG -> ATCTCGTCTGG
# AATCTGATCAA -> ATCTGATCAAC
# AATGAGGATCT -> ATGAGGATCTT
# AATGATCGGGT -> ATGATCGGGTC
# AATGCGTCCAT -> ATGCGTCCATA
# AATTAACCCTT -> ATTAACCCTTA
# AATTACTGTAA -> ATTACTGTAAG
# AATTATCTGTG -> ATTATCTGTGA
# AATTCTCATGT -> ATTCTCATGTA
# AATTGACCTCA -> ATTGACCTCAT
# AATTGTGAATC -> ATTGTGAATCT
# AATTTAGAGTT -> ATTTAGAGTTC
# AATTTAGCAGT -> ATTTAGCAGTT
# AATTTCATCTA -> ATTTCATCTAC
# AATTTCGCCGT -> ATTTCGCCGTA
# ACAAAATCTGA -> CAAAATCTGAT
# ACAACAACCCA -> CAACAACCCAC
# ACAACCCACCT -> CAACCCACCTG
# ACAACGGGAAA -> CAACGGGAAAC
# ACAATTATCTG -> CAATTATCTGT
# ACACAATTATC -> CACAATTATCT
# ACACATGCCAT -> CACATGCCATG
# ACACCGCGGAT -> CACCGCGGATT
# ACACCTACGTT -> CACCTACGTTC
# ACACGTATAAA -> CACGTATAAAC
# ACAGAAGGCAA -> CAGAAGGCAAC
# ACAGATCGTAG -> CAGATCGTAGG
# ACAGCGCTGCG -> CAGCGCTGCGC
# ACAGCGGGTGG -> CAGCGGGTGGC
# ACAGCGTCCCC -> CAGCGTCCCCC
# ACAGGCGGTTG -> CAGGCGGTTGG
# ACAGGCTAACC -> CAGGCTAACCC
# ACAGGGGACCC -> CAGGGGACCCA
# ACAGTAAAAAA -> CAGTAAAAAAT
# ACAGTACACCG -> CAGTACACCGC
# ACAGTTTTCCT -> CAGTTTTCCTA
# ACATAACTCGG -> CATAACTCGGA
# ACATATAGACG -> CATATAGACGG
# ACATATTTTCA -> CATATTTTCAA
# ACATCAGTATA -> CATCAGTATAA
# ACATCATCACG -> CATCATCACGA
# ACATGAGTGTC -> CATGAGTGTCC
# ACATGCCATGG -> CATGCCATGGC,CATGCCATGGC
# ACATGGAAAAT -> CATGGAAAATC
# ACATGTCACTA -> CATGTCACTAG
# ACATTAGGGAA -> CATTAGGGAAT
# ACATTCGCTCT -> CATTCGCTCTC
# ACATTGGCGCA -> CATTGGCGCAG
# ACATTGGCGTC -> CATTGGCGTCC
# ACCAAGACTCT -> CCAAGACTCTT
# ACCACATATTT -> CCACATATTTT
# ACCAGCAGACC -> CCAGCAGACCA
# ACCATAGTTAT -> CCATAGTTATA
# ACCATGAAAAT -> CCATGAAAATG
# ACCATGATCGG -> CCATGATCGGT
# ACCCAATCACC -> CCCAATCACCA
# ACCCACCTGCT -> CCCACCTGCTG
# ACCCAGCCTCG -> CCCAGCCTCGG
# ACCCAGTCGCA -> CCCAGTCGCAA
# ACCCAGTTCTT -> CCCAGTTCTTT
# ACCCATGTCTT -> CCCATGTCTTT
# ACCCCACAGTA -> CCCCACAGTAC
# ACCCCGAGACT -> CCCCGAGACTA
# ACCCGATCCTG -> CCCGATCCTGG
# ACCCGCCAACT -> CCCGCCAACTC
# ACCCGGCCCGT -> CCCGGCCCGTG
# ACCCTCACATG -> CCCTCACATGT
# ACCCTGAGTCG -> CCCTGAGTCGC
# ACCCTGCCTTA -> CCCTGCCTTAC
# ACCCTTACATT -> CCCTTACATTG
# ACCCTTGTTAT -> CCCTTGTTATA
# ACCGACGTGTC -> CCGACGTGTCG
# ACCGATTTGCT -> CCGATTTGCTG
# ACCGCCTCGCA -> CCGCCTCGCAA
# ACCGCGGATTA -> CCGCGGATTAT
# ACCGCGTCGGT -> CCGCGTCGGTT
# ACCGCTAAATT -> CCGCTAAATTG
# ACCGGATGAGT -> CCGGATGAGTT
# ACCGGTCGGCG -> CCGGTCGGCGT
# ACCTACGTTCC -> CCTACGTTCCG
# ACCTATAATAG -> CCTATAATAGG
# ACCTCATCCAG -> CCTCATCCAGA
# ACCTCTCGGGC -> CCTCTCGGGCG
# ACCTGCTGGAG -> CCTGCTGGAGA
# ACCTGTTGACA -> CCTGTTGACAT
# ACCTTGCAGCA -> CCTTGCAGCAA
# ACCTTTCATGC -> CCTTTCATGCG
# ACCTTTTGATC -> CCTTTTGATCA
# ACGACAGTTTT -> CGACAGTTTTC
# ACGACTGTGGC -> CGACTGTGGCT
# ACGAGGCTAAC -> CGAGGCTAACA
# ACGAGTCGGGT -> CGAGTCGGGTT
# ACGCATTAAAT -> CGCATTAAATT
# ACGCCAGATAT -> CGCCAGATATT
# ACGCCAGTTAC -> CGCCAGTTACA
# ACGCCCAGACC -> CGCCCAGACCC
# ACGCCCCACGC -> CGCCCCACGCG
# ACGCGTCAGTC -> CGCGTCAGTCG
# ACGCGTGACTT -> CGCGTGACTTG
# ACGGAGGTATG -> CGGAGGTATGC
# ACGGATCGCTC -> CGGATCGCTCG
# ACGGCAGTTGC -> CGGCAGTTGCT
# ACGGCGGCGGA -> CGGCGGCGGAC
# ACGGGAAACGT -> CGGGAAACGTA
# ACGGGAGCATA -> CGGGAGCATAC
# ACGGTACATTC -> CGGTACATTCG
# ACGGTCAGAAG -> CGGTCAGAAGA
# ACGGTCTATAC -> CGGTCTATACC
# ACGTACAGAAG -> CGTACAGAAGG
# ACGTACTAGTC -> CGTACTAGTCG
# ACGTATAAACT -> CGTATAAACTT
# ACGTCCGCAGT -> CGTCCGCAGTG
# ACGTCTCAGCT -> CGTCTCAGCTA
# ACGTCTTACTA -> CGTCTTACTAA
# ACGTCTTGCCA -> CGTCTTGCCAA
# ACGTGACCCTG -> CGTGACCCTGA
# ACGTGCATCTG -> CGTGCATCTGG
# ACGTGTCGCTT -> CGTGTCGCTTC
# ACGTTCCGGGA -> CGTTCCGGGAT
# ACTAAACCTTT -> CTAAACCTTTT
# ACTAAGAAACA -> CTAAGAAACAT
# ACTACACATGC -> CTACACATGCC
# ACTACAGATCG -> CTACAGATCGT
# ACTACGTACAG -> CTACGTACAGA
# ACTAGAAATGC -> CTAGAAATGCG
# ACTAGTCGGCA -> CTAGTCGGCAG
# ACTATAGTATT -> CTATAGTATTT
# ACTATCCCGTT -> CTATCCCGTTC
# ACTATGAAAGC -> CTATGAAAGCA
# ACTATTACCCA -> CTATTACCCAA
# ACTCATCGCCT -> CTCATCGCCTG
# ACTCATGCAAC -> CTCATGCAACG
# ACTCCAGGTAA -> CTCCAGGTAAT
# ACTCCGGAGAA -> CTCCGGAGAAT
# ACTCGACCCCA -> CTCGACCCCAC
# ACTCGCTAGTG -> CTCGCTAGTGA
# ACTCGGACAGC -> CTCGGACAGCG
# ACTCTCCGACG -> CTCTCCGACGG
# ACTCTTTTGAT -> CTCTTTTGATA
# ACTGACCTTTC -> CTGACCTTTCA
# ACTGGACAGCG -> CTGGACAGCGT
# ACTGGTATAAG -> CTGGTATAAGA
# ACTGTAAGCAG -> CTGTAAGCAGG
# ACTGTAAGTTC -> CTGTAAGTTCA
# ACTGTCGGGGT -> CTGTCGGGGTG
# ACTGTGGCTTC -> CTGTGGCTTCC
# ACTTAACCATA -> CTTAACCATAG
# ACTTCATATCA -> CTTCATATCAA
# ACTTGAAACTT -> CTTGAAACTTT
# ACTTGATACCG -> CTTGATACCGG
# ACTTTATCATT -> CTTTATCATTG
# ACTTTCGGGCT -> CTTTCGGGCTA
# AGAAACATCAT -> GAAACATCATC
# AGAAATGCGTC -> GAAATGCGTCC
# AGAACACGTAT -> GAACACGTATA
# AGAACATATAG -> GAACATATAGA
# AGAACATTGGC -> GAACATTGGCG
# AGAAGAGCCAG -> GAAGAGCCAGA
# AGAAGGCAACA -> GAAGGCAACAT
# AGAATGAGGAT -> GAATGAGGATC
# AGAATTTAGAG -> GAATTTAGAGT
# AGAATTTCATC -> GAATTTCATCT
# AGACCATGATC -> GACCATGATCG
# AGACCCGATCC -> GACCCGATCCT
# AGACGGTCTAT -> GACGGTCTATA
# AGACTACAGAT -> GACTACAGATC
# AGACTACGTAC -> GACTACGTACA
# AGACTATCCCG -> GACTATCCCGT
# AGACTCTTTTG -> GACTCTTTTGA
# AGACTGACCTT -> GACTGACCTTT
# AGAGCCAGAGG -> GAGCCAGAGGG
# AGAGCGAGGAA -> GAGCGAGGAAA
# AGAGCTACACA -> GAGCTACACAA
# AGAGCTGAACC -> GAGCTGAACCC
# AGAGGGGACCG -> GAGGGGACCGG
# AGAGTTATGGC -> GAGTTATGGCT
# AGAGTTCTCTT -> GAGTTCTCTTA
# AGATATTACGG -> GATATTACGGA
# AGATATTTCCC -> GATATTTCCCA
# AGATCGAAAAC -> GATCGAAAACA
# AGATCGTAGGC -> GATCGTAGGCC
# AGATGAGCTAT -> GATGAGCTATC
# AGATGCACAGG -> GATGCACAGGC
# AGATTCATCAC -> GATTCATCACC
# AGCAACGACTG -> GCAACGACTGT
# AGCACCTTGCA -> GCACCTTGCAG
# AGCAGACCATG -> GCAGACCATGA
# AGCAGGGAAAT -> GCAGGGAAATT
# AGCAGTTGTCC -> GCAGTTGTCCT
# AGCATACTCTC -> GCATACTCTCC
# AGCATGAGTAG -> GCATGAGTAGA
# AGCCAACTTTC -> GCCAACTTTCG
# AGCCAGAGGGG -> GCCAGAGGGGA
# AGCCCGCCATC -> GCCCGCCATCT
# AGCCGACATGG -> GCCGACATGGA
# AGCCTCGGAGA -> GCCTCGGAGAT
# AGCGAGGAAAC -> GCGAGGAAACT
# AGCGCCGAAAA -> GCGCCGAAAAC
# AGCGCTGCGCG -> GCGCTGCGCGT
# AGCGGCGCGAC -> GCGGCGCGACT
# AGCGGGATCGA -> GCGGGATCGAC
# AGCGGGTGAAC -> GCGGGTGAACA
# AGCGGGTGGCT -> GCGGGTGGCTG
# AGCGGGTGTCT -> GCGGGTGTCTC
# AGCGTCCCCCG -> GCGTCCCCCGA
# AGCTACACAAT -> GCTACACAATT
# AGCTACGCCCA -> GCTACGCCCAG
# AGCTATCGACT -> GCTATCGACTG
# AGCTGAACCCT -> GCTGAACCCTG
# AGGAAACTCGA -> GGAAACTCGAC
# AGGACACCTAC -> GGACACCTACG
# AGGACGGCGGC -> GGACGGCGGCG
# AGGATCTTCCG -> GGATCTTCCGA
# AGGCAACATGC -> GGCAACATGCC
# AGGCAGATGAG -> GGCAGATGAGC
# AGGCATGGATC -> GGCATGGATCT
# AGGCCCTAACG -> GGCCCTAACGC
# AGGCGCTTACG -> GGCGCTTACGG
# AGGCGGAACTT -> GGCGGAACTTA
# AGGCGGTTGGT -> GGCGGTTGGTT
# AGGCTAACATA -> GGCTAACATAA
# AGGCTAACCCT -> GGCTAACCCTC
# AGGCTAGGCAT -> GGCTAGGCATG
# AGGGAAATTTC -> GGGAAATTTCG
# AGGGAATAGGA -> GGGAATAGGAC
# AGGGACGAGGC -> GGGACGAGGCT
# AGGGAGACTAC -> GGGAGACTACG
# AGGGCATACAG -> GGGCATACAGG
# AGGGGACCCAG -> GGGGACCCAGC
# AGGGGACCGGA -> GGGGACCGGAT
# AGGGGGACAAA -> GGGGGACAAAA
# AGGTAATTCTC -> GGTAATTCTCA
# AGGTATGCGCT -> GGTATGCGCTG
# AGGTGCCAGAC -> GGTGCCAGACT
# AGTAAAAAATA -> GTAAAAAATAG
# AGTACACCGCG -> GTACACCGCGG
# AGTACCCATGT -> GTACCCATGTC
# AGTACCGATTT -> GTACCGATTTG
# AGTACGTCCGC -> GTACGTCCGCA
# AGTACTAAACC -> GTACTAAACCT
# AGTACTCCGGA -> GTACTCCGGAG
# AGTAGAACATA -> GTAGAACATAT
# AGTATAAGCGG -> GTATAAGCGGG
# AGTATAGGGAG -> GTATAGGGAGA
# AGTATTTACGT -> GTATTTACGTG
# AGTCACTGTCG -> GTCACTGTCGG
# AGTCGACCTGT -> GTCGACCTGTT
# AGTCGCAAATT -> GTCGCAAATTG
# AGTCGCGAATA -> GTCGCGAATAG
# AGTCGCGGCTA -> GTCGCGGCTAG
# AGTCGGCAGGT -> GTCGGCAGGTG
# AGTCGGGTTTG -> GTCGGGTTTGA
# AGTGATACCTA -> GTGATACCTAT
# AGTGCACGCCA -> GTGCACGCCAG
# AGTGCAGCATG -> GTGCAGCATGA
# AGTGGACGTGC -> GTGGACGTGCA
# AGTGTCCTGGG -> GTGTCCTGGGT
# AGTTACAGCGG -> GTTACAGCGGG
# AGTTATACCCG -> GTTATACCCGG
# AGTTATGGCTT -> GTTATGGCTTG
# AGTTCAGTACT -> GTTCAGTACTA
# AGTTCCTACTC -> GTTCCTACTCA
# AGTTCTCTTAT -> GTTCTCTTATG
# AGTTCTTTGCG -> GTTCTTTGCGA
# AGTTGCTGGAT -> GTTGCTGGATG
# AGTTGTCCTTT -> GTTGTCCTTTC
# AGTTTTCCTAG -> GTTTTCCTAGT
# ATAAACTTCAT -> TAAACTTCATA
# ATAACTCGGAC -> TAACTCGGACA
# ATAAGAGCTAC -> TAAGAGCTACA
# ATAAGCGGGTG -> TAAGCGGGTGA
# ATAATAGGCGC -> TAATAGGCGCT
# ATACAGGCTAA -> TACAGGCTAAC
# ATACCCGGCCC -> TACCCGGCCCG
# ATACCGACGTG -> TACCGACGTGT
# ATACCGGTCGG -> TACCGGTCGGC
# ATACCTATAAT -> TACCTATAATA
# ATACCTCTCGG -> TACCTCTCGGG
# ATACTCTCCGA -> TACTCTCCGAC
# ATAGAACACGT -> TAGAACACGTA
# ATAGACGGTCT -> TAGACGGTCTA
# ATAGACTATCC -> TAGACTATCCC
# ATAGAGCTGAA -> TAGAGCTGAAC
# ATAGGACGGCG -> TAGGACGGCGG
# ATAGGCGCTTA -> TAGGCGCTTAC
# ATAGGCTAGGC -> TAGGCTAGGCA
# ATAGGGAGACT -> TAGGGAGACTA
# ATAGGGCATAC -> TAGGGCATACA
# ATAGTATTTAC -> TAGTATTTACG
# ATAGTCACTGT -> TAGTCACTGTC
# ATAGTTATACC -> TAGTTATACCC
# ATATAGACGGT -> TATAGACGGTC
# ATATCAACGCG -> TATCAACGCGT
# ATATCGAAGCG -> TATCGAAGCGG
# ATATCGCTGGT -> TATCGCTGGTG
# ATATGCTATGA -> TATGCTATGAT
# ATATTACGGAT -> TATTACGGATC
# ATATTTCCCAA -> TATTTCCCAAG
# ATATTTTCAAG -> TATTTTCAAGG
# ATCAAACCCTT -> TCAAACCCTTG
# ATCAACGCGTC -> TCAACGCGTCA
# ATCAACTATGA -> TCAACTATGAA
# ATCACCACATA -> TCACCACATAT
# ATCACCCGCCA -> TCACCCGCCAA
# ATCACGAGTCG -> TCACGAGTCGG
# ATCAGTATAAG -> TCAGTATAAGC
# ATCATCACGAG -> TCATCACGAGT
# ATCATCGACCC -> TCATCGACCCC
# ATCATTGTCTC -> TCATTGTCTCA
# ATCCAAATCTC -> TCCAAATCTCG
# ATCCACCCAGT -> TCCACCCAGTC
# ATCCAGAACAT -> TCCAGAACATT
# ATCCAGAATTT -> TCCAGAATTTC
# ATCCCACCGCT -> TCCCACCGCTA
# ATCCCACGCCA -> TCCCACGCCAG
# ATCCCGTTCCA -> TCCCGTTCCAC
# ATCCTGGGCCA -> TCCTGGGCCAC
# ATCGAAAACAA -> TCGAAAACAAC
# ATCGAAGCGGG -> TCGAAGCGGGA
# ATCGACCATGA -> TCGACCATGAA
# ATCGACCCCGA -> TCGACCCCGAG
# ATCGACTGGAC -> TCGACTGGACA
# ATCGCCGACTC -> TCGCCGACTCC
# ATCGCCTGAGG -> TCGCCTGAGGA
# ATCGCTCGATG -> TCGCTCGATGT
# ATCGCTGGTGT -> TCGCTGGTGTT
# ATCGGCTGCTG -> TCGGCTGCTGG
# ATCGGGCCACA -> TCGGGCCACAG
# ATCGGGTCGTG -> TCGGGTCGTGA
# ATCGGTTATAG -> TCGGTTATAGG
# ATCGTAGGCCC -> TCGTAGGCCCT
# ATCGTATCGGG -> TCGTATCGGGC
# ATCGTTAAGCC -> TCGTTAAGCCA
# ATCTACCAAGA -> TCTACCAAGAC
# ATCTAGATTCA -> TCTAGATTCAT
# ATCTCCAGAAT -> TCTCCAGAATT
# ATCTCGTCTGG -> TCTCGTCTGGA
# ATCTCTTAATA -> TCTCTTAATAG
# ATCTGATCAAC -> TCTGATCAACT
# ATCTGGCCAAT -> TCTGGCCAATT
# ATCTGGTATCC -> TCTGGTATCCC
# ATCTGTGAGTA -> TCTGTGAGTAT
# ATCTTCCGAGT -> TCTTCCGAGTG
# ATGAAAATGAT -> TGAAAATGATC
# ATGAAAGCACC -> TGAAAGCACCT
# ATGAGCTATCG -> TGAGCTATCGA
# ATGAGGATCTT -> TGAGGATCTTC
# ATGAGTAGAAC -> TGAGTAGAACA
# ATGAGTGTCCT -> TGAGTGTCCTG
# ATGAGTTCCTA -> TGAGTTCCTAC
# ATGATCGGGTC -> TGATCGGGTCG
# ATGATCGGTTA -> TGATCGGTTAT
# ATGATCGTTAA -> TGATCGTTAAG
# ATGATTGATGC -> TGATTGATGCA
# ATGATTTAACT -> TGATTTAACTG
# ATGCAACGTCT -> TGCAACGTCTT
# ATGCACAGGCG -> TGCACAGGCGG
# ATGCACGCCCC -> TGCACGCCCCA
# ATGCCATGGCA -> TGCCATGGCAT
# ATGCCATGGCC -> TGCCATGGCCG
# ATGCGCTGAGA -> TGCGCTGAGAG
# ATGCGGGATAG -> TGCGGGATAGT
# ATGCGTCCATA -> TGCGTCCATAT
# ATGCTATGATT -> TGCTATGATTG
# ATGGAAAATCC -> TGGAAAATCCA
# ATGGATCTAGA -> TGGATCTAGAT
# ATGGCATTTGT -> TGGCATTTGTT
# ATGGCCGGTTC -> TGGCCGGTTCT
# ATGGCGAACAA -> TGGCGAACAAC
# ATGGCTTGGCA -> TGGCTTGGCAG
# ATGGGGGGTAC -> TGGGGGGTACG
# ATGGTGCCTGA -> TGGTGCCTGAT
# ATGTAGCCCGC -> TGTAGCCCGCC
# ATGTATATGCT -> TGTATATGCTA
# ATGTCACTAGA -> TGTCACTAGAA
# ATGTCTTTCTA -> TGTCTTTCTAG
# ATTAAATTTAG -> TTAAATTTAGC
# ATTAACCCTTA -> TTAACCCTTAC
# ATTACCCAATC -> TTACCCAATCA
# ATTACGGATCG -> TTACGGATCGC
# ATTACTGTAAG -> TTACTGTAAGC
# ATTAGGGAATA -> TTAGGGAATAG
# ATTAGGGGGAC -> TTAGGGGGACA
# ATTATCTGTGA -> TTATCTGTGAG
# ATTATGATTTA -> TTATGATTTAA
# ATTCATCACCC -> TTCATCACCCG
# ATTCCATCGGC -> TTCCATCGGCT
# ATTCGAAATTA -> TTCGAAATTAC
# ATTCGCTCTCA -> TTCGCTCTCAC
# ATTCTCATGTA -> TTCTCATGTAT
# ATTGACCTCAT -> TTGACCTCATC
# ATTGATGCACG -> TTGATGCACGC
# ATTGGCGCAGA -> TTGGCGCAGAG
# ATTGGCGTCCC -> TTGGCGTCCCT
# ATTGTCACGGG -> TTGTCACGGGA
# ATTGTCTCAGA -> TTGTCTCAGAT
# ATTGTGAATCT -> TTGTGAATCTC
# ATTTAACTGTA -> TTTAACTGTAA
# ATTTACGTGAC -> TTTACGTGACC
# ATTTACTATTA -> TTTACTATTAC
# ATTTAGAGTTC -> TTTAGAGTTCT
# ATTTAGCAGTT -> TTTAGCAGTTG
# ATTTAGTGCAG -> TTTAGTGCAGC
# ATTTCATCTAC -> TTTCATCTACC
# ATTTCCCAAGC -> TTTCCCAAGCG
# ATTTCGCCGTA -> TTTCGCCGTAA
# ATTTGCTGGCG -> TTTGCTGGCGA
# ATTTGTTCGGC -> TTTGTTCGGCC
# ATTTTCAAGGC -> TTTTCAAGGCG
# CAAAATCTGAT -> AAAATCTGATC
# CAAACCCTTGT -> AAACCCTTGTT
# CAAACTTGAAA -> AAACTTGAAAC
# CAAATCTCGTC -> AAATCTCGTCT
# CAAATTGACCT -> AAATTGACCTC
# CAACAACCCAC -> AACAACCCACC
# CAACAGGGGAC -> AACAGGGGACC
# CAACATGCCAT -> AACATGCCATG
# CAACATTAGGG -> AACATTAGGGA
# CAACCCACCTG -> AACCCACCTGC
# CAACGACTGTG -> AACGACTGTGG
# CAACGCGTCAG -> AACGCGTCAGT
# CAACGGGAAAC -> AACGGGAAACG
# CAACGTCTTGC -> AACGTCTTGCC
# CAACTATGAAA -> AACTATGAAAG
# CAACTCGCTAG -> AACTCGCTAGT
# CAACTTTCGGG -> AACTTTCGGGC
# CAAGACTCTTT -> AAGACTCTTTT
# CAAGCGCCGAA -> AAGCGCCGAAA
# CAAGGCAGATG -> AAGGCAGATGA
# CAAGGCGGAAC -> AAGGCGGAACT
# CAATCACCACA -> AATCACCACAT
# CAATTAACCCT -> AATTAACCCTT
# CAATTATCTGT -> AATTATCTGTG
# CACAATTATCT -> ACAATTATCTG
# CACAGGCGGTT -> ACAGGCGGTTG
# CACAGTAAAAA -> ACAGTAAAAAA
# CACAGTACACC -> ACAGTACACCG
# CACATATTTTC -> ACATATTTTCA
# CACATGCCATG -> ACATGCCATGG
# CACATGTCACT -> ACATGTCACTA
# CACCACATATT -> ACCACATATTT
# CACCCAGTCGC -> ACCCAGTCGCA
# CACCCGCCAAC -> ACCCGCCAACT
# CACCGCGGATT -> ACCGCGGATTA
# CACCGCGTCGG -> ACCGCGTCGGT
# CACCGCTAAAT -> ACCGCTAAATT
# CACCTACGTTC -> ACCTACGTTCC
# CACCTGCTGGA -> ACCTGCTGGAG
# CACCTTGCAGC -> ACCTTGCAGCA
# CACGAGTCGGG -> ACGAGTCGGGT
# CACGCCAGATA -> ACGCCAGATAT
# CACGCCAGTTA -> ACGCCAGTTAC
# CACGCCCCACG -> ACGCCCCACGC
# CACGCGTGACT -> ACGCGTGACTT
# CACGGGAGCAT -> ACGGGAGCATA
# CACGGTACATT -> ACGGTACATTC
# CACGTATAAAC -> ACGTATAAACT
# CACGTCTCAGC -> ACGTCTCAGCT
# CACTAGAAATG -> ACTAGAAATGC
# CACTGGTATAA -> ACTGGTATAAG
# CACTGTCGGGG -> ACTGTCGGGGT
# CAGAACATTGG -> AGAACATTGGC
# CAGAAGAGCCA -> AGAAGAGCCAG
# CAGAAGGCAAC -> AGAAGGCAACA
# CAGAATTTAGA -> AGAATTTAGAG
# CAGAATTTCAT -> AGAATTTCATC
# CAGACCATGAT -> AGACCATGATC
# CAGACCCGATC -> AGACCCGATCC
# CAGACTGACCT -> AGACTGACCTT
# CAGAGGGGACC -> AGAGGGGACCG
# CAGAGTTATGG -> AGAGTTATGGC
# CAGATATTTCC -> AGATATTTCCC
# CAGATCGAAAA -> AGATCGAAAAC
# CAGATCGTAGG -> AGATCGTAGGC
# CAGATGAGCTA -> AGATGAGCTAT
# CAGCAACGACT -> AGCAACGACTG
# CAGCAGACCAT -> AGCAGACCATG
# CAGCATGAGTA -> AGCATGAGTAG
# CAGCCTCGGAG -> AGCCTCGGAGA
# CAGCGCTGCGC -> AGCGCTGCGCG
# CAGCGGGTGGC -> AGCGGGTGGCT
# CAGCGTCCCCC -> AGCGTCCCCCG
# CAGCTACGCCC -> AGCTACGCCCA
# CAGGCGGTTGG -> AGGCGGTTGGT
# CAGGCTAACCC -> AGGCTAACCCT
# CAGGGAAATTT -> AGGGAAATTTC
# CAGGGACGAGG -> AGGGACGAGGC
# CAGGGGACCCA -> AGGGGACCCAG
# CAGGTAATTCT -> AGGTAATTCTC
# CAGGTGCCAGA -> AGGTGCCAGAC
# CAGTAAAAAAT -> AGTAAAAAATA
# CAGTACACCGC -> AGTACACCGCG
# CAGTACTAAAC -> AGTACTAAACC
# CAGTATAAGCG -> AGTATAAGCGG
# CAGTCGACCTG -> AGTCGACCTGT
# CAGTCGCAAAT -> AGTCGCAAATT
# CAGTGCACGCC -> AGTGCACGCCA
# CAGTTACAGCG -> AGTTACAGCGG
# CAGTTCTTTGC -> AGTTCTTTGCG
# CAGTTGCTGGA -> AGTTGCTGGAT
# CAGTTGTCCTT -> AGTTGTCCTTT
# CAGTTTTCCTA -> AGTTTTCCTAG
# CATAACTCGGA -> ATAACTCGGAC
# CATACAGGCTA -> ATACAGGCTAA
# CATACTCTCCG -> ATACTCTCCGA
# CATAGTTATAC -> ATAGTTATACC
# CATATAGACGG -> ATATAGACGGT
# CATATCAACGC -> ATATCAACGCG
# CATATCGCTGG -> ATATCGCTGGT
# CATATTTTCAA -> ATATTTTCAAG
# CATCACCCGCC -> ATCACCCGCCA
# CATCACGAGTC -> ATCACGAGTCG
# CATCAGTATAA -> ATCAGTATAAG
# CATCATCACGA -> ATCATCACGAG
# CATCCAGAACA -> ATCCAGAACAT
# CATCGACCCCG -> ATCGACCCCGA
# CATCGCCTGAG -> ATCGCCTGAGG
# CATCGGCTGCT -> ATCGGCTGCTG
# CATCTACCAAG -> ATCTACCAAGA
# CATCTCTTAAT -> ATCTCTTAATA
# CATCTGGTATC -> ATCTGGTATCC
# CATGAAAATGA -> ATGAAAATGAT
# CATGAGTAGAA -> ATGAGTAGAAC
# CATGAGTGTCC -> ATGAGTGTCCT
# CATGATCGGTT -> ATGATCGGTTA
# CATGCAACGTC -> ATGCAACGTCT
# CATGCCATGGC -> ATGCCATGGCA,ATGCCATGGCC
# CATGCGGGATA -> ATGCGGGATAG
# CATGGAAAATC -> ATGGAAAATCC
# CATGGATCTAG -> ATGGATCTAGA
# CATGGCATTTG -> ATGGCATTTGT
# CATGGCCGGTT -> ATGGCCGGTTC
# CATGTATATGC -> ATGTATATGCT
# CATGTCACTAG -> ATGTCACTAGA
# CATGTCTTTCT -> ATGTCTTTCTA
# CATTAAATTTA -> ATTAAATTTAG
# CATTAGGGAAT -> ATTAGGGAATA
# CATTCGCTCTC -> ATTCGCTCTCA
# CATTGGCGCAG -> ATTGGCGCAGA
# CATTGGCGTCC -> ATTGGCGTCCC
# CATTGTCTCAG -> ATTGTCTCAGA
# CATTTGTTCGG -> ATTTGTTCGGC
# CCAAATCTCGT -> CAAATCTCGTC
# CCAACATTAGG -> CAACATTAGGG
# CCAACTCGCTA -> CAACTCGCTAG
# CCAACTTTCGG -> CAACTTTCGGG
# CCAAGACTCTT -> CAAGACTCTTT
# CCAAGCGCCGA -> CAAGCGCCGAA
# CCAATCACCAC -> CAATCACCACA
# CCAATTAACCC -> CAATTAACCCT
# CCACAGTAAAA -> CACAGTAAAAA
# CCACAGTACAC -> CACAGTACACC
# CCACATATTTT -> CACATATTTTC
# CCACCCAGTCG -> CACCCAGTCGC
# CCACCGCTAAA -> CACCGCTAAAT
# CCACCTGCTGG -> CACCTGCTGGA
# CCACGCCAGAT -> CACGCCAGATA
# CCACGCGTGAC -> CACGCGTGACT
# CCACGGTACAT -> CACGGTACATT
# CCACGTCTCAG -> CACGTCTCAGC
# CCACTGGTATA -> CACTGGTATAA
# CCAGAACATTG -> CAGAACATTGG
# CCAGAATTTAG -> CAGAATTTAGA
# CCAGAATTTCA -> CAGAATTTCAT
# CCAGACCCGAT -> CAGACCCGATC
# CCAGACTGACC -> CAGACTGACCT
# CCAGAGGGGAC -> CAGAGGGGACC
# CCAGATATTTC -> CAGATATTTCC
# CCAGCAGACCA -> CAGCAGACCAT
# CCAGCCTCGGA -> CAGCCTCGGAG
# CCAGGTAATTC -> CAGGTAATTCT
# CCAGTCGCAAA -> CAGTCGCAAAT
# CCAGTTACAGC -> CAGTTACAGCG
# CCAGTTCTTTG -> CAGTTCTTTGC
# CCATAGTTATA -> CATAGTTATAC
# CCATATCGCTG -> CATATCGCTGG
# CCATCGGCTGC -> CATCGGCTGCT
# CCATCTCTTAA -> CATCTCTTAAT
# CCATGAAAATG -> CATGAAAATGA
# CCATGATCGGT -> CATGATCGGTT
# CCATGGCATTT -> CATGGCATTTG
# CCATGGCCGGT -> CATGGCCGGTT
# CCATGTCTTTC -> CATGTCTTTCT
# CCCAAGCGCCG -> CCAAGCGCCGA
# CCCAATCACCA -> CCAATCACCAC
# CCCACAGTACA -> CCACAGTACAC
# CCCACCGCTAA -> CCACCGCTAAA
# CCCACCTGCTG -> CCACCTGCTGG
# CCCACGCCAGA -> CCACGCCAGAT
# CCCACGCGTGA -> CCACGCGTGAC
# CCCAGACCCGA -> CCAGACCCGAT
# CCCAGCCTCGG -> CCAGCCTCGGA
# CCCAGTCGCAA -> CCAGTCGCAAA
# CCCAGTTCTTT -> CCAGTTCTTTG
# CCCATGTCTTT -> CCATGTCTTTC
# CCCCACAGTAC -> CCCACAGTACA
# CCCCACGCGTG -> CCCACGCGTGA
# CCCCGAGACTA -> CCCGAGACTAC
# CCCCGCAACAG -> CCCGCAACAGG
# CCCGAGACTAC -> CCGAGACTACA
# CCCGATCCTGG -> CCGATCCTGGG
# CCCGCAACAGG -> CCGCAACAGGG
# CCCGCCAACTC -> CCGCCAACTCG
# CCCGCCATCTC -> CCGCCATCTCT
# CCCGGCCCGTG -> CCGGCCCGTGT
# CCCGTGTACGG -> CCGTGTACGGA
# CCCGTTCCACG -> CCGTTCCACGG
# CCCTAACGCAT -> CCTAACGCATT
# CCCTATCGTAT -> CCTATCGTATC
# CCCTCACATGT -> CCTCACATGTC
# CCCTCCCCGCA -> CCTCCCCGCAA
# CCCTGAGTCGC -> CCTGAGTCGCG
# CCCTGCCTTAC -> CCTGCCTTACC
# CCCTTACATTG -> CCTTACATTGG
# CCCTTGTTATA -> CCTTGTTATAT
# CCGAAAACTCA -> CGAAAACTCAT
# CCGACATGGAA -> CGACATGGAAA
# CCGACGGTCAG -> CGACGGTCAGA
# CCGACGTGTCG -> CGACGTGTCGC
# CCGACTCCAGG -> CGACTCCAGGT
# CCGAGACTACA -> CGAGACTACAG
# CCGAGTGGACG -> CGAGTGGACGT
# CCGATCCTGGG -> CGATCCTGGGC
# CCGATCGCCGA -> CGATCGCCGAC
# CCGATTTGCTG -> CGATTTGCTGG
# CCGCAACAGGG -> CGCAACAGGGG
# CCGCAGTGCAC -> CGCAGTGCACG
# CCGCCAACTCG -> CGCCAACTCGC
# CCGCCATCTCT -> CGCCATCTCTT
# CCGCCTCGCAA -> CGCCTCGCAAA
# CCGCGGATTAT -> CGCGGATTATG
# CCGCGTCGGTT -> CGCGTCGGTTC
# CCGCTAAATTG -> CGCTAAATTGT
# CCGGAGAATGA -> CGGAGAATGAG
# CCGGATGAGTT -> CGGATGAGTTC
# CCGGCCCGTGT -> CGGCCCGTGTA
# CCGGGATCCAC -> CGGGATCCACC
# CCGGTCGGCGT -> CGGTCGGCGTT
# CCGGTTCTATT -> CGGTTCTATTT
# CCGTAATCCCA -> CGTAATCCCAC
# CCGTGTACGGA -> CGTGTACGGAG
# CCGTTCCACGG -> CGTTCCACGGT
# CCTAACGCATT -> CTAACGCATTA
# CCTACGTTCCG -> CTACGTTCCGG
# CCTACTCATCG -> CTACTCATCGC
# CCTAGTCGCGG -> CTAGTCGCGGC
# CCTATAATAGG -> CTATAATAGGC
# CCTATCGTATC -> CTATCGTATCG
# CCTCACATGTC -> CTCACATGTCA
# CCTCATCCAGA -> CTCATCCAGAA
# CCTCCCCGCAA -> CTCCCCGCAAC
# CCTCGCAAACT -> CTCGCAAACTT
# CCTCGGAGATG -> CTCGGAGATGC
# CCTCTCGGGCG -> CTCTCGGGCGT
# CCTGAGGACAC -> CTGAGGACACC
# CCTGAGTCGCG -> CTGAGTCGCGA
# CCTGATCAAAC -> CTGATCAAACC
# CCTGCCTTACC -> CTGCCTTACCA
# CCTGCTGGAGA -> CTGCTGGAGAT
# CCTGGGCCACT -> CTGGGCCACTG
# CCTGGGTGATT -> CTGGGTGATTA
# CCTGTTGACAT -> CTGTTGACATC
# CCTTACATTGG -> CTTACATTGGC
# CCTTACCAGCA -> CTTACCAGCAG
# CCTTGCAGCAA -> CTTGCAGCAAC
# CCTTGTTATAT -> CTTGTTATATC
# CCTTTCATGCG -> CTTTCATGCGG
# CCTTTCGCGAT -> CTTTCGCGATT
# CCTTTTGATCA -> CTTTTGATCAT
# CGAAAACAACG -> GAAAACAACGG
# CGAAAACTCAT -> GAAAACTCATG
# CGAAATTACTG -> GAAATTACTGT
# CGAACAACAAC -> GAACAACAACC
# CGAAGCGGGAT -> GAAGCGGGATC
# CGAATAGGGCA -> GAATAGGGCAT
# CGACAGTTTTC -> GACAGTTTTCC
# CGACATGGAAA -> GACATGGAAAA
# CGACCATGAAA -> GACCATGAAAA
# CGACCCCACAG -> GACCCCACAGT
# CGACCCCGAGA -> GACCCCGAGAC
# CGACCTGTTGA -> GACCTGTTGAC
# CGACGGTCAGA -> GACGGTCAGAA
# CGACGTCTTAC -> GACGTCTTACT
# CGACGTGTCGC -> GACGTGTCGCT
# CGACTATAGTA -> GACTATAGTAT
# CGACTCCAGGT -> GACTCCAGGTA
# CGACTGGACAG -> GACTGGACAGC
# CGACTGTGGCT -> GACTGTGGCTT
# CGAGACTACAG -> GAGACTACAGA
# CGAGGAAACTC -> GAGGAAACTCG
# CGAGGCTAACA -> GAGGCTAACAT
# CGAGTCGGGTT -> GAGTCGGGTTT
# CGAGTGGACGT -> GAGTGGACGTG
# CGATCCTGGGC -> GATCCTGGGCC
# CGATCGCCGAC -> GATCGCCGACT
# CGATCTGGCCA -> GATCTGGCCAA
# CGATGTAGCCC -> GATGTAGCCCG
# CGATTCCATCG -> GATTCCATCGG
# CGATTGTCACG -> GATTGTCACGG
# CGATTTAGTGC -> GATTTAGTGCA
# CGATTTGCTGG -> GATTTGCTGGC
# CGCAAACTTGA -> GCAAACTTGAA
# CGCAAATTGAC -> GCAAATTGACC
# CGCAACAGGGG -> GCAACAGGGGA
# CGCAGAGTTAT -> GCAGAGTTATG
# CGCAGTGCACG -> GCAGTGCACGC
# CGCATTAAATT -> GCATTAAATTT
# CGCCAACTCGC -> GCCAACTCGCT
# CGCCAGATATT -> GCCAGATATTT
# CGCCAGTTACA -> GCCAGTTACAG
# CGCCATCTCTT -> GCCATCTCTTA
# CGCCCAGACCC -> GCCCAGACCCG
# CGCCCCACGCG -> GCCCCACGCGT
# CGCCGAAAACT -> GCCGAAAACTC
# CGCCGACTCCA -> GCCGACTCCAG
# CGCCGTAATCC -> GCCGTAATCCC
# CGCCTCGCAAA -> GCCTCGCAAAC
# CGCCTGAGGAC -> GCCTGAGGACA
# CGCGAATAGGG -> GCGAATAGGGC
# CGCGACTATAG -> GCGACTATAGT
# CGCGATTCCAT -> GCGATTCCATC
# CGCGGATTATG -> GCGGATTATGA
# CGCGGCTAGCC -> GCGGCTAGCCG
# CGCGTATGGGG -> GCGTATGGGGG
# CGCGTCAGTCG -> GCGTCAGTCGA
# CGCGTCGGTTC -> GCGTCGGTTCG
# CGCGTGACTTG -> GCGTGACTTGA
# CGCTAAATTGT -> GCTAAATTGTG
# CGCTAGTGATA -> GCTAGTGATAC
# CGCTCGATGTA -> GCTCGATGTAG
# CGCTCTCACCG -> GCTCTCACCGC
# CGCTGAGAGCG -> GCTGAGAGCGA
# CGCTGCGCGTA -> GCTGCGCGTAT
# CGCTGGTGTTA -> GCTGGTGTTAA
# CGCTTACGGCA -> GCTTACGGCAG
# CGCTTCAAGGC -> GCTTCAAGGCA
# CGGAACTTAAC -> GGAACTTAACC
# CGGACAGCGCT -> GGACAGCGCTG
# CGGACTACACA -> GGACTACACAT
# CGGAGAATGAG -> GGAGAATGAGG
# CGGAGATGCAC -> GGAGATGCACA
# CGGAGGTATGC -> GGAGGTATGCG
# CGGATCGCTCG -> GGATCGCTCGA
# CGGATGAGTTC -> GGATGAGTTCC
# CGGATTATGAT -> GGATTATGATT
# CGGCAGGTGCC -> GGCAGGTGCCA
# CGGCAGTTGCT -> GGCAGTTGCTG
# CGGCCCGTGTA -> GGCCCGTGTAC
# CGGCCCTCCCC -> GGCCCTCCCCG
# CGGCGCGACTA -> GGCGCGACTAT
# CGGCGGACTAC -> GGCGGACTACA
# CGGCGGCGGAC -> GGCGGCGGACT
# CGGCGTTGGGG -> GGCGTTGGGGG
# CGGCTAGCCGA -> GGCTAGCCGAC
# CGGCTGCTGGA -> GGCTGCTGGAT
# CGGGAAACGTA -> GGGAAACGTAC
# CGGGAGCATAC -> GGGAGCATACT
# CGGGATAGTCA -> GGGATAGTCAC
# CGGGATCCACC -> GGGATCCACCC
# CGGGATCGACC -> GGGATCGACCA
# CGGGCCACAGT -> GGGCCACAGTA
# CGGGCGTAGTA -> GGGCGTAGTAC
# CGGGCTAAGCG -> GGGCTAAGCGG
# CGGGGTGGCGG -> GGGGTGGCGGT
# CGGGTCGTGAA -> GGGTCGTGAAT
# CGGGTGAACAT -> GGGTGAACATG
# CGGGTGGCTGA -> GGGTGGCTGAG
# CGGGTGTCTCC -> GGGTGTCTCCA
# CGGGTTTGAAA -> GGGTTTGAAAG
# CGGTACATTCG -> GGTACATTCGC
# CGGTATTCGAA -> GGTATTCGAAA
# CGGTCAGAAGA -> GGTCAGAAGAG
# CGGTCGGCGTT -> GGTCGGCGTTG
# CGGTCTATACC -> GGTCTATACCT
# CGGTTATAGGC -> GGTTATAGGCT
# CGGTTCGATTT -> GGTTCGATTTA
# CGGTTCTATTT -> GGTTCTATTTA
# CGGTTGGTTTC -> GGTTGGTTTCG
# CGTAATCCCAC -> GTAATCCCACC
# CGTACAGAAGG -> GTACAGAAGGC
# CGTACTAGTCG -> GTACTAGTCGG
# CGTAGGCCCTA -> GTAGGCCCTAA
# CGTAGTACTCC -> GTAGTACTCCG
# CGTATAAACTT -> GTATAAACTTC
# CGTATCGGGCC -> GTATCGGGCCA
# CGTATGGGGGG -> GTATGGGGGGT
# CGTCAGTCGAC -> GTCAGTCGACC
# CGTCCATATCG -> GTCCATATCGC
# CGTCCCCCGAA -> GTCCCCCGAAC
# CGTCCCTATCG -> GTCCCTATCGT
# CGTCCGCAGTG -> GTCCGCAGTGC
# CGTCGGTTCGA -> GTCGGTTCGAT
# CGTCTCAGCTA -> GTCTCAGCTAC
# CGTCTGGAACC -> GTCTGGAACCG
# CGTCTTACTAA -> GTCTTACTAAG
# CGTCTTGCCAA -> GTCTTGCCAAC
# CGTGAATACCG -> GTGAATACCGA
# CGTGACCCTGA -> GTGACCCTGAG
# CGTGACTTGAT -> GTGACTTGATA
# CGTGCATCTGG -> GTGCATCTGGT
# CGTGTACGGAG -> GTGTACGGAGG
# CGTGTCGCTTC -> GTGTCGCTTCA
# CGTTAAGCCAA -> GTTAAGCCAAC
# CGTTCCACGGT -> GTTCCACGGTA
# CGTTCCGGGAT -> GTTCCGGGATC
# CGTTGGGGGTA -> GTTGGGGGTAC
# CTAAACCTTTT -> TAAACCTTTTG
# CTAAATTGTGA -> TAAATTGTGAA
# CTAACATAACT -> TAACATAACTC
# CTAACCCTCAC -> TAACCCTCACA
# CTAACGCATTA -> TAACGCATTAA
# CTAAGAAACAT -> TAAGAAACATC
# CTAAGCGGGTG -> TAAGCGGGTGT
# CTACACAATTA -> TACACAATTAT
# CTACACATGCC -> TACACATGCCA
# CTACAGATCGT -> TACAGATCGTA
# CTACCAAGACT -> TACCAAGACTC
# CTACGCCCAGA -> TACGCCCAGAC
# CTACGTACAGA -> TACGTACAGAA
# CTACGTTCCGG -> TACGTTCCGGG
# CTACTCATCGC -> TACTCATCGCC
# CTAGAAATGCG -> TAGAAATGCGT
# CTAGATTCATC -> TAGATTCATCA
# CTAGCCGACAT -> TAGCCGACATG
# CTAGCGGCGCG -> TAGCGGCGCGA
# CTAGGCATGGA -> TAGGCATGGAT
# CTAGTCGCGGC -> TAGTCGCGGCT
# CTAGTCGGCAG -> TAGTCGGCAGG
# CTAGTGATACC -> TAGTGATACCT
# CTATAATAGGC -> TATAATAGGCG
# CTATACCTCTC -> TATACCTCTCG
# CTATAGTATTT -> TATAGTATTTA
# CTATCCAGAAT -> TATCCAGAATT
# CTATCCCGTTC -> TATCCCGTTCC
# CTATCGACTGG -> TATCGACTGGA
# CTATCGTATCG -> TATCGTATCGG
# CTATGAAAGCA -> TATGAAAGCAC
# CTATGATTGAT -> TATGATTGATG
# CTATTACCCAA -> TATTACCCAAT
# CTATTTACTAT -> TATTTACTATT
# CTCACATGTCA -> TCACATGTCAC
# CTCACCGCGTC -> TCACCGCGTCG
# CTCAGATCGAA -> TCAGATCGAAA
# CTCAGCTACGC -> TCAGCTACGCC
# CTCATCCAGAA -> TCATCCAGAAC
# CTCATCGCCTG -> TCATCGCCTGA
# CTCATGCAACG -> TCATGCAACGT
# CTCATGTATAT -> TCATGTATATG
# CTCCACGTCTC -> TCCACGTCTCA
# CTCCAGAATTT -> TCCAGAATTTA
# CTCCAGGTAAT -> TCCAGGTAATT
# CTCCCCGCAAC -> TCCCCGCAACA
# CTCCGACGGTC -> TCCGACGGTCA
# CTCCGGAGAAT -> TCCGGAGAATG
# CTCGACCCCAC -> TCGACCCCACA
# CTCGATGTAGC -> TCGATGTAGCC
# CTCGCAAACTT -> TCGCAAACTTG
# CTCGCTAGTGA -> TCGCTAGTGAT
# CTCGGACAGCG -> TCGGACAGCGC
# CTCGGAGATGC -> TCGGAGATGCA
# CTCGGGCGTAG -> TCGGGCGTAGT
# CTCGTCTGGAA -> TCGTCTGGAAC
# CTCTCACCGCG -> TCTCACCGCGT
# CTCTCCGACGG -> TCTCCGACGGT
# CTCTCGGGCGT -> TCTCGGGCGTA
# CTCTTAATAGA -> TCTTAATAGAG
# CTCTTATGGCG -> TCTTATGGCGA
# CTCTTTTGATA -> TCTTTTGATAG
# CTGAACCCTGC -> TGAACCCTGCC
# CTGACCTTTCA -> TGACCTTTCAT
# CTGAGAGCGAG -> TGAGAGCGAGG
# CTGAGGACACC -> TGAGGACACCT
# CTGAGTACCGA -> TGAGTACCGAT
# CTGAGTCGCGA -> TGAGTCGCGAA
# CTGATCAAACC -> TGATCAAACCC
# CTGATCAACTA -> TGATCAACTAT
# CTGCCTTACCA -> TGCCTTACCAG
# CTGCGCGTATG -> TGCGCGTATGG
# CTGCTGGAGAT -> TGCTGGAGATA
# CTGCTGGATGG -> TGCTGGATGGT
# CTGGAACCGCC -> TGGAACCGCCT
# CTGGACAGCGT -> TGGACAGCGTC
# CTGGAGATATT -> TGGAGATATTA
# CTGGATGATCG -> TGGATGATCGT
# CTGGATGGTGC -> TGGATGGTGCC
# CTGGCCAATTA -> TGGCCAATTAA
# CTGGCGATCTG -> TGGCGATCTGG
# CTGGGCCACTG -> TGGGCCACTGG
# CTGGGTGATTA -> TGGGTGATTAG
# CTGGTATAAGA -> TGGTATAAGAG
# CTGGTATCCCA -> TGGTATCCCAC
# CTGGTGTTAAG -> TGGTGTTAAGT
# CTGTAAGCAGG -> TGTAAGCAGGG
# CTGTAAGTTCA -> TGTAAGTTCAG
# CTGTCGGGGTG -> TGTCGGGGTGG
# CTGTGAGTATA -> TGTGAGTATAG
# CTGTGGCTTCC -> TGTGGCTTCCG
# CTGTTGACATC -> TGTTGACATCA
# CTTAACCATAG -> TTAACCATAGT
# CTTAATAGAGC -> TTAATAGAGCT
# CTTACATTGGC -> TTACATTGGCG
# CTTACCAGCAG -> TTACCAGCAGA
# CTTACGGCAGT -> TTACGGCAGTT
# CTTACTAAGAA -> TTACTAAGAAA
# CTTATGGCGAA -> TTATGGCGAAC
# CTTCAAGGCAG -> TTCAAGGCAGA
# CTTCATATCAA -> TTCATATCAAC
# CTTCCGAGTGG -> TTCCGAGTGGA
# CTTCCGATCGC -> TTCCGATCGCC
# CTTGAAACTTT -> TTGAAACTTTA
# CTTGATACCGG -> TTGATACCGGT
# CTTGCAGCAAC -> TTGCAGCAACG
# CTTGCCAACAT -> TTGCCAACATT
# CTTGGCAGGGA -> TTGGCAGGGAC
# CTTGTTATATC -> TTGTTATATCG
# CTTTATCATTG -> TTTATCATTGT
# CTTTCATGCGG -> TTTCATGCGGG
# CTTTCGCGATT -> TTTCGCGATTC
# CTTTCGGGCTA -> TTTCGGGCTAA
# CTTTCTAGCGG -> TTTCTAGCGGC
# CTTTGCGATTG -> TTTGCGATTGT
# CTTTTGATAGA -> TTTTGATAGAC
# CTTTTGATCAT -> TTTTGATCATC
# GAAAACAACGG -> AAAACAACGGG
# GAAAACTCATG -> AAAACTCATGC
# GAAAATCCAAA -> AAAATCCAAAT
# GAAAATGATCG -> AAAATGATCGG
# GAAACATCATC -> AAACATCATCA
# GAAACGTACTA -> AAACGTACTAG
# GAAACTCGACC -> AAACTCGACCC
# GAAACTTTATC -> AAACTTTATCA
# GAAAGCACCTT -> AAAGCACCTTG
# GAAAGTACCCA -> AAAGTACCCAT
# GAAATGCGTCC -> AAATGCGTCCA
# GAAATTACTGT -> AAATTACTGTA
# GAAATTTCGCC -> AAATTTCGCCG
# GAACAACAACC -> AACAACAACCC
# GAACACGTATA -> AACACGTATAA
# GAACATATAGA -> AACATATAGAC
# GAACATGAGTG -> AACATGAGTGT
# GAACATTGGCG -> AACATTGGCGC
# GAACCCTGCCT -> AACCCTGCCTT
# GAACCGCCTCG -> AACCGCCTCGC
# GAACTTAACCA -> AACTTAACCAT
# GAAGAGCCAGA -> AAGAGCCAGAG
# GAAGCGGGATC -> AAGCGGGATCG
# GAAGGCAACAT -> AAGGCAACATG
# GAATACCGACG -> AATACCGACGT
# GAATAGGACGG -> AATAGGACGGC
# GAATAGGGCAT -> AATAGGGCATA
# GAATCTCCAGA -> AATCTCCAGAA
# GAATGAGGATC -> AATGAGGATCT
# GAATTTAGAGT -> AATTTAGAGTT
# GAATTTCATCT -> AATTTCATCTA
# GACAAAATCTG -> ACAAAATCTGA
# GACACCTACGT -> ACACCTACGTT
# GACAGCGCTGC -> ACAGCGCTGCG
# GACAGCGTCCC -> ACAGCGTCCCC
# GACAGTTTTCC -> ACAGTTTTCCT
# GACATCAGTAT -> ACATCAGTATA
# GACATGGAAAA -> ACATGGAAAAT
# GACCATGAAAA -> ACCATGAAAAT
# GACCATGATCG -> ACCATGATCGG
# GACCCAGCCTC -> ACCCAGCCTCG
# GACCCCACAGT -> ACCCCACAGTA
# GACCCCGAGAC -> ACCCCGAGACT
# GACCCGATCCT -> ACCCGATCCTG
# GACCCTGAGTC -> ACCCTGAGTCG
# GACCGGATGAG -> ACCGGATGAGT
# GACCTCATCCA -> ACCTCATCCAG
# GACCTGTTGAC -> ACCTGTTGACA
# GACCTTTCATG -> ACCTTTCATGC
# GACGAGGCTAA -> ACGAGGCTAAC
# GACGGCGGCGG -> ACGGCGGCGGA
# GACGGTCAGAA -> ACGGTCAGAAG
# GACGGTCTATA -> ACGGTCTATAC
# GACGTCTTACT -> ACGTCTTACTA
# GACGTGCATCT -> ACGTGCATCTG
# GACGTGTCGCT -> ACGTGTCGCTT
# GACTACACATG -> ACTACACATGC
# GACTACAGATC -> ACTACAGATCG
# GACTACGTACA -> ACTACGTACAG
# GACTATAGTAT -> ACTATAGTATT
# GACTATCCCGT -> ACTATCCCGTT
# GACTCCAGGTA -> ACTCCAGGTAA
# GACTCTTTTGA -> ACTCTTTTGAT
# GACTGACCTTT -> ACTGACCTTTC
# GACTGGACAGC -> ACTGGACAGCG
# GACTGTGGCTT -> ACTGTGGCTTC
# GACTTGATACC -> ACTTGATACCG
# GAGAATGAGGA -> AGAATGAGGAT
# GAGACTACAGA -> AGACTACAGAT
# GAGACTACGTA -> AGACTACGTAC
# GAGAGCGAGGA -> AGAGCGAGGAA
# GAGATATTACG -> AGATATTACGG
# GAGATGCACAG -> AGATGCACAGG
# GAGCATACTCT -> AGCATACTCTC
# GAGCCAGAGGG -> AGCCAGAGGGG
# GAGCGAGGAAA -> AGCGAGGAAAC
# GAGCTACACAA -> AGCTACACAAT
# GAGCTATCGAC -> AGCTATCGACT
# GAGCTGAACCC -> AGCTGAACCCT
# GAGGAAACTCG -> AGGAAACTCGA
# GAGGACACCTA -> AGGACACCTAC
# GAGGATCTTCC -> AGGATCTTCCG
# GAGGCTAACAT -> AGGCTAACATA
# GAGGGGACCGG -> AGGGGACCGGA
# GAGGTATGCGC -> AGGTATGCGCT
# GAGTACCGATT -> AGTACCGATTT
# GAGTAGAACAT -> AGTAGAACATA
# GAGTATAGGGA -> AGTATAGGGAG
# GAGTCGCGAAT -> AGTCGCGAATA
# GAGTCGGGTTT -> AGTCGGGTTTG
# GAGTGGACGTG -> AGTGGACGTGC
# GAGTGTCCTGG -> AGTGTCCTGGG
# GAGTTATGGCT -> AGTTATGGCTT
# GAGTTCCTACT -> AGTTCCTACTC
# GAGTTCTCTTA -> AGTTCTCTTAT
# GATACCGGTCG -> ATACCGGTCGG
# GATACCTATAA -> ATACCTATAAT
# GATAGACTATC -> ATAGACTATCC
# GATAGTCACTG -> ATAGTCACTGT
# GATATTACGGA -> ATATTACGGAT
# GATATTTCCCA -> ATATTTCCCAA
# GATCAAACCCT -> ATCAAACCCTT
# GATCAACTATG -> ATCAACTATGA
# GATCATCGACC -> ATCATCGACCC
# GATCCACCCAG -> ATCCACCCAGT
# GATCCTGGGCC -> ATCCTGGGCCA
# GATCGAAAACA -> ATCGAAAACAA
# GATCGACCATG -> ATCGACCATGA
# GATCGCCGACT -> ATCGCCGACTC
# GATCGCTCGAT -> ATCGCTCGATG
# GATCGGGTCGT -> ATCGGGTCGTG
# GATCGGTTATA -> ATCGGTTATAG
# GATCGTAGGCC -> ATCGTAGGCCC
# GATCGTTAAGC -> ATCGTTAAGCC
# GATCTAGATTC -> ATCTAGATTCA
# GATCTGGCCAA -> ATCTGGCCAAT
# GATCTTCCGAG -> ATCTTCCGAGT
# GATGAGCTATC -> ATGAGCTATCG
# GATGAGTTCCT -> ATGAGTTCCTA
# GATGATCGTTA -> ATGATCGTTAA
# GATGCACAGGC -> ATGCACAGGCG
# GATGCACGCCC -> ATGCACGCCCC
# GATGGTGCCTG -> ATGGTGCCTGA
# GATGTAGCCCG -> ATGTAGCCCGC
# GATTAGGGGGA -> ATTAGGGGGAC
# GATTATGATTT -> ATTATGATTTA
# GATTCATCACC -> ATTCATCACCC
# GATTCCATCGG -> ATTCCATCGGC
# GATTGATGCAC -> ATTGATGCACG
# GATTGTCACGG -> ATTGTCACGGG
# GATTTAACTGT -> ATTTAACTGTA
# GATTTAGTGCA -> ATTTAGTGCAG
# GATTTGCTGGC -> ATTTGCTGGCG
# GCAAACTTGAA -> CAAACTTGAAA
# GCAAATTGACC -> CAAATTGACCT
# GCAACAGGGGA -> CAACAGGGGAC
# GCAACATGCCA -> CAACATGCCAT
# GCAACGACTGT -> CAACGACTGTG
# GCAACGTCTTG -> CAACGTCTTGC
# GCACAGGCGGT -> CACAGGCGGTT
# GCACCTTGCAG -> CACCTTGCAGC
# GCACGCCAGTT -> CACGCCAGTTA
# GCACGCCCCAC -> CACGCCCCACG
# GCAGACCATGA -> CAGACCATGAT
# GCAGAGTTATG -> CAGAGTTATGG
# GCAGATGAGCT -> CAGATGAGCTA
# GCAGCAACGAC -> CAGCAACGACT
# GCAGCATGAGT -> CAGCATGAGTA
# GCAGGGAAATT -> CAGGGAAATTT
# GCAGGGACGAG -> CAGGGACGAGG
# GCAGGTGCCAG -> CAGGTGCCAGA
# GCAGTGCACGC -> CAGTGCACGCC
# GCAGTTGCTGG -> CAGTTGCTGGA
# GCAGTTGTCCT -> CAGTTGTCCTT
# GCATACAGGCT -> CATACAGGCTA
# GCATACTCTCC -> CATACTCTCCG
# GCATCTGGTAT -> CATCTGGTATC
# GCATGAGTAGA -> CATGAGTAGAA
# GCATGGATCTA -> CATGGATCTAG
# GCATTAAATTT -> CATTAAATTTA
# GCATTTGTTCG -> CATTTGTTCGG
# GCCAACATTAG -> CCAACATTAGG
# GCCAACTCGCT -> CCAACTCGCTA
# GCCAACTTTCG -> CCAACTTTCGG
# GCCAATTAACC -> CCAATTAACCC
# GCCACAGTAAA -> CCACAGTAAAA
# GCCACTGGTAT -> CCACTGGTATA
# GCCAGACTGAC -> CCAGACTGACC
# GCCAGAGGGGA -> CCAGAGGGGAC
# GCCAGATATTT -> CCAGATATTTC
# GCCAGTTACAG -> CCAGTTACAGC
# GCCATCTCTTA -> CCATCTCTTAA
# GCCATGGCATT -> CCATGGCATTT
# GCCATGGCCGG -> CCATGGCCGGT
# GCCCAGACCCG -> CCCAGACCCGA
# GCCCCACGCGT -> CCCCACGCGTG
# GCCCGCCATCT -> CCCGCCATCTC
# GCCCGTGTACG -> CCCGTGTACGG
# GCCCTAACGCA -> CCCTAACGCAT
# GCCCTCCCCGC -> CCCTCCCCGCA
# GCCGAAAACTC -> CCGAAAACTCA
# GCCGACATGGA -> CCGACATGGAA
# GCCGACTCCAG -> CCGACTCCAGG
# GCCGGTTCTAT -> CCGGTTCTATT
# GCCGTAATCCC -> CCGTAATCCCA
# GCCTCGCAAAC -> CCTCGCAAACT
# GCCTCGGAGAT -> CCTCGGAGATG
# GCCTGAGGACA -> CCTGAGGACAC
# GCCTGATCAAA -> CCTGATCAAAC
# GCCTTACCAGC -> CCTTACCAGCA
# GCGAACAACAA -> CGAACAACAAC
# GCGAATAGGGC -> CGAATAGGGCA
# GCGACTATAGT -> CGACTATAGTA
# GCGAGGAAACT -> CGAGGAAACTC
# GCGATCTGGCC -> CGATCTGGCCA
# GCGATTCCATC -> CGATTCCATCG
# GCGATTGTCAC -> CGATTGTCACG
# GCGCAGAGTTA -> CGCAGAGTTAT
# GCGCCGAAAAC -> CGCCGAAAACT
# GCGCGACTATA -> CGCGACTATAG
# GCGCGTATGGG -> CGCGTATGGGG
# GCGCTGAGAGC -> CGCTGAGAGCG
# GCGCTGCGCGT -> CGCTGCGCGTA
# GCGCTTACGGC -> CGCTTACGGCA
# GCGGAACTTAA -> CGGAACTTAAC
# GCGGACTACAC -> CGGACTACACA
# GCGGATTATGA -> CGGATTATGAT
# GCGGCGCGACT -> CGGCGCGACTA
# GCGGCGGACTA -> CGGCGGACTAC
# GCGGCTAGCCG -> CGGCTAGCCGA
# GCGGGATAGTC -> CGGGATAGTCA
# GCGGGATCGAC -> CGGGATCGACC
# GCGGGTGAACA -> CGGGTGAACAT
# GCGGGTGGCTG -> CGGGTGGCTGA
# GCGGGTGTCTC -> CGGGTGTCTCC
# GCGGTATTCGA -> CGGTATTCGAA
# GCGGTTGGTTT -> CGGTTGGTTTC
# GCGTAGTACTC -> CGTAGTACTCC
# GCGTATGGGGG -> CGTATGGGGGG
# GCGTCAGTCGA -> CGTCAGTCGAC
# GCGTCCATATC -> CGTCCATATCG
# GCGTCCCCCGA -> CGTCCCCCGAA
# GCGTCCCTATC -> CGTCCCTATCG
# GCGTCGGTTCG -> CGTCGGTTCGA
# GCGTGACTTGA -> CGTGACTTGAT
# GCGTTGGGGGT -> CGTTGGGGGTA
# GCTAAATTGTG -> CTAAATTGTGA
# GCTAACATAAC -> CTAACATAACT
# GCTAACCCTCA -> CTAACCCTCAC
# GCTAAGCGGGT -> CTAAGCGGGTG
# GCTACACAATT -> CTACACAATTA
# GCTACGCCCAG -> CTACGCCCAGA
# GCTAGCCGACA -> CTAGCCGACAT
# GCTAGGCATGG -> CTAGGCATGGA
# GCTAGTGATAC -> CTAGTGATACC
# GCTATCGACTG -> CTATCGACTGG
# GCTATGATTGA -> CTATGATTGAT
# GCTCGATGTAG -> CTCGATGTAGC
# GCTCTCACCGC -> CTCTCACCGCG
# GCTGAACCCTG -> CTGAACCCTGC
# GCTGAGAGCGA -> CTGAGAGCGAG
# GCTGAGTACCG -> CTGAGTACCGA
# GCTGCGCGTAT -> CTGCGCGTATG
# GCTGCTGGATG -> CTGCTGGATGG
# GCTGGAGATAT -> CTGGAGATATT
# GCTGGATGATC -> CTGGATGATCG
# GCTGGATGGTG -> CTGGATGGTGC
# GCTGGCGATCT -> CTGGCGATCTG
# GCTGGTGTTAA -> CTGGTGTTAAG
# GCTTACGGCAG -> CTTACGGCAGT
# GCTTCAAGGCA -> CTTCAAGGCAG
# GCTTCCGATCG -> CTTCCGATCGC
# GCTTGGCAGGG -> CTTGGCAGGGA
# GGAAAATCCAA -> GAAAATCCAAA
# GGAAACGTACT -> GAAACGTACTA
# GGAAACTCGAC -> GAAACTCGACC
# GGAAATTTCGC -> GAAATTTCGCC
# GGAACCGCCTC -> GAACCGCCTCG
# GGAACTTAACC -> GAACTTAACCA
# GGAATAGGACG -> GAATAGGACGG
# GGACAAAATCT -> GACAAAATCTG
# GGACACCTACG -> GACACCTACGT
# GGACAGCGCTG -> GACAGCGCTGC
# GGACAGCGTCC -> GACAGCGTCCC
# GGACCCAGCCT -> GACCCAGCCTC
# GGACCGGATGA -> GACCGGATGAG
# GGACGAGGCTA -> GACGAGGCTAA
# GGACGGCGGCG -> GACGGCGGCGG
# GGACGTGCATC -> GACGTGCATCT
# GGACTACACAT -> GACTACACATG
# GGAGAATGAGG -> GAGAATGAGGA
# GGAGACTACGT -> GAGACTACGTA
# GGAGATATTAC -> GAGATATTACG
# GGAGATGCACA -> GAGATGCACAG
# GGAGCATACTC -> GAGCATACTCT
# GGAGGTATGCG -> GAGGTATGCGC
# GGATAGTCACT -> GATAGTCACTG
# GGATCCACCCA -> GATCCACCCAG
# GGATCGACCAT -> GATCGACCATG
# GGATCGCTCGA -> GATCGCTCGAT
# GGATCTAGATT -> GATCTAGATTC
# GGATCTTCCGA -> GATCTTCCGAG
# GGATGAGTTCC -> GATGAGTTCCT
# GGATGATCGTT -> GATGATCGTTA
# GGATGGTGCCT -> GATGGTGCCTG
# GGATTATGATT -> GATTATGATTT
# GGCAACATGCC -> GCAACATGCCA
# GGCAGATGAGC -> GCAGATGAGCT
# GGCAGGGACGA -> GCAGGGACGAG
# GGCAGGTGCCA -> GCAGGTGCCAG
# GGCAGTTGCTG -> GCAGTTGCTGG
# GGCATACAGGC -> GCATACAGGCT
# GGCATGGATCT -> GCATGGATCTA
# GGCATTTGTTC -> GCATTTGTTCG
# GGCCAATTAAC -> GCCAATTAACC
# GGCCACAGTAA -> GCCACAGTAAA
# GGCCACTGGTA -> GCCACTGGTAT
# GGCCCGTGTAC -> GCCCGTGTACG
# GGCCCTAACGC -> GCCCTAACGCA
# GGCCCTCCCCG -> GCCCTCCCCGC
# GGCCGGTTCTA -> GCCGGTTCTAT
# GGCGAACAACA -> GCGAACAACAA
# GGCGATCTGGC -> GCGATCTGGCC
# GGCGCAGAGTT -> GCGCAGAGTTA
# GGCGCGACTAT -> GCGCGACTATA
# GGCGCTTACGG -> GCGCTTACGGC
# GGCGGAACTTA -> GCGGAACTTAA
# GGCGGACTACA -> GCGGACTACAC
# GGCGGCGGACT -> GCGGCGGACTA
# GGCGGTATTCG -> GCGGTATTCGA
# GGCGGTTGGTT -> GCGGTTGGTTT
# GGCGTAGTACT -> GCGTAGTACTC
# GGCGTCCCTAT -> GCGTCCCTATC
# GGCGTTGGGGG -> GCGTTGGGGGT
# GGCTAACATAA -> GCTAACATAAC
# GGCTAACCCTC -> GCTAACCCTCA
# GGCTAAGCGGG -> GCTAAGCGGGT
# GGCTAGCCGAC -> GCTAGCCGACA
# GGCTAGGCATG -> GCTAGGCATGG
# GGCTGAGTACC -> GCTGAGTACCG
# GGCTGCTGGAT -> GCTGCTGGATG
# GGCTTCCGATC -> GCTTCCGATCG
# GGCTTGGCAGG -> GCTTGGCAGGG
# GGGAAACGTAC -> GGAAACGTACT
# GGGAAATTTCG -> GGAAATTTCGC
# GGGAATAGGAC -> GGAATAGGACG
# GGGACAAAATC -> GGACAAAATCT
# GGGACCCAGCC -> GGACCCAGCCT
# GGGACCGGATG -> GGACCGGATGA
# GGGACGAGGCT -> GGACGAGGCTA
# GGGAGACTACG -> GGAGACTACGT
# GGGAGCATACT -> GGAGCATACTC
# GGGATAGTCAC -> GGATAGTCACT
# GGGATCCACCC -> GGATCCACCCA
# GGGATCGACCA -> GGATCGACCAT
# GGGCATACAGG -> GGCATACAGGC
# GGGCCACAGTA -> GGCCACAGTAA
# GGGCCACTGGT -> GGCCACTGGTA
# GGGCGTAGTAC -> GGCGTAGTACT
# GGGCTAAGCGG -> GGCTAAGCGGG
# GGGGACAAAAT -> GGGACAAAATC
# GGGGACCCAGC -> GGGACCCAGCC
# GGGGACCGGAT -> GGGACCGGATG
# GGGGGACAAAA -> GGGGACAAAAT
# GGGGGGTACGA -> GGGGGTACGAC
# GGGGGTACCCA -> GGGGTACCCAG
# GGGGGTACGAC -> GGGGTACGACA
# GGGGTACCCAG -> GGGTACCCAGT
# GGGGTACGACA -> GGGTACGACAG
# GGGGTGGCGGT -> GGGTGGCGGTA
# GGGTACCCAGT -> GGTACCCAGTT
# GGGTACGACAG -> GGTACGACAGT
# GGGTCGTGAAT -> GGTCGTGAATA
# GGGTGAACATG -> GGTGAACATGA
# GGGTGATTAGG -> GGTGATTAGGG
# GGGTGGCGGTA -> GGTGGCGGTAT
# GGGTGGCTGAG -> GGTGGCTGAGT
# GGGTGTCTCCA -> GGTGTCTCCAC
# GGGTTTGAAAG -> GGTTTGAAAGT
# GGTAATTCTCA -> GTAATTCTCAT
# GGTACATTCGC -> GTACATTCGCT
# GGTACCCAGTT -> GTACCCAGTTC
# GGTACGACAGT -> GTACGACAGTT
# GGTATAAGAGC -> GTATAAGAGCT
# GGTATCCCACG -> GTATCCCACGC
# GGTATGCGCTG -> GTATGCGCTGA
# GGTATTCGAAA -> GTATTCGAAAT
# GGTCAGAAGAG -> GTCAGAAGAGC
# GGTCGGCGTTG -> GTCGGCGTTGG
# GGTCGTGAATA -> GTCGTGAATAC
# GGTCTATACCT -> GTCTATACCTC
# GGTGAACATGA -> GTGAACATGAG
# GGTGATTAGGG -> GTGATTAGGGG
# GGTGCCAGACT -> GTGCCAGACTG
# GGTGCCTGATC -> GTGCCTGATCA
# GGTGGCGGTAT -> GTGGCGGTATT
# GGTGGCTGAGT -> GTGGCTGAGTA
# GGTGTCTCCAC -> GTGTCTCCACG
# GGTGTTAAGTA -> GTGTTAAGTAC
# GGTTATAGGCT -> GTTATAGGCTA
# GGTTCGATTTA -> GTTCGATTTAG
# GGTTCTATTTA -> GTTCTATTTAC
# GGTTGGTTTCG -> GTTGGTTTCGA
# GGTTTCGACGT -> GTTTCGACGTC
# GGTTTGAAAGT -> GTTTGAAAGTA
# GTAAAAAATAG -> TAAAAAATAGA
# GTAAGCAGGGA -> TAAGCAGGGAA
# GTAAGTTCAGT -> TAAGTTCAGTA
# GTAATCCCACC -> TAATCCCACCG
# GTAATTCTCAT -> TAATTCTCATG
# GTACACCGCGG -> TACACCGCGGA
# GTACAGAAGGC -> TACAGAAGGCA
# GTACATTCGCT -> TACATTCGCTC
# GTACCCAGTTC -> TACCCAGTTCT
# GTACCCATGTC -> TACCCATGTCT
# GTACCGATTTG -> TACCGATTTGC
# GTACGACAGTT -> TACGACAGTTT
# GTACGGAGGTA -> TACGGAGGTAT
# GTACGTCCGCA -> TACGTCCGCAG
# GTACTAAACCT -> TACTAAACCTT
# GTACTAGTCGG -> TACTAGTCGGC
# GTACTCCGGAG -> TACTCCGGAGA
# GTAGAACATAT -> TAGAACATATA
# GTAGCCCGCCA -> TAGCCCGCCAT
# GTAGGCCCTAA -> TAGGCCCTAAC
# GTAGTACTCCG -> TAGTACTCCGG
# GTATAAACTTC -> TATAAACTTCA
# GTATAAGAGCT -> TATAAGAGCTA
# GTATAAGCGGG -> TATAAGCGGGT
# GTATAGGGAGA -> TATAGGGAGAC
# GTATATGCTAT -> TATATGCTATG
# GTATCCCACGC -> TATCCCACGCC
# GTATCGGGCCA -> TATCGGGCCAC
# GTATGCGCTGA -> TATGCGCTGAG
# GTATGGGGGGT -> TATGGGGGGTA
# GTATTCGAAAT -> TATTCGAAATT
# GTATTTACGTG -> TATTTACGTGA
# GTCACGGGAGC -> TCACGGGAGCA
# GTCACTAGAAA -> TCACTAGAAAT
# GTCACTGTCGG -> TCACTGTCGGG
# GTCAGAAGAGC -> TCAGAAGAGCC
# GTCAGTCGACC -> TCAGTCGACCT
# GTCCATATCGC -> TCCATATCGCT
# GTCCCCCGAAC -> TCCCCCGAACT
# GTCCCTATCGT -> TCCCTATCGTA
# GTCCGCAGTGC -> TCCGCAGTGCA
# GTCCTGGGTGA -> TCCTGGGTGAT
# GTCCTTTCGCG -> TCCTTTCGCGA
# GTCGACCTGTT -> TCGACCTGTTG
# GTCGCAAATTG -> TCGCAAATTGA
# GTCGCGAATAG -> TCGCGAATAGG
# GTCGCGGCTAG -> TCGCGGCTAGC
# GTCGCTTCAAG -> TCGCTTCAAGG
# GTCGGCAGGTG -> TCGGCAGGTGC
# GTCGGCGTTGG -> TCGGCGTTGGG
# GTCGGGGTGGC -> TCGGGGTGGCG
# GTCGGGTTTGA -> TCGGGTTTGAA
# GTCGGTTCGAT -> TCGGTTCGATT
# GTCGTGAATAC -> TCGTGAATACC
# GTCTATACCTC -> TCTATACCTCT
# GTCTCAGATCG -> TCTCAGATCGA
# GTCTCAGCTAC -> TCTCAGCTACG
# GTCTCCACGTC -> TCTCCACGTCT
# GTCTGGAACCG -> TCTGGAACCGC
# GTCTTACTAAG -> TCTTACTAAGA
# GTCTTGCCAAC -> TCTTGCCAACA
# GTCTTTCTAGC -> TCTTTCTAGCG
# GTGAACATGAG -> TGAACATGAGT
# GTGAATACCGA -> TGAATACCGAC
# GTGAATCTCCA -> TGAATCTCCAG
# GTGACCCTGAG -> TGACCCTGAGT
# GTGACTTGATA -> TGACTTGATAC
# GTGAGTATAGG -> TGAGTATAGGG
# GTGATACCTAT -> TGATACCTATA
# GTGATTAGGGG -> TGATTAGGGGG
# GTGCACGCCAG -> TGCACGCCAGT
# GTGCAGCATGA -> TGCAGCATGAG
# GTGCATCTGGT -> TGCATCTGGTA
# GTGCCAGACTG -> TGCCAGACTGA
# GTGCCTGATCA -> TGCCTGATCAA
# GTGGACGTGCA -> TGGACGTGCAT
# GTGGCGGTATT -> TGGCGGTATTC
# GTGGCTGAGTA -> TGGCTGAGTAC
# GTGGCTTCCGA -> TGGCTTCCGAT
# GTGTACGGAGG -> TGTACGGAGGT
# GTGTCCTGGGT -> TGTCCTGGGTG
# GTGTCGCTTCA -> TGTCGCTTCAA
# GTGTCTCCACG -> TGTCTCCACGT
# GTGTTAAGTAC -> TGTTAAGTACG
# GTTAAGCCAAC -> TTAAGCCAACT
# GTTAAGTACGT -> TTAAGTACGTC
# GTTACAGCGGG -> TTACAGCGGGT
# GTTATACCCGG -> TTATACCCGGC
# GTTATAGGCTA -> TTATAGGCTAG
# GTTATATCGAA -> TTATATCGAAG
# GTTATGGCTTG -> TTATGGCTTGG
# GTTCAGTACTA -> TTCAGTACTAA
# GTTCCACGGTA -> TTCCACGGTAC
# GTTCCGGGATC -> TTCCGGGATCC
# GTTCCTACTCA -> TTCCTACTCAT
# GTTCGATTTAG -> TTCGATTTAGT
# GTTCGGCCCTC -> TTCGGCCCTCC
# GTTCTATTTAC -> TTCTATTTACT
# GTTCTCTTATG -> TTCTCTTATGG
# GTTCTTTGCGA -> TTCTTTGCGAT
# GTTGACATCAG -> TTGACATCAGT
# GTTGCTGGATG -> TTGCTGGATGA
# GTTGGGGGTAC -> TTGGGGGTACC
# GTTGGTTTCGA -> TTGGTTTCGAC
# GTTGTCCTTTC -> TTGTCCTTTCG
# GTTTCGACGTC -> TTTCGACGTCT
# GTTTGAAAGTA -> TTTGAAAGTAC
# GTTTTCCTAGT -> TTTTCCTAGTC
# TAAAAAATAGA -> AAAAAATAGAA
# TAAACCTTTTG -> AAACCTTTTGA
# TAAACTTCATA -> AAACTTCATAT
# TAAATTGTGAA -> AAATTGTGAAT
# TAAATTTAGCA -> AAATTTAGCAG
# TAACATAACTC -> AACATAACTCG
# TAACCATAGTT -> AACCATAGTTA
# TAACCCTCACA -> AACCCTCACAT
# TAACCCTTACA -> AACCCTTACAT
# TAACGCATTAA -> AACGCATTAAA
# TAACTCGGACA -> AACTCGGACAG
# TAACTGTAAGT -> AACTGTAAGTT
# TAAGAAACATC -> AAGAAACATCA
# TAAGAGCTACA -> AAGAGCTACAC
# TAAGCAGGGAA -> AAGCAGGGAAA
# TAAGCCAACTT -> AAGCCAACTTT
# TAAGCGGGTGA -> AAGCGGGTGAA
# TAAGCGGGTGT -> AAGCGGGTGTC
# TAAGTACGTCC -> AAGTACGTCCG
# TAAGTTCAGTA -> AAGTTCAGTAC
# TAATAGAGCTG -> AATAGAGCTGA
# TAATAGGCGCT -> AATAGGCGCTT
# TAATCCCACCG -> AATCCCACCGC
# TAATTCTCATG -> AATTCTCATGT
# TACACAATTAT -> ACACAATTATC
# TACACATGCCA -> ACACATGCCAT
# TACACCGCGGA -> ACACCGCGGAT
# TACAGAAGGCA -> ACAGAAGGCAA
# TACAGATCGTA -> ACAGATCGTAG
# TACAGCGGGTG -> ACAGCGGGTGG
# TACAGGCTAAC -> ACAGGCTAACC
# TACATTCGCTC -> ACATTCGCTCT
# TACATTGGCGT -> ACATTGGCGTC
# TACCAAGACTC -> ACCAAGACTCT
# TACCAGCAGAC -> ACCAGCAGACC
# TACCCAATCAC -> ACCCAATCACC
# TACCCAGTTCT -> ACCCAGTTCTT
# TACCCATGTCT -> ACCCATGTCTT
# TACCCGGCCCG -> ACCCGGCCCGT
# TACCGACGTGT -> ACCGACGTGTC
# TACCGATTTGC -> ACCGATTTGCT
# TACCGGTCGGC -> ACCGGTCGGCG
# TACCTATAATA -> ACCTATAATAG
# TACCTCTCGGG -> ACCTCTCGGGC
# TACGACAGTTT -> ACGACAGTTTT
# TACGCCCAGAC -> ACGCCCAGACC
# TACGGAGGTAT -> ACGGAGGTATG
# TACGGATCGCT -> ACGGATCGCTC
# TACGGCAGTTG -> ACGGCAGTTGC
# TACGTACAGAA -> ACGTACAGAAG
# TACGTCCGCAG -> ACGTCCGCAGT
# TACGTGACCCT -> ACGTGACCCTG
# TACGTTCCGGG -> ACGTTCCGGGA
# TACTAAACCTT -> ACTAAACCTTT
# TACTAAGAAAC -> ACTAAGAAACA
# TACTAGTCGGC -> ACTAGTCGGCA
# TACTATTACCC -> ACTATTACCCA
# TACTCATCGCC -> ACTCATCGCCT
# TACTCCGGAGA -> ACTCCGGAGAA
# TACTCTCCGAC -> ACTCTCCGACG
# TACTGTAAGCA -> ACTGTAAGCAG
# TAGAAATGCGT -> AGAAATGCGTC
# TAGAACACGTA -> AGAACACGTAT
# TAGAACATATA -> AGAACATATAG
# TAGACGGTCTA -> AGACGGTCTAT
# TAGACTATCCC -> AGACTATCCCG
# TAGAGCTGAAC -> AGAGCTGAACC
# TAGAGTTCTCT -> AGAGTTCTCTT
# TAGATTCATCA -> AGATTCATCAC
# TAGCAGTTGTC -> AGCAGTTGTCC
# TAGCCCGCCAT -> AGCCCGCCATC
# TAGCCGACATG -> AGCCGACATGG
# TAGCGGCGCGA -> AGCGGCGCGAC
# TAGGACGGCGG -> AGGACGGCGGC
# TAGGCATGGAT -> AGGCATGGATC
# TAGGCCCTAAC -> AGGCCCTAACG
# TAGGCGCTTAC -> AGGCGCTTACG
# TAGGCTAGGCA -> AGGCTAGGCAT
# TAGGGAATAGG -> AGGGAATAGGA
# TAGGGAGACTA -> AGGGAGACTAC
# TAGGGCATACA -> AGGGCATACAG
# TAGGGGGACAA -> AGGGGGACAAA
# TAGTACTCCGG -> AGTACTCCGGA
# TAGTATTTACG -> AGTATTTACGT
# TAGTCACTGTC -> AGTCACTGTCG
# TAGTCGCGGCT -> AGTCGCGGCTA
# TAGTCGGCAGG -> AGTCGGCAGGT
# TAGTGATACCT -> AGTGATACCTA
# TAGTGCAGCAT -> AGTGCAGCATG
# TAGTTATACCC -> AGTTATACCCG
# TATAAACTTCA -> ATAAACTTCAT
# TATAAGAGCTA -> ATAAGAGCTAC
# TATAAGCGGGT -> ATAAGCGGGTG
# TATAATAGGCG -> ATAATAGGCGC
# TATACCCGGCC -> ATACCCGGCCC
# TATACCTCTCG -> ATACCTCTCGG
# TATAGACGGTC -> ATAGACGGTCT
# TATAGGCTAGG -> ATAGGCTAGGC
# TATAGGGAGAC -> ATAGGGAGACT
# TATAGTATTTA -> ATAGTATTTAC
# TATATCGAAGC -> ATATCGAAGCG
# TATATGCTATG -> ATATGCTATGA
# TATCAACGCGT -> ATCAACGCGTC
# TATCATTGTCT -> ATCATTGTCTC
# TATCCAGAATT -> ATCCAGAATTT
# TATCCCACGCC -> ATCCCACGCCA
# TATCCCGTTCC -> ATCCCGTTCCA
# TATCGAAGCGG -> ATCGAAGCGGG
# TATCGACTGGA -> ATCGACTGGAC
# TATCGCTGGTG -> ATCGCTGGTGT
# TATCGGGCCAC -> ATCGGGCCACA
# TATCGTATCGG -> ATCGTATCGGG
# TATCTGTGAGT -> ATCTGTGAGTA
# TATGAAAGCAC -> ATGAAAGCACC
# TATGATTGATG -> ATGATTGATGC
# TATGATTTAAC -> ATGATTTAACT
# TATGCGCTGAG -> ATGCGCTGAGA
# TATGCTATGAT -> ATGCTATGATT
# TATGGCGAACA -> ATGGCGAACAA
# TATGGCTTGGC -> ATGGCTTGGCA
# TATGGGGGGTA -> ATGGGGGGTAC
# TATTACCCAAT -> ATTACCCAATC
# TATTACGGATC -> ATTACGGATCG
# TATTCGAAATT -> ATTCGAAATTA
# TATTTACGTGA -> ATTTACGTGAC
# TATTTACTATT -> ATTTACTATTA
# TATTTCCCAAG -> ATTTCCCAAGC
# TATTTTCAAGG -> ATTTTCAAGGC
# TCAAACCCTTG -> CAAACCCTTGT
# TCAACGCGTCA -> CAACGCGTCAG
# TCAACTATGAA -> CAACTATGAAA
# TCAAGGCAGAT -> CAAGGCAGATG
# TCAAGGCGGAA -> CAAGGCGGAAC
# TCACATGTCAC -> CACATGTCACT
# TCACCACATAT -> CACCACATATT
# TCACCCGCCAA -> CACCCGCCAAC
# TCACCGCGTCG -> CACCGCGTCGG
# TCACGAGTCGG -> CACGAGTCGGG
# TCACGGGAGCA -> CACGGGAGCAT
# TCACTAGAAAT -> CACTAGAAATG
# TCACTGTCGGG -> CACTGTCGGGG
# TCAGAAGAGCC -> CAGAAGAGCCA
# TCAGATCGAAA -> CAGATCGAAAA
# TCAGCTACGCC -> CAGCTACGCCC
# TCAGTACTAAA -> CAGTACTAAAC
# TCAGTATAAGC -> CAGTATAAGCG
# TCAGTCGACCT -> CAGTCGACCTG
# TCATATCAACG -> CATATCAACGC
# TCATCACCCGC -> CATCACCCGCC
# TCATCACGAGT -> CATCACGAGTC
# TCATCCAGAAC -> CATCCAGAACA
# TCATCGACCCC -> CATCGACCCCG
# TCATCGCCTGA -> CATCGCCTGAG
# TCATCTACCAA -> CATCTACCAAG
# TCATGCAACGT -> CATGCAACGTC
# TCATGCGGGAT -> CATGCGGGATA
# TCATGTATATG -> CATGTATATGC
# TCATTGTCTCA -> CATTGTCTCAG
# TCCAAATCTCG -> CCAAATCTCGT
# TCCACCCAGTC -> CCACCCAGTCG
# TCCACGGTACA -> CCACGGTACAT
# TCCACGTCTCA -> CCACGTCTCAG
# TCCAGAACATT -> CCAGAACATTG
# TCCAGAATTTA -> CCAGAATTTAG
# TCCAGAATTTC -> CCAGAATTTCA
# TCCAGGTAATT -> CCAGGTAATTC
# TCCATATCGCT -> CCATATCGCTG
# TCCATCGGCTG -> CCATCGGCTGC
# TCCCAAGCGCC -> CCCAAGCGCCG
# TCCCACCGCTA -> CCCACCGCTAA
# TCCCACGCCAG -> CCCACGCCAGA
# TCCCCGCAACA -> CCCCGCAACAG
# TCCCGTTCCAC -> CCCGTTCCACG
# TCCCTATCGTA -> CCCTATCGTAT
# TCCGACGGTCA -> CCGACGGTCAG
# TCCGAGTGGAC -> CCGAGTGGACG
# TCCGATCGCCG -> CCGATCGCCGA
# TCCGCAGTGCA -> CCGCAGTGCAC
# TCCGGAGAATG -> CCGGAGAATGA
# TCCGGGATCCA -> CCGGGATCCAC
# TCCTACTCATC -> CCTACTCATCG
# TCCTAGTCGCG -> CCTAGTCGCGG
# TCCTGGGCCAC -> CCTGGGCCACT
# TCCTGGGTGAT -> CCTGGGTGATT
# TCCTTTCGCGA -> CCTTTCGCGAT
# TCGAAAACAAC -> CGAAAACAACG
# TCGAAATTACT -> CGAAATTACTG
# TCGAAGCGGGA -> CGAAGCGGGAT
# TCGACCATGAA -> CGACCATGAAA
# TCGACCCCACA -> CGACCCCACAG
# TCGACCCCGAG -> CGACCCCGAGA
# TCGACCTGTTG -> CGACCTGTTGA
# TCGACGTCTTA -> CGACGTCTTAC
# TCGACTGGACA -> CGACTGGACAG
# TCGATGTAGCC -> CGATGTAGCCC
# TCGATTTAGTG -> CGATTTAGTGC
# TCGCAAACTTG -> CGCAAACTTGA
# TCGCAAATTGA -> CGCAAATTGAC
# TCGCCGACTCC -> CGCCGACTCCA
# TCGCCGTAATC -> CGCCGTAATCC
# TCGCCTGAGGA -> CGCCTGAGGAC
# TCGCGAATAGG -> CGCGAATAGGG
# TCGCGATTCCA -> CGCGATTCCAT
# TCGCGGCTAGC -> CGCGGCTAGCC
# TCGCTAGTGAT -> CGCTAGTGATA
# TCGCTCGATGT -> CGCTCGATGTA
# TCGCTCTCACC -> CGCTCTCACCG
# TCGCTGGTGTT -> CGCTGGTGTTA
# TCGCTTCAAGG -> CGCTTCAAGGC
# TCGGACAGCGC -> CGGACAGCGCT
# TCGGAGATGCA -> CGGAGATGCAC
# TCGGCAGGTGC -> CGGCAGGTGCC
# TCGGCCCTCCC -> CGGCCCTCCCC
# TCGGCGTTGGG -> CGGCGTTGGGG
# TCGGCTGCTGG -> CGGCTGCTGGA
# TCGGGCCACAG -> CGGGCCACAGT
# TCGGGCGTAGT -> CGGGCGTAGTA
# TCGGGCTAAGC -> CGGGCTAAGCG
# TCGGGGTGGCG -> CGGGGTGGCGG
# TCGGGTCGTGA -> CGGGTCGTGAA
# TCGGGTTTGAA -> CGGGTTTGAAA
# TCGGTTATAGG -> CGGTTATAGGC
# TCGGTTCGATT -> CGGTTCGATTT
# TCGTAGGCCCT -> CGTAGGCCCTA
# TCGTATCGGGC -> CGTATCGGGCC
# TCGTCTGGAAC -> CGTCTGGAACC
# TCGTGAATACC -> CGTGAATACCG
# TCGTTAAGCCA -> CGTTAAGCCAA
# TCTACCAAGAC -> CTACCAAGACT
# TCTAGATTCAT -> CTAGATTCATC
# TCTAGCGGCGC -> CTAGCGGCGCG
# TCTATACCTCT -> CTATACCTCTC
# TCTATCCAGAA -> CTATCCAGAAT
# TCTATTTACTA -> CTATTTACTAT
# TCTCACCGCGT -> CTCACCGCGTC
# TCTCAGATCGA -> CTCAGATCGAA
# TCTCAGCTACG -> CTCAGCTACGC
# TCTCATGTATA -> CTCATGTATAT
# TCTCCACGTCT -> CTCCACGTCTC
# TCTCCAGAATT -> CTCCAGAATTT
# TCTCCGACGGT -> CTCCGACGGTC
# TCTCGGGCGTA -> CTCGGGCGTAG
# TCTCGTCTGGA -> CTCGTCTGGAA
# TCTCTTAATAG -> CTCTTAATAGA
# TCTCTTATGGC -> CTCTTATGGCG
# TCTGATCAACT -> CTGATCAACTA
# TCTGGAACCGC -> CTGGAACCGCC
# TCTGGCCAATT -> CTGGCCAATTA
# TCTGGTATCCC -> CTGGTATCCCA
# TCTGTGAGTAT -> CTGTGAGTATA
# TCTTAATAGAG -> CTTAATAGAGC
# TCTTACTAAGA -> CTTACTAAGAA
# TCTTATGGCGA -> CTTATGGCGAA
# TCTTCCGAGTG -> CTTCCGAGTGG
# TCTTGCCAACA -> CTTGCCAACAT
# TCTTTCTAGCG -> CTTTCTAGCGG
# TCTTTGCGATT -> CTTTGCGATTG
# TCTTTTGATAG -> CTTTTGATAGA
# TGAAAATGATC -> GAAAATGATCG
# TGAAACTTTAT -> GAAACTTTATC
# TGAAAGCACCT -> GAAAGCACCTT
# TGAAAGTACCC -> GAAAGTACCCA
# TGAACATGAGT -> GAACATGAGTG
# TGAACCCTGCC -> GAACCCTGCCT
# TGAATACCGAC -> GAATACCGACG
# TGAATCTCCAG -> GAATCTCCAGA
# TGACATCAGTA -> GACATCAGTAT
# TGACCCTGAGT -> GACCCTGAGTC
# TGACCTCATCC -> GACCTCATCCA
# TGACCTTTCAT -> GACCTTTCATG
# TGACTTGATAC -> GACTTGATACC
# TGAGAGCGAGG -> GAGAGCGAGGA
# TGAGCTATCGA -> GAGCTATCGAC
# TGAGGACACCT -> GAGGACACCTA
# TGAGGATCTTC -> GAGGATCTTCC
# TGAGTACCGAT -> GAGTACCGATT
# TGAGTAGAACA -> GAGTAGAACAT
# TGAGTATAGGG -> GAGTATAGGGA
# TGAGTCGCGAA -> GAGTCGCGAAT
# TGAGTGTCCTG -> GAGTGTCCTGG
# TGAGTTCCTAC -> GAGTTCCTACT
# TGATACCGGTC -> GATACCGGTCG
# TGATACCTATA -> GATACCTATAA
# TGATAGACTAT -> GATAGACTATC
# TGATCAAACCC -> GATCAAACCCT
# TGATCAACTAT -> GATCAACTATG
# TGATCATCGAC -> GATCATCGACC
# TGATCGGGTCG -> GATCGGGTCGT
# TGATCGGTTAT -> GATCGGTTATA
# TGATCGTTAAG -> GATCGTTAAGC
# TGATGCACGCC -> GATGCACGCCC
# TGATTAGGGGG -> GATTAGGGGGA
# TGATTGATGCA -> GATTGATGCAC
# TGATTTAACTG -> GATTTAACTGT
# TGCAACGTCTT -> GCAACGTCTTG
# TGCACAGGCGG -> GCACAGGCGGT
# TGCACGCCAGT -> GCACGCCAGTT
# TGCACGCCCCA -> GCACGCCCCAC
# TGCAGCAACGA -> GCAGCAACGAC
# TGCAGCATGAG -> GCAGCATGAGT
# TGCATCTGGTA -> GCATCTGGTAT
# TGCCAACATTA -> GCCAACATTAG
# TGCCAGACTGA -> GCCAGACTGAC
# TGCCATGGCAT -> GCCATGGCATT
# TGCCATGGCCG -> GCCATGGCCGG
# TGCCTGATCAA -> GCCTGATCAAA
# TGCCTTACCAG -> GCCTTACCAGC
# TGCGATTGTCA -> GCGATTGTCAC
# TGCGCGTATGG -> GCGCGTATGGG
# TGCGCTGAGAG -> GCGCTGAGAGC
# TGCGGGATAGT -> GCGGGATAGTC
# TGCGTCCATAT -> GCGTCCATATC
# TGCTATGATTG -> GCTATGATTGA
# TGCTGGAGATA -> GCTGGAGATAT
# TGCTGGATGAT -> GCTGGATGATC
# TGCTGGATGGT -> GCTGGATGGTG
# TGCTGGCGATC -> GCTGGCGATCT
# TGGAAAATCCA -> GGAAAATCCAA
# TGGAACCGCCT -> GGAACCGCCTC
# TGGACAGCGTC -> GGACAGCGTCC
# TGGACGTGCAT -> GGACGTGCATC
# TGGAGATATTA -> GGAGATATTAC
# TGGATCTAGAT -> GGATCTAGATT
# TGGATGATCGT -> GGATGATCGTT
# TGGATGGTGCC -> GGATGGTGCCT
# TGGCAGGGACG -> GGCAGGGACGA
# TGGCATTTGTT -> GGCATTTGTTC
# TGGCCAATTAA -> GGCCAATTAAC
# TGGCCGGTTCT -> GGCCGGTTCTA
# TGGCGAACAAC -> GGCGAACAACA
# TGGCGATCTGG -> GGCGATCTGGC
# TGGCGCAGAGT -> GGCGCAGAGTT
# TGGCGGTATTC -> GGCGGTATTCG
# TGGCGTCCCTA -> GGCGTCCCTAT
# TGGCTGAGTAC -> GGCTGAGTACC
# TGGCTTCCGAT -> GGCTTCCGATC
# TGGCTTGGCAG -> GGCTTGGCAGG
# TGGGCCACTGG -> GGGCCACTGGT
# TGGGGGGTACG -> GGGGGGTACGA
# TGGGGGTACCC -> GGGGGTACCCA
# TGGGTGATTAG -> GGGTGATTAGG
# TGGTATAAGAG -> GGTATAAGAGC
# TGGTATCCCAC -> GGTATCCCACG
# TGGTGCCTGAT -> GGTGCCTGATC
# TGGTGTTAAGT -> GGTGTTAAGTA
# TGGTTTCGACG -> GGTTTCGACGT
# TGTAAGCAGGG -> GTAAGCAGGGA
# TGTAAGTTCAG -> GTAAGTTCAGT
# TGTACGGAGGT -> GTACGGAGGTA
# TGTAGCCCGCC -> GTAGCCCGCCA
# TGTATATGCTA -> GTATATGCTAT
# TGTCACGGGAG -> GTCACGGGAGC
# TGTCACTAGAA -> GTCACTAGAAA
# TGTCCTGGGTG -> GTCCTGGGTGA
# TGTCCTTTCGC -> GTCCTTTCGCG
# TGTCGCTTCAA -> GTCGCTTCAAG
# TGTCGGGGTGG -> GTCGGGGTGGC
# TGTCTCAGATC -> GTCTCAGATCG
# TGTCTCCACGT -> GTCTCCACGTC
# TGTCTTTCTAG -> GTCTTTCTAGC
# TGTGAATCTCC -> GTGAATCTCCA
# TGTGAGTATAG -> GTGAGTATAGG
# TGTGGCTTCCG -> GTGGCTTCCGA
# TGTTAAGTACG -> GTTAAGTACGT
# TGTTATATCGA -> GTTATATCGAA
# TGTTCGGCCCT -> GTTCGGCCCTC
# TGTTGACATCA -> GTTGACATCAG
# TTAAATTTAGC -> TAAATTTAGCA
# TTAACCATAGT -> TAACCATAGTT
# TTAACCCTTAC -> TAACCCTTACA
# TTAACTGTAAG -> TAACTGTAAGT
# TTAAGCCAACT -> TAAGCCAACTT
# TTAAGTACGTC -> TAAGTACGTCC
# TTAATAGAGCT -> TAATAGAGCTG
# TTACAGCGGGT -> TACAGCGGGTG
# TTACATTGGCG -> TACATTGGCGT
# TTACCAGCAGA -> TACCAGCAGAC
# TTACCCAATCA -> TACCCAATCAC
# TTACGGATCGC -> TACGGATCGCT
# TTACGGCAGTT -> TACGGCAGTTG
# TTACGTGACCC -> TACGTGACCCT
# TTACTAAGAAA -> TACTAAGAAAC
# TTACTATTACC -> TACTATTACCC
# TTACTGTAAGC -> TACTGTAAGCA
# TTAGAGTTCTC -> TAGAGTTCTCT
# TTAGCAGTTGT -> TAGCAGTTGTC
# TTAGGGAATAG -> TAGGGAATAGG
# TTAGGGGGACA -> TAGGGGGACAA
# TTAGTGCAGCA -> TAGTGCAGCAT
# TTATACCCGGC -> TATACCCGGCC
# TTATAGGCTAG -> TATAGGCTAGG
# TTATATCGAAG -> TATATCGAAGC
# TTATCATTGTC -> TATCATTGTCT
# TTATCTGTGAG -> TATCTGTGAGT
# TTATGATTTAA -> TATGATTTAAC
# TTATGGCGAAC -> TATGGCGAACA
# TTATGGCTTGG -> TATGGCTTGGC
# TTCAAGGCAGA -> TCAAGGCAGAT
# TTCAAGGCGGA -> TCAAGGCGGAA
# TTCAGTACTAA -> TCAGTACTAAA
# TTCATATCAAC -> TCATATCAACG
# TTCATCACCCG -> TCATCACCCGC
# TTCATCTACCA -> TCATCTACCAA
# TTCATGCGGGA -> TCATGCGGGAT
# TTCCACGGTAC -> TCCACGGTACA
# TTCCATCGGCT -> TCCATCGGCTG
# TTCCCAAGCGC -> TCCCAAGCGCC
# TTCCGAGTGGA -> TCCGAGTGGAC
# TTCCGATCGCC -> TCCGATCGCCG
# TTCCGGGATCC -> TCCGGGATCCA
# TTCCTACTCAT -> TCCTACTCATC
# TTCCTAGTCGC -> TCCTAGTCGCG
# TTCGAAATTAC -> TCGAAATTACT
# TTCGACGTCTT -> TCGACGTCTTA
# TTCGATTTAGT -> TCGATTTAGTG
# TTCGCCGTAAT -> TCGCCGTAATC
# TTCGCGATTCC -> TCGCGATTCCA
# TTCGCTCTCAC -> TCGCTCTCACC
# TTCGGCCCTCC -> TCGGCCCTCCC
# TTCGGGCTAAG -> TCGGGCTAAGC
# TTCTAGCGGCG -> TCTAGCGGCGC
# TTCTATTTACT -> TCTATTTACTA
# TTCTCATGTAT -> TCTCATGTATA
# TTCTCTTATGG -> TCTCTTATGGC
# TTCTTTGCGAT -> TCTTTGCGATT
# TTGAAACTTTA -> TGAAACTTTAT
# TTGAAAGTACC -> TGAAAGTACCC
# TTGACATCAGT -> TGACATCAGTA
# TTGACCTCATC -> TGACCTCATCC
# TTGATACCGGT -> TGATACCGGTC
# TTGATAGACTA -> TGATAGACTAT
# TTGATCATCGA -> TGATCATCGAC
# TTGATGCACGC -> TGATGCACGCC
# TTGCAGCAACG -> TGCAGCAACGA
# TTGCCAACATT -> TGCCAACATTA
# TTGCGATTGTC -> TGCGATTGTCA
# TTGCTGGATGA -> TGCTGGATGAT
# TTGCTGGCGAT -> TGCTGGCGATC
# TTGGCAGGGAC -> TGGCAGGGACG
# TTGGCGCAGAG -> TGGCGCAGAGT
# TTGGCGTCCCT -> TGGCGTCCCTA
# TTGGGGGTACC -> TGGGGGTACCC
# TTGGTTTCGAC -> TGGTTTCGACG
# TTGTCACGGGA -> TGTCACGGGAG
# TTGTCCTTTCG -> TGTCCTTTCGC
# TTGTCTCAGAT -> TGTCTCAGATC
# TTGTGAATCTC -> TGTGAATCTCC
# TTGTTATATCG -> TGTTATATCGA
# TTGTTCGGCCC -> TGTTCGGCCCT
# TTTAACTGTAA -> TTAACTGTAAG
# TTTACGTGACC -> TTACGTGACCC
# TTTACTATTAC -> TTACTATTACC
# TTTAGAGTTCT -> TTAGAGTTCTC
# TTTAGCAGTTG -> TTAGCAGTTGT
# TTTAGTGCAGC -> TTAGTGCAGCA
# TTTATCATTGT -> TTATCATTGTC
# TTTCAAGGCGG -> TTCAAGGCGGA
# TTTCATCTACC -> TTCATCTACCA
# TTTCATGCGGG -> TTCATGCGGGA
# TTTCCCAAGCG -> TTCCCAAGCGC
# TTTCCTAGTCG -> TTCCTAGTCGC
# TTTCGACGTCT -> TTCGACGTCTT
# TTTCGCCGTAA -> TTCGCCGTAAT
# TTTCGCGATTC -> TTCGCGATTCC
# TTTCGGGCTAA -> TTCGGGCTAAG
# TTTCTAGCGGC -> TTCTAGCGGCG
# TTTGAAAGTAC -> TTGAAAGTACC
# TTTGATAGACT -> TTGATAGACTA
# TTTGATCATCG -> TTGATCATCGA
# TTTGCGATTGT -> TTGCGATTGTC
# TTTGCTGGCGA -> TTGCTGGCGAT
# TTTGTTCGGCC -> TTGTTCGGCCC
# TTTTCAAGGCG -> TTTCAAGGCGG
# TTTTCCTAGTC -> TTTCCTAGTCG
# TTTTGATAGAC -> TTTGATAGACT
# TTTTGATCATC -> TTTGATCATCG
