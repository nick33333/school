# %% [markdown]
# # Notes
#
# ### NULL Model
# - For a Markov(1) Model, we consider a preceding base
#     - Ex:
#
#         $P(A|T_{prev}) = \frac{P(TA)}{P(T)} = \frac{\frac{c(TA)}{N}}{\frac{c(T)}{N}} = \frac{c(TA)}{c(T)}$
#
#         - N is not the same in the cases of TA and T, but the difference is negligible for now
# - Increasing the order of a Markov Model makes our model more informed
# - Check Week 2 Overview Video 3 for more details on detailed Markov Model for 4-mer described by $k_{1}k_{2}k_{3}k_{4}$

# %%
import sys
import os 
import numpy as np
from fastaReader import FastAreader

# holds files
dataList = os.listdir('mdata')
print(f"{os.listdir()} \n{os.listdir('mdata')}")
print('mdata/'+dataList[0])

### SEQUENCE LIST ###
seqList = []
readData = FastAreader('mdata/'+dataList[0]).readFasta()
for line in readData:
    seqList.append(line[1])
    
### SEQUENCE STRING ###
# seqString = ''.join(seqList)

### SEQUENCE LENGTH ###
# seqLength = len(seqList[0])

### REVERESE COMPLIMENT FUNCTION ###
def revComp(seqStr):
    newStr = ''
    baseDict = {'A':'T', 'T':'A', 'C':'G', 'G':'C', 'N':'N'}
    for char in seqStr:
        newStr += baseDict[char]
    return newStr[::-1]

### PALINDROME LIST ###
# BAD, uses seqString which we shouldn't use due to possible multiple fasta's
# palList = []
# for i in range(seqLength - 8):
#     palList.append(f"{seqString[i:8+i]}:{revComp(seqString[i:8+i])}")
# Out:
# ['.ipynb_checkpoints', 'data', 'dummm.txt', 'fastaReader.py', 'mdata', 'notes.md', 'program.py', 'testing.ipynb', '__pycache__']
# ['Arthrospira-platensis-NIES-39.fna', 'Ecoli-UMN026.fa', 'Synechococcus7002.fna', 'Zm4-genomic.fna']
# mdata/Arthrospira-platensis-NIES-39.fna

# %%
class SearchForMissing:
    def __init__(self, seqList, minMotif, maxMotif, zCut):
        self.seqList = seqList
        self.minMotif = minMotif
        self.maxMotif = maxMotif
        self.zCut = zCut
        
        self.N = self.genomeLen() - self.maxMotif
        self.ctDict = self.ctDictMake()
        self.prDict = self.prDictMake()

    def genomeLen(self):
        '''
        Takes the sum of sequence lengths from the list of sequences, seqList.
        seqList is made with the FastAreader class and has 1 fasta seq per entry.
        '''
        totLen = 0
        for seq in seqList:
            totLen += len(seq)
        return totLen

    def ctDictMake(self):
        '''
        Stores a dict of dicts
        {1:{'A':25, 'C':33,...}, ... ,8:{'AAAAGGGG':12, 'AAAATTTT':11, ...}}
        Reads over each sequence in the fasta. For each sequence, a sliding window
        moves over its respective sequence length and k-mers are counted.
        '''
        
        massDict = dict() # dictionary that holds dictionaries which hold k-mers and their respective counts
        for k in range(1, self.maxMotif+1): # Initialize dictionaries for min to max motif sizes within massDict; MAYBE START WITH 1 AND NOT MIN MOTIF
            massDict[k] = dict()
        print(massDict)
        for seq in self.seqList:
            for k in range(1, self.maxMotif+1):
                for kmer_idx in range((len(seq)-k)):
                    kmer = seq[kmer_idx:kmer_idx+k]
                    if 'N' not in kmer:
                        if kmer in massDict[k]:
                            massDict[k][kmer] += 1
                        else:
                            massDict[k][kmer] = 1
        return massDict
                            
    # Friggin destroy this method    
    def finalCtDictMake(self):              
        finalDict = dict()
        banned = set()
        for k in range(1, self.maxMotif+1): # Initialize dictionaries for min to max motif sizes within massDict; MAYBE START WITH 1 AND NOT MIN MOTIF
            finalDict[k] = dict()
        for k in range(1, self.maxMotif+1):
            for kmer in self.ctDict[k].keys():
                if kmer not in banned:
                    tmpPair = sorted([kmer, revComp(kmer)])
                    if revComp(kmer) in self.ctDict[k]: # Case 1: k-mer and its reverse complement exist in massDict, proceed to combine their keys and vals
                        finalDict[k][f'{tmpPair[0]}:{tmpPair[1]}'] = self.ctDict[k][kmer] + self.ctDict[k][revComp(kmer)] # arranges revere complement palindromes in alphabetical order
                    if kmer == revComp(kmer): # Case 2: k-mer and its reverse complement are the same, proceed to make a single entry for both using existing count info
                        finalDict[k][f'{tmpPair[0]}:{tmpPair[1]}'] = self.ctDict[k][kmer]
                    # Case 3: k-mer exists in massDict but not its reverse complement, proceed to combine their keys and vals (by default the other would be 0)
                    # Case 3 is covered by condition for Case 2
                    banned.add(kmer)
                    banned.add(revComp(kmer))
        return finalDict
    
    def meanAndSD(self):
        
                
                                
#     def ctDictMake(self):
#         '''
#         Stores a dict of dicts
#         {1:{'A':25, 'C':33,...}, ... ,8:{'AAAAGGGG':12, 'AAAATTTT':11, ...}}
#         Reads over each sequence in the fasta. For each sequence, a sliding window
#         moves over its respective sequence length and k-mers are counted.
#         '''
#         massDict = dict() # dictionary that holds dictionaries which hold k-mers and their respective counts
#         for k in range(1, self.maxMotif+1): # Initialize dictionaries for min to max motif sizes within massDict; MAYBE START WITH 1 AND NOT MIN MOTIF
#             massDict[k] = dict()
#         print(massDict)
#         for seq in self.seqList:
#             for k in range(1, self.maxMotif+1):
#                 for kmer_idx in range((len(seq)-k)):
#                     kmer = seq[kmer_idx:kmer_idx+k]
#                     if 'N' not in kmer:
#                         if kmer in massDict[k]:
#                             massDict[k][kmer] += 1
#                         else:
#                             massDict[k][kmer] = 1
#                         # Used to match other ppl's output \-_-/, works but is fucking slow
#                         if revComp(kmer) != kmer:
#                             if revComp(kmer) in massDict[k]:
#                                 massDict[k][revComp(kmer)] += 1
#                             else:
#                                 massDict[k][revComp(kmer)] = 1
#         return massDict

    def prDictMake(self): # VERY DEPENDENT ON ctDict
        massDict = dict() # dictionary that holds dictionaries which hold k-mers and their respective counts
        for k in range(self.minMotif, self.maxMotif+1): # Initialize dictionaries for min to max motif sizes within massDict
            massDict[k] = dict()
#         print(massDict)
        for k in range(self.minMotif, self.maxMotif+1):
            for kmer in self.ctDict[k].keys():
                massDict[k][kmer] = (1/self.N) * ((self.ctDict[k-1][kmer[:-1]] * self.ctDict[k-1][kmer[1:]]) / self.ctDict[k-2][kmer[1:-1]])
        return massDict

# %%
sfm = SearchForMissing(seqList, 3, 8, 0)
countDict = sfm.ctDict
# Out:
# {1: {}, 2: {}, 3: {}, 4: {}, 5: {}, 6: {}, 7: {}, 8: {}}

# %%
# AAAATTTA:TAAATTTT	
a = countDict[8]['AAAATTTA']
b = countDict[8][revComp('AAAATTTA')]
print(a, b)
# Out:
# Genome Len N: 6788427
# 418 416

# %%
# Basically Expected count = Pr(K) * N
# Making some sort of double stranded choice with *2 I think 
pra = sfm.prDict[8]['AAAATTTA']
prb = sfm.prDict[8][revComp('AAAATTTA')]
prab = pra + prb
N = sfm.N # GOOD
exp = (prab * sfm.N*2)  # The necessity of needing to find the expected counts of each to match Harrison's answers indicate the need to combine counts   # GOOD
obs = (sfm.ctDict[8]['AAAATTTA'] + sfm.ctDict[8][revComp('AAAATTTA')]) # GOOD
print('Pr(AAAATTTA) = {}'.format(str(pra)))
print('Pr(TAAATTTT) = {}'.format(str(prb)))
# Genome length kinda
print(f'Genome Len N = {N}')
print(f"Expect (np) = {exp}") # Composed from: rev comp counts from BOTH strands
print(f"count = {obs}")

# Pr(a:b) to use for z is calculated by summing Pr(a) and Pr(b) where a and b are rev comps
pr = exp/(N)

sd = (2*(obs)*(1-prab))**.5
print(f"sd = {sd}")
Z = ((obs)-exp)/sd +1 # dogshit z score soln
Z
# Out:
# Pr(AAAATTTA) = 6.44041436287385e-05
# Pr(TAAATTTT) = 6.350870716171334e-05
# Genome Len N = 6788427
# Expect (np) = 1736.6540999057495
# count = 834
# sd = 40.83854357546167
# -21.10299439885315

# %%
mean =
# Out:
#   File "<ipython-input-248-e908386a6b4f>", line 1
#     mean =
#            ^
# SyntaxError: invalid syntax

# %%
fakeExpect = 1736.6540999057495
# Out:
# 6788427

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-214-b83f625b6b8c> in <module>
# ----> 1 sfm.finalCtDictMake()[8]['AAAATTTT:TTTTAAAA']
#
# KeyError: 'AAAATTTT:TTTTAAAA'

# %%
aaa = []
ttt = aaa
ttt.append('apple')
print(aaa, ttt)
# Out:
# ['apple'] ['apple']

# %%
with open('mdata/Synechococcus7002.fna', 'r') as myfile:
    st = ''
    dd = dict()
    for line in myfile:
        st += line.rstrip()
    rn = len(st)
    for i in range(rn-8):
        if st[i:i+8] in dd:
            dd[st[i:i+8]] += 1
        else:
            dd[st[i:i+8]] = 1

# %%
dd['AAAATTTT']
# Out:
# 418

# %%
# Might just save trouble and make keep counts for revComps separate (Not necessary to combine them now)
newDict = dict()
exclude = set()
for key in x[8]:
    if key not in exclude:
        if revComp(key) in x[8]:
            newDict[f"{key}:{revComp(key)}"] = (x[8][key]+x[8][revComp(key)])
        else: 
            newDict[f"{key}:{revComp(key)}"] = (x[8][key])
    exclude.add(key)
    exclude.add(revComp(key))
newDict
# Out:
# {'AGCGTTTA:TAAACGCT': 261,
#  'GCGTTTAA:TTAAACGC': 288,
#  'CGTTTAAC:GTTAAACG': 256,
#  'GTTTAACC:GGTTAAAC': 495,
#  'TTTAACCG:CGGTTAAA': 456,
#  'TTAACCGA:TCGGTTAA': 394,
#  'TAACCGAG:CTCGGTTA': 286,
#  'AACCGAGA:TCTCGGTT': 321,
#  'ACCGAGAG:CTCTCGGT': 168,
#  'CCGAGAGG:CCTCTCGG': 112,
#  'CGAGAGGT:ACCTCTCG': 82,
#  'GAGAGGTC:GACCTCTC': 118,
#  'AGAGGTCG:CGACCTCT': 95,
#  'GAGGTCGC:GCGACCTC': 106,
#  'AGGTCGCC:GGCGACCT': 237,
#  'GGTCGCCG:CGGCGACC': 186,
#  'GTCGCCGT:ACGGCGAC': 192,
#  'TCGCCGTG:CACGGCGA': 118,
#  'CGCCGTGA:TCACGGCG': 113,
#  'GCCGTGAA:TTCACGGC': 97,
#  'CCGTGAAA:TTTCACGG': 139,
#  'CGTGAAAT:ATTTCACG': 99,
#  'GTGAAATT:AATTTCAC': 398,
#  'TGAAATTC:GAATTTCA': 465,
#  'GAAATTCA:TGAATTTC': 544,
#  'AAATTCAT:ATGAATTT': 637,
#  'AATTCATT:AATGAATT': 432,
#  'ATTCATTG:CAATGAAT': 362,
#  'TTCATTGA:TCAATGAA': 326,
#  'TCATTGAC:GTCAATGA': 255,
#  'CATTGACA:TGTCAATG': 319,
#  'ATTGACAG:CTGTCAAT': 439,
#  'TTGACAGC:GCTGTCAA': 309,
#  'TGACAGCA:TGCTGTCA': 277,
#  'GACAGCAA:TTGCTGTC': 245,
#  'ACAGCAAT:ATTGCTGT': 387,
#  'CAGCAATT:AATTGCTG': 815,
#  'AGCAATTC:GAATTGCT': 422,
#  'GCAATTCC:GGAATTGC': 451,
#  'CAATTCCC:GGGAATTG': 947,
#  'AATTCCCC:GGGGAATT': 1051,
#  'ATTCCCCT:AGGGGAAT': 524,
#  'TTCCCCTT:AAGGGGAA': 700,
#  'TCCCCTTT:AAAGGGGA': 300,
#  'CCCCTTTT:AAAAGGGG': 316,
#  'CCCTTTTT:AAAAAGGG': 334,
#  'CCTTTTTT:AAAAAAGG': 490,
#  'CTTTTTTG:CAAAAAAG': 623,
#  'TTTTTTGA:TCAAAAAA': 1009,
#  'TTTTTGAA:TTCAAAAA': 652,
#  'TTTTGAAA:TTTCAAAA': 576,
#  'TTTGAAAT:ATTTCAAA': 375,
#  'TTGAAATA:TATTTCAA': 414,
#  'TGAAATAG:CTATTTCA': 445,
#  'GAAATAGT:ACTATTTC': 318,
#  'AAATAGTT:AACTATTT': 499,
#  'AATAGTTG:CAACTATT': 437,
#  'ATAGTTGG:CCAACTAT': 303,
#  'TAGTTGGA:TCCAACTA': 138,
#  'AGTTGGAC:GTCCAACT': 114,
#  'GTTGGACG:CGTCCAAC': 80,
#  'TTGGACGG:CCGTCCAA': 133,
#  'TGGACGGC:GCCGTCCA': 94,
#  'GGACGGCG:CGCCGTCC': 159,
#  'GACGGCGG:CCGCCGTC': 290,
#  'ACGGCGGC:GCCGCCGT': 333,
#  'CGGCGGCG:CGCCGCCG': 831,
#  'GGCGGCGG:CCGCCGCC': 1458,
#  'GCGGCGGG:CCCGCCGC': 551,
#  'CGGCGGGG:CCCCGCCG': 326,
#  'GGCGGGGC:GCCCCGCC': 96,
#  'GCGGGGCG:CGCCCCGC': 78,
#  'CGGGGCGT:ACGCCCCG': 85,
#  'GGGGCGTA:TACGCCCC': 103,
#  'GGGCGTAC:GTACGCCC': 39,
#  'GGCGTACC:GGTACGCC': 66,
#  'GCGTACCT:AGGTACGC': 53,
#  'CGTACCTG:CAGGTACG': 50,
#  'GTACCTGC:GCAGGTAC': 82,
#  'TACCTGCC:GGCAGGTA': 124,
#  'ACCTGCCA:TGGCAGGT': 199,
#  'CCTGCCAT:ATGGCAGG': 235,
#  'CTGCCATT:AATGGCAG': 457,
#  'TGCCATTC:GAATGGCA': 246,
#  'GCCATTCG:CGAATGGC': 119,
#  'CCATTCGA:TCGAATGG': 84,
#  'CATTCGAC:GTCGAATG': 68,
#  'ATTCGACA:TGTCGAAT': 128,
#  'TTCGACAA:TTGTCGAA': 276,
#  'TCGACAAA:TTTGTCGA': 250,
#  'CGACAAAT:ATTTGTCG': 296,
#  'GACAAATT:AATTTGTC': 522,
#  'ACAAATTC:GAATTTGT': 642,
#  'CAAATTCT:AGAATTTG': 648,
#  'AAATTCTC:GAGAATTT': 708,
#  'AATTCTCC:GGAGAATT': 506,
#  'ATTCTCCG:CGGAGAAT': 214,
#  'TTCTCCGA:TCGGAGAA': 225,
#  'TCTCCGAG:CTCGGAGA': 153,
#  'CTCCGAGG:CCTCGGAG': 177,
#  'TCCGAGGC:GCCTCGGA': 146,
#  'CCGAGGCG:CGCCTCGG': 145,
#  'CGAGGCGG:CCGCCTCG': 134,
#  'GAGGCGGT:ACCGCCTC': 321,
#  'AGGCGGTT:AACCGCCT': 405,
#  'GGCGGTTT:AAACCGCC': 659,
#  'GCGGTTTC:GAAACCGC': 298,
#  'CGGTTTCC:GGAAACCG': 526,
#  'GGTTTCCC:GGGAAACC': 804,
#  'GTTTCCCA:TGGGAAAC': 529,
#  'TTTCCCAG:CTGGGAAA': 658,
#  'TTCCCAGT:ACTGGGAA': 543,
#  'TCCCAGTT:AACTGGGA': 441,
#  'CCCAGTTT:AAACTGGG': 657,
#  'CCAGTTTG:CAAACTGG': 280,
#  'CAGTTTGC:GCAAACTG': 187,
#  'AGTTTGCC:GGCAAACT': 179,
#  'GTTTGCCT:AGGCAAAC': 99,
#  'TTTGCCTA:TAGGCAAA': 184,
#  'TTGCCTAA:TTAGGCAA': 249,
#  'TGCCTAAT:ATTAGGCA': 267,
#  'GCCTAATT:AATTAGGC': 331,
#  'CCTAATTC:GAATTAGG': 479,
#  'CTAATTCC:GGAATTAG': 630,
#  'TAATTCCT:AGGAATTA': 669,
#  'AATTCCTG:CAGGAATT': 638,
#  'ATTCCTGG:CCAGGAAT': 358,
#  'TTCCTGGT:ACCAGGAA': 474,
#  'TCCTGGTT:AACCAGGA': 454,
#  'CCTGGTTG:CAACCAGG': 284,
#  'CTGGTTGA:TCAACCAG': 317,
#  'TGGTTGAG:CTCAACCA': 347,
#  'GGTTGAGT:ACTCAACC': 450,
#  'GTTGAGTT:AACTCAAC': 445,
#  'TTGAGTTT:AAACTCAA': 710,
#  'TGAGTTTT:AAAACTCA': 616,
#  'GAGTTTTT:AAAAACTC': 836,
#  'AGTTTTTC:GAAAAACT': 698,
#  'GTTTTTCA:TGAAAAAC': 428,
#  'TTTTTCAT:ATGAAAAA': 699,
#  'TTTTCATT:AATGAAAA': 444,
#  'TTTCATTC:GAATGAAA': 191,
#  'TTCATTCT:AGAATGAA': 156,
#  'TCATTCTG:CAGAATGA': 155,
#  'CATTCTGT:ACAGAATG': 123,
#  'ATTCTGTT:AACAGAAT': 323,
#  'TTCTGTTG:CAACAGAA': 296,
#  'TCTGTTGT:ACAACAGA': 252,
#  'CTGTTGTT:AACAACAG': 421,
#  'TGTTGTTT:AAACAACA': 391,
#  'GTTGTTTG:CAAACAAC': 368,
#  'TTGTTTGA:TCAAACAA': 451,
#  'TGTTTGAT:ATCAAACA': 397,
#  'GTTTGATT:AATCAAAC': 760,
#  'TTTGATTA:TAATCAAA': 912,
#  'TTGATTAT:ATAATCAA': 893,
#  'TGATTATT:AATAATCA': 752,
#  'GATTATTC:GAATAATC': 338,
#  'ATTATTCG:CGAATAAT': 248,
#  'TTATTCGT:ACGAATAA': 163,
#  'TATTCGTT:AACGAATA': 137,
#  'ATTCGTTC:GAACGAAT': 93,
#  'TTCGTTCG:CGAACGAA': 35,
#  'TCGTTCGG:CCGAACGA': 64,
#  'CGTTCGGT:ACCGAACG': 99,
#  'GTTCGGTT:AACCGAAC': 227,
#  'TTCGGTTT:AAACCGAA': 556,
#  'TCGGTTTC:GAAACCGA': 637,
#  'GTTTCCCG:CGGGAAAC': 400,
#  'TTTCCCGG:CCGGGAAA': 474,
#  'TTCCCGGA:TCCGGGAA': 516,
#  'TCCCGGAA:TTCCGGGA': 380,
#  'CCCGGAAG:CTTCCGGG': 356,
#  'CCGGAAGC:GCTTCCGG': 271,
#  'CGGAAGCG:CGCTTCCG': 270,
#  'GGAAGCGG:CCGCTTCC': 328,
#  'GAAGCGGC:GCCGCTTC': 279,
#  'AAGCGGCG:CGCCGCTT': 229,
#  'AGCGGCGA:TCGCCGCT': 255,
#  'GCGGCGAT:ATCGCCGC': 732,
#  'CGGCGATC:GATCGCCG': 998,
#  'GGCGATCG:CGATCGCC': 7306,
#  'GCGATCGC:GCGATCGC': 15366,
#  'CGATCGCT:AGCGATCG': 5297,
#  'GATCGCTT:AAGCGATC': 2262,
#  'ATCGCTTT:AAAGCGAT': 1322,
#  'TCGCTTTC:GAAAGCGA': 479,
#  'CGCTTTCT:AGAAAGCG': 231,
#  'GCTTTCTT:AAGAAAGC': 236,
#  'CTTTCTTG:CAAGAAAG': 219,
#  'TTTCTTGG:CCAAGAAA': 443,
#  'TTCTTGGG:CCCAAGAA': 367,
#  'TCTTGGGA:TCCCAAGA': 237,
#  'CTTGGGAT:ATCCCAAG': 295,
#  'TTGGGATT:AATCCCAA': 651,
#  'TGGGATTG:CAATCCCA': 521,
#  'GGGATTGT:ACAATCCC': 260,
#  'GGATTGTT:AACAATCC': 206,
#  'GATTGTTC:GAACAATC': 172,
#  'ATTGTTCT:AGAACAAT': 311,
#  'TTGTTCTC:GAGAACAA': 209,
#  'TGTTCTCG:CGAGAACA': 157,
#  'GTTCTCGG:CCGAGAAC': 166,
#  'TTCTCGGA:TCCGAGAA': 315,
#  'TCTCGGAA:TTCCGAGA': 451,
#  'CTCGGAAG:CTTCCGAG': 192,
#  'TCGGAAGC:GCTTCCGA': 170,
#  'CTTTCTTC:GAAGAAAG': 175,
#  'TTTCTTCG:CGAAGAAA': 233,
#  'TTCTTCGG:CCGAAGAA': 295,
#  'TCTTCGGA:TCCGAAGA': 121,
#  'CTTCGGAT:ATCCGAAG': 78,
#  'TTCGGATT:AATCCGAA': 315,
#  'TCGGATTG:CAATCCGA': 216,
#  'CGGATTGT:ACAATCCG': 103,
#  'GGATTGTC:GACAATCC': 194,
#  'GATTGTCG:CGACAATC': 164,
#  'ATTGTCGC:GCGACAAT': 304,
#  'TTGTCGCT:AGCGACAA': 181,
#  'TGTCGCTG:CAGCGACA': 180,
#  'GTCGCTGG:CCAGCGAC': 152,
#  'TCGCTGGA:TCCAGCGA': 180,
#  'CGCTGGAG:CTCCAGCG': 111,
#  'GCTGGAGG:CCTCCAGC': 111,
#  'CTGGAGGA:TCCTCCAG': 137,
#  'TGGAGGAG:CTCCTCCA': 161,
#  'GGAGGAGT:ACTCCTCC': 188,
#  'GAGGAGTT:AACTCCTC': 407,
#  'AGGAGTTG:CAACTCCT': 402,
#  'GGAGTTGC:GCAACTCC': 264,
#  'GAGTTGCC:GGCAACTC': 170,
#  'AGTTGCCG:CGGCAACT': 182,
#  'GTTGCCGG:CCGGCAAC': 79,
#  'TTGCCGGG:CCCGGCAA': 164,
#  'TGCCGGGT:ACCCGGCA': 134,
#  'GCCGGGTT:AACCCGGC': 263,
#  'CCGGGTTT:AAACCCGG': 505,
#  'CGGGTTTC:GAAACCCG': 410,
#  'GGGTTTCT:AGAAACCC': 735,
#  'GGTTTCTT:AAGAAACC': 515,
#  'GTTTCTTG:CAAGAAAC': 279,
#  'TTTCTTGA:TCAAGAAA': 481,
#  'TTCTTGAA:TTCAAGAA': 376,
#  'TCTTGAAA:TTTCAAGA': 286,
#  'CTTGAAAT:ATTTCAAG': 302,
#  'TTGAAATT:AATTTCAA': 605,
#  'TGAAATTG:CAATTTCA': 558,
#  'GAAATTGG:CCAATTTC': 616,
#  'AAATTGGC:GCCAATTT': 828,
#  'AATTGGCG:CGCCAATT': 621,
#  'ATTGGCGT:ACGCCAAT': 157,
#  'TTGGCGTT:AACGCCAA': 369,
#  'TGGCGTTC:GAACGCCA': 169,
#  'GGCGTTCG:CGAACGCC': 64,
#  'GCGTTCGG:CCGAACGC': 70,
#  'CGGTTTCT:AGAAACCG': 577,
#  'GTTTCTTT:AAAGAAAC': 430,
#  'TTTCTTTC:GAAAGAAA': 390,
#  'TTCTTTCT:AGAAAGAA': 234,
#  'TCTTTCTG:CAGAAAGA': 255,
#  'CTTTCTGG:CCAGAAAG': 318,
#  'TTTCTGGG:CCCAGAAA': 785,
#  'TTCTGGGC:GCCCAGAA': 224,
#  'TCTGGGCT:AGCCCAGA': 233,
#  'CTGGGCTT:AAGCCCAG': 250,
#  'TGGGCTTC:GAAGCCCA': 319,
#  'GGGCTTCT:AGAAGCCC': 342,
#  'GGCTTCTG:CAGAAGCC': 570,
#  'GCTTCTGC:GCAGAAGC': 265,
#  'CTTCTGCC:GGCAGAAG': 165,
#  'TTCTGCCA:TGGCAGAA': 370,
#  'TCTGCCAG:CTGGCAGA': 125,
#  'CTGCCAGT:ACTGGCAG': 115,
#  'TGCCAGTT:AACTGGCA': 235,
#  'GCCAGTTC:GAACTGGC': 198,
#  'CCAGTTCC:GGAACTGG': 317,
#  'CAGTTCCG:CGGAACTG': 277,
#  'AGTTCCGC:GCGGAACT': 201,
#  'GTTCCGCC:GGCGGAAC': 282,
#  'TTCCGCCA:TGGCGGAA': 536,
#  'TCCGCCAG:CTGGCGGA': 212,
#  'CCGCCAGC:GCTGGCGG': 261,
#  'CGCCAGCA:TGCTGGCG': 216,
#  'GCCAGCAG:CTGCTGGC': 188,
#  'CCAGCAGC:GCTGCTGG': 291,
#  'CAGCAGCC:GGCTGCTG': 323,
#  'AGCAGCCT:AGGCTGCT': 248,
#  'GCAGCCTC:GAGGCTGC': 102,
#  'CAGCCTCC:GGAGGCTG': 156,
#  'AGCCTCCA:TGGAGGCT': 172,
#  'GCCTCCAA:TTGGAGGC': 172,
#  'CCTCCAAA:TTTGGAGG': 329,
#  'CTCCAAAC:GTTTGGAG': 261,
#  'TCCAAACA:TGTTTGGA': 288,
#  'CCAAACAT:ATGTTTGG': 339,
#  'CAAACATC:GATGTTTG': 303,
#  'AAACATCG:CGATGTTT': 217,
#  'AACATCGT:ACGATGTT': 100,
#  'ACATCGTC:GACGATGT': 65,
#  'CATCGTCA:TGACGATG': 193,
#  'ATCGTCAG:CTGACGAT': 178,
#  'TCGTCAGC:GCTGACGA': 148,
#  'CGTCAGCA:TGCTGACG': 225,
#  'GTCAGCAT:ATGCTGAC': 255,
#  'TCAGCATT:AATGCTGA': 421,
#  'CAGCATTG:CAATGCTG': 198,
#  'AGCATTGG:CCAATGCT': 168,
#  'GCATTGGT:ACCAATGC': 230,
#  'CATTGGTG:CACCAATG': 277,
#  'ATTGGTGG:CCACCAAT': 577,
#  'TTGGTGGT:ACCACCAA': 596,
#  'TGGTGGTC:GACCACCA': 248,
#  'GGTGGTCA:TGACCACC': 297,
#  'GTGGTCAT:ATGACCAC': 264,
#  'TGGTCATG:CATGACCA': 304,
#  'GGTCATGG:CCATGACC': 339,
#  'GTCATGGG:CCCATGAC': 221,
#  'TCATGGGG:CCCCATGA': 234,
#  'CATGGGGG:CCCCCATG': 210,
#  'ATGGGGGT:ACCCCCAT': 425,
#  'TGGGGGTT:AACCCCCA': 659,
#  'GGGGGTTC:GAACCCCC': 324,
#  'GGGGTTCC:GGAACCCC': 313,
#  'GGGTTCCT:AGGAACCC': 309,
#  'GGTTCCTC:GAGGAACC': 267,
#  'GTTCCTCT:AGAGGAAC': 220,
#  'TTCCTCTC:GAGAGGAA': 162,
#  'TCCTCTCA:TGAGAGGA': 135,
#  'CCTCTCAG:CTGAGAGG': 129,
#  'CTCTCAGG:CCTGAGAG': 134,
#  'TCTCAGGT:ACCTGAGA': 223,
#  'CTCAGGTG:CACCTGAG': 147,
#  'TCAGGTGT:ACACCTGA': 147,
#  'CAGGTGTC:GACACCTG': 96,
#  'AGGTGTCT:AGACACCT': 85,
#  'GGTGTCTC:GAGACACC': 100,
#  'GTGTCTCA:TGAGACAC': 97,
#  'TGTCTCAA:TTGAGACA': 185,
#  'GTCTCAAT:ATTGAGAC': 175,
#  'TCTCAATC:GATTGAGA': 320,
#  'CTCAATCA:TGATTGAG': 482,
#  'TCAATCAT:ATGATTGA': 528,
#  'CAATCATC:GATGATTG': 546,
#  'AATCATCC:GGATGATT': 645,
#  'ATCATCCA:TGGATGAT': 366,
#  'TCATCCAT:ATGGATGA': 261,
#  'CATCCATT:AATGGATG': 248,
#  'ATCCATTT:AAATGGAT': 327,
#  'TCCATTTT:AAAATGGA': 361,
#  'CCATTTTA:TAAAATGG': 439,
#  'CATTTTAG:CTAAAATG': 348,
#  'ATTTTAGC:GCTAAAAT': 772,
#  'TTTTAGCC:GGCTAAAA': 650,
#  'TTTAGCCA:TGGCTAAA': 788,
#  'TTAGCCAC:GTGGCTAA': 426,
#  'TAGCCACT:AGTGGCTA': 299,
#  'AGCCACTT:AAGTGGCT': 241,
#  'GCCACTTT:AAAGTGGC': 245,
#  'CCACTTTC:GAAAGTGG': 197,
#  'CACTTTCC:GGAAAGTG': 234,
#  'ACTTTCCA:TGGAAAGT': 300,
#  'CTTTCCAC:GTGGAAAG': 304,
#  'TTTCCACT:AGTGGAAA': 315,
#  'TTCCACTA:TAGTGGAA': 229,
#  'TCCACTAT:ATAGTGGA': 117,
#  'CCACTATG:CATAGTGG': 111,
#  'CACTATGC:GCATAGTG': 81,
#  'ACTATGCG:CGCATAGT': 64,
#  'CTATGCGA:TCGCATAG': 102,
#  'TATGCGAT:ATCGCATA': 386,
#  'ATGCGATC:GATCGCAT': 2169,
#  'TGCGATCG:CGATCGCA': 4648,
#  'GCTTTCTG:CAGAAAGC': 240,
#  'TTTCTGGT:ACCAGAAA': 730,
#  'TTCTGGTA:TACCAGAA': 479,
#  'TCTGGTAA:TTACCAGA': 482,
#  'CTGGTAAG:CTTACCAG': 180,
#  'TGGTAAGA:TCTTACCA': 140,
#  'GGTAAGAT:ATCTTACC': 155,
#  'GTAAGATG:CATCTTAC': 90,
#  'TAAGATGC:GCATCTTA': 85,
#  'AAGATGCG:CGCATCTT': 324,
#  'AGATGCGA:TCGCATCT': 410,
#  'GATGCGAT:ATCGCATC': 778,
#  'GATCGCAC:GTGCGATC': 1312,
#  'ATCGCACT:AGTGCGAT': 766,
#  'TCGCACTT:AAGTGCGA': 417,
#  'CGCACTTC:GAAGTGCG': 268,
#  'GCACTTCC:GGAAGTGC': 228,
#  'CACTTCCG:CGGAAGTG': 230,
#  'ACTTCCGA:TCGGAAGT': 295,
#  'TCCGAGAG:CTCTCGGA': 336,
#  'CGAGAGGC:GCCTCTCG': 132,
#  'GAGAGGCT:AGCCTCTC': 147,
#  'AGAGGCTA:TAGCCTCT': 275,
#  'GAGGCTAC:GTAGCCTC': 145,
#  'AGGCTACG:CGTAGCCT': 108,
#  'GGCTACGG:CCGTAGCC': 283,
#  'GCTACGGG:CCCGTAGC': 216,
#  'CTACGGGA:TCCCGTAG': 238,
#  'TACGGGAA:TTCCCGTA': 221,
#  'ACGGGAAT:ATTCCCGT': 301,
#  'CGGGAATG:CATTCCCG': 285,
#  'GGGAATGC:GCATTCCC': 299,
#  'GGAATGCA:TGCATTCC': 98,
#  'GAATGCAC:GTGCATTC': 91,
#  'AATGCACT:AGTGCATT': 161,
#  'ATGCACTT:AAGTGCAT': 124,
#  'TGCACTTC:GAAGTGCA': 131,
#  'TTCCGAGG:CCTCGGAA': 241,
#  'CGAGGCGA:TCGCCTCG': 206,
#  'GAGGCGAT:ATCGCCTC': 1313,
#  'AGGCGATA:TATCGCCT': 373,
#  'GGCGATAG:CTATCGCC': 555,
#  'GCGATAGG:CCTATCGC': 192,
#  'CGATAGGC:GCCTATCG': 186,
#  'GATAGGCG:CGCCTATC': 190,
#  'ATAGGCGA:TCGCCTAT': 362,
#  'TAGGCGAT:ATCGCCTA': 729,
#  'GGCGATAC:GTATCGCC': 201,
#  'GCGATACG:CGTATCGC': 79,
#  'CGATACGC:GCGTATCG': 74,
#  'GATACGCC:GGCGTATC': 159,
#  'ATACGCCC:GGGCGTAT': 145,
#  'TACGCCCT:AGGGCGTA': 106,
#  'ACGCCCTA:TAGGGCGT': 121,
#  'CGCCCTAC:GTAGGGCG': 159,
#  'GCCCTACG:CGTAGGGC': 63,
#  'CCCTACGG:CCGTAGGG': 226,
#  'CCTACGGG:CCCGTAGG': 183,
#  'CTACGGGC:GCCCGTAG': 61,
#  'TACGGGCA:TGCCCGTA': 141,
#  'ACGGGCAC:GTGCCCGT': 34,
#  'CGGGCACG:CGTGCCCG': 56,
#  'GGGCACGC:GCGTGCCC': 41,
#  'GGCACGCT:AGCGTGCC': 68,
#  'GCACGCTG:CAGCGTGC': 76,
#  'CACGCTGC:GCAGCGTG': 130,
#  'ACGCTGCG:CGCAGCGT': 321,
#  'CGCTGCGC:GCGCAGCG': 367,
#  'GCTGCGCG:CGCGCAGC': 90,
#  'CTGCGCGA:TCGCGCAG': 102,
#  'TGCGCGAT:ATCGCGCA': 228,
#  'GCGCGATC:GATCGCGC': 588,
#  'CGCGATCG:CGATCGCG': 1844,
#  'TCGCACTG:CAGTGCGA': 310,
#  'CGCACTGG:CCAGTGCG': 113,
#  'GCACTGGC:GCCAGTGC': 98,
#  'CACTGGCG:CGCCAGTG': 164,
#  'ACTGGCGA:TCGCCAGT': 283,
#  'CTGGCGAG:CTCGCCAG': 172,
#  'TGGCGAGG:CCTCGCCA': 264,
#  'GGCGAGGC:GCCTCGCC': 88,
#  'GCGAGGCG:CGCCTCGC': 81,
#  'AGGCGATC:GATCGCCT': 3104,
#  'GCCCTACA:TGTAGGGC': 144,
#  'CCCTACAG:CTGTAGGG': 512,
#  'CCTACAGG:CCTGTAGG': 298,
#  'CTACAGGC:GCCTGTAG': 137,
#  'TACAGGCA:TGCCTGTA': 105,
#  'ACAGGCAC:GTGCCTGT': 40,
#  'CAGGCACG:CGTGCCTG': 26,
#  'AGGCACGC:GCGTGCCT': 35,
#  'TGCGCGAA:TTCGCGCA': 74,
#  'GCGCGAAC:GTTCGCGC': 89,
#  'CGCGAACG:CGTTCGCG': 75,
#  'GCGAACGC:GCGTTCGC': 49,
#  'CGAACGCA:TGCGTTCG': 74,
#  'GAACGCAC:GTGCGTTC': 117,
#  'AACGCACT:AGTGCGTT': 110,
#  'ACGCACTT:AAGTGCGT': 68,
#  'CCGAGAAT:ATTCTCGG': 249,
#  'CGAGAATG:CATTCTCG': 199,
#  'GAGAATGT:ACATTCTC': 190,
#  'AGAATGTA:TACATTCT': 144,
#  'GAATGTAG:CTACATTC': 139,
#  'AATGTAGG:CCTACATT': 181,
#  'ATGTAGGC:GCCTACAT': 97,
#  'TGTAGGCG:CGCCTACA': 150,
#  'GTAGGCGA:TCGCCTAC': 236,
#  'CGAGAGGG:CCCTCTCG': 107,
#  'GAGAGGGT:ACCCTCTC': 235,
#  'AGAGGGTA:TACCCTCT': 217,
#  'GAGGGTAG:CTACCCTC': 256,
#  'AGGGTAGG:CCTACCCT': 179,
#  'GGGTAGGC:GCCTACCC': 137,
#  'GGTAGGCG:CGCCTACC': 158,
#  'GCACTTCT:AGAAGTGC': 203,
#  'CACTTCTG:CAGAAGTG': 316,
#  'ACTTCTGA:TCAGAAGT': 291,
#  'CTTCTGAG:CTCAGAAG': 224,
#  'TTCTGAGG:CCTCAGAA': 387,
#  'TCTGAGGT:ACCTCAGA': 336,
#  'CTGAGGTA:TACCTCAG': 131,
#  'TGAGGTAG:CTACCTCA': 208,
#  'GAGGTAGG:CCTACCTC': 162,
#  'AGGTAGGC:GCCTACCT': 115,
#  'GAGGCTAG:CTAGCCTC': 105,
#  'AGGCTAGG:CCTAGCCT': 158,
#  'GGCTAGGC:GCCTAGCC': 133,
#  'GCTAGGCG:CGCCTAGC': 126,
#  'CTAGGCGA:TCGCCTAG': 215,
#  'GATCGCTC:GAGCGATC': 1188,
#  'ATCGCTCC:GGAGCGAT': 335,
#  'TCGCTCCT:AGGAGCGA': 180,
#  'CGCTCCTT:AAGGAGCG': 139,
#  'GCTCCTTA:TAAGGAGC': 100,
#  'CTCCTTAT:ATAAGGAG': 189,
#  'TCCTTATT:AATAAGGA': 158,
#  'CCTTATTC:GAATAAGG': 147,
#  'CTTATTCT:AGAATAAG': 107,
#  'TTATTCTG:CAGAATAA': 246,
#  'TATTCTGT:ACAGAATA': 222,
#  'ATTCTGTG:CACAGAAT': 197,
#  'TTCTGTGG:CCACAGAA': 418,
#  'TCTGTGGG:CCCACAGA': 295,
#  'CTGTGGGT:ACCCACAG': 306,
#  'TGTGGGTC:GACCCACA': 160,
#  'GTGGGTCT:AGACCCAC': 126,
#  'TGGGTCTA:TAGACCCA': 220,
#  'GGGTCTAT:ATAGACCC': 213,
#  'GGTCTATT:AATAGACC': 211,
#  'GTCTATTA:TAATAGAC': 181,
#  'TCTATTAA:TTAATAGA': 298,
#  'CTATTAAC:GTTAATAG': 355,
#  'TATTAACA:TGTTAATA': 358,
#  'ATTAACAT:ATGTTAAT': 401,
#  'TTAACATC:GATGTTAA': 336,
#  'TAACATCA:TGATGTTA': 359,
#  'AACATCAC:GTGATGTT': 277,
#  'ACATCACA:TGTGATGT': 156,
#  'CATCACAA:TTGTGATG': 179,
#  'ATCACAAC:GTTGTGAT': 286,
#  'TCACAACT:AGTTGTGA': 232,
#  'CACAACTA:TAGTTGTG': 180,
#  'ACAACTAA:TTAGTTGT': 260,
#  'CAACTAAC:GTTAGTTG': 194,
#  'AACTAACA:TGTTAGTT': 203,
#  'ACTAACAT:ATGTTAGT': 169,
#  'CTAACATT:AATGTTAG': 228,
#  'TAACATTT:AAATGTTA': 422,
#  'AACATTTG:CAAATGTT': 388,
#  'ACATTTGT:ACAAATGT': 174,
#  'CATTTGTC:GACAAATG': 193,
#  'ATTTGTCA:TGACAAAT': 369,
#  'TTTGTCAA:TTGACAAA': 645,
#  'TTGTCAAG:CTTGACAA': 353,
#  'TGTCAAGT:ACTTGACA': 218,
#  'GTCAAGTA:TACTTGAC': 163,
#  'TCAAGTAC:GTACTTGA': 166,
#  'CAAGTACG:CGTACTTG': 104,
#  'AAGTACGG:CCGTACTT': 121,
#  'AGTACGGA:TCCGTACT': 55,
#  'GTACGGAT:ATCCGTAC': 67,
#  'TACGGATA:TATCCGTA': 172,
#  'ACGGATAA:TTATCCGT': 214,
#  'CGGATAAC:GTTATCCG': 172,
#  'GGATAACC:GGTTATCC': 321,
#  'GATAACCG:CGGTTATC': 266,
#  'ATAACCGA:TCGGTTAT': 282,
#  'TAACCGAA:TTCGGTTA': 275,
#  'AACCGAAT:ATTCGGTT': 401,
#  'ACCGAATA:TATTCGGT': 233,
#  'CCGAATAC:GTATTCGG': 133,
#  'CGAATACT:AGTATTCG': 117,
#  'GAATACTT:AAGTATTC': 187,
#  'AATACTTT:AAAGTATT': 368,
#  'ATACTTTA:TAAAGTAT': 261,
#  'TACTTTAT:ATAAAGTA': 228,
#  'ACTTTATT:AATAAAGT': 305,
#  'CTTTATTC:GAATAAAG': 202,
#  'TTTATTCC:GGAATAAA': 276,
#  'TTATTCCG:CGGAATAA': 130,
#  'TATTCCGG:CCGGAATA': 237,
#  'ATTCCGGA:TCCGGAAT': 55,
#  'TTCCGGAA:TTCCGGAA': 114,
#  'TCCGGAAA:TTTCCGGA': 115,
#  'CCGGAAAA:TTTTCCGG': 628,
#  'CGGAAAAC:GTTTTCCG': 345,
#  'GGAAAACC:GGTTTTCC': 501,
#  'GAAAACCG:CGGTTTTC': 344,
#  'AAAACCGA:TCGGTTTT': 482,
#  'ACCGAATC:GATTCGGT': 193,
#  'CCGAATCA:TGATTCGG': 253,
#  'CGAATCAA:TTGATTCG': 153,
#  'GAATCAAT:ATTGATTC': 381,
#  'AATCAATT:AATTGATT': 875,
#  'ATCAATTC:GAATTGAT': 550,
#  'TCAATTCT:AGAATTGA': 461,
#  'CAATTCTC:GAGAATTG': 457,
#  'AATTCTCG:CGAGAATT': 386,
#  'ATTCTCGT:ACGAGAAT': 155,
#  'TTCTCGTC:GACGAGAA': 121,
#  'TCTCGTCT:AGACGAGA': 78,
#  'CTCGTCTC:GAGACGAG': 72,
#  'TCGTCTCT:AGAGACGA': 65,
#  'CGTCTCTG:CAGAGACG': 60,
#  'GTCTCTGG:CCAGAGAC': 204,
#  'TCTCTGGG:CCCAGAGA': 330,
#  'CTCTGGGA:TCCCAGAG': 314,
#  'TCTGGGAC:GTCCCAGA': 136,
#  'CTGGGACT:AGTCCCAG': 211,
#  'TGGGACTT:AAGTCCCA': 285,
#  'GGGACTTG:CAAGTCCC': 227,
#  'GGACTTGA:TCAAGTCC': 236,
#  'GACTTGAC:GTCAAGTC': 196,
#  'CTTGACAG:CTGTCAAG': 169,
#  'TTGACAGA:TCTGTCAA': 310,
#  'TGACAGAA:TTCTGTCA': 277,
#  'GACAGAAG:CTTCTGTC': 189,
#  'ACAGAAGA:TCTTCTGT': 313,
#  'CAGAAGAT:ATCTTCTG': 326,
#  'AGAAGATG:CATCTTCT': 401,
#  'GAAGATGG:CCATCTTC': 287,
#  'AAGATGGG:CCCATCTT': 293,
#  'AGATGGGC:GCCCATCT': 108,
#  'GATGGGCT:AGCCCATC': 172,
#  'ATGGGCTA:TAGCCCAT': 181,
#  'TGGGCTAG:CTAGCCCA': 174,
#  'GGGCTAGG:CCTAGCCC': 185,
#  'GGCTAGGG:CCCTAGCC': 379,
#  'GCTAGGGT:ACCCTAGC': 315,
#  'CTAGGGTT:AACCCTAG': 402,
#  'TAGGGTTT:AAACCCTA': 652,
#  'AGGGTTTT:AAAACCCT': 574,
#  'GGGTTTTG:CAAAACCC': 753,
#  'GGTTTTGA:TCAAAACC': 764,
#  'GTTTTGAT:ATCAAAAC': 641,
#  'TTTTGATA:TATCAAAA': 943,
#  'TTTGATAT:ATATCAAA': 712,
#  'TTGATATG:CATATCAA': 254,
#  'TGATATGG:CCATATCA': 263,
#  'GATATGGG:CCCATATC': 270,
#  'ATATGGGG:CCCCATAT': 289,
#  'TATGGGGT:ACCCCATA': 303,
#  'ATGGGGTA:TACCCCAT': 327,
#  'TGGGGTAA:TTACCCCA': 553,
#  'GGGGTAAG:CTTACCCC': 223,
#  'GGGTAAGT:ACTTACCC': 231,
#  'GGTAAGTT:AACTTACC': 233,
#  'GTAAGTTG:CAACTTAC': 142,
#  'TAAGTTGT:ACAACTTA': 265,
#  'AAGTTGTT:AACAACTT': 426,
#  'AGTTGTTT:AAACAACT': 496,
#  'GTTGTTTT:AAAACAAC': 373,
#  'TTGTTTTC:GAAAACAA': 263,
#  'TGTTTTCA:TGAAAACA': 221,
#  'GTTTTCAC:GTGAAAAC': 188,
#  'TTTTCACT:AGTGAAAA': 336,
#  'TTTCACTA:TAGTGAAA': 322,
#  'TTCACTAC:GTAGTGAA': 257,
#  'TCACTACA:TGTAGTGA': 116,
#  'CACTACAG:CTGTAGTG': 129,
#  'ACTACAGT:ACTGTAGT': 136,
#  'CTACAGTA:TACTGTAG': 157,
#  'TACAGTAT:ATACTGTA': 107,
#  'ACAGTATT:AATACTGT': 218,
#  'CAGTATTT:AAATACTG': 388,
#  'AGTATTTT:AAAATACT': 574,
#  'GTATTTTT:AAAAATAC': 656,
#  'TATTTTTG:CAAAAATA': 928,
#  'ATTTTTGC:GCAAAAAT': 766,
#  'TTTTTGCC:GGCAAAAA': 800,
#  'TTTTGCCA:TGGCAAAA': 775,
#  'TTTGCCAA:TTGGCAAA': 584,
#  'TTGCCAAC:GTTGGCAA': 287,
#  'TGCCAACC:GGTTGGCA': 426,
#  'GCCAACCT:AGGTTGGC': 255,
#  'CCAACCTT:AAGGTTGG': 260,
#  'CAACCTTT:AAAGGTTG': 326,
#  'AACCTTTG:CAAAGGTT': 419,
#  'ACCTTTGA:TCAAAGGT': 333,
#  'CCTTTGAA:TTCAAAGG': 259,
#  'CTTTGAAC:GTTCAAAG': 249,
#  'TTTGAACT:AGTTCAAA': 315,
#  'TTGAACTC:GAGTTCAA': 207,
#  'TGAACTCT:AGAGTTCA': 110,
#  'GAACTCTG:CAGAGTTC': 139,
#  'AACTCTGT:ACAGAGTT': 204,
#  'ACTCTGTC:GACAGAGT': 100,
#  'CTCTGTCC:GGACAGAG': 88,
#  'TCTGTCCA:TGGACAGA': 147,
#  'CTGTCCAC:GTGGACAG': 113,
#  'TGTCCACC:GGTGGACA': 116,
#  'GTCCACCC:GGGTGGAC': 85,
#  'TCCACCCA:TGGGTGGA': 362,
#  'CCACCCAC:GTGGGTGG': 258,
#  'CACCCACT:AGTGGGTG': 185,
#  'ACCCACTG:CAGTGGGT': 126,
#  'CCCACTGA:TCAGTGGG': 174,
#  'CCACTGAT:ATCAGTGG': 249,
#  'CACTGATA:TATCAGTG': 245,
#  'ACTGATAA:TTATCAGT': 439,
#  'CTGATAAA:TTTATCAG': 633,
#  'TGATAAAC:GTTTATCA': 430,
#  'GATAAACA:TGTTTATC': 276,
#  'ATAAACAT:ATGTTTAT': 300,
#  'TAAACATA:TATGTTTA': 235,
#  'AAACATAA:TTATGTTT': 302,
#  'AACATAAA:TTTATGTT': 386,
#  'ACATAAAA:TTTTATGT': 423,
#  'CATAAAAT:ATTTTATG': 572,
#  'ATAAAATC:GATTTTAT': 788,
#  'TAAAATCC:GGATTTTA': 597,
#  'AAAATCCA:TGGATTTT': 549,
#  'AAATCCAA:TTGGATTT': 518,
#  'AATCCAAC:GTTGGATT': 289,
#  'ATCCAACC:GGTTGGAT': 229,
#  'TCCAACCC:GGGTTGGA': 272,
#  'CCAACCCG:CGGGTTGG': 297,
#  'CAACCCGG:CCGGGTTG': 264,
#  'AACCCGGT:ACCGGGTT': 544,
#  'ACCCGGTC:GACCGGGT': 197,
#  'CCCGGTCG:CGACCGGG': 116,
#  'CCGGTCGC:GCGACCGG': 80,
#  'CGGTCGCC:GGCGACCG': 112,
#  'GGTCGCCC:GGGCGACC': 198,
#  'GTCGCCCT:AGGGCGAC': 224,
#  'TCGCCCTA:TAGGGCGA': 414,
#  'CGCCCTAG:CTAGGGCG': 379,
#  'GCCCTAGC:GCTAGGGC': 243,
#  'CCTAGCCG:CGGCTAGG': 194,
#  'CTAGCCGC:GCGGCTAG': 121,
#  'TAGCCGCC:GGCGGCTA': 410,
#  'AGCCGCCT:AGGCGGCT': 316,
#  'GCCGCCTG:CAGGCGGC': 289,
#  'CCGCCTGA:TCAGGCGG': 201,
#  'CGCCTGAC:GTCAGGCG': 124,
#  'GCCTGACT:AGTCAGGC': 93,
#  'CCTGACTG:CAGTCAGG': 151,
#  'CTGACTGT:ACAGTCAG': 258,
#  'TGACTGTC:GACAGTCA': 140,
#  'GACTGTCA:TGACAGTC': 132,
#  'ACTGTCAT:ATGACAGT': 142,
#  'CTGTCATA:TATGACAG': 115,
#  'TGTCATAT:ATATGACA': 100,
#  'GTCATATT:AATATGAC': 288,
#  'TCATATTG:CAATATGA': 285,
#  'CATATTGA:TCAATATG': 342,
#  'ATATTGAC:GTCAATAT': 518,
#  'TATTGACT:AGTCAATA': 375,
#  'ATTGACTA:TAGTCAAT': 363,
#  'TTGACTAT:ATAGTCAA': 418,
#  'TGACTATC:GATAGTCA': 273,
#  'GACTATCT:AGATAGTC': 308,
#  'ACTATCTC:GAGATAGT': 230,
#  'CTATCTCC:GGAGATAG': 281,
#  'TATCTCCT:AGGAGATA': 324,
#  'ATCTCCTA:TAGGAGAT': 274,
#  'TCTCCTAA:TTAGGAGA': 341,
#  'CTCCTAAA:TTTAGGAG': 471,
#  'TCCTAAAA:TTTTAGGA': 413,
#  'CCTAAAAA:TTTTTAGG': 571,
#  'CTAAAAAT:ATTTTTAG': 740,
#  'TAAAAATA:TATTTTTA': 858,
#  'AAAAATAG:CTATTTTT': 721,
#  'AAAATAGG:CCTATTTT': 470,
#  'AAATAGGG:CCCTATTT': 684,
#  'AATAGGGC:GCCCTATT': 333,
#  'ATAGGGCG:CGCCCTAT': 198,
#  'TAGGGCGG:CCGCCCTA': 358,
#  'AGGGCGGG:CCCGCCCT': 470,
#  'GGGCGGGT:ACCCGCCC': 1536,
#  'GGCGGGTT:AACCCGCC': 1678,
#  'GCGGGTTG:CAACCCGC': 258,
#  'CGGGTTGT:ACAACCCG': 250,
#  'GGGTTGTT:AACAACCC': 345,
#  'GGTTGTTT:AAACAACC': 270,
#  'GTTGTTTA:TAAACAAC': 407,
#  'TTGTTTAA:TTAAACAA': 656,
#  'TGTTTAAT:ATTAAACA': 513,
#  'GTTTAATA:TATTAAAC': 388,
#  'TTTAATAT:ATATTAAA': 556,
#  'TTAATATT:AATATTAA': 708,
#  'TAATATTG:CAATATTA': 555,
#  'AATATTGC:GCAATATT': 506,
#  'ATATTGCC:GGCAATAT': 579,
#  'TATTGCCA:TGGCAATA': 563,
#  'ATTGCCAT:ATGGCAAT': 517,
#  'TTGCCATT:AATGGCAA': 696,
#  'TGCCATTA:TAATGGCA': 510,
#  'GCCATTAT:ATAATGGC': 453,
#  'CCATTATC:GATAATGG': 427,
#  'CATTATCT:AGATAATG': 370,
#  'ATTATCTA:TAGATAAT': 577,
#  'TTATCTAA:TTAGATAA': 536,
#  'TATCTAAC:GTTAGATA': 288,
#  'ATCTAACT:AGTTAGAT': 297,
#  'TCTAACTC:GAGTTAGA': 336,
#  'CTAACTCC:GGAGTTAG': 347,
#  'TAACTCCC:GGGAGTTA': 470,
#  'AACTCCCG:CGGGAGTT': 404,
#  'ACTCCCGA:TCGGGAGT': 266,
#  'CTCCCGAT:ATCGGGAG': 178,
#  'TCCCGATG:CATCGGGA': 239,
#  'CCCGATGT:ACATCGGG': 116,
#  'CCGATGTA:TACATCGG': 95,
#  'CGATGTAA:TTACATCG': 161,
#  'GATGTAAT:ATTACATC': 280,
#  'ATGTAATA:TATTACAT': 206,
#  'TGTAATAT:ATATTACA': 222,
#  'GTAATATC:GATATTAC': 497,
#  'TAATATCT:AGATATTA': 507,
#  'AATATCTG:CAGATATT': 658,
#  'ATATCTGT:ACAGATAT': 282,
#  'TATCTGTT:AACAGATA': 356,
#  'ATCTGTTC:GAACAGAT': 234,
#  'TCTGTTCC:GGAACAGA': 209,
#  'CTGTTCCT:AGGAACAG': 302,
#  'TGTTCCTT:AAGGAACA': 202,
#  'GTTCCTTG:CAAGGAAC': 215,
#  'TTCCTTGC:GCAAGGAA': 168,
#  'TCCTTGCG:CGCAAGGA': 80,
#  'CCTTGCGG:CCGCAAGG': 209,
#  'CTTGCGGT:ACCGCAAG': 128,
#  'TTGCGGTC:GACCGCAA': 92,
#  'TGCGGTCA:TGACCGCA': 176,
#  'GCGGTCAG:CTGACCGC': 197,
#  'CGGTCAGG:CCTGACCG': 182,
#  'GGTCAGGA:TCCTGACC': 401,
#  'GTCAGGAC:GTCCTGAC': 149,
#  'TCAGGACT:AGTCCTGA': 326,
#  'CAGGACTG:CAGTCCTG': 219,
#  'AGGACTGC:GCAGTCCT': 98,
#  'GGACTGCC:GGCAGTCC': 89,
#  'GACTGCCA:TGGCAGTC': 158,
#  'ACTGCCAA:TTGGCAGT': 551,
#  'CTGCCAAA:TTTGGCAG': 364,
#  'TGCCAAAA:TTTTGGCA': 697,
#  'GCCAAAAA:TTTTTGGC': 855,
#  'CCAAAAAT:ATTTTTGG': 1023,
#  'CAAAAATT:AATTTTTG': 1036,
#  'AAAAATTC:GAATTTTT': 728,
#  'AAAATTCC:GGAATTTT': 818,
#  'AAATTCCC:GGGAATTT': 1038,
#  'ATTCCCCC:GGGGGAAT': 668,
#  'TTCCCCCA:TGGGGGAA': 735,
#  'TCCCCCAT:ATGGGGGA': 327,
#  'CCCCCATC:GATGGGGG': 287,
#  'CCCCATCA:TGATGGGG': 600,
#  'CCCATCAA:TTGATGGG': 496,
#  'CCATCAAA:TTTGATGG': 665,
#  'CATCAAAC:GTTTGATG': 475,
#  'TCAAACAG:CTGTTTGA': 377,
#  'CAAACAGG:CCTGTTTG': 297,
#  'AAACAGGG:CCCTGTTT': 389,
#  'AACAGGGA:TCCCTGTT': 333,
#  'ACAGGGAG:CTCCCTGT': 186,
#  'CAGGGAGT:ACTCCCTG': 259,
#  'AGGGAGTC:GACTCCCT': 250,
#  'GGGAGTCT:AGACTCCC': 242,
#  'GGAGTCTA:TAGACTCC': 154,
#  'GAGTCTAA:TTAGACTC': 200,
#  'AGTCTAAC:GTTAGACT': 148,
#  'GTCTAACC:GGTTAGAC': 179,
#  'TCTAACCC:GGGTTAGA': 316,
#  'CTAACCCC:GGGGTTAG': 385,
#  'TAACCCCC:GGGGGTTA': 449,
#  'AACCCCCG:CGGGGGTT': 261,
#  'ACCCCCGT:ACGGGGGT': 175,
#  'CCCCCGTT:AACGGGGG': 208,
#  'CCCCGTTG:CAACGGGG': 214,
#  'CCCGTTGT:ACAACGGG': 215,
#  'CCGTTGTC:GACAACGG': 144,
#  'CGTTGTCT:AGACAACG': 104,
#  'GTTGTCTA:TAGACAAC': 197,
#  'TTGTCTAA:TTAGACAA': 336,
#  'TGTCTAAA:TTTAGACA': 276,
#  'GTCTAAAG:CTTTAGAC': 206,
#  'TCTAAAGA:TCTTTAGA': 400,
#  'CTAAAGAT:ATCTTTAG': 438,
#  'TAAAGATA:TATCTTTA': 364,
#  'AAAGATAT:ATATCTTT': 404,
#  'AAGATATC:GATATCTT': 508,
#  'AGATATCT:AGATATCT': 372,
#  'GATATCTC:GAGATATC': 355,
#  'ATATCTCG:CGAGATAT': 235,
#  'TATCTCGC:GCGAGATA': 165,
#  'ATCTCGCA:TGCGAGAT': 172,
#  'TCTCGCAG:CTGCGAGA': 164,
#  'CTCGCAGT:ACTGCGAG': 169,
#  'TCGCAGTT:AACTGCGA': 344,
#  'CGCAGTTC:GAACTGCG': 156,
#  'GCAGTTCA:TGAACTGC': 171,
#  'CAGTTCAT:ATGAACTG': 217,
#  'AGTTCATT:AATGAACT': 203,
#  'GTTCATTT:AAATGAAC': 246,
#  'TTCATTTT:AAAATGAA': 470,
#  'TCATTTTG:CAAAATGA': 387,
#  'CATTTTGG:CCAAAATG': 487,
#  'ATTTTGGT:ACCAAAAT': 709,
#  'TTTTGGTC:GACCAAAA': 552,
#  'TTTGGTCG:CGACCAAA': 332,
#  'TTGGTCGC:GCGACCAA': 266,
#  'TGGTCGCC:GGCGACCA': 327,
#  'GGTCGCCA:TGGCGACC': 314,
#  'GTCGCCAC:GTGGCGAC': 222,
#  'TCGCCACC:GGTGGCGA': 475,
#  'CGCCACCG:CGGTGGCG': 381,
#  'GCCACCGG:CCGGTGGC': 209,
#  'CCACCGGA:TCCGGTGG': 453,
#  'CACCGGAG:CTCCGGTG': 305,
#  'ACCGGAGA:TCTCCGGT': 390,
#  'CCGGAGAC:GTCTCCGG': 159,
#  'CGGAGACA:TGTCTCCG': 97,
#  'GGAGACAA:TTGTCTCC': 170,
#  'GAGACAAT:ATTGTCTC': 232,
#  'AGACAATG:CATTGTCT': 216,
#  'GACAATGA:TCATTGTC': 286,
#  'ACAATGAG:CTCATTGT': 116,
#  'CAATGAGC:GCTCATTG': 87,
#  'AATGAGCC:GGCTCATT': 111,
#  'ATGAGCCA:TGGCTCAT': 223,
#  'TGAGCCAC:GTGGCTCA': 202,
#  'GAGCCACC:GGTGGCTC': 207,
#  'AGCCACCG:CGGTGGCT': 332,
#  'GCCACCGA:TCGGTGGC': 241,
#  'CCACCGAC:GTCGGTGG': 230,
#  'CACCGACT:AGTCGGTG': 196,
#  'ACCGACTA:TAGTCGGT': 186,
#  'CCGACTAG:CTAGTCGG': 93,
#  'CGACTAGA:TCTAGTCG': 98,
#  'GACTAGAG:CTCTAGTC': 124,
#  'ACTAGAGG:CCTCTAGT': 162,
#  'CTAGAGGC:GCCTCTAG': 108,
#  'TAGAGGCA:TGCCTCTA': 173,
#  'AGAGGCAG:CTGCCTCT': 208,
#  'GAGGCAGT:ACTGCCTC': 137,
#  'AGGCAGTT:AACTGCCT': 255,
#  'GGCAGTTT:AAACTGCC': 382,
#  'GCAGTTTG:CAAACTGC': 371,
#  'CAGTTTGT:ACAAACTG': 307,
#  'AGTTTGTT:AACAAACT': 389,
#  'GTTTGTTG:CAACAAAC': 333,
#  'TTTGTTGG:CCAACAAA': 539,
#  'TTGTTGGC:GCCAACAA': 335,
#  'TGTTGGCG:CGCCAACA': 427,
#  'GTTGGCGT:ACGCCAAC': 191,
#  'TTGGCGTA:TACGCCAA': 202,
#  'TGGCGTAA:TTACGCCA': 189,
#  'GGCGTAAT:ATTACGCC': 172,
#  'GCGTAATT:AATTACGC': 164,
#  'CGTAATTC:GAATTACG': 126,
#  'GTAATTCT:AGAATTAC': 334,
#  'TAATTCTG:CAGAATTA': 570,
#  'AATTCTGC:GCAGAATT': 381,
#  'ATTCTGCT:AGCAGAAT': 361,
#  'TTCTGCTA:TAGCAGAA': 489,
#  'TCTGCTAA:TTAGCAGA': 434,
#  'CTGCTAAA:TTTAGCAG': 483,
#  'TGCTAAAC:GTTTAGCA': 361,
#  'GCTAAACC:GGTTTAGC': 405,
#  'CTAAACCC:GGGTTTAG': 539,
#  'TAAACCCT:AGGGTTTA': 512,
#  'AAACCCTC:GAGGGTTT': 434,
#  'AACCCTCG:CGAGGGTT': 204,
#  'ACCCTCGG:CCGAGGGT': 152,
#  'CCCTCGGC:GCCGAGGG': 111,
#  'CCTCGGCG:CGCCGAGG': 142,
#  'CTCGGCGA:TCGCCGAG': 137,
#  'TCGGCGAC:GTCGCCGA': 190,
#  'CGGCGACT:AGTCGCCG': 248,
#  'GGCGACTT:AAGTCGCC': 312,
#  'GCGACTTC:GAAGTCGC': 197,
#  'CGACTTCA:TGAAGTCG': 125,
#  'GACTTCAC:GTGAAGTC': 109,
#  'ACTTCACA:TGTGAAGT': 87,
#  'CTTCACAG:CTGTGAAG': 178,
#  'TTCACAGG:CCTGTGAA': 132,
#  'TCACAGGT:ACCTGTGA': 183,
#  'CACAGGTG:CACCTGTG': 157,
#  'ACAGGTGA:TCACCTGT': 351,
#  'CAGGTGAG:CTCACCTG': 178,
#  'AGGTGAGT:ACTCACCT': 155,
#  'GGTGAGTA:TACTCACC': 189,
#  'GTGAGTAA:TTACTCAC': 219,
#  'TGAGTAAA:TTTACTCA': 375,
#  'GAGTAAAC:GTTTACTC': 198,
#  'AGTAAACC:GGTTTACT': 269,
#  'GTAAACCT:AGGTTTAC': 260,
#  'TAAACCTC:GAGGTTTA': 258,
#  'AAACCTCG:CGAGGTTT': 227,
#  'AACCTCGG:CCGAGGTT': 244,
#  'ACCTCGGC:GCCGAGGT': 138,
#  'CTCGGCGG:CCGCCGAG': 163,
#  'TCGGCGGA:TCCGCCGA': 139,
#  'CGGCGGAC:GTCCGCCG': 126,
#  'GGCGGACT:AGTCCGCC': 198,
#  'GCGGACTT:AAGTCCGC': 165,
#  'CGGACTTC:GAAGTCCG': 162,
#  'GGACTTCT:AGAAGTCC': 217,
#  'GACTTCTT:AAGAAGTC': 222,
#  'ACTTCTTG:CAAGAAGT': 254,
#  'CTTCTTGG:CCAAGAAG': 274,
#  'TCTTGGGC:GCCCAAGA': 305,
#  'CTTGGGCG:CGCCCAAG': 317,
#  'TTGGGCGT:ACGCCCAA': 184,
#  'TGGGCGTA:TACGCCCA': 100,
#  'GGGCGTAA:TTACGCCC': 94,
#  'GGCGTAAA:TTTACGCC': 176,
#  ...}
