# %%
#!/usr/bin/env python3

########################################################################
# File: Chan_Nicholas_missingMotif.ipynb
# Purpose: to find hidden motifs
#   main(infile='FILE_PATH',outfile='FILE_PATH', inCL=['--minMotif', '3', '--maxMotif', '8', '--cutoff', '0'])
#
# Author: Nicholas Chan
# History: 10/18/2021 Created
########################################################################

# %% [markdown]
# # Command Line Class
# Provided by Dr. B for parsing command line arguments

# %%
########################################################################
# CommandLine
########################################################################


class CommandLine():
    """
    Handle the command line, usage and help requests.

    CommandLine uses argparse,
    it implements a standard command line argument parser with various argument options,
    a standard usage and help, and an error termination exception Usage.
    """

    def __init__(self, inOpts = None):
        """
        CommandLine constructor.
        
        Implement a parser to interpret the command line argv string using argparse.
        """
        import argparse
        self.parser = argparse.ArgumentParser(
            description='Program prolog - a brief description of what this thing does',
            epilog='Program epilog - some other stuff you feel compelled to say',
            add_help=True,  # default is True
            prefix_chars='-',
            usage='%(prog)s [options] -option1[default] <input >output'
            )

        self.parser.add_argument('-m', '--minMotif', type=int, default=3, action='store', help='minimum motif length to consider for Markov Model')
        self.parser.add_argument('-M', '--maxMotif', type=int, default=8, action='store', help='maximum motif length to consider for Markov Model')
        self.parser.add_argument('-c', '--cutoff', type=int, default=-4, action='store', help='Significant Z-score cutoff value')
        # Command line option to use Gibbs sampling to find the optimal consensus motif.
#         self.parser.add_argument('-g', '--gibbsampling', type=float, default=1, action='store', help='implement Gibbs sampling')

        if inOpts is None:
            self.args = self.parser.parse_args()
        else:
            self.args = self.parser.parse_args(inOpts)

# %% [markdown]
# # FastAreader Class
# Provided by Dr. B for reading Fasta Files.

# %%
import sys

class FastAreader():
    """
    Read in files and preprocess.
    """
    def __init__(self, fname=''):
        """ Contructor: saves attribute fname. """
        self.fname = fname

    def doOpen(self):
        """ Open a file."""
        if self.fname == '':
            return sys.stdin
        else:
            return open(self.fname)

    def readFasta(self):
        """ Read in a fasta file and yield header and sequences separately"""
        header = ''
        sequence = ''

        with self.doOpen() as fileH:

            header = ''
            sequence = ''

            # skip to first fasta header
            line = fileH.readline()
            while not line.startswith('>'):
                line = fileH.readline()
            header = line[1:].rstrip()

            # Separate headers and sequences
            for line in fileH:
                if line.startswith('>'):
                    yield header, sequence
                    header = line[1:].rstrip()
                    sequence = ''
                else:
                    sequence += ''.join(line.rstrip().split()).upper()

        yield header, sequence

# %% [markdown]
# # Assignment 2: Missing Motif
#
# For this assingment, I used a Markov(K-2) Model to find the probabilities of K-mers (of length K) which I assumed
# followed the binomial distribution. With these statistics I was able to print out motifs by order of their z-score (ascending order)
# and then by their length (descending order). Through the nature of this output, we can assume that the motifs
# hiding from us are those with lower z-score (closer to the top relative to motifs of the same length).
#
# ### NULL Model
# - For a Markov(1) Model, we consider a preceding base
#     - Ex:
#
#         $P(A|T_{prev}) = \frac{P(TA)}{P(T)} = \frac{\frac{c(TA)}{N}}{\frac{c(T)}{N}} = \frac{c(TA)}{c(T)}$
#
#         - N is not the same in the cases of TA and T, but the difference is negligible for now
# - For a Markov(8) Model, we consider a preceding base
#     - Ex:
#
#         $Pr(K) = N * E(K) = \frac{1}{N} \frac{c(k_{1}k_{2}k_{3}k_{4}k_{5}k_{6}k_{7}) * c(k_{2}k_{3}k_{4}k_{5}k_{6}k_{7}k_{8})}{c(k_{2}k_{3}k_{4}k_{5}k_{6}k_{7})} $
# - Increasing the order of a Markov Model makes our model more informed
# - Check Week 2 Overview Video 3 for more details on detailed Markov Model for 4-mer described by $k_{1}k_{2}k_{3}k_{4}$

# %%
## LATEST TO WORK KINDA
import sys
import os 

class SearchForMissing:
    '''
    Initializes a length for the seqList fed as input, a dictionary, 
    a dictionary with nucleotide counts from a given list of sequences 
    (read in with FastAreader), and a list of motif (including the motif's 
    reverse complement) statistics.
    '''
    def __init__(self, seqList, minMotif, maxMotif, zCut):
        self.seqList = seqList
        self.minMotif = minMotif
        self.maxMotif = maxMotif
        self.zCut = zCut
        
        self.N = self.genomeLen() 
        self.ctDict = self.ctDictMake()
        self.output = self.outputMake()

    def genomeLen(self):
        '''
        Takes the sum of sequence lengths from the list of sequences, seqList.
        seqList is made with the FastAreader class and has 1 fasta seq per entry.
        '''
        totLen = 0
        for seq in self.seqList:
            totLen += len(seq)
        return totLen

    def ctDictMake(self):
        '''
        Stores a dict of dicts
        {1:{'A':25, 'C':33,...}, ... ,8:{'AAAAGGGG':12, 'AAAATTTT':11, ...}}
        Reads over each sequence in the fasta. For each sequence, a sliding window
        moves over its respective sequence length and k-mers are counted.
        '''
        
        finalDict = dict() # The final dict returned, stores "collapsed counts" of motifs and their reverse complements
        massDict = dict() # Dictionary that holds dictionaries which hold k-mers and their respective counts
        for k in range(1, self.maxMotif+1): # Initialize dictionaries for min to max motif sizes within massDict
            massDict[k] = dict()
        for k in range(1, self.maxMotif+1): # Initialize dictionaries for min to max motif sizes within massDict
            finalDict[k] = dict()
        for seq in self.seqList: # Loop through seqs in a fasta file
            for k in range(1, self.maxMotif+1): # Loop through possible motif lengths
                for kmer_idx in range((len(seq)-k)): # Loop through all sliding frame indices of a sequence string
                    kmer = seq[kmer_idx:kmer_idx+k]
                    if 'N' not in kmer: # Ignore motifs with N as a nucleotide
                        if kmer in massDict[k]: # If motif exists in dict, increment
                            massDict[k][kmer] += 1
                        else: # If motif is new to dict, create an entry with value = 1
                            massDict[k][kmer] = 1
        # Finished composing massDict
        # Begin composing finalDict
        for k in range(1, self.maxMotif+1): # Loop through possible motif lengths
            banned = set() # Create a set to hold already considered motifs, this prevents overcounting
            for kmer in massDict[k]: # Loop through all motif entries in massDict
                if kmer not in banned: # If motif is not considered yet, proceed
                    banned.add(kmer)
                    banned.add(revComp(kmer))
                    if kmer != revComp(kmer): # If k-mer and its reverse complements are the same, collapse their counts
                        if revComp(kmer) in massDict[k]: # If k-mer and its reverse complements exist, collapse their counts
                            finalDict[k][kmer] = massDict[k][kmer] + massDict[k][revComp(kmer)]
                            finalDict[k][revComp(kmer)] = massDict[k][kmer] + massDict[k][revComp(kmer)]
                        else: # If reverse complement isn't found, but the k-mer is
                            finalDict[k][revComp(kmer)] = massDict[k][kmer]
                    else: # If k-mer and its reverse complements are the same, make an entry for the reverse complement with the k-mer's count, REVERSE COMPLEMENT PALINDROME
                        finalDict[k][revComp(kmer)] = massDict[k][kmer]
                else: # I k-mer is already considered, continue
                    continue
        return finalDict
    
    
    def outputMake(self):
        '''
        Creates a list containing sorted output. This method calculates statistics such
        as motif counts, motif expectation, motif standard deviation, and motif z-score
        following the binomial distribution as well as a Markov(K-2) Model where K = motif length.
        Entries are taken from ctDict keys and are transformed into output through this method.
        '''
        finalList = [] # List which will hold tuples of printable output 
        for k in range(self.minMotif, self.maxMotif+1):
            banned = set()
            for kmer in self.ctDict[k]:
                if kmer not in banned:
                    banned.add(kmer) 
                    banned.add(revComp(kmer))
                    # Compute sequenceReverse entry
                    reverseCompKmer = revComp(kmer) # K-mer reverse compliment variable
                    tmpList = sorted([kmer,reverseCompKmer]) # Temporary list used for sorting kmer and reverse kmer for output
                    sequenceReverse = (tmpList[0],tmpList[1]) # sequence: reverse entry for output
                    # Compute count entry
                    count = self.ctDict[k][kmer]
                    # Compute expectation entry
                    Lkmer = self.ctDict[k-1][kmer[:-1]] 
                    Rkmer = self.ctDict[k-1][kmer[1:]] 
                    Mkmer = self.ctDict[k-2][kmer[1:-1]]
                    expectation = (Lkmer*Rkmer)/Mkmer # Mean following binomial distribution
                    # Compute zscore entry
                    numerator = count - expectation
                    sd = (expectation * (1 - expectation/self.N))**0.5 # Standard deviation following binomial distribution
                    zscore = numerator/sd
                    entry = (tmpList, count, expectation, zscore, k) # k (motif length) has been included for sorting purposes
                    # Append finished entry into list
                    finalList.append(entry)
                else:
                    continue
        finalList.sort(key=lambda x:x[-2]) # Sort by z-score
        finalList.sort(reverse=True, key=lambda x:x[-1]) # Sort by motif length
        return finalList

# %% [markdown]
# # Main function
# Main function is written here. This function handles argument parsing, input, and output.

# %%
### REVERESE COMPLIMENT FUNCTION ###
def revComp(seqStr):
    newStr = ''
    baseDict = {'A':'T', 'T':'A', 'C':'G', 'G':'C', 'N':'N'}
    for char in seqStr:
        newStr += baseDict[char]
    return newStr[::-1]

def main(infile, outfile='', inCL=None):
    '''
    This is the main function. Arguments are parsed here with the CommandLine class
    provided by Dr. B. Infile and outfile are also read here, with an outfile file being 
    optional. IF no outfile is provided, output is printed. Infile is read in through the
    readData function which returns fasta file information for the missingMotif to read.
    This way, input only needs to be read once. missingMotif is called on a fasta file holding
    either one or many sequences. Statistics such as observed counts, expected values, and z-score
    are printed to output after a call to main(). Output is sorted by order of z-score (in ascending 
    order technically) and by order of motif lenght (in descending order).
    '''

    myCommandLine = CommandLine(inCL)
    minMotif = myCommandLine.args.minMotif
    maxMotif = myCommandLine.args.maxMotif
    cutoff = myCommandLine.args.cutoff
    
    def readData(infile:'str') -> 'tuple(list,str)':
        '''
        Reads in fasta file as input. 
        Returns [0]: a list of seqs [1]: a string of catted seqs.
        '''
        seqList = []
        readData = FastAreader(infile).readFasta()
        for line in readData:
            seqList.append(line[1]) # Append seq and not head to seqList
        return seqList
    
    seqList = readData(infile) # Saves output of FastAreader(infile).readFasta() as seqList
    
    sfm = SearchForMissing(seqList, minMotif, maxMotif, cutoff)

    if len(outfile) > 0:
        with open(outfile, 'w') as myfile:
            myfile.write(f'N = {sfm.N}\n')
            myfile.write("{0:8}:{1:>8}\t{2:5}\t{3:>7}\t{4:1}\n".format("sequence","reverse","count","Expect","Zscore"))
            for line in sfm.output:
                if line[3] < cutoff:
                    myfile.write('{0:8}:{1:8}\t{2:0d}\t{3:0.2f}\t{4:0.2f}\n'.format(line[0][0],line[0][1], line[1], line[2],line[3]))   
    else:        
        print(f'N = {sfm.N}')
        print("{0:8}:{1:>8}\t{2:5}\t{3:>7}\t{4:1}".format("sequence","reverse","count","Expect","Zscore"))
        for line in sfm.output:
            if line[3] < cutoff:
                print('{0:8}:{1:8}\t{2:0d}\t{3:0.2f}\t{4:0.2f}'.format(line[0][0],line[0][1], line[1], line[2],line[3]))

# %%
if __name__ == "__main__":
    '''
    Usage:
        main(infile='FILE_PATH', outfile='FILE_PATH', inCL=[-ipk] )
    Arguments:
        --minMotif
            Minimum motif length to consider for Markov Model
        --maxMotif
            Maximum motif length to consider for Markov Model
        --cutoff
            Significant Z-score cutoff value
    '''
    main(infile='mdata/Arthrospira-platensis-NIES-39.fna',outfile='', inCL=['--minMotif', '3', '--maxMotif', '8', '--cutoff', '-4'])
# Out:
# N = 6788435
# sequence: reverse	count	 Expect	Zscore
# GCGATCGC:GCGATCGC	7683	31752.94	-135.39
# AATTAATT:AATTAATT	558	2580.47	-39.82
# AAAATTTT:AAAATTTT	501	2185.49	-36.04
# TTAATTAA:TTAATTAA	537	2205.76	-35.54
# AAATATTT:AAATATTT	365	1705.30	-32.46
# ATAATTAT:ATAATTAT	364	1681.01	-32.13
# TTTTAAAA:TTTTAAAA	298	1251.69	-26.96
# CAAATTTG:CAAATTTG	245	1158.42	-26.84
# TAATATTA:TAATATTA	296	1222.71	-26.50
# TAAATTTA:TAAATTTA	413	1380.29	-26.04
# GATTAATC:GATTAATC	390	1342.07	-25.99
# TGATATCA:TGATATCA	300	1184.38	-25.70
# TATTAATA:TATTAATA	385	1310.43	-25.57
# ATCGCGAT:ATCGCGAT	294	1155.39	-25.34
# AATATATT:AATATATT	255	1051.57	-24.57
# ATTTAAAT:ATTTAAAT	195	945.67	-24.41
# GTTTAAAC:GTTTAAAC	269	1057.29	-24.25
# CCCTAGGG:CCCTAGGG	232	997.07	-24.23
# CAATATTG:CAATATTG	230	971.23	-23.79
# ACAATTGT:ACAATTGT	115	750.77	-23.20
# CATTAATG:CATTAATG	165	800.99	-22.47
# CTTTAAAG:CTTTAAAG	260	935.23	-22.08
# TTAGCTAA:TTAGCTAA	226	865.22	-21.73
# AAAATTTA:TAAATTTT	834	1736.84	-21.67
# GGTTAACC:GGTTAACC	191	798.36	-21.50
# TTGATCAA:TTGATCAA	225	851.57	-21.47
# GATTAATA:TATTAATC	549	1326.16	-21.34
# AGTTAACT:AGTTAACT	174	760.13	-21.26
# AATTAATA:TATTAATT	928	1838.89	-21.24
# AGATATCT:AGATATCT	186	776.94	-21.20
# AAACGTTT:AAACGTTT	89	610.72	-21.11
# GAATATTC:GAATATTC	169	740.56	-21.00
# ATCATGAT:ATCATGAT	201	791.44	-20.99
# AATTAATC:GATTAATT	976	1860.96	-20.52
# ATAATTAA:TTAATTAT	1032	1925.60	-20.37
# GAAATTTA:TAAATTTC	377	1030.37	-20.36
# TTTATAAA:TTTATAAA	207	772.49	-20.35
# CCGATCGC:GCGATCGG	1322	2283.15	-20.12
# ATATATAT:ATATATAT	253	830.94	-20.05
# TATATATA:TATATATA	162	675.77	-19.76
# TCAATTGA:TCAATTGA	151	654.34	-19.68
# GCGATCGA:TCGATCGC	1220	2120.19	-19.55
# TTGTACAA:TTGTACAA	95	550.76	-19.42
# GAAATTTC:GAAATTTC	233	769.16	-19.33
# GGATATCC:GGATATCC	162	652.30	-19.20
# ATAGCTAT:ATAGCTAT	150	629.24	-19.11
# TATCGATA:TATCGATA	147	624.39	-19.11
# ATTATAAT:ATTATAAT	200	708.17	-19.10
# TTTGCAAA:TTTGCAAA	133	590.67	-18.83
# ACGATCGC:GCGATCGT	1187	2033.72	-18.78
# GTTTAAAA:TTTTAAAC	518	1150.39	-18.65
# AAATATTA:TAATATTT	737	1443.98	-18.61
# GCAATTGC:GCAATTGC	136	581.59	-18.48
# CCAATTGG:CCAATTGG	133	575.88	-18.46
# AAAATTTG:CAAATTTT	856	1591.14	-18.43
# CTGATCAG:CTGATCAG	117	532.48	-18.01
# TTATATAA:TTATATAA	192	650.74	-17.98
# AATCGATT:AATCGATT	141	568.86	-17.94
# CTATATAG:CTATATAG	88	468.63	-17.58
# CATTAATC:GATTAATG	478	1036.81	-17.36
# GCTATAGC:GCTATAGC	130	528.57	-17.34
# ATATATAA:TTATATAT	270	735.34	-17.16
# TCCTAGGA:TCCTAGGA	61	407.10	-17.15
# ATTTAAAG:CTTTAAAT	418	940.43	-17.04
# GAACGTTC:GAACGTTC	34	354.42	-17.02
# GATATATC:GATATATC	134	517.04	-16.85
# AAATATTG:CAATATTT	686	1286.95	-16.75
# CAAATTTA:TAAATTTG	669	1264.50	-16.75
# CTTTAAAC:GTTTAAAG	467	994.39	-16.73
# GTAATTAA:TTAATTAC	449	967.52	-16.67
# CATTAATA:TATTAATG	503	1024.52	-16.29
# AAAATTTC:GAAATTTT	713	1296.53	-16.21
# CAATATTA:TAATATTG	555	1089.74	-16.20
# CTAATTAG:CTAATTAG	98	434.63	-16.15
# TGTTAACA:TGTTAACA	124	470.63	-15.98
# AATATATA:TATATATT	381	842.98	-15.91
# CTAATTAA:TTAATTAG	484	979.13	-15.82
# AATTAATG:CATTAATT	839	1437.68	-15.79
# GTAATTAC:GTAATTAC	101	424.38	-15.70
# ATGATCAT:ATGATCAT	118	451.10	-15.68
# CAAATTTC:GAAATTTG	464	943.94	-15.62
# GAATATTA:TAATATTC	470	951.57	-15.61
# CTTTAAAA:TTTTAAAG	571	1081.95	-15.53
# GGAATTCC:GGAATTCC	127	459.42	-15.51
# CAATATTC:GAATATTG	397	848.09	-15.49
# GGATATCA:TGATATCC	420	878.96	-15.48
# ATTATAAA:TTTATAAT	319	739.63	-15.47
# TTCATGAA:TTCATGAA	129	456.50	-15.33
# AGATATCA:TGATATCT	492	959.26	-15.09
# GCCATGGC:GCCATGGC	105	409.19	-15.04
# CCCATGGG:CCCATGGG	109	409.19	-14.84
# AAATATTC:GAATATTT	627	1123.78	-14.82
# ATTTAAAA:TTTTAAAT	601	1087.97	-14.76
# CGATATCG:CGATATCG	135	441.84	-14.60
# ATAGCTAA:TTAGCTAT	345	737.85	-14.46
# CCAATTGA:TCAATTGG	260	613.86	-14.28
# ATAATTAG:CTAATTAT	440	854.76	-14.19
# TCCATGGA:TCCATGGA	40	271.41	-14.05
# GTTATAAC:GTTATAAC	72	319.42	-13.84
# ACTATAGT:ACTATAGT	76	325.81	-13.84
# TAGCGCTA:TAGCGCTA	116	387.19	-13.78
# ATTGCAAT:ATTGCAAT	79	324.57	-13.63
# GTTGCAAC:GTTGCAAC	98	351.72	-13.53
# AGTTAACC:GGTTAACT	402	779.01	-13.51
# ATAATTAC:GTAATTAT	453	844.63	-13.48
# CGATATCA:TGATATCG	361	723.40	-13.47
# AGATATCG:CGATATCT	260	585.90	-13.46
# ATTTAAAC:GTTTAAAT	578	999.93	-13.34
# CATCGATG:CATCGATG	73	304.48	-13.27
# CATATATC:GATATATG	118	374.50	-13.25
# CCAATTGC:GCAATTGG	260	578.73	-13.25
# ACCTAGGT:ACCTAGGT	69	295.51	-13.18
# ATGATCAA:TTGATCAT	292	619.79	-13.17
# ATCATGAA:TTCATGAT	279	601.07	-13.14
# CAACGTTG:CAACGTTG	45	247.87	-12.89
# GATATATA:TATATATC	281	591.10	-12.76
# ACCTAGGG:CCCTAGGT	247	542.81	-12.70
# GTGATCAA:TTGATCAC	214	493.25	-12.57
# GGTTAACA:TGTTAACC	303	612.97	-12.52
# GTAGCTAC:GTAGCTAC	59	260.32	-12.48
# ATGTACAT:ATGTACAT	48	240.75	-12.42
# ACAATTGC:GCAATTGT	342	660.79	-12.40
# AATATATG:CATATATT	249	534.09	-12.34
# GTGATCAC:GTGATCAC	78	285.71	-12.29
# ACCATGGT:ACCATGGT	83	293.18	-12.28
# CGATATCC:GGATATCG	253	536.85	-12.25
# ATATATAG:CTATATAT	318	624.02	-12.25
# GATCGATC:GATCGATC	35	214.09	-12.24
# CCGATCGG:CCGATCGG	9	164.17	-12.11
# AGAATTCT:AGAATTCT	51	234.69	-11.99
# CTGATCAA:TTGATCAG	363	673.38	-11.96
# AGATATCC:GGATATCT	393	711.89	-11.95
# ACAATTGA:TCAATTGT	386	700.90	-11.90
# CCCATGGC:GCCATGGG	169	409.19	-11.87
# CATATATG:CATATATG	77	271.26	-11.80
# AGTTAACA:TGTTAACT	312	598.11	-11.70
# CCCCGCCC:GGGCGGGG	190	432.05	-11.65
# TTCGCGAA:TTCGCGAA	66	249.50	-11.62
# ATCGCGAA:TTCGCGAT	268	536.91	-11.61
# CCTATAGG:CCTATAGG	76	262.36	-11.51
# GTAGCTAA:TTAGCTAC	224	474.59	-11.50
# CATCGATA:TATCGATG	196	436.02	-11.50
# ATGGCCAT:ATGGCCAT	48	216.99	-11.47
# TTGGCCAA:TTGGCCAA	41	204.51	-11.43
# AAGCGCTT:AAGCGCTT	47	212.41	-11.35
# GTTGCAAA:TTTGCAAC	214	455.80	-11.33
# CAGATCTG:CAGATCTG	70	248.20	-11.31
# ATGATCAG:CTGATCAT	242	490.10	-11.21
# AAACGTTA:TAACGTTT	117	314.97	-11.15
# ACGATCGG:CCGATCGT	12	146.23	-11.10
# AATCGATA:TATCGATT	326	595.98	-11.06
# TCGATCGA:TCGATCGA	10	141.57	-11.06
# CCCGCCCA:TGGGCGGG	192	417.56	-11.04
# ACGATCGT:ACGATCGT	5	130.26	-10.97
# GCAATTGA:TCAATTGC	345	616.90	-10.95
# CCTATAGC:GCTATAGG	162	372.39	-10.90
# AATATATC:GATATATT	443	737.36	-10.84
# AATCGATG:CATCGATT	197	416.18	-10.74
# GGGCGGGA:TCCCGCCC	217	442.97	-10.74
# GGCGCGCC:GGCGCGCC	66	227.97	-10.73
# CCGATCGA:TCGATCGG	21	152.45	-10.65
# ATTATAAC:GTTATAAT	244	475.61	-10.62
# ATCGCGAC:GTCGCGAT	235	461.97	-10.56
# CTGTACAG:CTGTACAG	57	208.79	-10.50
# ACGATCGA:TCGATCGT	14	135.79	-10.45
# CTGGCCAG:CTGGCCAG	36	173.39	-10.43
# GTCATGAC:GTCATGAC	53	200.87	-10.43
# ATTGCAAA:TTTGCAAT	221	437.86	-10.36
# CTTATAAA:TTTATAAG	185	389.14	-10.35
# ACCATGGG:CCCATGGT	154	346.36	-10.34
# AAAGCTTT:AAAGCTTT	53	197.94	-10.30
# GCGGCCGC:GCGGCCGC	44	183.47	-10.30
# TAGATCTA:TAGATCTA	48	189.62	-10.28
# GTTGGGTA:TACCCAAC	327	571.37	-10.22
# CCCTAGGA:TCCTAGGG	380	637.11	-10.19
# ACCCAACT:AGTTGGGT	392	650.65	-10.14
# AATCGATC:GATCGATT	160	348.98	-10.12
# AAGCGCTA:TAGCGCTT	116	286.78	-10.08
# GTCGCGAC:GTCGCGAC	48	184.71	-10.06
# GGAATTCA:TGAATTCC	120	289.48	-9.96
# CCATATGG:CCATATGG	21	137.67	-9.94
# AAACCTAC:GTAGGTTT	258	473.92	-9.92
# ACCCGCCA:TGGCGGGT	418	674.70	-9.88
# TCTATAGA:TCTATAGA	59	196.22	-9.80
# ATTATAAG:CTTATAAT	185	372.59	-9.72
# CGTTAACA:TGTTAACG	119	282.28	-9.72
# GTTATAAA:TTTATAAC	281	496.74	-9.68
# CTAATTAC:GTAATTAG	229	429.48	-9.67
# AGCCGGCT:AGCCGGCT	18	125.80	-9.61
# ACCCGGGT:ACCCGGGT	47	173.00	-9.58
# CTATATAA:TTATATAG	328	552.23	-9.54
# GTATATAA:TTATATAC	141	307.70	-9.50
# CGTTAACG:CGTTAACG	46	169.31	-9.48
# CTTGCAAG:CTTGCAAG	32	146.01	-9.44
# CTGATCAC:GTGATCAG	204	390.04	-9.42
# GACTAGTC:GACTAGTC	2	92.53	-9.41
# ATCATGAC:GTCATGAT	211	398.72	-9.40
# CTTATAAC:GTTATAAG	102	250.23	-9.37
# GTAGGGTA:TACCCTAC	144	308.35	-9.36
# GTCATGAA:TTCATGAC	140	302.81	-9.36
# CTAGCTAG:CTAGCTAG	33	145.12	-9.31
# CTTATAAG:CTTATAAG	66	196.03	-9.29
# ACCCGCCG:CGGCGGGT	281	485.00	-9.26
# GACCCAAC:GTTGGGTC	148	311.46	-9.26
# ATATATAC:GTATATAT	175	347.70	-9.26
# TTCCGGAA:TTCCGGAA	57	181.79	-9.26
# ACTATAGA:TCTATAGT	106	252.84	-9.23
# CAGCGCTG:CAGCGCTG	27	133.73	-9.23
# ATCGCGAG:CTCGCGAT	127	281.73	-9.22
# TCACGTGA:TCACGTGA	4	91.86	-9.17
# CGTTAACC:GGTTAACG	192	367.66	-9.16
# AGTTAACG:CGTTAACT	186	358.75	-9.12
# CACTAGTG:CACTAGTG	5	92.53	-9.10
# ACTATAGC:GCTATAGT	230	414.99	-9.08
# AACCGGTT:AACCGGTT	50	167.50	-9.08
# GGTATACC:GGTATACC	43	155.67	-9.03
# TACCGGTA:TACCGGTA	39	149.34	-9.03
# AGAATTCC:GGAATTCT	165	328.36	-9.02
# ACAATTGG:CCAATTGT	427	657.54	-8.99
# CAACGTTC:GAACGTTG	142	296.40	-8.97
# TGTATACA:TGTATACA	40	149.65	-8.96
# GGTTTATA:TATAAACC	293	490.90	-8.93
# GATCGATA:TATCGATC	195	365.62	-8.92
# ATGATCAC:GTGATCAT	190	359.00	-8.92
# TGAATTCA:TGAATTCA	62	182.40	-8.91
# ACCATGGC:GCCATGGT	181	346.36	-8.89
# ACCATGGA:TCCATGGT	133	282.09	-8.88
# CTTGCAAC:GTTGCAAG	93	226.62	-8.88
# AACCCGCA:TGCGGGTT	315	516.66	-8.87
# GAACGTTA:TAACGTTC	103	239.94	-8.84
# GGACGCAC:GTGCGTCC	104	240.07	-8.78
# ATCATGAG:CTCATGAT	164	320.77	-8.75
# CTGTACAA:TTGTACAG	180	339.10	-8.64
# GCTATAGA:TCTATAGC	167	322.05	-8.64
# ATAGCTAG:CTAGCTAT	152	302.18	-8.64
# TCGCGCGA:TCGCGCGA	25	118.90	-8.61
# CTCATGAG:CTCATGAG	32	130.01	-8.60
# GTATATAC:GTATATAC	42	145.49	-8.58
# AGTATACT:AGTATACT	31	126.75	-8.50
# CTAGCTAA:TTAGCTAG	195	354.34	-8.47
# ATTGCAAC:GTTGCAAT	183	337.87	-8.43
# ACTGCAGT:ACTGCAGT	12	92.79	-8.39
# TCCCGGGA:TCCCGGGA	27	118.06	-8.38
# CCGCGCGG:CCGCGCGG	29	121.25	-8.38
# CTGCGTCA:TGACGCAG	117	248.61	-8.35
# ATGTACAG:CTGTACAT	100	224.20	-8.29
# GCCCCTAA:TTAGGGGC	188	340.18	-8.25
# CGGCGATC:GATCGCCG	998	1294.27	-8.24
# ATAGCTAC:GTAGCTAT	240	404.73	-8.19
# ATTGCAAG:CTTGCAAT	97	217.70	-8.18
# AGCCCCTA:TAGGGGCT	160	301.71	-8.16
# CCCTAGGC:GCCTAGGG	125	255.01	-8.14
# GTGAAACA:TGTTTCAC	90	206.45	-8.10
# AAACGTTG:CAACGTTT	230	389.07	-8.06
# CTATATAC:GTATATAG	131	261.12	-8.05
# AAGGCCTT:AAGGCCTT	15	92.12	-8.04
# ACTATAGG:CCTATAGT	155	292.36	-8.03
# ATGGGAGA:TCTCCCAT	250	413.29	-8.03
# CACCGGTG:CACCGGTG	43	136.69	-8.01
# GCACGTGC:GCACGTGC	4	71.94	-8.01
# ACATATGT:ACATATGT	7	77.17	-7.99
# TGCGTCAA:TTGACGCA	149	282.44	-7.94
# GCCATGGA:TCCATGGC	189	333.25	-7.90
# CCTATAGA:TCTATAGG	108	226.89	-7.89
# CAGATCTC:GAGATCTG	73	178.18	-7.88
# CAGCGCTA:TAGCGCTG	109	227.55	-7.86
# CTAGCTAC:GTAGCTAG	85	194.36	-7.84
# AACCGGTG:CACCGGTT	55	151.31	-7.83
# ACTCGAGT:ACTCGAGT	16	90.37	-7.82
# CAACCCGC:GCGGGTTG	258	417.54	-7.81
# GTCGCGAA:TTCGCGAC	101	214.67	-7.76
# ATCCGGAT:ATCCGGAT	47	137.20	-7.70
# ATGGCCAG:CTGGCCAT	88	193.97	-7.61
# CTCATGAA:TTCATGAG	125	243.62	-7.60
# ACCTAGGA:TCCTAGGT	206	346.85	-7.56
# CAGATCTA:TAGATCTG	106	216.94	-7.53
# GCCCGCCC:GGGCGGGC	80	181.32	-7.52
# GGTATACA:TGTATACC	60	152.63	-7.50
# TAACGTTA:TAACGTTA	67	162.44	-7.49
# ATGGCCAA:TTGGCCAT	102	210.66	-7.49
# CGAATTCG:CGAATTCG	17	85.98	-7.44
# ACCTACAG:CTGTAGGT	198	332.74	-7.39
# AAGATCTT:AAGATCTT	21	91.47	-7.37
# TAGTACTA:TAGTACTA	41	122.46	-7.36
# GCCTAGGA:TCCTAGGC	69	162.94	-7.36
# TTCTAGAA:TTCTAGAA	20	88.83	-7.30
# AGAATTCA:TGAATTCT	102	206.90	-7.29
# CAAGCTTG:CAAGCTTG	11	73.25	-7.27
# AATCGCCT:AGGCGATT	341	504.14	-7.27
# GCGGGTTA:TAACCCGC	288	439.32	-7.22
# GGAAACCC:GGGTTTCC	518	709.86	-7.20
# AGGCGATA:TATCGCCT	373	539.72	-7.18
# GCTGCGCC:GGCGCAGC	134	246.46	-7.16
# GAGCGCTC:GAGCGCTC	13	75.06	-7.16
# AAATGGGA:TCCCATTT	325	481.45	-7.13
# GAGATCTA:TAGATCTC	67	155.74	-7.11
# AACCCGCG:CGCGGGTT	127	235.79	-7.08
# CGAATTCC:GGAATTCG	99	198.74	-7.08
# TCTCGAGA:TCTCGAGA	12	71.96	-7.07
# CATATATA:TATATATG	283	428.15	-7.01
# ACGCTGCT:AGCAGCGT	111	213.47	-7.01
# GTAGGGGA:TCCCCTAC	263	403.96	-7.01
# GAGCGCTA:TAGCGCTC	79	170.48	-7.01
# AGGCGATG:CATCGCCT	206	333.72	-6.99
# CGCGCGCC:GGCGCGCG	58	141.02	-6.99
# GTGGCCAC:GTGGCCAC	18	80.76	-6.98
# ATGTACAA:TTGTACAT	231	364.14	-6.98
# ACGGCCGC:GCGGCCGT	45	122.08	-6.98
# CACCCGCC:GGCGGGTG	347	503.05	-6.96
# AGGGTGCA:TGCACCCT	100	197.72	-6.95
# TAGGGTGA:TCACCCTA	291	435.25	-6.91
# CGACGCAC:GTGCGTCG	70	155.92	-6.88
# ACACCAGT:ACTGGTGT	134	240.49	-6.87
# CCCATGGA:TCCATGGG	208	333.25	-6.86
# TCGGCCGA:TCGGCCGA	15	73.98	-6.86
# CACCATCC:GGATGGTG	190	310.81	-6.85
# AGACGCAC:GTGCGTCT	70	155.43	-6.85
# GGCGGGTA:TACCCGCC	273	411.63	-6.83
# AGACCTTG:CAAGGTCT	117	217.79	-6.83
# CTCATGAC:GTCATGAG	75	161.60	-6.81
# ATGTACAC:GTGTACAT	53	130.91	-6.81
# GAGATCTC:GAGATCTC	51	127.91	-6.80
# AACGCACC:GGTGCGTT	177	293.16	-6.78
# CGCGCGCG:CGCGCGCG	24	87.23	-6.77
# CAACGTTA:TAACGTTG	105	200.66	-6.75
# TGGTACCA:TGGTACCA	12	67.12	-6.73
# AGCGTCAG:CTGACGCT	173	286.27	-6.69
# TGCCGGCA:TGCCGGCA	22	82.91	-6.69
# TGCGCGCA:TGCGCGCA	22	82.77	-6.68
# AATACGCT:AGCGTATT	61	139.96	-6.67
# AATTATCT:AGATAATT	625	815.47	-6.67
# GTGTACAC:GTGTACAC	15	71.18	-6.66
# ACACCGTC:GACGGTGT	59	136.62	-6.64
# GCGCGCGC:GCGCGCGC	38	106.43	-6.63
# AGTATACC:GGTATACT	62	140.47	-6.62
# CAGGTTGG:CCAACCTG	202	320.42	-6.62
# ATCCGGAA:TTCCGGAT	75	157.93	-6.60
# AAATTACA:TGTAATTT	308	447.10	-6.58
# GTGGCCAA:TTGGCCAC	54	128.52	-6.57
# ACCCCAGT:ACTGGGGT	216	336.42	-6.57
# GCGCGCGA:TCGCGCGC	43	112.49	-6.55
# GCGCAGCC:GGCTGCGC	69	148.64	-6.53
# CCGCAGCG:CGCTGCGG	98	186.69	-6.49
# GCCGCCCC:GGGGCGGC	339	481.35	-6.49
# CTCCGGAA:TTCCGGAG	37	102.48	-6.47
# GACGCACA:TGTGCGTC	71	150.10	-6.46
# CAGCGATC:GATCGCTG	883	1096.55	-6.45
# CGCCGGCG:CGCCGGCG	15	68.25	-6.45
# GAAAGGAA:TTCCTTTC	171	277.98	-6.42
# ACGTTCCC:GGGAACGT	116	208.05	-6.38
# AGCGCGCT:AGCGCGCT	11	60.70	-6.38
# CTGGCCAC:GTGGCCAG	49	118.34	-6.37
# AGAGTAAT:ATTACTCT	173	279.34	-6.36
# CACCGGTA:TACCGGTG	67	142.88	-6.35
# AGACACGC:GCGTGTCT	26	84.04	-6.33
# GTAGATAA:TTATCTAC	248	369.66	-6.33
# TCGTCAGA:TCTGACGA	92	175.90	-6.33
# TGAGCTCA:TGAGCTCA	1	41.93	-6.32
# CCTGCAGG:CCTGCAGG	22	77.59	-6.31
# GCCATAAC:GTTATGGC	229	345.96	-6.29
# ATCTAGAT:ATCTAGAT	28	86.34	-6.28
# CAACCTAA:TTAGGTTG	248	368.36	-6.27
# CGGTACCG:CGGTACCG	20	73.86	-6.27
# AAGATCTC:GAGATCTT	43	108.17	-6.27
# CTGTACAC:GTGTACAG	53	121.91	-6.24
# CCGGCCGG:CCGGCCGG	11	58.89	-6.24
# CCCAACCA:TGGTTGGG	475	631.72	-6.24
# AAGAAAGT:ACTTTCTT	141	236.64	-6.22
# TCCCTACA:TGTAGGGA	176	279.80	-6.21
# CCCCTGCC:GGCAGGGG	114	202.24	-6.20
# CGGGTTTC:GAAACCCG	410	556.22	-6.20
# CGAATTCA:TGAATTCG	56	125.23	-6.19
# GTAGGTTA:TAACCTAC	243	360.40	-6.18
# ACAATGGT:ACCATTGT	256	375.62	-6.17
# GAGTACTA:TAGTACTC	23	77.25	-6.17
# CTTGCAAA:TTTGCAAG	188	293.68	-6.17
# CTGCGATC:GATCGCAG	524	685.39	-6.16
# CTCCTAAC:GTTAGGAG	178	281.14	-6.15
# AAATCCTA:TAGGATTT	403	546.82	-6.15
# AACCCTAC:GTAGGGTT	315	444.37	-6.14
# AAACCAAG:CTTGGTTT	359	495.58	-6.14
# CCGGAACG:CGTTCCGG	82	159.14	-6.11
# ACCAACCT:AGGTTGGT	233	346.80	-6.11
# ATGCGTCA:TGACGCAT	96	177.34	-6.11
# ATGCGATG:CATCGCAT	92	172.10	-6.11
# CCCCTTTC:GAAAGGGG	190	294.43	-6.09
# GGCGGGGA:TCCCCGCC	325	454.64	-6.08
# CAATCCCC:GGGGATTG	257	374.48	-6.07
# ACGTTTAT:ATAAACGT	111	195.94	-6.07
# CAGGTTTC:GAAACCTG	286	408.65	-6.07
# CCCGCCCG:CGGGCGGG	136	227.19	-6.05
# CAGGCCTA:TAGGCCTG	23	75.61	-6.05
# AGCATTAT:ATAATGCT	281	402.12	-6.04
# GAGGGTGC:GCACCCTC	112	196.50	-6.03
# AGGCAGTG:CACTGCCT	69	140.37	-6.02
# AGTGCGTC:GACGCACT	93	171.90	-6.02
# ACCCGGGA:TCCCGGGT	71	142.91	-6.02
# GCAAAAGA:TCTTTTGC	121	207.67	-6.01
# CGAGAGTA:TACTCTCG	92	169.96	-5.98
# CGCAGTTA:TAACTGCG	138	228.31	-5.98
# CATTCCAA:TTGGAATG	155	249.28	-5.97
# AGCGCGCC:GGCGCGCT	53	117.64	-5.96
# AGCTATCG:CGATAGCT	110	192.67	-5.96
# TGGATCCA:TGGATCCA	5	44.63	-5.93
# AAGATCTG:CAGATCTT	78	150.67	-5.92
# CCCCAACA:TGTTGGGG	393	529.18	-5.92
# ACAACAGT:ACTGTTGT	176	273.84	-5.91
# GCTCAACC:GGTTGAGC	143	233.29	-5.91
# AAAATGTT:AACATTTT	414	552.97	-5.91
# ACCACCTG:CAGGTGGT	190	290.72	-5.91
# ACGGCCGT:ACGGCCGT	28	81.23	-5.91
# GACCCGCC:GGCGGGTC	181	279.65	-5.90
# GTAATGAA:TTCATTAC	140	229.09	-5.89
# CAGGCCTG:CAGGCCTG	26	77.88	-5.88
# CCAAGGCA:TGCCTTGG	199	300.96	-5.88
# AGACTACA:TGTAGTCT	103	182.34	-5.88
# GAGTAACC:GGTTACTC	150	241.24	-5.87
# CCGCGCGC:GCGCGCGG	51	113.59	-5.87
# CGCGTCAG:CTGACGCG	71	140.19	-5.84
# GGCGCGCA:TGCGCGCC	69	137.37	-5.83
# AACCGGTA:TACCGGTT	85	158.16	-5.82
# GTCAACCA:TGGTTGAC	177	272.98	-5.81
# CGGGAATC:GATTCCCG	164	257.04	-5.80
# CGGGAGAG:CTCTCCCG	145	233.45	-5.79
# ACCCGCCT:AGGCGGGT	244	352.64	-5.79
# CAGATATC:GATATCTG	298	415.78	-5.78
# AAGGGGAT:ATCCCCTT	251	360.62	-5.77
# TAGGCCTA:TAGGCCTA	24	73.40	-5.77
# CTCGCGAA:TTCGCGAG	65	130.92	-5.76
# AAACCGTT:AACGGTTT	236	342.58	-5.76
# CGGGACAC:GTGTCCCG	36	90.88	-5.76
# ACCTAGGC:GCCTAGGT	71	138.83	-5.76
# ATCATACG:CGTATGAT	35	89.37	-5.75
# GATGGTTA:TAACCATC	396	528.07	-5.75
# ATACGCTA:TAGCGTAT	39	95.02	-5.75
# ACAGTGGT:ACCACTGT	136	221.38	-5.74
# AAGGACAT:ATGTCCTT	80	150.28	-5.73
# CAACCTAG:CTAGGTTG	227	331.32	-5.73
# ATCCGGAG:CTCCGGAT	35	89.02	-5.73
# CTTGTCCA:TGGACAAG	117	197.23	-5.71
# GGCAAAAC:GTTTTGCC	337	459.33	-5.71
# GCGGCCGA:TCGGCCGC	55	116.50	-5.70
# AAATAGGA:TCCTATTT	251	358.92	-5.70
# AGGTCTGA:TCAGACCT	161	251.18	-5.69
# GACGTTCC:GGAACGTC	107	184.17	-5.69
# GGTTGGGA:TCCCAACC	406	537.86	-5.69
# GGAAAAAA:TTTTTTCC	635	795.18	-5.68
# CGCCGGCA:TGCCGGCG	26	75.23	-5.68
# AGGTTGGA:TCCAACCT	150	237.38	-5.67
# ACGGCCGG:CCGGCCGT	22	69.16	-5.67
# GGTATCAA:TTGATACC	315	432.84	-5.66
# GGTACAAA:TTTGTACC	154	242.13	-5.66
# TAAACCCA:TGGGTTTA	675	838.89	-5.66
# CAGGGTGC:GCACCCTG	118	197.51	-5.66
# CCCCGGGG:CCCCGGGG	21	67.47	-5.66
# ATAGGGGC:GCCCCTAT	151	238.09	-5.64
# AACGTTCA:TGAACGTT	100	174.37	-5.63
# ATGCGATA:TATCGCAT	97	170.53	-5.63
# CCGGAAAG:CTTTCCGG	201	298.09	-5.62
# GGATGGTA:TACCATCC	224	325.42	-5.62
# CCGCCTTC:GAAGGCGG	169	259.49	-5.62
# GCCTGTTA:TAACAGGC	101	175.32	-5.61
# AAGATGGT:ACCATCTT	280	390.58	-5.60
# CTTATTTC:GAAATAAG	138	220.92	-5.58
# TCCCAGGA:TCCTGGGA	227	327.86	-5.57
# GCATATCA:TGATATGC	117	194.59	-5.56
# ACTAGTCC:GGACTAGT	2	34.74	-5.55
# CTAGGGGC:GCCCCTAG	165	253.32	-5.55
# CTTGCCTA:TAGGCAAG	72	136.86	-5.54
# AACCCCGG:CCGGGGTT	218	316.55	-5.54
# AAAAGTTT:AAACTTTT	520	662.47	-5.54
# CGCAGCGA:TCGCTGCG	150	234.82	-5.54
# GTGTGGAA:TTCCACAC	123	201.51	-5.53
# ATCCGGAC:GTCCGGAT	21	65.85	-5.53
# CATCGATC:GATCGATG	167	255.32	-5.53
# GCCTTATA:TATAAGGC	77	143.12	-5.53
# ACAGAAAT:ATTTCTGT	329	445.65	-5.53
# CCGCGATC:GATCGCGG	396	522.23	-5.52
# ATTGAACC:GGTTCAAT	328	444.19	-5.51
# TACCCCGA:TCGGGGTA	169	256.71	-5.47
# CTCCTTTC:GAAAGGAG	91	160.29	-5.47
# GGGCATGA:TCATGCCC	90	158.90	-5.47
# CTTGCTCA:TGAGCAAG	167	253.94	-5.46
# ACCATTAT:ATAATGGT	372	493.15	-5.46
# ACGGAACT:AGTTCCGT	128	206.33	-5.45
# ACGGTTTC:GAAACCGT	233	332.38	-5.45
# AATTGCTA:TAGCAATT	480	615.21	-5.45
# AAAGAGAT:ATCTCTTT	169	256.23	-5.45
# CTAAGTCC:GGACTTAG	115	190.11	-5.45
# AATAAACA:TGTTTATT	431	559.88	-5.45
# CTCGCGAC:GTCGCGAG	55	112.65	-5.43
# ATGCCTTG:CAAGGCAT	172	259.38	-5.43
# CGGAAGTC:GACTTCCG	125	202.01	-5.42
# AGCACCCT:AGGGTGCT	133	211.79	-5.41
# CCTTGGGC:GCCCAAGG	167	252.90	-5.40
# CCGTTCCG:CGGAACGG	87	153.85	-5.39
# CAATTGCC:GGCAATTG	264	367.04	-5.38
# CGATGGTC:GACCATCG	107	178.89	-5.38
# AGAAACCT:AGGTTTCT	343	457.99	-5.37
# CATATGTC:GACATATG	8	43.37	-5.37
# ACCGTGAT:ATCACGGT	138	217.02	-5.36
# AAGGTCTA:TAGACCTT	109	181.16	-5.36
# CACCCTAA:TTAGGGTG	291	397.67	-5.35
# AAAGCTTC:GAAGCTTT	38	88.25	-5.35
# GAAAAGTC:GACTTTTC	203	294.75	-5.34
# GAAACAAC:GTTGTTTC	180	267.38	-5.34
# ATCCATGC:GCATGGAT	85	150.52	-5.34
# ACGAACCT:AGGTTCGT	43	95.04	-5.34
# GAATGTCA:TGACATTC	152	233.55	-5.34
# AACACTTA:TAAGTGTT	101	170.65	-5.33
# TCCTGGAA:TTCCAGGA	238	335.66	-5.33
# ATGTGACA:TGTCACAT	41	92.17	-5.33
# ATCGGGAG:CTCCCGAT	178	264.61	-5.32
# TCTGCAGA:TCTGCAGA	11	47.71	-5.32
# GGTGAAAA:TTTTCACC	467	596.76	-5.31
# AGGTTCTG:CAGAACCT	288	393.31	-5.31
# GCGCAGCA:TGCTGCGC	79	142.32	-5.31
# ACCCGGGC:GCCCGGGT	34	82.05	-5.30
# ACCCCTAC:GTAGGGGT	429	553.83	-5.30
# AGTATACG:CGTATACT	17	57.06	-5.30
# CGTGACCA:TGGTCACG	97	165.05	-5.30
# CTGCCTTC:GAAGGCAG	88	153.57	-5.29
# TGACGCAA:TTGCGTCA	226	320.46	-5.28
# CGAGGTGA:TCACCTCG	83	146.91	-5.27
# CTCGCGAG:CTCGCGAG	25	68.70	-5.27
# AAAGTACG:CGTACTTT	45	96.88	-5.27
# ATCTGGTG:CACCAGAT	211	302.58	-5.27
# AACCATCT:AGATGGTT	317	425.57	-5.26
# ATAGGGTG:CACCCTAT	195	283.62	-5.26
# AACCCAAA:TTTGGGTT	683	835.01	-5.26
# AGGTTTAT:ATAAACCT	368	483.55	-5.25
# GTCAAACA:TGTTTGAC	228	322.33	-5.25
# GTAAGCGA:TCGCTTAC	123	196.59	-5.25
# CCATACGG:CCGTATGG	85	149.04	-5.25
# GCTGACAA:TTGTCAGC	159	240.21	-5.24
# CATATAAG:CTTATATG	142	219.53	-5.23
# CATGGATA:TATCCATG	157	237.66	-5.23
# CTCCGGAG:CTCCGGAG	18	57.77	-5.23
# AAAGCTTG:CAAGCTTT	63	120.41	-5.23
# GCCTAGGC:GCCTAGGC	23	65.22	-5.23
# AGTGTAAT:ATTACACT	114	184.95	-5.22
# CAGCGCTC:GAGCGCTG	48	100.19	-5.21
# ACCGTACC:GGTACGGT	53	106.87	-5.21
# CGTATACA:TGTATACG	21	62.00	-5.21
# CCCACTGC:GCAGTGGG	115	185.97	-5.20
# CGCTGATC:GATCAGCG	70	129.12	-5.20
# ACCCAACG:CGTTGGGT	216	307.17	-5.20
# ACCCGGGG:CCCCGGGT	54	108.04	-5.20
# CCGCCCCG:CGGGGCGG	170	252.52	-5.19
# ATCTAGAA:TTCTAGAT	39	87.58	-5.19
# AAAATAGG:CCTATTTT	470	596.80	-5.19
# GTGTACAA:TTGTACAC	125	198.00	-5.19
# CTCAAGTC:GACTTGAG	130	204.10	-5.19
# AAATCCGA:TCGGATTT	436	558.53	-5.18
# AATGGGAT:ATCCCATT	331	439.71	-5.18
# AAGGGTGC:GCACCCTT	90	154.41	-5.18
# CAAGTACC:GGTACTTG	94	159.45	-5.18
# CATGATTC:GAATCATG	199	286.72	-5.18
# ACCACAAT:ATTGTGGT	291	393.72	-5.18
# CTTCCATC:GATGGAAG	169	251.01	-5.18
# CAAATCTG:CAGATTTG	341	450.85	-5.17
# ACGGTGTC:GACACCGT	51	103.68	-5.17
# ATTGGACA:TGTCCAAT	149	226.87	-5.17
# GGGGCCCC:GGGGCCCC	10	44.46	-5.17
# ACGGAAGT:ACTTCCGT	146	223.15	-5.16
# CCCTGCCG:CGGCAGGG	46	96.69	-5.16
# GGAGCCGA:TCGGCTCC	101	167.75	-5.15
# GCCCAACC:GGTTGGGC	163	243.40	-5.15
# CAAGGGGG:CCCCCTTG	224	315.53	-5.15
# GCAACCTA:TAGGTTGC	156	234.96	-5.15
# CTCTAAAG:CTTTAGAG	143	219.16	-5.14
# CCCCTACC:GGTAGGGG	392	507.91	-5.14
# GAAGGTCA:TGACCTTC	125	197.20	-5.14
# ACGGCTCA:TGAGCCGT	87	149.95	-5.14
# GTAGGGAA:TTCCCTAC	216	305.87	-5.14
# AAACCACA:TGTGGTTT	331	438.62	-5.14
# ACACCTGT:ACAGGTGT	105	172.42	-5.13
# GGATTCCC:GGGAATCC	192	277.51	-5.13
# CCTTAAGG:CCTTAAGG	5	35.57	-5.13
# ACTCCAAA:TTTGGAGT	298	400.54	-5.12
# AACTGCTA:TAGCAGTT	474	599.40	-5.12
# ATGGAATA:TATTCCAT	162	241.58	-5.12
# TAAGTTGA:TCAACTTA	214	303.13	-5.12
# GAAGAGTA:TACTCTTC	79	139.37	-5.11
# GTGGATAA:TTATCCAC	193	278.23	-5.11
# AATTCCCA:TGGGAATT	823	983.01	-5.10
# CGCGCGCA:TGCGCGCG	38	84.97	-5.10
# CTCTTTTC:GAAAAGAG	119	189.07	-5.10
# CAAACTGG:CCAGTTTG	280	379.22	-5.10
# AAACCCGT:ACGGGTTT	322	427.22	-5.09
# ATTGTACA:TGTACAAT	137	210.90	-5.09
# TAGACGGA:TCCGTCTA	66	122.23	-5.09
# GCACTGCC:GGCAGTGC	67	123.46	-5.08
# CTGCCAAA:TTTGGCAG	364	474.67	-5.08
# GACGCTGC:GCAGCGTC	86	147.66	-5.07
# ACGCTTCT:AGAAGCGT	73	131.08	-5.07
# GATCAGAA:TTCTGATC	138	211.80	-5.07
# CAACGCAG:CTGCGTTG	50	100.91	-5.07
# AGTGCGAA:TTCGCACT	101	166.29	-5.06
# GAACAATA:TATTGTTC	207	293.68	-5.06
# CGGCGCCG:CGGCGCCG	17	54.23	-5.06
# CGCCTTGC:GCAAGGCG	54	105.99	-5.05
# CGGTCAAG:CTTGACCG	175	255.68	-5.05
# GCGTCAGC:GCTGACGC	186	268.66	-5.04
# CGGGCATC:GATGCCCG	60	113.77	-5.04
# TAGGTTGA:TCAACCTA	472	594.87	-5.04
# CGGATCCG:CGGATCCG	11	44.63	-5.03
# ACGGCGAG:CTCGCCGT	86	147.03	-5.03
# GGGGTGAA:TTCACCCC	360	468.88	-5.03
# ATGGTCAC:GTGACCAT	118	186.67	-5.03
# ATCGCCAG:CTGGCGAT	409	523.95	-5.02
# TACTCCAA:TTGGAGTA	140	213.35	-5.02
# ATCACCCA:TGGGTGAT	387	499.19	-5.02
# GGGAGAGA:TCTCTCCC	204	289.35	-5.02
# AAGACCTT:AAGGTCTT	122	191.40	-5.02
# ATATGGGA:TCCCATAT	215	302.00	-5.01
# CGCCCCTC:GAGGGGCG	95	157.89	-5.01
# AAGGAGAG:CTCTCCTT	103	167.83	-5.00
# ATGATTAA:TTAATCAT	667	809.29	-5.00
# GTACGGTA:TACCGTAC	23	62.55	-5.00
# CGGGTGTC:GACACCCG	74	131.22	-4.99
# ATATGAGG:CCTCATAT	111	177.47	-4.99
# AACGCTGC:GCAGCGTT	135	206.72	-4.99
# ACACATAA:TTATGTGT	101	165.08	-4.99
# ACTTCGAG:CTCGAAGT	67	122.00	-4.98
# ACTTTTCG:CGAAAAGT	172	250.79	-4.98
# AAGCGCTG:CAGCGCTT	104	168.54	-4.97
# GAAAATTA:TAATTTTC	598	732.50	-4.97
# GACTTATC:GATAAGTC	139	211.23	-4.97
# CCTGCAGC:GCTGCAGG	18	54.71	-4.96
# GCAGCCAC:GTGGCTGC	176	255.25	-4.96
# ACTCGCTG:CAGCGAGT	131	201.33	-4.96
# CTGAAACC:GGTTTCAG	271	365.79	-4.96
# AATAAACG:CGTTTATT	243	333.27	-4.94
# CCCAGTTC:GAACTGGG	165	241.78	-4.94
# AGTGCGAG:CTCGCACT	158	233.39	-4.94
# AAAACCCG:CGGGTTTT	522	647.55	-4.93
# AGGATCCT:AGGATCCT	6	35.27	-4.93
# GTCCGGAA:TTCCGGAC	33	75.80	-4.92
# CCAACCAG:CTGGTTGG	233	321.05	-4.91
# CTTATCAC:GTGATAAG	75	131.18	-4.91
# AAACTGGT:ACCAGTTT	422	535.47	-4.90
# ATCCCAAC:GTTGGGAT	306	404.62	-4.90
# CCGGATTC:GAATCCGG	106	169.86	-4.90
# CCTCTTAC:GTAAGAGG	31	72.80	-4.90
# CACCACTG:CAGTGGTG	193	274.02	-4.89
# AAATTGCA:TGCAATTT	329	430.51	-4.89
# CTGATGCC:GGCATCAG	205	288.00	-4.89
# TATGCATA:TATGCATA	20	56.82	-4.88
# ACCTGAAG:CTTCAGGT	124	191.57	-4.88
# GGGGCGGA:TCCGCCCC	204	286.59	-4.88
# GCATCTTA:TAAGATGC	85	143.39	-4.88
# ACAAGGTC:GACCTTGT	59	110.13	-4.87
# CCCGTTAC:GTAACGGG	99	160.70	-4.87
# CGTCTCGA:TCGAGACG	42	87.52	-4.87
# ACTTAAGT:ACTTAAGT	12	44.43	-4.87
# AAGCGATA:TATCGCTT	250	339.66	-4.86
# CCCAACCC:GGGTTGGG	514	636.71	-4.86
# AGGTTGGC:GCCAACCT	255	345.31	-4.86
# CCACGTGC:GCACGTGG	9	39.57	-4.86
# CCGTCTCG:CGAGACGG	72	126.61	-4.85
# GGACATTA:TAATGTCC	132	200.66	-4.85
# GTAATAAA:TTTATTAC	298	394.17	-4.84
# ATGTTCTA:TAGAACAT	143	213.79	-4.84
# ATTCCATG:CATGGAAT	148	219.76	-4.84
# ACGCACCT:AGGTGCGT	161	235.22	-4.84
# ACCAAGGT:ACCTTGGT	153	225.69	-4.84
# ATCTAGAC:GTCTAGAT	17	51.81	-4.84
# CCGAATGC:GCATTCGG	81	137.64	-4.83
# GTACCCCA:TGGGGTAC	95	155.11	-4.83
# ACTGCGTC:GACGCAGT	71	124.94	-4.83
# AGTCCCAA:TTGGGACT	223	307.52	-4.82
# CAGGCAAG:CTTGCCTG	68	121.01	-4.82
# CCTATTCA:TGAATAGG	135	203.76	-4.82
# CTTAACAC:GTGTTAAG	75	129.83	-4.81
# CGAGACGA:TCGTCTCG	58	107.99	-4.81
# AATAAGGA:TCCTTATT	158	231.11	-4.81
# AACTGCCA:TGGCAGTT	375	480.29	-4.80
# GTGCAACA:TGTTGCAC	94	153.50	-4.80
# AAGAGTAG:CTACTCTT	83	139.72	-4.80
# CAGGGGCG:CGCCCCTG	113	176.70	-4.79
# CCCCGGGA:TCCCGGGG	44	89.25	-4.79
# ATATGAAA:TTTCATAT	178	254.36	-4.79
# CTTCTTCA:TGAAGAAG	191	269.53	-4.78
# CACCCTGA:TCAGGGTG	199	278.88	-4.78
# CTCCACAC:GTGTGGAG	45	90.48	-4.78
# CAAGCAGG:CCTGCTTG	112	175.21	-4.78
# CAAGGATG:CATCCTTG	114	177.63	-4.77
# TCTCGACA:TGTCGAGA	110	172.74	-4.77
# GAAGTGCC:GGCACTTC	69	121.62	-4.77
# CGGTTTCA:TGAAACCG	230	314.56	-4.77
# AAATCTCT:AGAGATTT	402	509.60	-4.77
# TCCTGTCA:TGACAGGA	136	204.06	-4.76
# GCTGCAGC:GCTGCAGC	9	38.57	-4.76
# GTTGGCAA:TTGCCAAC	287	379.78	-4.76
# AGCGAAAA:TTTTCGCT	298	392.13	-4.75
# GCCATCCC:GGGATGGC	187	264.25	-4.75
# GTGAAAGA:TCTTTCAC	120	184.50	-4.75
# ACAGCGAA:TTCGCTGT	136	203.76	-4.75
# ATTACAGG:CCTGTAAT	216	297.93	-4.75
# AAAACCTA:TAGGTTTT	422	531.35	-4.74
# GACGGCTC:GAGCCGTC	72	125.03	-4.74
# CATCACAA:TTGTGATG	179	254.64	-4.74
# GATTATTA:TAATAATC	553	676.25	-4.74
# GCCCTATA:TATAGGGC	82	137.59	-4.74
# ACGTTGCT:AGCAACGT	47	92.56	-4.74
# ATCCTTTA:TAAAGGAT	198	276.78	-4.74
# CCTCCTGA:TCAGGAGG	183	259.21	-4.73
# AAGTCGGT:ACCGACTT	145	214.26	-4.73
# GTTGTAAA:TTTACAAC	244	329.83	-4.73
# GCTTGTGA:TCACAAGC	70	122.24	-4.73
# CAGATTGG:CCAATCTG	161	233.13	-4.72
# AAGTTATG:CATAACTT	247	333.21	-4.72
# CTGAATGA:TCATTCAG	130	196.06	-4.72
# AAAGCGCA:TGCGCTTT	104	164.48	-4.72
# TGATGGAA:TTCCATCA	351	451.17	-4.72
# AAAGCTTA:TAAGCTTT	33	73.40	-4.72
# ACCTTTAT:ATAAAGGT	276	366.23	-4.72
# ATATCTCA:TGAGATAT	176	250.53	-4.71
# CCATCATC:GATGATGG	478	592.61	-4.71
# CGATCGCG:CGCGATCG	1844	2057.51	-4.71
# CCTTGATA:TATCAAGG	247	332.79	-4.70
# ATAAACCA:TGGTTTAT	450	561.43	-4.70
# CTACGGGC:GCCCGTAG	61	110.39	-4.70
# CCGGAAGG:CCTTCCGG	141	208.83	-4.69
# AATTCCTA:TAGGAATT	408	514.35	-4.69
# AATACCCT:AGGGTATT	331	427.99	-4.69
# CTCGGAAC:GTTCCGAG	121	184.72	-4.69
# CACAGACG:CGTCTGTG	75	128.03	-4.69
# AGCGCAGA:TCTGCGCT	52	98.51	-4.69
# AGCTGCGC:GCGCAGCT	33	73.03	-4.68
# AGGGGGCG:CGCCCCCT	187	262.91	-4.68
# GCCACCCA:TGGGTGGC	270	358.61	-4.68
# AAGATCTA:TAGATCTT	78	131.70	-4.68
# GAAGCTTC:GAAGCTTC	10	39.34	-4.68
# GGGTTTAA:TTAAACCC	687	821.03	-4.68
# AACATCCT:AGGATGTT	220	301.16	-4.68
# CCCCATTC:GAATGGGG	281	371.05	-4.68
# AAAACAGT:ACTGTTTT	357	456.88	-4.67
# CAAGGCAC:GTGCCTTG	65	115.07	-4.67
# CAATAGGG:CCCTATTG	216	296.24	-4.66
# ACGTGAGG:CCTCACGT	16	48.44	-4.66
# CATTATGC:GCATAATG	78	131.42	-4.66
# CTTATTAA:TTAATAAG	226	307.69	-4.66
# CATATGGC:GCCATATG	18	51.37	-4.66
# AAAACCGA:TCGGTTTT	482	595.56	-4.65
# TCACATCA:TGATGTGA	301	393.18	-4.65
# AAACGTTC:GAACGTTT	365	465.24	-4.65
# GACCGTCA:TGACGGTC	96	153.59	-4.65
# CCCCGGGC:GCCCGGGG	18	51.24	-4.64
# AACGAACA:TGTTCGTT	74	126.16	-4.64
# ACGCTGCC:GGCAGCGT	52	97.90	-4.64
# CGTTGAAA:TTTCAACG	143	210.23	-4.64
# AGCAAAAA:TTTTTGCT	543	662.24	-4.63
# GAGGACGC:GCGTCCTC	35	75.16	-4.63
# GACAATTA:TAATTGTC	494	608.23	-4.63
# GAAAAGCC:GGCTTTTC	327	422.14	-4.63
# GAGACTTA:TAAGTCTC	142	208.92	-4.63
# CCAACCTC:GAGGTTGG	230	311.71	-4.63
# GAACGCCC:GGGCGTTC	54	100.36	-4.63
# CTAGTGGC:GCCACTAG	109	169.18	-4.63
# GCCAGGTA:TACCTGGC	119	181.28	-4.63
# AGGCAAGG:CCTTGCCT	86	140.90	-4.62
# AGCTCCAT:ATGGAGCT	38	79.09	-4.62
# AGAATTCG:CGAATTCT	87	142.05	-4.62
# TCATTACA:TGTAATGA	114	175.09	-4.62
# AGTGGTCA:TGACCACT	170	241.78	-4.62
# AGAATCAT:ATGATTCT	320	413.83	-4.61
# GACCCCTC:GAGGGGTC	79	131.96	-4.61
# GCGATTTA:TAAATCGC	264	350.24	-4.61
# AATCGCAT:ATGCGATT	218	297.44	-4.61
# ACGCGCGT:ACGCGCGT	3	26.88	-4.61
# AGGGCCCT:AGGGCCCT	1	23.09	-4.60
# GATTTCGC:GCGAAATC	171	242.58	-4.60
# AGAGTGTA:TACACTCT	58	105.09	-4.59
# GTTGGGCA:TGCCCAAC	132	196.32	-4.59
# ATTCGGTA:TACCGAAT	153	221.29	-4.59
# AAATTGTT:AACAATTT	544	662.11	-4.59
# CGGGATTC:GAATCCCG	85	139.12	-4.59
# GACATATC:GATATGTC	120	181.86	-4.59
# ATTCGAAT:ATTCGAAT	7	33.58	-4.59
# GAGTAGAC:GTCTACTC	71	121.57	-4.59
# CCTACATC:GATGTAGG	148	215.27	-4.59
# GCTCTTAA:TTAAGAGC	46	89.33	-4.58
# CTGTTAAG:CTTAACAG	170	241.17	-4.58
# ACCGTGTG:CACACGGT	22	56.42	-4.58
# CGCAACAA:TTGTTGCG	144	210.46	-4.58
# CGCATGGC:GCCATGCG	90	145.18	-4.58
# CGCACCCA:TGGGTGCG	250	333.65	-4.58
# TCCTTAGA:TCTAAGGA	135	199.71	-4.58
# AGGACAAT:ATTGTCCT	279	366.68	-4.58
# CAGGATTC:GAATCCTG	123	185.32	-4.58
# CCGCGCGA:TCGCGCGG	70	120.07	-4.57
# GCTGACCA:TGGTCAGC	254	338.00	-4.57
# AGGGTTAT:ATAACCCT	267	352.81	-4.57
# GTTAGGGA:TCCCTAAC	224	303.53	-4.57
# GAATCCGC:GCGGATTC	78	130.05	-4.56
# AGGAACGG:CCGTTCCT	86	139.99	-4.56
# CTCACTCC:GGAGTGAG	77	128.78	-4.56
# AATCAAAA:TTTTGATT	856	1000.13	-4.56
# CACGGTTA:TAACCGTG	119	180.18	-4.56
# CGGTTGCC:GGCAACCG	97	153.28	-4.55
# CAAAGTAC:GTACTTTG	83	136.01	-4.55
# CATTACAC:GTGTAATG	60	106.93	-4.54
# ACAAGAGC:GCTCTTGT	46	88.67	-4.53
# CTCAGGCA:TGCCTGAG	54	99.03	-4.53
# GCATATGC:GCATATGC	11	39.37	-4.52
# CAAGAGTA:TACTCTTG	86	139.37	-4.52
# GACCCTGC:GCAGGGTC	49	92.44	-4.52
# AGGTAGGG:CCCTACCT	163	231.74	-4.52
# CAAAACTC:GAGTTTTG	466	574.20	-4.52
# ACGTGCAT:ATGCACGT	23	57.13	-4.52
# CACTCCAA:TTGGAGTG	112	171.05	-4.52
# CACCCCTC:GAGGGGTG	127	189.07	-4.51
# CCTTCCGA:TCGGAAGG	108	166.17	-4.51
# GAGCGATA:TATCGCTC	119	179.44	-4.51
# GGGTAACC:GGTTACCC	40	80.45	-4.51
# ACCTACCA:TGGTAGGT	241	321.90	-4.51
# AACCCGCT:AGCGGGTT	255	337.88	-4.51
# CACACCCC:GGGGTGTG	121	181.79	-4.51
# GGCATTCA:TGAATGCC	149	215.07	-4.51
# GAGATGGA:TCCATCTC	184	256.09	-4.50
# GTCCCGTA:TACGGGAC	45	86.99	-4.50
# AGAGCTCT:AGAGCTCT	8	34.39	-4.50
# CTCTAGAG:CTCTAGAG	6	31.08	-4.50
# GTTAATAA:TTATTAAC	436	540.59	-4.50
# AGGGTCGA:TCGACCCT	87	140.22	-4.49
# CTATTGCC:GGCAATAG	199	273.19	-4.49
# CCATCTTC:GAAGATGG	287	373.75	-4.49
# CGGAAAGA:TCTTTCCG	156	222.99	-4.49
# ACCCTACA:TGTAGGGT	341	434.38	-4.48
# AATAGGTA:TACCTATT	206	281.05	-4.48
# ATAACCAA:TTGGTTAT	420	522.14	-4.47
# AATACCGT:ACGGTATT	114	172.71	-4.47
# CTTTTGGC:GCCAAAAG	292	378.94	-4.47
# CAGGAGAC:GTCTCCTG	92	145.90	-4.46
# CCGTTTAA:TTAAACGG	232	310.60	-4.46
# AACCCGTG:CACGGGTT	119	178.60	-4.46
# CTACGTGA:TCACGTAG	1	21.85	-4.46
# CGGCTCCC:GGGAGCCG	110	167.75	-4.46
# GAGCAAGC:GCTTGCTC	100	155.62	-4.46
# AAGATTCG:CGAATCTT	93	147.02	-4.45
# CCAGCTGG:CCAGCTGG	2	23.68	-4.45
# CCTGGTGA:TCACCAGG	171	240.00	-4.45
# ACAACGCC:GGCGTTGT	126	186.84	-4.45
# AGACGTAT:ATACGTCT	25	59.26	-4.45
# GCACTGTA:TACAGTGC	53	96.74	-4.45
# CGAATCCA:TGGATTCG	90	143.21	-4.45
# GATTCTAC:GTAGAATC	171	239.82	-4.44
# CTTCCGTC:GACGGAAG	148	212.83	-4.44
# CCTTGGTA:TACCAAGG	133	195.06	-4.44
# CAGCAAGG:CCTTGCTG	171	239.72	-4.44
# GCGTATCC:GGATACGC	50	92.74	-4.44
# GGGGTTAC:GTAACCCC	168	236.18	-4.44
# CCGGCCGA:TCGGCCGG	30	66.00	-4.43
# AATTATGT:ACATAATT	300	387.20	-4.43
# GACCGGTA:TACCGGTC	24	57.62	-4.43
# GTTCTGCA:TGCAGAAC	95	149.08	-4.43
# CAAAAGTA:TACTTTTG	250	330.50	-4.43
# AGGAGACT:AGTCTCCT	113	170.84	-4.43
# TACGCTGA:TCAGCGTA	57	101.61	-4.43
# AGCATTCC:GGAATGCT	180	249.92	-4.42
# AAGGGCGT:ACGCCCTT	39	78.07	-4.42
# AAAGTCTA:TAGACTTT	214	289.16	-4.42
# AACTCTCA:TGAGAGTT	350	443.02	-4.42
# CGTCTACC:GGTAGACG	70	117.98	-4.42
# GTCCATGA:TCATGGAC	113	170.68	-4.42
# ATCGTAAC:GTTACGAT	96	150.09	-4.42
# GATAGGAA:TTCCTATC	155	220.46	-4.41
# AGGGAACG:CGTTCCCT	111	168.14	-4.41
# CGAGTAAC:GTTACTCG	58	102.56	-4.40
# CCTACCAC:GTGGTAGG	153	217.95	-4.40
# CATACGTC:GACGTATG	16	45.75	-4.40
# CTGGCCAA:TTGGCCAG	128	188.31	-4.39
# GAATCGAC:GTCGATTC	89	141.21	-4.39
# TCTTGGAA:TTCCAAGA	199	271.37	-4.39
# CAGGGCGG:CCGCCCTG	134	195.41	-4.39
# AACATGGA:TCCATGTT	128	188.25	-4.39
# GCTTTCGA:TCGAAAGC	74	122.62	-4.39
# CCGCAAGC:GCTTGCGG	85	136.22	-4.39
# CGTTCCTA:TAGGAACG	43	82.97	-4.39
# CCATATGC:GCATATGG	36	73.62	-4.38
# ACCAGGTC:GACCTGGT	134	195.26	-4.38
# AAATAATT:AATTATTT	853	990.86	-4.38
# GTCTGTGA:TCACAGAC	135	196.31	-4.38
# GGTTGGAA:TTCCAACC	188	258.22	-4.37
# TCTAATCA:TGATTAGA	251	330.40	-4.37
# AGCCGGCA:TGCCGGCT	58	102.13	-4.37
# CATCGCTC:GAGCGATG	51	93.14	-4.37
# CGTTCTTA:TAAGAACG	25	58.32	-4.36
# AAGGCATT:AATGCCTT	325	413.74	-4.36
# AGGTGTAT:ATACACCT	120	178.24	-4.36
# GTCTGTCA:TGACAGAC	97	150.51	-4.36
# GCATTCCC:GGGAATGC	299	384.52	-4.36
# AACGCCTT:AAGGCGTT	124	182.98	-4.36
# GGAAGAGA:TCTCTTCC	124	182.97	-4.36
# CCCATTCC:GGAATGGG	289	373.20	-4.36
# AACGCTTA:TAAGCGTT	120	178.13	-4.36
# AAGTTTGT:ACAAACTT	207	279.83	-4.35
# TAAATCGA:TCGATTTA	274	356.16	-4.35
# ATGTCGCA:TGCGACAT	57	100.68	-4.35
# AGTTACAC:GTGTAACT	104	158.79	-4.35
# AAAGGCAG:CTGCCTTT	232	308.32	-4.35
# ACCCGGTG:CACCGGGT	224	299.17	-4.35
# GAAACCGC:GCGGTTTC	298	383.03	-4.34
# GATGATTA:TAATCATC	692	816.09	-4.34
# ATAGCGAA:TTCGCTAT	206	278.47	-4.34
# GTACCTAC:GTAGGTAC	48	88.92	-4.34
# GTCCCGAA:TTCGGGAC	155	219.22	-4.34
# CTATCGGC:GCCGATAG	119	176.62	-4.34
# CTAAGTAG:CTACTTAG	67	113.07	-4.33
# AAATTAGA:TCTAATTT	530	639.40	-4.33
# CAGATTCC:GGAATCTG	142	203.74	-4.33
# GTGATATA:TATATCAC	151	214.32	-4.33
# ACAGACAT:ATGTCTGT	129	188.35	-4.32
# ATGAAGCG:CGCTTCAT	174	241.15	-4.32
# GTGACTTA:TAAGTCAC	101	154.77	-4.32
# AGGATATA:TATATCCT	296	380.17	-4.32
# CTCAAGAC:GTCTTGAG	142	203.55	-4.31
# AAATGTAC:GTACATTT	107	161.89	-4.31
# AAGGAGCC:GGCTCCTT	114	170.23	-4.31
# GCCTTGCC:GGCAAGGC	68	114.02	-4.31
# ACTCAAGT:ACTTGAGT	191	260.56	-4.31
# AACATATA:TATATGTT	215	288.14	-4.31
# CAGGGAAA:TTTCCCTG	409	505.89	-4.31
# ACGTTATC:GATAACGT	74	121.48	-4.31
# ACGCTAGT:ACTAGCGT	44	83.32	-4.31
# ACATTCGT:ACGAATGT	40	78.03	-4.30
# ACGCTACT:AGTAGCGT	71	117.69	-4.30
# CCCGGAAC:GTTCCGGG	265	344.93	-4.30
# ATAATGCA:TGCATTAT	107	161.73	-4.30
# ATTCCAGG:CCTGGAAT	223	297.16	-4.30
# AAGCTATA:TATAGCTT	223	297.13	-4.30
# AAAGCTGA:TCAGCTTT	420	517.78	-4.30
# ATAATCAT:ATGATTAT	604	719.22	-4.30
# GGAGTGCC:GGCACTCC	69	115.09	-4.30
# CCAATTAA:TTAATTGG	553	663.67	-4.30
# AGCGATCA:TGATCGCT	128	186.61	-4.29
# CGCATGCG:CGCATGCG	1	20.35	-4.29
# AGGAGCCA:TGGCTCCT	186	254.38	-4.29
# GCTATGCC:GGCATAGC	91	142.06	-4.28
# ACAGAGTC:GACTCTGT	87	137.17	-4.28
# ACTTCAAT:ATTGAAGT	287	369.30	-4.28
# AGCATGCT:AGCATGCT	2	22.15	-4.28
# CATACACC:GGTGTATG	68	113.64	-4.28
# AACCTCAT:ATGAGGTT	191	260.03	-4.28
# CGGGTGAA:TTCACCCG	161	225.24	-4.28
# AATTCATA:TATGAATT	222	295.58	-4.28
# AACACAGA:TCTGTGTT	179	246.13	-4.28
# ACTATTTC:GAAATAGT	318	403.99	-4.28
# CGGAAGGA:TCCTTCCG	103	156.52	-4.28
# AAAGGTCA:TGACCTTT	192	261.13	-4.28
# AAGGGATA:TATCCCTT	197	266.80	-4.27
# CGCCAACC:GGTTGGCG	319	404.96	-4.27
# CGAATGCC:GGCATTCG	71	117.25	-4.27
# GGACGGTA:TACCGTCC	99	151.59	-4.27
# AGACAAAT:ATTTGTCT	252	329.44	-4.27
# ATGCCAGG:CCTGGCAT	97	149.04	-4.26
# ATCGAAAG:CTTTCGAT	112	167.01	-4.26
# ATTTAGCA:TGCTAAAT	343	431.40	-4.26
# GCGAATTA:TAATTCGC	192	260.70	-4.26
# CGTACATC:GATGTACG	23	54.36	-4.25
# GAGAGTAC:GTACTCTC	53	94.24	-4.25
# GTCAATTA:TAATTGAC	476	578.13	-4.25
# ACATTTAT:ATAAATGT	212	283.50	-4.25
# CTCCGTTC:GAACGGAG	57	99.30	-4.24
# TACGATGA:TCATCGTA	94	145.09	-4.24
# CATCCTGG:CCAGGATG	151	212.84	-4.24
# GATACCCA:TGGGTATC	256	333.38	-4.24
# AAAAGGTC:GACCTTTT	135	194.02	-4.24
# AGGTCAGG:CCTGACCT	147	208.12	-4.24
# CGCTGCGA:TCGCAGCG	113	167.89	-4.24
# CCGATAGC:GCTATCGG	195	263.80	-4.24
# AGTAGCGG:CCGCTACT	112	166.65	-4.23
# CTGACCAG:CTGGTCAG	218	290.10	-4.23
# GATTTCTA:TAGAAATC	323	408.56	-4.23
# AAATCGGT:ACCGATTT	331	417.47	-4.23
# ACCCTATG:CATAGGGT	108	161.84	-4.23
# CCTAGACA:TGTCTAGG	105	158.23	-4.23
# AGCATGAA:TTCATGCT	141	200.97	-4.23
# GCTATCGA:TCGATAGC	128	185.61	-4.23
# ATACACAG:CTGTGTAT	82	130.22	-4.23
# GTCAGGCA:TGCCTGAC	57	99.03	-4.22
# ATGTATTC:GAATACAT	93	143.62	-4.22
# AACGCAGA:TCTGCGTT	58	100.29	-4.22
# GTAAGCAA:TTGCTTAC	99	150.86	-4.22
# GACCACTC:GAGTGGTC	59	101.55	-4.22
# CATTGCAA:TTGCAATG	67	111.60	-4.22
# GAAGTGTA:TACACTTC	73	119.06	-4.22
# GCTTAACA:TGTTAAGC	108	161.66	-4.22
# AAAGGAAG:CTTCCTTT	148	209.00	-4.22
# GCATTATA:TATAATGC	165	228.81	-4.22
# AACCGTGG:CCACGGTT	130	187.80	-4.22
# CCGGGTTC:GAACCCGG	259	336.27	-4.21
# AATAATGT:ACATTATT	227	299.98	-4.21
# ACATTGTC:GACAATGT	100	151.92	-4.21
# TCAATGCA:TGCATTGA	88	137.37	-4.21
# ACGCTGTC:GACAGCGT	46	84.74	-4.21
# GCTTATTA:TAATAAGC	212	282.77	-4.21
# CGTATCAG:CTGATACG	69	113.91	-4.21
# CATGCGTC:GACGCATG	24	55.25	-4.20
# AGCCGTTA:TAACGGCT	232	305.46	-4.20
# CACCCAAA:TTTGGGTG	493	595.50	-4.20
# ATACGATG:CATCGTAT	56	97.46	-4.20
# GTCCGGAC:GTCCGGAC	8	31.61	-4.20
# ACCTTGAT:ATCAAGGT	256	332.56	-4.20
# CCCTGAAC:GTTCAGGG	156	217.93	-4.20
# GCGAGACC:GGTCTCGC	81	128.56	-4.19
# ACATATGC:GCATATGT	24	55.12	-4.19
# GTTATTTA:TAAATAAC	394	486.42	-4.19
# GATTAGAC:GTCTAATC	127	183.78	-4.19
# AGCAGTGG:CCACTGCT	244	318.73	-4.19
# CCAACTAA:TTAGTTGG	203	272.03	-4.19
# ACCCCGCT:AGCGGGGT	115	169.42	-4.18
# CTTTGGTC:GACCAAAG	218	289.02	-4.18
# GGAGAGTA:TACTCTCC	186	252.34	-4.18
# CAGTCACC:GGTGACTG	151	211.77	-4.18
# ACGGAACA:TGTTCCGT	112	165.74	-4.17
# CTTACACC:GGTGTAAG	89	138.04	-4.17
# CCTTTTAA:TTAAAAGG	209	278.66	-4.17
# TAGCTAGA:TCTAGCTA	119	174.05	-4.17
# AAGGTTAT:ATAACCTT	205	274.06	-4.17
# GCGGAAAC:GTTTCCGC	337	422.74	-4.17
# ATGGGAAG:CTTCCCAT	266	343.24	-4.17
# ATAAGATG:CATCTTAT	87	135.53	-4.17
# ACGCGCGC:GCGCGCGT	23	53.49	-4.17
# ACTTTCAA:TTGAAAGT	266	343.21	-4.17
# AAGTGTAT:ATACACTT	83	130.60	-4.17
# ACCGTATG:CATACGGT	54	94.48	-4.16
# AAGGGGCG:CGCCCCTT	164	226.69	-4.16
# TCCATGAA:TTCATGGA	158	219.71	-4.16
# AACAGTGA:TCACTGTT	156	217.36	-4.16
# CAGCAATC:GATTGCTG	215	285.28	-4.16
# CTCAACAC:GTGTTGAG	108	160.75	-4.16
# GACATGGC:GCCATGTC	98	148.70	-4.16
# GAGTCGGC:GCCGACTC	105	157.07	-4.15
# CGGACTTA:TAAGTCCG	113	166.63	-4.15
# ACCGGAGT:ACTCCGGT	183	248.44	-4.15
# CTCAGCCC:GGGCTGAG	133	190.26	-4.15
# CTTGTTCC:GGAACAAG	159	220.64	-4.15
# ACTTAAGC:GCTTAAGT	14	40.34	-4.15
# CACCCTAG:CTAGGGTG	246	320.17	-4.15
# GCCTCTTA:TAAGAGGC	53	92.96	-4.14
# ACTTTGAG:CTCAAAGT	229	300.87	-4.14
# GAGGATTA:TAATCCTC	323	406.38	-4.14
# AAAATCCT:AGGATTTT	611	722.14	-4.14
# AAAAGTAT:ATACTTTT	303	384.02	-4.13
# ACTAGTGA:TCACTAGT	5	26.13	-4.13
# GTTTTTCA:TGAAAAAC	428	522.45	-4.13
# GATATTCC:GGAATATC	377	466.20	-4.13
# AGGTTCCG:CGGAACCT	194	260.61	-4.13
# CCACAGAC:GTCTGTGG	228	299.39	-4.13
# CTATACCC:GGGTATAG	155	215.53	-4.12
# GGGTAAAC:GTTTACCC	321	403.81	-4.12
# ACGAAATA:TATTTCGT	105	156.55	-4.12
# AGAGACCA:TGGTCTCT	119	173.19	-4.12
# AATAGCCA:TGGCTATT	524	627.08	-4.12
# GAGTACTC:GAGTACTC	20	48.72	-4.12
# GCTTACAA:TTGTAAGC	136	193.17	-4.11
# CTCATACC:GGTATGAG	98	148.01	-4.11
# CTTTCTTC:GAAGAAAG	175	238.44	-4.11
# ATGGTTGA:TCAACCAT	337	421.31	-4.11
# AAGGCCTA:TAGGCCTT	45	82.23	-4.11
# ACGCCACA:TGTGGCGT	58	98.79	-4.10
# AAGTCGCA:TGCGACTT	93	141.87	-4.10
# AGGCATGG:CCATGCCT	97	146.69	-4.10
# ACAAGTGT:ACACTTGT	46	83.48	-4.10
# AAGGCAAT:ATTGCCTT	344	428.94	-4.10
# AACCGGTC:GACCGGTT	29	61.02	-4.10
# GCCCTTTA:TAAAGGGC	80	126.01	-4.10
# GCTAAAGA:TCTTTAGC	238	310.17	-4.10
# CCCTGCCA:TGGCAGGG	198	264.67	-4.10
# AGTAGGTA:TACCTACT	219	288.62	-4.10
# GTTCCCTA:TAGGGAAC	255	329.36	-4.10
# AATCAGGA:TCCTGATT	504	604.76	-4.10
# GACCACTA:TAGTGGTC	131	187.03	-4.10
# CCATATGA:TCATATGG	28	59.63	-4.10
# GAGAGGAA:TTCCTCTC	162	223.19	-4.10
# AAAGCCTA:TAGGCTTT	334	417.69	-4.09
# ACGTTTCT:AGAAACGT	52	91.06	-4.09
# ACGTCTCA:TGAGACGT	37	71.65	-4.09
# AATGCGGA:TCCGCATT	202	269.14	-4.09
# CTGCTGCC:GGCAGCAG	134	190.38	-4.09
# AGTACTCA:TGAGTACT	3	22.29	-4.09
# ACGGTCAT:ATGACCGT	122	176.23	-4.09
# TAACCAGA:TCTGGTTA	276	352.71	-4.08
# CGCCGCAG:CTGCGGCG	89	136.77	-4.08
# ACCGGGTC:GACCCGGT	172	234.53	-4.08
# CCTGCAGA:TCTGCAGG	29	60.85	-4.08
# AATGTCCT:AGGACATT	120	173.81	-4.08
# CCCCATCC:GGATGGGG	188	252.91	-4.08
# GGTCTTCA:TGAAGACC	112	164.31	-4.08
# CCTTGAAC:GTTCAAGG	143	200.78	-4.08
# AGGTTATG:CATAACCT	216	284.76	-4.07
# CGCTCTTA:TAAGAGCG	34	67.45	-4.07
# CACCATAA:TTATGGTG	306	386.02	-4.07
# GCTTGTTA:TAACAAGC	129	184.28	-4.07
# GCGTTGCC:GGCAACGC	37	71.41	-4.07
# GGTTTCCA:TGGAAACC	390	479.10	-4.07
# CTGGTTCA:TGAACCAG	220	289.21	-4.07
# CGGTGTCA:TGACACCG	95	143.80	-4.07
# CGCCACCC:GGGTGGCG	347	431.53	-4.07
# ACGATGGG:CCCATCGT	72	115.77	-4.07
# GATAAATA:TATTTATC	528	630.10	-4.07
# AGTATACA:TGTATACT	90	137.72	-4.07
# AAGGTTGG:CCAACCTT	260	334.35	-4.07
# AAATTTGT:ACAAATTT	453	548.19	-4.07
# GCGAGTTA:TAACTCGC	172	234.21	-4.06
# TGTCATAA:TTATGACA	140	197.04	-4.06
# AAGTAATA:TATTACTT	157	216.84	-4.06
# TCAGCGAA:TTCGCTGA	132	187.65	-4.06
# CCTCTGAA:TTCAGAGG	125	179.38	-4.06
# CGCGTATC:GATACGCG	16	42.45	-4.06
# ACTGGGTC:GACCCAGT	100	149.64	-4.06
# AGTCCTAT:ATAGGACT	106	156.81	-4.06
# ATCAGACA:TGTCTGAT	198	263.89	-4.06
# ACACCTTC:GAAGGTGT	118	171.04	-4.06
# AGGGACAT:ATGTCCCT	93	141.18	-4.05
# ACTCCCAA:TTGGGAGT	409	499.59	-4.05
# GAAAACTA:TAGTTTTC	272	347.53	-4.05
# GCGTATGA:TCATACGC	18	45.25	-4.05
# GACCCGTC:GACGGGTC	81	126.57	-4.05
# CCATTCCA:TGGAATGG	210	277.43	-4.05
# CACGTGCC:GGCACGTG	1	18.34	-4.05
# ACGGTTAT:ATAACCGT	161	221.19	-4.05
# GTCACCAA:TTGGTGAC	218	286.44	-4.04
# ACCTGTTG:CAACAGGT	365	450.87	-4.04
# ATTCGCTG:CAGCGAAT	119	172.02	-4.04
# CACTGCCC:GGGCAGTG	60	100.51	-4.04
# CCTGAAGC:GCTTCAGG	140	196.67	-4.04
# TAGGCTCA:TGAGCCTA	105	155.33	-4.04
# CATGCCCA:TGGGCATG	69	111.66	-4.04
# AAGTCGGG:CCCGACTT	154	212.90	-4.04
# GAGTCTCA:TGAGACTC	177	239.46	-4.04
# CAAGCAAA:TTTGCTTG	184	247.49	-4.04
# CGCACCAA:TTGGTGCG	292	369.58	-4.04
# AGAACCCA:TGGGTTCT	322	402.98	-4.03
# ACCCTAGG:CCTAGGGT	243	314.53	-4.03
# GGTAGGTA:TACCTACC	159	218.63	-4.03
# ACATCAAT:ATTGATGT	410	500.16	-4.03
# AATCATCT:AGATGATT	512	611.65	-4.03
# AGTTCGTA:TACGAACT	74	117.71	-4.03
# CATTCCAG:CTGGAATG	189	253.06	-4.03
# AGCGCGCA:TGCGCGCT	37	70.89	-4.02
# ACAAGACT:AGTCTTGT	104	153.92	-4.02
# CTTTGATC:GATCAAAG	113	164.59	-4.02
# TAAGGCAA:TTGCCTTA	134	189.31	-4.02
# AAAGTACA:TGTACTTT	194	258.63	-4.02
# GAAGGGTA:TACCCTTC	93	140.65	-4.02
# TAGGACGA:TCGTCCTA	93	140.64	-4.02
# ACAGGTCT:AGACCTGT	152	210.25	-4.02
# AAGTACGT:ACGTACTT	9	31.56	-4.02
# CGTTCAGA:TCTGAACG	65	106.43	-4.02
# GACAGGTA:TACCTGTC	120	172.77	-4.01
# TGCGAGAA:TTCTCGCA	200	265.38	-4.01
# TCCCGGAA:TTCCGGGA	380	466.69	-4.01
# GGAAGCCA:TGGCTTCC	328	409.14	-4.01
# CAAAATGG:CCATTTTG	388	475.46	-4.01
# AAGACGGT:ACCGTCTT	100	148.95	-4.01
# CGACGCTA:TAGCGTCG	55	93.85	-4.01
# CATAATGC:GCATTATG	109	159.66	-4.01
# ACGTTCAC:GTGAACGT	39	73.29	-4.01
# GGACAAAA:TTTTGTCC	365	449.94	-4.00
# GATGGGTA:TACCCATC	155	213.49	-4.00
# GCGGTGGA:TCCACCGC	176	237.71	-4.00
# ATAAAACG:CGTTTTAT	137	192.54	-4.00
# AGGCAGGA:TCCTGCCT	100	148.82	-4.00
# ACTGCAGG:CCTGCAGT	48	84.85	-4.00
# CCTCAGG :CCTGAGG 	43	632.99	-23.45
# GCTAAGC :GCTTAGC 	9	465.44	-21.16
# CCTAAGG :CCTTAGG 	46	528.42	-20.99
# GGTCACC :GGTGACC 	121	596.85	-19.48
# GCTCAGC :GCTGAGC 	5	365.65	-18.86
# GCGATCA :TGATCGC 	686	1377.42	-18.63
# GCGATCC :GGATCGC 	374	937.71	-18.41
# GGTAACC :GGTTACC 	257	717.25	-17.19
# AGATCGC :GCGATCT 	383	841.59	-15.81
# TATCGCA :TGCGATA 	434	773.12	-12.20
# ACGCACT :AGTGCGT 	276	561.57	-12.05
# CTGACGA :TCGTCAG 	490	809.62	-11.23
# ATGCGAG :CTCGCAT 	346	608.47	-10.64
# GCGTCAA :TTGACGC 	425	705.64	-10.57
# CATTTTA :TAAAATG 	1224	1653.55	-10.56
# ATGACGC :GCGTCAT 	253	480.20	-10.37
# CTTCAAG :CTTGAAG 	445	720.48	-10.26
# TGTCACA :TGTGACA 	307	541.66	-10.08
# ATCGCAG :CTGCGAT 	912	1270.05	-10.05
# AAAACCC :GGGTTTT 	2581	3121.23	-9.67
# CCTTTCA :TGAAAGG 	600	883.87	-9.55
# GCCCTAC :GTAGGGC 	437	681.50	-9.37
# AAACCTA :TAGGTTT 	1457	1860.50	-9.36
# GAACGGC :GCCGTTC 	246	441.68	-9.31
# GGCCGCC :GGCGGCC 	243	436.04	-9.24
# GCCCAAC :GTTGGGC 	739	1031.95	-9.12
# CTTTTTA :TAAAAAG 	1146	1495.58	-9.04
# AACGCAC :GTGCGTT 	428	658.43	-8.98
# AGCGGCG :CGCCGCT 	631	893.47	-8.78
# CATCATG :CATGATG 	721	997.28	-8.75
# CCTGCTA :TAGCAGG 	569	819.34	-8.75
# CCTAAAG :CTTTAGG 	655	920.29	-8.75
# GATAAAC :GTTTATC 	1412	1779.36	-8.71
# AAAAAAA :TTTTTTT 	2784	3275.90	-8.60
# ACCGCCC :GGGCGGT 	872	1164.47	-8.57
# CGCGTCA :TGACGCG 	238	411.76	-8.56
# CTAGCGA :TCGCTAG 	324	517.87	-8.52
# CGGTTTA :TAAACCG 	1054	1364.15	-8.40
# AGTTGTA :TACAACT 	696	953.89	-8.35
# ACCCGCT :AGCGGGT 	652	901.40	-8.31
# CCTTTAG :CTAAAGG 	676	928.52	-8.29
# TAAGGCA :TGCCTTA 	527	754.56	-8.28
# AACAACC :GGTTGTT 	964	1256.67	-8.26
# ATGCGTC :GACGCAT 	311	494.50	-8.25
# ATCGCTG :CAGCGAT 	1557	1917.50	-8.23
# CAACCTG :CAGGTTG 	920	1205.60	-8.23
# CATATCA :TGATATG 	780	1044.15	-8.18
# AGGCGGG :CCCGCCT 	738	993.24	-8.10
# AGGCGAG :CTCGCCT 	526	747.02	-8.09
# AGGGTGG :CCACCCT 	789	1050.05	-8.06
# AGGCGAC :GTCGCCT 	719	968.64	-8.02
# CCCCACA :TGTGGGG 	989	1275.31	-8.02
# GCCGCCC :GGGCGGC 	1043	1334.42	-7.98
# GGCAAAC :GTTTGCC 	477	684.33	-7.93
# CAAAACG :CGTTTTG 	720	965.70	-7.91
# CCGCTTA :TAAGCGG 	362	546.16	-7.88
# AAACCCC :GGGGTTT 	2197	2597.94	-7.87
# ACGCCTC :GAGGCGT 	195	339.25	-7.83
# AGACGCA :TGCGTCT 	314	486.41	-7.82
# AAATTCC :GGAATTT 	2640	3072.31	-7.80
# AAATTAA :TTAATTT 	2949	3403.72	-7.80
# CCGCCCA :TGGGCGG 	941	1211.94	-7.78
# GCCAGGC :GCCTGGC 	198	341.71	-7.77
# CAATTTA :TAAATTG 	1737	2092.10	-7.76
# TCCCCCA :TGGGGGA 	1781	2138.77	-7.74
# ACCCAAA :TTTGGGT 	2155	2545.21	-7.74
# AAAAACC :GGTTTTT 	2610	3035.65	-7.73
# AAGAGCC :GGCTCTT 	268	427.77	-7.73
# AGGCGAA :TTCGCCT 	602	823.61	-7.72
# ACCCAAT :ATTGGGT 	1206	1504.60	-7.70
# ATTTTAA :TTAAAAT 	2383	2789.28	-7.69
# CTTAAAG :CTTTAAG 	668	896.96	-7.65
# CGCCGCA :TGCGGCG 	629	851.75	-7.63
# GTTGTTA :TAACAAC 	697	928.80	-7.61
# CATCCTA :TAGGATG 	534	740.52	-7.59
# GTCCTTA :TAAGGAC 	257	408.38	-7.49
# CCCCAAC :GTTGGGG 	1730	2065.95	-7.39
# CAAAACA :TGTTTTG 	1270	1560.97	-7.37
# GCTTTCC :GGAAAGC 	905	1154.78	-7.35
# TAGGGGA :TCCCCTA 	1469	1777.75	-7.32
# CACATCG :CGATGTG 	260	407.43	-7.30
# GACCACC :GGTGGTC 	652	866.65	-7.29
# CGTCACG :CGTGACG 	102	205.94	-7.24
# CTATTTA :TAAATAG 	1347	1639.92	-7.23
# AAGAACC :GGTTCTT 	778	1007.39	-7.23
# GGGCGGA :TCCGCCC 	621	826.94	-7.16
# TGTGAAA :TTTCACA 	663	873.97	-7.14
# CATAATG :CATTATG 	658	866.58	-7.09
# GGTGCGA :TCGCACC 	1336	1618.16	-7.02
# CCGACTA :TAGTCGG 	589	785.47	-7.01
# CCCGCCG :CGGCGGG 	1015	1263.73	-7.00
# GAACCCC :GGGGTTC 	1113	1372.18	-7.00
# ACATACG :CGTATGT 	78	168.40	-6.97
# CCGGTTA :TAACCGG 	707	917.69	-6.96
# CGCGATC :GATCGCG 	2213	2565.12	-6.95
# CTAGTTA :TAACTAG 	570	761.65	-6.94
# CCCGCCA :TGGCGGG 	1412	1697.87	-6.94
# AGGCACC :GGTGCCT 	60	142.65	-6.92
# CAAGGCG :CGCCTTG 	655	857.42	-6.91
# CATTCCG :CGGAATG 	405	569.74	-6.90
# CTTGCTA :TAGCAAG 	421	588.09	-6.89
# ACCCCGC :GCGGGGT 	612	807.71	-6.89
# AAGCCCC :GGGGCTT 	711	918.55	-6.85
# CATGAGG :CCTCATG 	341	492.81	-6.84
# AATGGTC :GACCATT 	761	974.20	-6.83
# CTCATTA :TAATGAG 	684	885.78	-6.78
# CACAACA :TGTTGTG 	549	732.39	-6.78
# CACCCCG :CGGGGTG 	553	736.58	-6.76
# CATGGAG :CTCCATG 	426	590.30	-6.76
# AGTAGGG :CCCTACT 	982	1217.87	-6.76
# CTCGTTA :TAACGAG 	248	379.67	-6.76
# TATCCCA :TGGGATA 	1262	1525.89	-6.76
# CTAAAAG :CTTTTAG 	778	990.27	-6.75
# AGCGTCA :TGACGCT 	486	659.15	-6.74
# CGGGTTA :TAACCCG 	1150	1402.46	-6.74
# GAGATGC :GCATCTC 	597	785.65	-6.73
# GACCTAC :GTAGGTC 	434	597.77	-6.70
# TAGCGCA :TGCGCTA 	333	479.26	-6.68
# GAACCAA :TTGGTTC 	814	1028.18	-6.68
# GTGCGTA :TACGCAC 	165	275.71	-6.67
# AATGATC :GATCATT 	478	647.23	-6.65
# AGATTCC :GGAATCT 	638	828.48	-6.62
# AGAGATC :GATCTCT 	178	290.83	-6.62
# CCGTCAG :CTGACGG 	742	945.20	-6.61
# CAAATCG :CGATTTG 	885	1104.44	-6.60
# CCGGCTA :TAGCCGG 	723	923.62	-6.60
# CAAAGAG :CTCTTTG 	507	678.57	-6.59
# AGGGGTG :CACCCCT 	1013	1244.76	-6.57
# GAGAGGC :GCCTCTC 	479	645.56	-6.56
# CCTCTTA :TAAGAGG 	311	450.00	-6.55
# ACCTTTC :GAAAGGT 	724	922.29	-6.53
# GTACTTA :TAAGTAC 	212	330.46	-6.52
# GACCCGC :GCGGGTC 	517	687.73	-6.51
# CGGCAAG :CTTGCCG 	278	409.68	-6.51
# CCTCAAG :CTTGAGG 	868	1081.70	-6.50
# GAATCAA :TTGATTC 	1265	1517.81	-6.49
# GGCACCC :GGGTGCC 	100	189.21	-6.49
# CTCTTTA :TAAAGAG 	584	763.15	-6.49
# ATGCCTC :GAGGCAT 	361	506.55	-6.47
# AAGCCGT :ACGGCTT 	838	1047.10	-6.46
# ACACTTC :GAAGTGT 	384	532.22	-6.43
# ATCGCCG :CGGCGAT 	1968	2273.93	-6.42
# TCCCCGA :TCGGGGA 	775	975.25	-6.41
# CCTTGCA :TGCAAGG 	310	444.84	-6.39
# CTAGGCA :TGCCTAG 	229	348.23	-6.39
# CCCGTTA :TAACGGG 	605	783.57	-6.38
# CTGTAAG :CTTACAG 	325	462.06	-6.38
# ACGCCCC :GGGGCGT 	322	458.18	-6.36
# CACTGCA :TGCAGTG 	240	360.80	-6.36
# ATGTCCA :TGGACAT 	436	590.47	-6.36
# GCGTTCC :GGAACGC 	378	523.29	-6.35
# AGTCTTC :GAAGACT 	490	652.19	-6.35
# GCTCCAC :GTGGAGC 	138	234.78	-6.32
# ACCCGCA :TGCGGGT 	997	1217.27	-6.31
# AGGGTTC :GAACCCT 	820	1021.17	-6.30
# CCCCTTA :TAAGGGG 	713	902.04	-6.29
# AAATAGT :ACTATTT 	1538	1804.92	-6.28
# CGATAGA :TCTATCG 	466	622.62	-6.28
# AGGACGG :CCGTCCT 	448	601.75	-6.27
# GTGAAAA :TTTTCAC 	1173	1408.09	-6.27
# TGTAAAA :TTTTACA 	901	1109.43	-6.26
# CGAATCA :TGATTCG 	595	767.57	-6.23
# AGCCTTC :GAAGGCT 	742	931.73	-6.22
# ATAACTC :GAGTTAT 	1051	1272.71	-6.22
# AAACTGT :ACAGTTT 	1502	1762.89	-6.21
# GACTCGC :GCGAGTC 	421	569.17	-6.21
# AATCCTC :GAGGATT 	1300	1543.22	-6.19
# ACTGCGC :GCGCAGT 	296	423.29	-6.19
# GCCCCGC :GCGGGGC 	221	333.76	-6.17
# CACCAAG :CTTGGTG 	748	935.75	-6.14
# ACCCAGT :ACTGGGT 	851	1049.50	-6.13
# AAAATTC :GAATTTT 	2467	2789.22	-6.10
# AGCCGCC :GGCGGCT 	1442	1692.35	-6.09
# GCGGGTA :TACCCGC 	761	948.32	-6.08
# CATTTCA :TGAAATG 	751	937.10	-6.08
# ATGCGAA :TTCGCAT 	424	568.95	-6.08
# GACCTTA :TAAGGTC 	353	487.03	-6.07
# CTATAAG :CTTATAG 	378	515.79	-6.07
# ATAATTC :GAATTAT 	1776	2050.62	-6.07
# GAAATCC :GGATTTC 	1168	1394.07	-6.06
# GACCCAA :TTGGGTC 	858	1054.48	-6.05
# CCCTTAG :CTAAGGG 	532	690.94	-6.05
# CAACTTG :CAAGTTG 	791	979.83	-6.03
# GATGCCC :GGGCATC 	493	646.10	-6.02
# CGCAAGA :TCTTGCG 	194	297.97	-6.02
# CCATTAG :CTAATGG 	900	1099.61	-6.02
# ATTCAAT :ATTGAAT 	1406	1650.43	-6.02
# GAGAGAC :GTCTCTC 	357	490.18	-6.02
# CTCGACA :TGTCGAG 	372	507.20	-6.00
# AAACTTC :GAAGTTT 	1209	1436.40	-6.00
# ATGCCCC :GGGGCAT 	384	520.91	-6.00
# GCCCACC :GGTGGGC 	400	538.95	-5.99
# AAGCGGT :ACCGCTT 	681	855.73	-5.97
# ATTCTCC :GGAGAAT 	1197	1421.64	-5.96
# CAAACAG :CTGTTTG 	1124	1341.50	-5.94
# TACACCA :TGGTGTA 	636	803.47	-5.91
# GAGCGCC :GGCGCTC 	338	465.46	-5.91
# ACCCCTG :CAGGGGT 	870	1062.37	-5.90
# ATATTTG :CAAATAT 	1499	1745.18	-5.89
# GCTGCGA :TCGCAGC 	500	650.03	-5.88
# ATGCGAC :GTCGCAT 	461	605.69	-5.88
# CTTTGCC :GGCAAAG 	492	640.12	-5.85
# CCTTGGA :TCCAAGG 	607	769.30	-5.85
# ACCATTC :GAATGGT 	863	1052.83	-5.85
# GAGGAGC :GCTCCTC 	281	397.26	-5.83
# AAAATAA :TTATTTT 	2502	2810.21	-5.82
# GAAATAC :GTATTTC 	870	1059.17	-5.81
# CATTTAG :CTAAATG 	749	925.56	-5.80
# ...
# AGTAAA  :TTTACT  	4340	4755.02	-6.02
# GAGATC  :GATCTC  	1184	1410.03	-6.02
# GCGAGC  :GCTCGC  	778	964.97	-6.02
# CCACCC  :GGGTGG  	4631	5057.39	-6.00
# AGAAAA  :TTTTCT  	7130	7654.16	-5.99
# CTTTTA  :TAAAAG  	4014	4410.62	-5.97
# ACCTTG  :CAAGGT  	2844	3179.77	-5.96
# AGCGAC  :GTCGCT  	2050	2337.76	-5.95
# CTGAAG  :CTTCAG  	2638	2959.61	-5.91
# AGACTA  :TAGTCT  	2473	2784.31	-5.90
# ATTGCA  :TGCAAT  	2982	3321.82	-5.90
# ACTGCA  :TGCAGT  	1841	2111.88	-5.90
# AATCAA  :TTGATT  	9407	9995.89	-5.89
# AGTTTA  :TAAACT  	5893	6361.45	-5.88
# GGAACA  :TGTTCC  	3576	3944.76	-5.87
# GTTCCA  :TGGAAC  	2982	3320.29	-5.87
# AGACGC  :GCGTCT  	970	1170.80	-5.87
# GCAAGA  :TCTTGC  	1684	1942.58	-5.87
# AACCCC  :GGGGTT  	7025	7532.35	-5.85
# ACTCTA  :TAGAGT  	2551	2862.88	-5.83
# AATGCA  :TGCATT  	2188	2476.85	-5.80
# ACTATA  :TATAGT  	2796	3118.47	-5.78
# CGACGC  :GCGTCG  	842	1026.66	-5.76
# AACCCT  :AGGGTT  	5228	5661.33	-5.76
# ATGCTG  :CAGCAT  	3588	3948.57	-5.74
# CCTGGC  :GCCAGG  	2342	2636.35	-5.73
# ATATGG  :CCATAT  	3746	4112.64	-5.72
# GCTCCC  :GGGAGC  	1689	1939.88	-5.70
# GCAGGA  :TCCTGC  	2045	2318.31	-5.68
# AATGCT  :AGCATT  	4454	4849.06	-5.68
# TCGAAA  :TTTCGA  	2460	2757.87	-5.67
# ACAAAG  :CTTTGT  	2957	3280.24	-5.65
# ATGTTG  :CAACAT  	3420	3766.16	-5.64
# ATTGTA  :TACAAT  	3486	3833.73	-5.62
# GGAGTA  :TACTCC  	2652	2957.36	-5.62
# AATCAG  :CTGATT  	6395	6859.38	-5.61
# GGCCAA  :TTGGCC  	1019	1214.41	-5.61
# CTAGTC  :GACTAG  	1711	1958.85	-5.60
# CGGTGC  :GCACCG  	1562	1797.98	-5.57
# GCCAAC  :GTTGGC  	3722	4076.36	-5.55
# ACCCGA  :TCGGGT  	3294	3626.67	-5.53
# ATACGA  :TCGTAT  	1096	1294.51	-5.52
# ACCCCA  :TGGGGT  	5933	6372.99	-5.51
# ATTCTA  :TAGAAT  	3676	4024.57	-5.50
# CGTCCA  :TGGACG  	1173	1376.75	-5.49
# CTCCTC  :GAGGAG  	2519	2809.22	-5.48
# CATAGG  :CCTATG  	2254	2528.70	-5.46
# ATTGCG  :CGCAAT  	2642	2937.66	-5.46
# GATCAA  :TTGATC  	2995	3307.46	-5.43
# ATTATG  :CATAAT  	5232	5639.38	-5.43
# ACCGAA  :TTCGGT  	3327	3654.84	-5.42
# CGTTAG  :CTAACG  	1446	1667.16	-5.42
# CGGGGC  :GCCCCG  	1238	1443.66	-5.41
# AGGTTA  :TAACCT  	4129	4490.25	-5.39
# CAGGGG  :CCCCTG  	3539	3874.34	-5.39
# AATTAA  :TTAATT  	11107	11689.01	-5.39
# ACAGGA  :TCCTGT  	3617	3953.42	-5.35
# ACCAAA  :TTTGGT  	6976	7435.22	-5.33
# AGATGA  :TCATCT  	4388	4754.04	-5.31
# AGTCCG  :CGGACT  	2321	2590.92	-5.30
# TCTGAA  :TTCAGA  	3710	4046.47	-5.29
# GCTCCA  :TGGAGC  	1242	1438.29	-5.18
# AGCCTC  :GAGGCT  	2837	3123.04	-5.12
# CACTTA  :TAAGTG  	1599	1817.19	-5.12
# CCACAA  :TTGTGG  	4304	4651.92	-5.10
# ATCTAG  :CTAGAT  	2395	2657.90	-5.10
# GGATCA  :TGATCC  	1769	1995.99	-5.08
# AAACTT  :AAGTTT  	6206	6617.51	-5.06
# AAAAGG  :CCTTTT  	4355	4699.37	-5.03
# CAACTG  :CAGTTG  	4234	4572.86	-5.01
# ATAAAA  :TTTTAT  	7371	7813.43	-5.01
# CTAAAC  :GTTTAG  	4412	4756.87	-5.00
# AATAGA  :TCTATT  	3814	4134.97	-4.99
# ACTTTA  :TAAAGT  	4257	4594.44	-4.98
# ACTCGG  :CCGAGT  	1719	1937.86	-4.97
# GGACCA  :TGGTCC  	926	1089.86	-4.96
# GCAGTA  :TACTGC  	2065	2302.91	-4.96
# GAAGCA  :TGCTTC  	2791	3065.09	-4.95
# ATCCAG  :CTGGAT  	3025	3309.63	-4.95
# AGAGAG  :CTCTCT  	1975	2206.90	-4.94
# GCATAC  :GTATGC  	981	1148.16	-4.93
# GACTGC  :GCAGTC  	1886	2112.45	-4.93
# GGGCGA  :TCGCCC  	4298	4632.97	-4.92
# CGAGGC  :GCCTCG  	1203	1386.04	-4.92
# ACTCCG  :CGGAGT  	1972	2202.60	-4.91
# ACTGTG  :CACAGT  	2169	2410.04	-4.91
# GGCTCA  :TGAGCC  	2458	2712.52	-4.89
# CCAGAC  :GTCTGG  	2924	3199.75	-4.88
# GCGAAC  :GTTCGC  	1422	1617.26	-4.86
# CATTTA  :TAAATG  	4232	4559.39	-4.85
# GGCTTA  :TAAGCC  	3083	3363.79	-4.84
# GAGGCC  :GGCCTC  	359	462.94	-4.83
# ATGACA  :TGTCAT  	2354	2600.14	-4.83
# ATAGCA  :TGCTAT  	4081	4397.79	-4.78
# AAACAA  :TTGTTT  	5667	6035.70	-4.75
# GCATCC  :GGATGC  	2197	2430.75	-4.74
# GGGTCA  :TGACCC  	3827	4131.09	-4.73
# ATGTCG  :CGACAT  	1775	1985.55	-4.73
# ATGAGA  :TCTCAT  	2283	2519.78	-4.72
# GTTGGA  :TCCAAC  	2995	3264.28	-4.71
# GTGGTA  :TACCAC  	2883	3147.38	-4.71
# AAGACG  :CGTCTT  	1266	1444.57	-4.70
# CCACTC  :GAGTGG  	1915	2131.90	-4.70
# AAGGAG  :CTCCTT  	2221	2452.87	-4.68
# GTCCCA  :TGGGAC  	2266	2499.74	-4.68
# CCTTAC  :GTAAGG  	1634	1833.87	-4.67
# CATCAC  :GTGATG  	3686	3980.13	-4.66
# AAGCGC  :GCGCTT  	1995	2213.84	-4.65
# AGCGGC  :GCCGCT  	1949	2165.21	-4.65
# CACGCG  :CGCGTG  	406	510.46	-4.62
# AGCCAA  :TTGGCT  	6567	6951.82	-4.62
# CCATTA  :TAATGG  	5377	5725.59	-4.61
# CAAGAG  :CTCTTG  	1937	2149.03	-4.57
# GATAAC  :GTTATC  	4109	4412.08	-4.56
# ACTCAA  :TTGAGT  	5659	6012.61	-4.56
# CTCCAG  :CTGGAG  	2567	2806.96	-4.53
# CCTCTC  :GAGAGG  	2546	2784.49	-4.52
# CAATGC  :GCATTG  	2982	3239.00	-4.52
# GAATAC  :GTATTC  	2425	2657.64	-4.51
# AGTTGG  :CCAACT  	4878	5202.94	-4.51
# ATTCTG  :CAGAAT  	4688	5005.96	-4.50
# GGGACC  :GGTCCC  	824	963.52	-4.50
# CGCTAG  :CTAGCG  	1366	1542.49	-4.49
# ACCGCA  :TGCGGT  	2312	2538.23	-4.49
# ATCTCG  :CGAGAT  	2497	2731.62	-4.49
# AAAACA  :TGTTTT  	5693	6040.91	-4.48
# AGTCAG  :CTGACT  	3027	3283.13	-4.47
# GAGACA  :TGTCTC  	1887	2090.68	-4.46
# ATCGGA  :TCCGAT  	3067	3323.27	-4.45
# AGGTCA  :TGACCT  	3199	3460.39	-4.44
# GGGACA  :TGTCCC  	2577	2812.41	-4.44
# ACACTG  :CAGTGT  	1462	1641.89	-4.44
# CTCTAC  :GTAGAG  	1894	2097.29	-4.44
# AGCCCC  :GGGGCT  	2851	3098.00	-4.44
# CTGCGA  :TCGCAG  	2389	2613.95	-4.40
# ATGTGC  :GCACAT  	1219	1380.37	-4.34
# AAGAGA  :TCTCTT  	1988	2191.14	-4.34
# ATTAGA  :TCTAAT  	4650	4954.13	-4.32
# GGAGAC  :GTCTCC  	2295	2510.39	-4.30
# AAAGAT  :ATCTTT  	4323	4613.42	-4.28
# CAAGTA  :TACTTG  	2054	2257.16	-4.28
# ATCACG  :CGTGAT  	1721	1906.73	-4.25
# CCAGGC  :GCCTGG  	1873	2065.79	-4.24
# CAACAC  :GTGTTG  	2536	2758.28	-4.23
# CCTCAG  :CTGAGG  	3008	3248.67	-4.22
# ACAACC  :GGTTGT  	3479	3736.97	-4.22
# GGGTTA  :TAACCC  	5823	6153.48	-4.21
# ACGCTC  :GAGCGT  	769	895.03	-4.21
# ATAATA  :TATTAT  	5780	6108.98	-4.21
# AGAAGG  :CCTTCT  	2959	3196.80	-4.21
# ATTACG  :CGTAAT  	1874	2064.57	-4.19
# CAGCGA  :TCGCTG  	3478	3733.44	-4.18
# ACCCAT  :ATGGGT  	3919	4189.37	-4.18
# CGTGAA  :TTCACG  	1285	1442.31	-4.14
# CTCAGC  :GCTGAG  	2612	2832.19	-4.14
# AGGTGG  :CCACCT  	3436	3686.01	-4.12
# ACGCAA  :TTGCGT  	1454	1619.47	-4.11
# CACTCG  :CGAGTG  	938	1072.49	-4.11
# ATAAGG  :CCTTAT  	2656	2875.86	-4.10
# ACTACA  :TGTAGT  	2644	2861.68	-4.07
# AGTCTA  :TAGACT  	2604	2819.87	-4.07
# AGAGTG  :CACTCT  	1493	1658.56	-4.07
# GACGGC  :GCCGTC  	1961	2148.46	-4.04
# TCCCAA  :TTGGGA  	6974	7319.73	-4.04
# AGGAAA  :TTTCCT  	6002	6323.26	-4.04
# GTTTCA  :TGAAAC  	4176	4444.98	-4.04
# AGGCAA  :TTGCCT  	2986	3214.72	-4.03
# TGGTAA  :TTACCA  	5545	5853.11	-4.03
# GCACGC  :GCGTGC  	527	627.65	-4.02
# ACCAAC  :GTTGGT  	4326	4597.15	-4.00
# GGACC   :GGTCC   	3403	7769.39	-49.57
# CATCG   :CGATG   	9063	14591.93	-45.82
# AATCG   :CGATT   	13892	19771.92	-41.88
# GCGAA   :TTCGC   	8835	12739.33	-34.62
# CGATA   :TATCG   	12823	16974.72	-31.91
# ATCGG   :CCGAT   	13262	17294.70	-30.70
# GGCAC   :GTGCC   	4515	6497.91	-24.61
# AATGA   :TCATT   	15065	18239.44	-23.54
# CAATC   :GATTG   	14762	17855.90	-23.18
# ACGAT   :ATCGT   	7878	10113.57	-22.25
# CTCGC   :GCGAG   	7622	9771.93	-21.76
# ACGCC   :GGCGT   	5720	7584.85	-21.42
# CCATC   :GATGG   	16132	18997.21	-20.82
# ATTGG   :CCAAT   	19598	22630.94	-20.19
# AAGCA   :TGCTT   	12650	14990.40	-19.14
# ATGGG   :CCCAT   	15564	18098.96	-18.87
# TTCAA   :TTGAA   	19467	22197.00	-18.35
# AGCGG   :CCGCT   	8808	10633.61	-17.72
# CCAGC   :GCTGG   	11310	13338.68	-17.58
# TCTCA   :TGAGA   	12423	14502.31	-17.28
# AACCA   :TGGTT   	21509	24130.09	-16.90
# GCGAC   :GTCGC   	9037	10776.92	-16.77
# GCCTA   :TAGGC   	8140	9774.36	-16.54
# GCGGA   :TCCGC   	8954	10633.81	-16.30
# CGCAA   :TTGCG   	9207	10879.25	-16.05
# AACGA   :TCGTT   	7541	9027.64	-15.66
# TAAGA   :TCTTA   	7677	9174.07	-15.64
# CGGAG   :CTCCG   	7184	8611.56	-15.39
# ATTTG   :CAAAT   	24516	27041.59	-15.39
# CAGGC   :GCCTG   	7833	9316.71	-15.38
# ATGAG   :CTCAT   	10129	11793.01	-15.34
# CAACC   :GGTTG   	17399	19499.34	-15.06
# AAGGA   :TCCTT   	11199	12904.94	-15.03
# CCTGC   :GCAGG   	7540	8955.50	-14.97
# AAACA   :TGTTT   	18654	20802.60	-14.92
# TAAAA   :TTTTA   	27847	30436.88	-14.88
# CTGTC   :GACAG   	9751	11323.61	-14.79
# CCCCG   :CGGGG   	10920	12545.13	-14.52
# AACTA   :TAGTT   	16799	18775.98	-14.45
# CTGGC   :GCCAG   	11340	12978.29	-14.39
# CACTC   :GAGTG   	6776	8057.17	-14.28
# TAGGA   :TCCTA   	11962	13597.80	-14.04
# TAATA   :TATTA   	21319	23398.65	-13.62
# TGTAA   :TTACA   	11332	12851.61	-13.42
# TCACA   :TGTGA   	8625	9954.13	-13.33
# AGGGA   :TCCCT   	13590	15225.56	-13.27
# GGGAC   :GTCCC   	8574	9875.96	-13.11
# CGCCA   :TGGCG   	17357	19094.47	-12.59
# CCTTC   :GAAGG   	10176	11519.62	-12.53
# CGCAG   :CTGCG   	7005	8129.90	-12.48
# AGTCA   :TGACT   	13047	14549.30	-12.47
# AAGGG   :CCCTT   	12037	13483.16	-12.47
# CAAAC   :GTTTG   	17629	19356.64	-12.44
# TGACA   :TGTCA   	11721	13144.07	-12.42
# GCTCC   :GGAGC   	5723	6705.73	-12.01
# GAATC   :GATTC   	12885	14319.78	-12.00
# ATAGG   :CCTAT   	12792	14188.84	-11.74
# CTTGC   :GCAAG   	7398	8465.85	-11.61
# AGGAA   :TTCCT   	17452	19046.74	-11.57
# CCTCC   :GGAGG   	10771	12016.46	-11.37
# CAGGG   :CCCTG   	12229	13541.86	-11.29
# AGTTC   :GAACT   	12612	13925.89	-11.15
# AGCAC   :GTGCT   	7571	8584.14	-10.94
# AATAA   :TTATT   	25399	27181.64	-10.83
# CGGCA   :TGCCG   	7149	8124.58	-10.83
# ACTTG   :CAAGT   	10858	12041.75	-10.80
# AAGAG   :CTCTT   	8287	9297.83	-10.49
# GCTTA   :TAAGC   	9280	10333.98	-10.38
# TCCAA   :TTGGA   	14736	16027.62	-10.21
# ATCCG   :CGGAT   	9496	10538.26	-10.16
# ACAGA   :TCTGT   	12589	13775.01	-10.12
# CAGTC   :GACTG   	9860	10906.16	-10.03
# CGAGC   :GCTCG   	3485	4122.86	-9.94
# TAACA   :TGTTA   	13576	14773.77	-9.87
# AAAAG   :CTTTT   	20419	21875.16	-9.86
# CGGGC   :GCCCG   	4962	5699.29	-9.77
# TGAAA   :TTTCA   	20288	21692.42	-9.55
# ACTGA   :TCAGT   	13083	14215.76	-9.51
# ATTAG   :CTAAT   	19713	21087.73	-9.48
# CCACG   :CGTGG   	4636	5327.50	-9.48
# AGAGA   :TCTCT   	10186	11187.61	-9.48
# ATAAC   :GTTAT   	15353	16566.97	-9.44
# CCCTC   :GAGGG   	10980	12003.92	-9.35
# GCACC   :GGTGC   	9314	10246.35	-9.22
# CCCAC   :GTGGG   	12510	13575.30	-9.15
# CCTAA   :TTAGG   	14860	15998.08	-9.01
# ACCAA   :TTGGT   	20753	22088.18	-9.00
# CGAAG   :CTTCG   	6344	7101.33	-8.99
# AGCCC   :GGGCT   	10646	11605.84	-8.92
# AAATG   :CATTT   	19412	20692.25	-8.91
# CTCAG   :CTGAG   	11058	12029.19	-8.86
# AAAAA   :TTTTT   	39769	41565.01	-8.84
# GCATA   :TATGC   	7990	8811.64	-8.76
# AGGTG   :CACCT   	11321	12287.37	-8.73
# CCCCC   :GGGGG   	19361	20583.70	-8.54
# CGCTA   :TAGCG   	9807	10677.44	-8.43
# TCAAA   :TTTGA   	27550	28981.65	-8.43
# AGACG   :CGTCT   	5637	6285.54	-8.18
# ATAGA   :TCTAT   	12607	13548.66	-8.10
# GACCC   :GGGTC   	10243	11095.03	-8.10
# TGGAA   :TTCCA   	17202	18276.69	-7.96
# ACCCA   :TGGGT   	19092	20208.39	-7.86
# CTATC   :GATAG   	14519	15463.35	-7.60
# AACGG   :CCGTT   	11158	11952.38	-7.27
# CAGCC   :GGCTG   	14924	15838.00	-7.27
# TATGA   :TCATA   	12547	13373.60	-7.15
# TCAGA   :TCTGA   	15314	16221.98	-7.14
# AAAGA   :TCTTT   	15235	16135.49	-7.10
# AACAA   :TTGTT   	19998	21017.86	-7.05
# CTGCC   :GGCAG   	8643	9301.86	-6.84
# ACTCG   :CGAGT   	7415	8021.75	-6.78
# AGTGG   :CCACT   	10567	11285.36	-6.77
# GTAAC   :GTTAC   	9803	10480.52	-6.62
# CACCC   :GGGTG   	15533	16379.35	-6.62
# CATAC   :GTATG   	6557	7114.29	-6.61
# GCAGA   :TCTGC   	9527	10190.59	-6.58
# AGAAC   :GTTCT   	12158	12898.51	-6.53
# ATCTG   :CAGAT   	14846	15661.81	-6.53
# GCTAC   :GTAGC   	11032	11736.38	-6.51
# ATGAC   :GTCAT   	10726	11418.23	-6.48
# GAGAC   :GTCTC   	8055	8647.93	-6.38
# ATCAA   :TTGAT   	29339	30432.59	-6.28
# GGCTA   :TAGCC   	16584	17394.27	-6.15
# ACGGA   :TCCGT   	7840	8379.35	-5.90
# GTCAC   :GTGAC   	7375	7898.01	-5.89
# GCAAC   :GTTGC   	10173	10778.32	-5.84
# AGTGA   :TCACT   	9083	9628.18	-5.56
# CTCAC   :GTGAG   	7664	8157.25	-5.46
# AGAAT   :ATTCT   	16690	17405.92	-5.43
# AAAGG   :CCTTT   	15615	16296.22	-5.34
# CTTTC   :GAAAG   	13814	14453.24	-5.32
# GAGAA   :TTCTC   	15130	15789.77	-5.26
# ATCCC   :GGGAT   	17173	17868.51	-5.21
# ACAAA   :TTTGT   	18900	19624.28	-5.18
# AATAG   :CTATT   	18394	19104.58	-5.15
# ATACA   :TGTAT   	9535	10042.57	-5.07
# CTACC   :GGTAG   	14776	15400.26	-5.04
# ACACA   :TGTGT   	6289	6659.83	-4.55
# AAGTA   :TACTT   	10658	11136.19	-4.54
# AGACA   :TGTCT   	9559	10011.85	-4.53
# CCAGG   :CCTGG   	12837	13357.89	-4.51
# ACCTC   :GAGGT   	10918	11395.33	-4.48
# GACGC   :GCGTC   	5169	5498.40	-4.44
# ACCTA   :TAGGT   	12974	13486.78	-4.42
# ATACG   :CGTAT   	4488	4792.28	-4.40
# CTTCA   :TGAAG   	11732	12214.31	-4.37
# GCGTA   :TACGC   	3835	4112.48	-4.33
# TCGCA   :TGCGA   	12332	12820.50	-4.32
# CCGAG   :CTCGG   	7194	7566.78	-4.29
# AGTCG   :CGACT   	8729	9135.03	-4.25
# CCACC   :GGTGG   	17983	18558.72	-4.23
# CTTCC   :GGAAG   	14818	15338.33	-4.21
# CAAGC   :GCTTG   	12232	12695.39	-4.12
# ATGTA   :TACAT   	8264	8646.35	-4.11
# ACTAA   :TTAGT   	14735	15234.30	-4.05
# TCCCA   :TGGGA   	19716	20285.78	-4.01
# AATT    :AATT    	63152	238046.70	-364.92
# TTAA    :TTAA    	48147	187075.82	-325.73
# GATC    :GATC    	23788	125581.41	-289.94
# ATAT    :ATAT    	38836	142572.49	-277.67
# TATA    :TATA    	25709	120235.52	-275.05
# GGCC    :GGCC    	5285	81006.26	-267.65
# AGCT    :AGCT    	17723	102300.79	-266.45
# TCGA    :TCGA    	16403	89064.21	-245.09
# CTAG    :CTAG    	19074	90748.08	-239.53
# CCGG    :CCGG    	19992	91391.55	-237.79
# GCGC    :GCGC    	12500	74580.72	-228.58
# AATC    :GATT    	81252	172899.51	-223.27
# CATG    :CATG    	14644	72991.50	-217.14
# CGCG    :CGCG    	10550	64826.00	-214.20
# TGCA    :TGCA    	14835	71405.07	-212.82
# ATAA    :TTAT    	79791	163315.23	-209.21
# AATA    :TATT    	86183	169179.40	-204.35
# AATG    :CATT    	62232	131815.72	-193.55
# GTAC    :GTAC    	9454	52286.92	-188.04
# CTAA    :TTAG    	63232	130294.94	-187.60
# ATAG    :CTAT    	56081	113746.12	-172.43
# ATAC    :GTAT    	39444	86340.47	-160.62
# AGCG    :CGCT    	36028	81435.56	-160.08
# CATA    :TATG    	45630	93681.22	-158.09
# CCGA    :TCGG    	43071	90220.38	-158.03
# GTAA    :TTAC    	50477	98902.07	-155.12
# GATA    :TATC    	69757	122879.40	-152.93
# CCGC    :GCGG    	42319	82559.36	-140.91
# GGCA    :TGCC    	37812	76054.31	-139.45
# ACGT    :ACGT    	6771	31050.67	-138.10
# CGCA    :TGCG    	33048	68036.05	-134.81
# ACGC    :GCGT    	20440	48122.56	-126.64
# AGCA    :TGCT    	49952	85468.09	-122.26
# ACGA    :TCGT    	25187	52588.05	-119.95
# CATC    :GATG    	59965	95741.19	-116.45
# AGCC    :GGCT    	58692	91032.99	-107.92
# CTAC    :GTAG    	44376	68883.51	-93.85
# GCGA    :TCGC    	55623	81501.36	-91.20
# ACGG    :CCGT    	33347	53270.71	-86.66
# CGCC    :GGCG    	53206	72465.94	-71.93
# GAGC    :GCTC    	24078	37822.35	-70.87
# GCCC    :GGGC    	31694	45591.72	-65.31
# CGAA    :TTCG    	35886	47028.51	-51.56
# TCCA    :TGGA    	48893	61046.62	-49.41
# GACC    :GGTC    	37413	47997.78	-48.49
# ATCC    :GGAT    	54789	66391.64	-45.25
# CTTA    :TAAG    	38576	48352.37	-44.62
# TGAA    :TTCA    	61724	73426.39	-43.42
# GGAC    :GTCC    	30282	37444.43	-37.12
# ATTC    :GAAT    	62736	71342.03	-32.39
# AGAT    :ATCT    	56220	63659.82	-29.63
# AGTG    :CACT    	33586	39443.61	-29.58
# CCAG    :CTGG    	55217	60415.91	-21.25
# CGAG    :CTCG    	27527	31193.81	-20.81
# CACG    :CGTG    	15855	18686.45	-20.74
# AAGA    :TCTT    	47986	52401.32	-19.36
# ACAC    :GTGT    	26736	29960.97	-18.67
# GAAC    :GTTC    	46490	50448.73	-17.69
# ACAT    :ATGT    	38830	42366.76	-17.24
# TAGA    :TCTA    	48762	52417.16	-16.03
# CGTA    :TACG    	18614	20537.86	-13.44
# ACTA    :TAGT    	48628	51484.41	-12.64
# CCCG    :CGGG    	42519	45148.26	-12.42
# ACTG    :CAGT    	48538	51323.45	-12.34
# ATTG    :CAAT    	78228	81627.39	-11.97
# CCAA    :TTGG    	80224	83267.28	-10.61
# GTGA    :TCAC    	39961	41841.07	-9.22
# AAAA    :TTTT    	128918	132207.43	-9.14
# AAGG    :CCTT    	48464	50432.54	-8.80
# AACA    :TGTT    	61806	63893.43	-8.30
# ACCT    :AGGT    	50537	52292.78	-7.71
# GCAA    :TTGC    	49538	51200.84	-7.38
# CAGG    :CCTG    	48675	50290.07	-7.23
# ACCG    :CGGT    	41880	43375.36	-7.20
# CTGA    :TCAG    	58929	60393.94	-5.99
# ATGA    :TCAT    	57772	59165.99	-5.76
# AGAG    :CTCT    	38524	39582.20	-5.33
# AACC    :GGTT    	81351	82855.34	-5.26
# AGGG    :CCCT    	53236	54430.16	-5.14
# TAAA    :TTTA    	94403	95818.09	-4.60
# AGTA    :TACT    	42417	43351.58	-4.50
# AAG     :CTT     	201776	248234.29	-95.00
# AGG     :CCT     	191352	214766.71	-51.34
# GGA     :TCC     	207354	226527.26	-40.97
# GAA     :TTC     	242367	261827.51	-38.79
# ACA     :TGT     	175177	189825.42	-34.10
# CAC     :GTG     	139396	150813.14	-29.73
# AGA     :TCT     	198822	208631.31	-21.81
# CTC     :GAG     	160761	165754.11	-12.42
# GAC     :GTC     	145821	149421.45	-9.42

# %%
# INSPECTION

# INSPECTION TEAM
# Jodi Lee
# Maxim Firsov
# Hsiang-Yun Lu (Eloise)
# Gabriel Aguiar

# RESPONSES
# - Markdown comments
# - Get more docstrings
# - Fix Null model
# - Finish main function

# CORRECTIONS
# - Made markdown comments
# - Made more docstrings and comments
# - Infile is only read once in the main function
# - Main function was put together
# - Null model was fixed
